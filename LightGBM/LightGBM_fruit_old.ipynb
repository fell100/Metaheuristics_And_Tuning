# %% [markdown]
# ## Definindo o Problema

# %%
#!pip install lightgbm;
#!pip install pymoo;
#!pip install -U pyrecorder;

# %%
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from yellowbrick.classifier import ConfusionMatrix
import numpy as np
from tqdm.notebook import tqdm as tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, KFold
#from google.colab import drive
import pickle
from pymoo.algorithms.soo.nonconvex.pso import PSO, PSOAnimation
#from pymoo.factory import Rastrigin
from pymoo.optimize import minimize
import matplotlib.pyplot as plt
from pymoo.factory import get_termination
#from pymoo.util.display import Display
from pymoo.core.callback import Callback

# %%
import lightgbm as lgb

# %%
#drive.mount('/content/gdrive')

# %%
#with open('/content/gdrive/MyDrive/datasets/credit.pkl', 'rb') as f:
#    x_fruit_train, x_fruit_test, y_fruit_train, y_fruit_test = pickle.load(f)
    
with open('./fruit.pkl', 'rb') as f:
    x_fruit, y_fruit = pickle.load(f)

# %% [markdown]
# Definindo as restrições

# %%
OBJECTIVE = ['Accuracy']
DIMENSIONS = 9 #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, subsample, reg_alpha, reg_lambda
ITERATIONS = 10
POPULATION = 15
num_leaves_min = 10
num_leaves_max = 200
min_child_samples_min = 10
min_child_samples_max = 50
n_estimators_min = 20
n_estimators_max = 1000

learning_rate_min = 0.001
learning_rate_max = 0.5
subsample_for_bin_min = 50000
subsample_for_bin_max = 500000
min_split_gain_min = 0.01
min_split_gain_max = 0.5
min_child_weight_min = 0.001
min_child_weight_max = 0.15
subsample_min = 1.0
subsample_max = 2.0
reg_alpha_min =0.01
reg_alpha_max = 100.0 
reg_lambda_min = 0.01
reg_lambda_max = 100.0

BOUNDS = []
SEED = 1
INDIVIDUALS = []

# %% [markdown]
# Definindo o problema

# %%
import numpy as np
from pymoo.core.problem import ElementwiseProblem

class OptimizeWithAccuracy(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.floor(x[0])), 
                                       min_child_samples = int(np.floor(x[1])), 
                                       n_estimators      = int(np.floor(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.floor(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_fruit, y_fruit, cv = kfold, n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemAccuracy = OptimizeWithAccuracy()

# %%
class OptimizeWithF1(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.round(x[0])), 
                                       min_child_samples = int(np.round(x[1])), 
                                       n_estimators      = int(np.round(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.round(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_fruit, y_fruit, cv = kfold, scoring='f1', n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemF1 = OptimizeWithF1()

# %%
class OptimizeWithAUC(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.round(x[0])), 
                                       min_child_samples = int(np.round(x[1])), 
                                       n_estimators      = int(np.round(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.round(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_fruit, y_fruit, cv = kfold, scoring='roc_auc', n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemAUC = OptimizeWithAUC()

# %%
from pymoo.util.display.column import Column
from pymoo.util.display.output import Output

# %%
class MyOutput(Output):

    def __init__(self):
        super().__init__()
        global pbar 
        pbar = tqdm(total=ITERATIONS)
        self.score = Column("score", width=13)
        self.Parameters = Column("Parameters", width=35)
        self.columns += [self.score, self.Parameters]

    def update(self, algorithm):
        super().update(algorithm)
        self.score.set(-np.min(algorithm.pop.get("F")))
        #self.Parameters.set(algorithm.pop.get("X")[0])
        pbar.update(1)
        if pbar.n == ITERATIONS: pbar.close()

# %% [markdown]
# ## Particle Swarm Optimization (PSO)

# %% [markdown]
# ### Acurácia

# %%
ITERATIONS = 32
POPULATION = 32

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAccuracy,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best Accuracy Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\2417788545.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8673883230 |                                   -
#      2 |       64 |  0.8673883230 |                                   -
#      3 |       96 |  0.8673883230 |                                   -
#      4 |      128 |  0.8673883230 |                                   -
#      5 |      160 |  0.8673883230 |                                   -
#      6 |      192 |  0.8673883230 |                                   -
#      7 |      224 |  0.8673883230 |                                   -
#      8 |      256 |  0.8673883230 |                                   -
#      9 |      288 |  0.8673883230 |                                   -
#     10 |      320 |  0.8673883230 |                                   -
#     11 |      352 |  0.8673883230 |                                   -
#     12 |      384 |  0.8673883230 |                                   -
#     13 |      416 |  0.8673883230 |                                   -
#     14 |      448 |  0.8673883230 |                                   -
#     15 |      480 |  0.8673883230 |                                   -
#     16 |      512 |  0.8673883230 |                                   -
#     17 |      544 |  0.8673883230 |                                   -
#     18 |      576 |  0.8673883230 |                                   -
#     19 |      608 |  0.8673883230 |                                   -
#     20 |      640 |  0.8673883230 |                                   -
#     21 |      672 |  0.8673883230 |                                   -
#     22 |      704 |  0.8673883230 |                                   -
#     23 |      736 |  0.8673883230 |                                   -
#     24 |      768 |  0.8673883230 |                                   -
#     25 |      800 |  0.8673883230 |                                   -
#     26 |      832 |  0.8673883230 |                                   -
#     27 |      864 |  0.8673883230 |                                   -
#     28 |      896 |  0.8673883230 |                                   -
#     29 |      928 |  0.8673883230 |                                   -
#     30 |      960 |  0.8673883230 |                                   -
#     31 |      992 |  0.8673883230 |                                   -
#     32 |     1024 |  0.8673883230 |                                   -
# Best Accuracy Score [0.86738832]
# Model parameters:
#  [2.18536100e+01 4.48954320e+01 4.80215352e+02 2.12005824e-01
#  7.88012531e+04 2.70326420e-01 2.62473360e-02 5.16238488e+00
#  1.06041558e+01]

# %%
final_model = lgb.LGBMClassifier(num_leaves       = int(np.floor(parameters_best_individual[0])), 
                                min_child_samples = int(np.floor(parameters_best_individual[1])), 
                                n_estimators      = int(np.floor(parameters_best_individual[2])),
                                learning_rate     = parameters_best_individual[3] ,
                                subsample_for_bin = int(np.floor(parameters_best_individual[4])),
                                min_split_gain    = parameters_best_individual[5],
                                min_child_weight  = parameters_best_individual[6],
                                reg_alpha         = parameters_best_individual[7],
                                reg_lambda        = parameters_best_individual[8],
                                max_depth=- 1
                                )


kfold = KFold(n_splits = 3, shuffle = True)

scores = cross_val_score(final_model, x_fruit, y_fruit, cv = kfold, n_jobs=-1)  

result = scores.mean()
#print(result)

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1))

# %%
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
Accuracy_PSO = scorelist

# %%
plt.plot(Accuracy_PSO);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_Accuracy = tracking
plt.plot(tracking)

# %% [markdown]
# ### F1 Score

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemF1,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best F1 Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\2645485919.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8850117778 |                                   -
#      2 |       64 |  0.8850117778 |                                   -
#      3 |       96 |  0.8850117778 |                                   -
#      4 |      128 |  0.8850117778 |                                   -
#      5 |      160 |  0.8850117778 |                                   -
#      6 |      192 |  0.8850117778 |                                   -
#      7 |      224 |  0.8850117778 |                                   -
#      8 |      256 |  0.8850117778 |                                   -
#      9 |      288 |  0.8850117778 |                                   -
#     10 |      320 |  0.8850117778 |                                   -
#     11 |      352 |  0.8850117778 |                                   -
#     12 |      384 |  0.8850117778 |                                   -
#     13 |      416 |  0.8850117778 |                                   -
#     14 |      448 |  0.8850117778 |                                   -
#     15 |      480 |  0.8850117778 |                                   -
#     16 |      512 |  0.8850117778 |                                   -
#     17 |      544 |  0.8850117778 |                                   -
#     18 |      576 |  0.8850117778 |                                   -
#     19 |      608 |  0.8850117778 |                                   -
#     20 |      640 |  0.8850117778 |                                   -
#     21 |      672 |  0.8850117778 |                                   -
#     22 |      704 |  0.8850117778 |                                   -
#     23 |      736 |  0.8850117778 |                                   -
#     24 |      768 |  0.8850117778 |                                   -
#     25 |      800 |  0.8850117778 |                                   -
#     26 |      832 |  0.8850117778 |                                   -
#     27 |      864 |  0.8850117778 |                                   -
#     28 |      896 |  0.8850117778 |                                   -
#     29 |      928 |  0.8850117778 |                                   -
#     30 |      960 |  0.8850117778 |                                   -
#     31 |      992 |  0.8850117778 |                                   -
#     32 |     1024 |  0.8850117778 |                                   -
# Best F1 Score [0.88501178]
# Model parameters:
#  [6.78296862e+01 3.48835890e+01 9.74819601e+02 1.70222805e-01
#  1.26029005e+05 9.12275296e-02 9.81195560e-02 4.78463344e+00
#  6.61442095e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
F1_PSO = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_F1 = tracking
plt.plot(tracking)

# %% [markdown]
# ### AUC

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAUC,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best AUC Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\4093374697.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.9310844552 |                                   -
#      2 |       64 |  0.9310844552 |                                   -
#      3 |       96 |  0.9310844552 |                                   -
#      4 |      128 |  0.9310844552 |                                   -
#      5 |      160 |  0.9310844552 |                                   -
#      6 |      192 |  0.9310844552 |                                   -
#      7 |      224 |  0.9310844552 |                                   -
#      8 |      256 |  0.9310844552 |                                   -
#      9 |      288 |  0.9310844552 |                                   -
#     10 |      320 |  0.9310844552 |                                   -
#     11 |      352 |  0.9310844552 |                                   -
#     12 |      384 |  0.9310844552 |                                   -
#     13 |      416 |  0.9310844552 |                                   -
#     14 |      448 |  0.9310844552 |                                   -
#     15 |      480 |  0.9310844552 |                                   -
#     16 |      512 |  0.9310844552 |                                   -
#     17 |      544 |  0.9310844552 |                                   -
#     18 |      576 |  0.9310844552 |                                   -
#     19 |      608 |  0.9310844552 |                                   -
#     20 |      640 |  0.9310844552 |                                   -
#     21 |      672 |  0.9310844552 |                                   -
#     22 |      704 |  0.9310844552 |                                   -
#     23 |      736 |  0.9310844552 |                                   -
#     24 |      768 |  0.9310844552 |                                   -
#     25 |      800 |  0.9310844552 |                                   -
#     26 |      832 |  0.9310844552 |                                   -
#     27 |      864 |  0.9310844552 |                                   -
#     28 |      896 |  0.9310844552 |                                   -
#     29 |      928 |  0.9310844552 |                                   -
#     30 |      960 |  0.9310844552 |                                   -
#     31 |      992 |  0.9310844552 |                                   -
#     32 |     1024 |  0.9310844552 |                                   -
# Best AUC Score [0.93108446]
# Model parameters:
#  [8.91399114e+01 1.65196226e+01 5.71453187e+01 4.55069477e-01
#  1.91438854e+05 4.24979117e-01 5.17340148e-02 1.97886803e+00
#  1.21783993e+00]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
AUC_PSO = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_AUC = tracking
plt.plot(tracking)

# %% [markdown]
# ## Algoritmo Genético (GA)

# %% [markdown]
# ### Acurácia

# %%
ITERATIONS = 32
POPULATION = 32

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAccuracy,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best Accuracy Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\3390466977.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8663395745 |                                   -
#      2 |       64 |  0.8663395745 |                                   -
#      3 |       96 |  0.8751439279 |                                   -
#      4 |      128 |  0.8762293459 |                                   -
#      5 |      160 |  0.8817664444 |                                   -
#      6 |      192 |  0.8817774453 |                                   -
#      7 |      224 |  0.8817774453 |                                   -
#      8 |      256 |  0.8817774453 |                                   -
#      9 |      288 |  0.8817774453 |                                   -
#     10 |      320 |  0.8817774453 |                                   -
#     11 |      352 |  0.8828921989 |                                   -
#     12 |      384 |  0.8839702830 |                                   -
#     13 |      416 |  0.8839702830 |                                   -
#     14 |      448 |  0.8839702830 |                                   -
#     15 |      480 |  0.8839702830 |                                   -
#     16 |      512 |  0.8839702830 |                                   -
#     17 |      544 |  0.8839702830 |                                   -
#     18 |      576 |  0.8839702830 |                                   -
#     19 |      608 |  0.8839702830 |                                   -
#     20 |      640 |  0.8839702830 |                                   -
#     21 |      672 |  0.8839702830 |                                   -
#     22 |      704 |  0.8839702830 |                                   -
#     23 |      736 |  0.8839702830 |                                   -
#     24 |      768 |  0.8839849508 |                                   -
#     25 |      800 |  0.8884109627 |                                   -
#     26 |      832 |  0.8884109627 |                                   -
#     27 |      864 |  0.8884109627 |                                   -
#     28 |      896 |  0.8884109627 |                                   -
#     29 |      928 |  0.8884109627 |                                   -
#     30 |      960 |  0.8884109627 |                                   -
#     31 |      992 |  0.8884109627 |                                   -
#     32 |     1024 |  0.8884109627 |                                   -
# Best Accuracy Score [0.88841096]
# Model parameters:
#  [1.13592579e+02 1.35209077e+01 6.45689855e+02 1.01318644e-01
#  3.81785762e+05 4.61759174e-02 1.08724596e-01 3.02213365e+00
#  4.41773249e+01]

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_Accuracy = tracking
plt.plot(tracking)

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1))

# %%
scorelist = []

for i in range(len(trlist)):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
Accuracy_GA = scorelist

# %%
plt.plot(scorelist);

# %% [markdown]
# ### F1 Score

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemF1,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best F1 Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\1745594656.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8860440128 |                                   -
#      2 |       64 |  0.8860440128 |                                   -
#      3 |       96 |  0.8896136666 |                                   -
#      4 |      128 |  0.8896136666 |                                   -
#      5 |      160 |  0.8906452186 |                                   -
#      6 |      192 |  0.8910036925 |                                   -
#      7 |      224 |  0.8937793869 |                                   -
#      8 |      256 |  0.8959375629 |                                   -
#      9 |      288 |  0.8959375629 |                                   -
#     10 |      320 |  0.8959375629 |                                   -
#     11 |      352 |  0.8959375629 |                                   -
#     12 |      384 |  0.8959375629 |                                   -
#     13 |      416 |  0.8959375629 |                                   -
#     14 |      448 |  0.8959375629 |                                   -
#     15 |      480 |  0.8959375629 |                                   -
#     16 |      512 |  0.8959375629 |                                   -
#     17 |      544 |  0.8959375629 |                                   -
#     18 |      576 |  0.8972550839 |                                   -
#     19 |      608 |  0.8972550839 |                                   -
#     20 |      640 |  0.8972550839 |                                   -
#     21 |      672 |  0.8972550839 |                                   -
#     22 |      704 |  0.8972550839 |                                   -
#     23 |      736 |  0.8972550839 |                                   -
#     24 |      768 |  0.8995163400 |                                   -
#     25 |      800 |  0.8995163400 |                                   -
#     26 |      832 |  0.8995163400 |                                   -
#     27 |      864 |  0.8995163400 |                                   -
#     28 |      896 |  0.8995163400 |                                   -
#     29 |      928 |  0.8995163400 |                                   -
#     30 |      960 |  0.8995163400 |                                   -
#     31 |      992 |  0.9000516031 |                                   -
#     32 |     1024 |  0.9000516031 |                                   -
# Best F1 Score [0.9000516]
# Model parameters:
#  [9.10675684e+01 3.33994046e+01 1.36720024e+02 4.39922426e-01
#  2.35669342e+05 1.98973749e-01 7.17150611e-02 7.61035283e-01
#  2.83168112e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
F1_GA = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_F1 = tracking
plt.plot(tracking)

# %% [markdown]
# ### AUC

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAUC,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best AUC Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_9164\365482116.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.9312362475 |                                   -
#      2 |       64 |  0.9312362475 |                                   -
#      3 |       96 |  0.9312362475 |                                   -
#      4 |      128 |  0.9357601102 |                                   -
#      5 |      160 |  0.9357601102 |                                   -
#      6 |      192 |  0.9357601102 |                                   -
#      7 |      224 |  0.9357601102 |                                   -
#      8 |      256 |  0.9368920689 |                                   -
#      9 |      288 |  0.9368920689 |                                   -
#     10 |      320 |  0.9368920689 |                                   -
#     11 |      352 |  0.9375001980 |                                   -
#     12 |      384 |  0.9375001980 |                                   -
#     13 |      416 |  0.9375001980 |                                   -
#     14 |      448 |  0.9375001980 |                                   -
#     15 |      480 |  0.9375001980 |                                   -
#     16 |      512 |  0.9375001980 |                                   -
#     17 |      544 |  0.9375001980 |                                   -
#     18 |      576 |  0.9389179560 |                                   -
#     19 |      608 |  0.9389179560 |                                   -
#     20 |      640 |  0.9389179560 |                                   -
#     21 |      672 |  0.9389179560 |                                   -
#     22 |      704 |  0.9389179560 |                                   -
#     23 |      736 |  0.9389179560 |                                   -
#     24 |      768 |  0.9389179560 |                                   -
#     25 |      800 |  0.9389179560 |                                   -
#     26 |      832 |  0.9389179560 |                                   -
#     27 |      864 |  0.9389179560 |                                   -
#     28 |      896 |  0.9389179560 |                                   -
#     29 |      928 |  0.9389179560 |                                   -
#     30 |      960 |  0.9389179560 |                                   -
#     31 |      992 |  0.9389179560 |                                   -
#     32 |     1024 |  0.9389179560 |                                   -
# Best AUC Score [0.93891796]
# Model parameters:
#  [1.97423101e+02 4.98926574e+01 1.20003341e+02 1.33870425e-01
#  1.04798590e+05 1.56554279e-02 8.47165797e-02 2.35797325e+00
#  1.16371807e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
AUC_GA = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_AUC = tracking
plt.plot(tracking)

# %% [markdown]
# ## Grid Search

# %% [markdown]
# ### Acurácia

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_possibilities = 2

#num_leaves_grid = [i for i in range(num_leaves_min,num_leaves_max, int((num_leaves_max)/13))]
num_leaves_grid = [i for i in map(lambda x: int(x), np.linspace(num_leaves_min, num_leaves_max, n_possibilities))]
num_leaves_grid = num_leaves_grid + [100, 50, 75, 125, 11,150]
print('Num_Leaves_Grid: ')
print(num_leaves_grid, len(num_leaves_grid))
print('\n')


min_child_samples_grid = [i for i in map(lambda x: int(x), np.linspace(min_child_samples_min, min_child_samples_max, n_possibilities))]
print('min_child_samples_grid:')
print(min_child_samples_grid, len(min_child_samples_grid))
print('\n')

n_estimators_grid = [i for i in map(lambda x: int(x), np.linspace(n_estimators_min, n_estimators_max, n_possibilities))]
print('n_estimators_grid:')
print(n_estimators_grid, len(n_estimators_grid))
print('\n')

learning_rate_grid = np.linspace(learning_rate_min, learning_rate_max, n_possibilities)
print('learning_rate_grid:')
print(learning_rate_grid, len(learning_rate_grid))
print('\n')

subsample_for_bin_grid = [i for i in map(lambda x: int(x), np.linspace(subsample_for_bin_min, subsample_for_bin_max, n_possibilities))]
print('subsample_for_bin_grid:')
print(subsample_for_bin_grid, len(subsample_for_bin_grid))
print('\n')

min_split_gain_grid = np.linspace(min_split_gain_min, min_split_gain_max, n_possibilities)
print('min_split_gain_grid:')
print(min_split_gain_grid, len(min_split_gain_grid))
print('\n')

min_child_weight_grid = np.linspace(min_child_weight_min, min_child_weight_max, n_possibilities)
print('min_child_weight_grid:')
print(min_child_weight_grid, len(min_child_weight_grid))
print('\n')

reg_alpha_grid = np.linspace(reg_alpha_min, reg_alpha_max, n_possibilities)
print('reg_alpha_grid:')
print(reg_alpha_grid, len(reg_alpha_grid))
print('\n')
# Out:
# Num_Leaves_Grid:
# [10, 200, 100, 50, 75, 125, 11, 150] 8
#
#
# min_child_samples_grid:
# [10, 50] 2
#
#
# n_estimators_grid:
# [20, 1000] 2
#
#
# learning_rate_grid:
# [0.001 0.5  ] 2
#
#
# subsample_for_bin_grid:
# [50000, 500000] 2
#
#
# min_split_gain_grid:
# [0.01 0.5 ] 2
#
#
# min_child_weight_grid:
# [0.001 0.15 ] 2
#
#
# reg_alpha_grid:
# [1.e-02 1.e+02] 2

# %%
parametros = {'num_leaves': num_leaves_grid, #int
              'min_child_samples': min_child_samples_grid,#int
              'n_estimators': n_estimators_grid, #int
              'learning_rate': learning_rate_grid,
              'subsample_for_bin': subsample_for_bin_grid, # int
              'min_split_gain': min_split_gain_grid,
              'min_child_weight': min_child_weight_grid,
              'reg_alpha': reg_alpha_grid,
              'max_depth': [-1],
              'n_jobs': [-1]}

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, verbose = 3)
grid_search.fit(x_fruit, y_fruit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 50, 'min_child_weight': 0.001, 'min_split_gain': 0.5, 'n_estimators': 20, 'n_jobs': -1, 'num_leaves': 10, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.8717996670406958

# %%
grid_search.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_learning_rate', 'param_max_depth', 'param_min_child_samples', 'param_min_child_weight', 'param_min_split_gain', 'param_n_estimators', 'param_n_jobs', 'param_num_leaves', 'param_reg_alpha', 'param_subsample_for_bin', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
trlist = grid_search.cv_results_['mean_test_score']

# %%
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
tracking_GS_Accuracy = scorelist
plt.plot(scorelist);

# %% [markdown]
# ### F1 Score

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, scoring='f1', verbose = 3)
grid_search.fit(x_fruit, y_fruit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)

trlist = grid_search.cv_results_['mean_test_score']


scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
tracking_GS_F1 = scorelist
plt.plot(scorelist);
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 10, 'min_child_weight': 0.001, 'min_split_gain': 0.01, 'n_estimators': 20, 'n_jobs': -1, 'num_leaves': 10, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.8774250440917107

# %% [markdown]
# ### AUC

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, scoring='roc_auc', verbose = 3)
grid_search.fit(x_fruit, y_fruit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)

trlist = grid_search.cv_results_['mean_test_score']


scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
tracking_GS_AUC = scorelist
plt.plot(scorelist);
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 50, 'min_child_weight': 0.001, 'min_split_gain': 0.5, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 10, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.9213878979795417

# %% [markdown]
# ## Optuna

# %% [markdown]
# ### Acurácia

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (3.1.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.9.2)
# Requirement already satisfied: cmaes>=0.9.1 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (23.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (2.0.0)
# Requirement already satisfied: tqdm in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (4.64.1)
# Requirement already satisfied: PyYAML in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %%
import optuna
import sklearn
from sklearn import datasets
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_fruit, y_fruit, n_jobs=-1, cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)
# Out:
# [I 2023-01-28 15:13:45,646] A new study created in memory with name: no-name-de4e78f3-210b-42fc-8227-85125d9e5b0f
# [I 2023-01-28 15:13:45,690] Trial 0 finished with value: 0.848620859093676 and parameters: {'num_leaves': 141, 'min_child_samples': 44, 'n_estimators': 136, 'learning_rate': 0.36620786754740087, 'subsample_for_bin': 229174, 'min_split_gain': 0.061849333618574455, 'min_child_weight': 0.05489661304149387, 'reg_alpha': 14.594406821230193, 'reg_lambda': 6.575621327113814}. Best is trial 0 with value: 0.848620859093676.
# [I 2023-01-28 15:13:45,697] Trial 1 finished with value: 0.8264981335210813 and parameters: {'num_leaves': 69, 'min_child_samples': 13, 'n_estimators': 299, 'learning_rate': 0.4306137329995218, 'subsample_for_bin': 241461, 'min_split_gain': 0.3030118384790862, 'min_child_weight': 0.09491494699402483, 'reg_alpha': 41.43599583100477, 'reg_lambda': 51.95589135724439}. Best is trial 0 with value: 0.848620859093676.
# [I 2023-01-28 15:13:45,713] Trial 6 finished with value: 0.8198536152486561 and parameters: {'num_leaves': 33, 'min_child_samples': 37, 'n_estimators': 45, 'learning_rate': 0.1569995695722502, 'subsample_for_bin': 380167, 'min_split_gain': 0.4610178369049885, 'min_child_weight': 0.008533052003617323, 'reg_alpha': 40.938152689049026, 'reg_lambda': 21.041140603267518}. Best is trial 0 with value: 0.848620859093676.
# [I 2023-01-28 15:13:45,722] Trial 3 finished with value: 0.8574912176483099 and parameters: {'num_leaves': 45, 'min_child_samples': 30, 'n_estimators': 170, 'learning_rate': 0.2510329457704254, 'subsample_for_bin': 107080, 'min_split_gain': 0.19203125324846418, 'min_child_weight': 0.02665702873944184, 'reg_alpha': 3.4655873724450514, 'reg_lambda': 39.300751925865576}. Best is trial 3 with value: 0.8574912176483099.
# [I 2023-01-28 15:13:45,741] Trial 4 finished with value: 0.5502555866024217 and parameters: {'num_leaves': 32, 'min_child_samples': 15, 'n_estimators': 877, 'learning_rate': 0.03520279975723459, 'subsample_for_bin': 338893, 'min_split_gain': 0.13794011785969168, 'min_child_weight': 0.10834312883369553, 'reg_alpha': 91.60555607069406, 'reg_lambda': 20.745884688969273}. Best is trial 3 with value: 0.8574912176483099.
# [I 2023-01-28 15:13:45,744] Trial 2 finished with value: 0.8773367656010502 and parameters: {'num_leaves': 85, 'min_child_samples': 35, 'n_estimators': 922, 'learning_rate': 0.31984576136993376, 'subsample_for_bin': 153854, 'min_split_gain': 0.4268244939703903, 'min_child_weight': 0.001590739159570964, 'reg_alpha': 2.6318811521172205, 'reg_lambda': 63.19303219550879}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,763] Trial 5 finished with value: 0.8596730544982508 and parameters: {'num_leaves': 40, 'min_child_samples': 41, 'n_estimators': 105, 'learning_rate': 0.28324094986234255, 'subsample_for_bin': 119489, 'min_split_gain': 0.13646779193646505, 'min_child_weight': 0.06821405995332169, 'reg_alpha': 7.427084041408909, 'reg_lambda': 22.742883302625515}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,769] Trial 14 finished with value: 0.7213776007861946 and parameters: {'num_leaves': 10, 'min_child_samples': 27, 'n_estimators': 188, 'learning_rate': 0.36652416718363484, 'subsample_for_bin': 362888, 'min_split_gain': 0.41375073019250747, 'min_child_weight': 0.14388370711287227, 'reg_alpha': 74.74291216971127, 'reg_lambda': 47.52982649669482}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,778] Trial 8 finished with value: 0.8221087911523766 and parameters: {'num_leaves': 161, 'min_child_samples': 41, 'n_estimators': 117, 'learning_rate': 0.440439859924089, 'subsample_for_bin': 50430, 'min_split_gain': 0.445542862998268, 'min_child_weight': 0.050696108063885, 'reg_alpha': 52.92433859922646, 'reg_lambda': 94.09413952707233}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,784] Trial 7 finished with value: 0.8221161250577546 and parameters: {'num_leaves': 16, 'min_child_samples': 35, 'n_estimators': 183, 'learning_rate': 0.32764548259034393, 'subsample_for_bin': 453954, 'min_split_gain': 0.04820759805931535, 'min_child_weight': 0.016777348452567144, 'reg_alpha': 21.881542594289165, 'reg_lambda': 32.26166359650524}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,845] Trial 10 finished with value: 0.8254420511466561 and parameters: {'num_leaves': 21, 'min_child_samples': 21, 'n_estimators': 140, 'learning_rate': 0.06407679595686493, 'subsample_for_bin': 242757, 'min_split_gain': 0.2369312810906271, 'min_child_weight': 0.07914294383482133, 'reg_alpha': 26.124259982812017, 'reg_lambda': 4.406225342263901}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,881] Trial 12 finished with value: 0.8210197062037506 and parameters: {'num_leaves': 73, 'min_child_samples': 25, 'n_estimators': 590, 'learning_rate': 0.4009752620315483, 'subsample_for_bin': 265173, 'min_split_gain': 0.23900257073716116, 'min_child_weight': 0.14567195236754465, 'reg_alpha': 41.42015526175488, 'reg_lambda': 84.5771767890219}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,888] Trial 15 finished with value: 0.5502812552712445 and parameters: {'num_leaves': 169, 'min_child_samples': 49, 'n_estimators': 462, 'learning_rate': 0.23095157850255882, 'subsample_for_bin': 341502, 'min_split_gain': 0.09306812901378425, 'min_child_weight': 0.05982461883541281, 'reg_alpha': 91.69932586184441, 'reg_lambda': 49.79583723118605}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,913] Trial 13 finished with value: 0.8243052958130734 and parameters: {'num_leaves': 17, 'min_child_samples': 20, 'n_estimators': 979, 'learning_rate': 0.3312087261396073, 'subsample_for_bin': 262016, 'min_split_gain': 0.3837187922451189, 'min_child_weight': 0.05766032976084049, 'reg_alpha': 43.74396020603631, 'reg_lambda': 91.367911573432}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,965] Trial 16 finished with value: 0.816597361260845 and parameters: {'num_leaves': 135, 'min_child_samples': 35, 'n_estimators': 423, 'learning_rate': 0.10316779216702822, 'subsample_for_bin': 358491, 'min_split_gain': 0.15429968919029508, 'min_child_weight': 0.06836476558379374, 'reg_alpha': 60.359555990792764, 'reg_lambda': 95.98960657236597}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:45,993] Trial 9 finished with value: 0.8165863604027782 and parameters: {'num_leaves': 61, 'min_child_samples': 46, 'n_estimators': 805, 'learning_rate': 0.002785277690530944, 'subsample_for_bin': 367000, 'min_split_gain': 0.2131609379992055, 'min_child_weight': 0.03559386690715672, 'reg_alpha': 43.0981964478054, 'reg_lambda': 4.879336447858405}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,021] Trial 17 finished with value: 0.8110382609843567 and parameters: {'num_leaves': 191, 'min_child_samples': 48, 'n_estimators': 705, 'learning_rate': 0.07364694214053921, 'subsample_for_bin': 170695, 'min_split_gain': 0.4089581931109921, 'min_child_weight': 0.11353340607995603, 'reg_alpha': 47.75734319625755, 'reg_lambda': 63.946660458663686}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,044] Trial 19 finished with value: 0.837564996736412 and parameters: {'num_leaves': 20, 'min_child_samples': 35, 'n_estimators': 904, 'learning_rate': 0.19850398023516824, 'subsample_for_bin': 402849, 'min_split_gain': 0.3238123754308, 'min_child_weight': 0.011353969797380493, 'reg_alpha': 16.850476965073998, 'reg_lambda': 99.31030820376391}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,079] Trial 18 finished with value: 0.8607841411630108 and parameters: {'num_leaves': 26, 'min_child_samples': 38, 'n_estimators': 989, 'learning_rate': 0.11093889445592209, 'subsample_for_bin': 149611, 'min_split_gain': 0.015031759114986743, 'min_child_weight': 0.03023516699753298, 'reg_alpha': 12.928117850848635, 'reg_lambda': 60.267204722787724}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,105] Trial 21 finished with value: 0.8033009908106167 and parameters: {'num_leaves': 53, 'min_child_samples': 47, 'n_estimators': 180, 'learning_rate': 0.4564558991684524, 'subsample_for_bin': 204243, 'min_split_gain': 0.4645559177109256, 'min_child_weight': 0.11614804010801713, 'reg_alpha': 56.73573256159925, 'reg_lambda': 50.53598117002947}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,132] Trial 11 finished with value: 0.8607584724941879 and parameters: {'num_leaves': 139, 'min_child_samples': 30, 'n_estimators': 813, 'learning_rate': 0.010447188524201755, 'subsample_for_bin': 370061, 'min_split_gain': 0.4878043073548064, 'min_child_weight': 0.02273305745230845, 'reg_alpha': 5.843312309751779, 'reg_lambda': 67.9355091809469}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,135] Trial 20 finished with value: 0.839776169207865 and parameters: {'num_leaves': 48, 'min_child_samples': 20, 'n_estimators': 306, 'learning_rate': 0.19467136738207558, 'subsample_for_bin': 236170, 'min_split_gain': 0.07521661248384943, 'min_child_weight': 0.08495485524023814, 'reg_alpha': 17.183992602576936, 'reg_lambda': 4.586296750700766}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,187] Trial 22 finished with value: 0.5502959230820004 and parameters: {'num_leaves': 155, 'min_child_samples': 19, 'n_estimators': 655, 'learning_rate': 0.3700350389056569, 'subsample_for_bin': 413816, 'min_split_gain': 0.029208471350160713, 'min_child_weight': 0.09026653417825527, 'reg_alpha': 95.50712390033064, 'reg_lambda': 75.8534870068034}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,205] Trial 23 finished with value: 0.8265128013318371 and parameters: {'num_leaves': 70, 'min_child_samples': 24, 'n_estimators': 748, 'learning_rate': 0.42979893100824595, 'subsample_for_bin': 245479, 'min_split_gain': 0.2909624337547565, 'min_child_weight': 0.12759267841656322, 'reg_alpha': 29.87344781764231, 'reg_lambda': 41.49775728397435}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,228] Trial 24 finished with value: 0.8287496424721129 and parameters: {'num_leaves': 109, 'min_child_samples': 50, 'n_estimators': 955, 'learning_rate': 0.489841477944163, 'subsample_for_bin': 174375, 'min_split_gain': 0.3373104599169794, 'min_child_weight': 0.00306318525964284, 'reg_alpha': 25.058387590661987, 'reg_lambda': 65.73842367916302}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,242] Trial 25 finished with value: 0.8309278123693647 and parameters: {'num_leaves': 99, 'min_child_samples': 50, 'n_estimators': 843, 'learning_rate': 0.1591615941284114, 'subsample_for_bin': 174598, 'min_split_gain': 0.33856757352320643, 'min_child_weight': 0.0032819261204808606, 'reg_alpha': 27.8182157941238, 'reg_lambda': 67.06296947327364}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,254] Trial 26 finished with value: 0.856376464030861 and parameters: {'num_leaves': 94, 'min_child_samples': 49, 'n_estimators': 787, 'learning_rate': 0.2508678023377981, 'subsample_for_bin': 154690, 'min_split_gain': 0.3216272115114255, 'min_child_weight': 0.047858490488217234, 'reg_alpha': 1.8385164316486378, 'reg_lambda': 67.27962593720397}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,281] Trial 29 finished with value: 0.8751475948457313 and parameters: {'num_leaves': 110, 'min_child_samples': 35, 'n_estimators': 700, 'learning_rate': 0.48642250075659954, 'subsample_for_bin': 158941, 'min_split_gain': 0.33399536661817353, 'min_child_weight': 0.003981732954933814, 'reg_alpha': 1.2709696311368919, 'reg_lambda': 62.98584914000655}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,298] Trial 28 finished with value: 0.8585949704076917 and parameters: {'num_leaves': 92, 'min_child_samples': 36, 'n_estimators': 717, 'learning_rate': 0.2726213043495032, 'subsample_for_bin': 159416, 'min_split_gain': 0.33011009807781766, 'min_child_weight': 0.03196430604831574, 'reg_alpha': 4.028873653734924, 'reg_lambda': 69.46450173595245}. Best is trial 2 with value: 0.8773367656010502.
# [I 2023-01-28 15:13:46,318] Trial 27 finished with value: 0.878458853123877 and parameters: {'num_leaves': 100, 'min_child_samples': 50, 'n_estimators': 916, 'learning_rate': 0.4841707410536077, 'subsample_for_bin': 130694, 'min_split_gain': 0.3373384767884699, 'min_child_weight': 0.038586706566480306, 'reg_alpha': 0.026767000689870812, 'reg_lambda': 67.89245849871341}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,355] Trial 30 finished with value: 0.8673919899085462 and parameters: {'num_leaves': 109, 'min_child_samples': 50, 'n_estimators': 666, 'learning_rate': 0.4982988468130586, 'subsample_for_bin': 162246, 'min_split_gain': 0.49125448725796056, 'min_child_weight': 0.03279228936299641, 'reg_alpha': 3.3202625842597575, 'reg_lambda': 66.44155125420704}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,362] Trial 31 finished with value: 0.8596657205928729 and parameters: {'num_leaves': 102, 'min_child_samples': 39, 'n_estimators': 633, 'learning_rate': 0.4749906047523964, 'subsample_for_bin': 169813, 'min_split_gain': 0.32095139199402856, 'min_child_weight': 0.009371007624394287, 'reg_alpha': 1.4952423410132383, 'reg_lambda': 60.30438591033581}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,409] Trial 32 finished with value: 0.8718033339933848 and parameters: {'num_leaves': 98, 'min_child_samples': 41, 'n_estimators': 607, 'learning_rate': 0.4949704440890351, 'subsample_for_bin': 161541, 'min_split_gain': 0.32667077844528236, 'min_child_weight': 0.00509002239581057, 'reg_alpha': 0.82596206199732, 'reg_lambda': 70.23766100576998}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,415] Trial 33 finished with value: 0.8784185166442983 and parameters: {'num_leaves': 96, 'min_child_samples': 41, 'n_estimators': 620, 'learning_rate': 0.49483476454496317, 'subsample_for_bin': 143243, 'min_split_gain': 0.47695749009790434, 'min_child_weight': 0.009324804766904088, 'reg_alpha': 2.0184532893425313, 'reg_lambda': 68.41698617011211}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,451] Trial 34 finished with value: 0.8685250782894398 and parameters: {'num_leaves': 99, 'min_child_samples': 32, 'n_estimators': 724, 'learning_rate': 0.1468779925700746, 'subsample_for_bin': 169312, 'min_split_gain': 0.036962697846673914, 'min_child_weight': 0.033073420681108134, 'reg_alpha': 5.6468553014673475, 'reg_lambda': 69.17741002326261}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,506] Trial 35 finished with value: 0.8740145064648376 and parameters: {'num_leaves': 88, 'min_child_samples': 31, 'n_estimators': 717, 'learning_rate': 0.1470270447077059, 'subsample_for_bin': 148712, 'min_split_gain': 0.020127524627288194, 'min_child_weight': 0.03571183109939258, 'reg_alpha': 2.7734943408486483, 'reg_lambda': 68.64758051746247}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,546] Trial 36 finished with value: 0.8696031623799989 and parameters: {'num_leaves': 97, 'min_child_samples': 31, 'n_estimators': 767, 'learning_rate': 0.12328459340446674, 'subsample_for_bin': 157547, 'min_split_gain': 0.4923585478778651, 'min_child_weight': 0.02864888547178015, 'reg_alpha': 1.3143280715335814, 'reg_lambda': 69.05575553994625}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,564] Trial 37 finished with value: 0.8696031623799989 and parameters: {'num_leaves': 94, 'min_child_samples': 30, 'n_estimators': 998, 'learning_rate': 0.1357815470691622, 'subsample_for_bin': 304020, 'min_split_gain': 0.4925718777860361, 'min_child_weight': 0.004115451741683902, 'reg_alpha': 2.3190295466159507, 'reg_lambda': 68.48636899091281}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,606] Trial 38 finished with value: 0.8651514818155815 and parameters: {'num_leaves': 111, 'min_child_samples': 30, 'n_estimators': 795, 'learning_rate': 0.12221786467877725, 'subsample_for_bin': 299770, 'min_split_gain': 0.49775259463625765, 'min_child_weight': 0.025784964454597385, 'reg_alpha': 0.9338435177373232, 'reg_lambda': 59.39949712589956}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,630] Trial 39 finished with value: 0.8408872558726248 and parameters: {'num_leaves': 98, 'min_child_samples': 31, 'n_estimators': 999, 'learning_rate': 0.499581542906712, 'subsample_for_bin': 308720, 'min_split_gain': 0.4859035673572862, 'min_child_weight': 0.022973913136163947, 'reg_alpha': 12.074916686474184, 'reg_lambda': 76.7434090444553}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,661] Trial 40 finished with value: 0.8563581292674162 and parameters: {'num_leaves': 93, 'min_child_samples': 31, 'n_estimators': 780, 'learning_rate': 0.11472917157147203, 'subsample_for_bin': 54011, 'min_split_gain': 0.27669124833027836, 'min_child_weight': 0.018957995631871328, 'reg_alpha': 10.475827733139294, 'reg_lambda': 76.23930514824437}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,717] Trial 41 finished with value: 0.8387017520699948 and parameters: {'num_leaves': 93, 'min_child_samples': 32, 'n_estimators': 992, 'learning_rate': 0.4755354288904359, 'subsample_for_bin': 54449, 'min_split_gain': 0.3702334146124712, 'min_child_weight': 0.04084727295679175, 'reg_alpha': 12.417786362653757, 'reg_lambda': 57.25246379092302}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,725] Trial 42 finished with value: 0.83975783444442 and parameters: {'num_leaves': 124, 'min_child_samples': 33, 'n_estimators': 990, 'learning_rate': 0.2946777961125914, 'subsample_for_bin': 53767, 'min_split_gain': 0.3711830896632038, 'min_child_weight': 0.016751317546289595, 'reg_alpha': 11.254412847946563, 'reg_lambda': 57.05366063873804}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,771] Trial 43 finished with value: 0.849709944042302 and parameters: {'num_leaves': 113, 'min_child_samples': 40, 'n_estimators': 599, 'learning_rate': 0.46174029241459735, 'subsample_for_bin': 76883, 'min_split_gain': 0.37576320930715534, 'min_child_weight': 0.02212553871672808, 'reg_alpha': 12.084444638273203, 'reg_lambda': 56.320833790398154}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,816] Trial 44 finished with value: 0.8442058480561485 and parameters: {'num_leaves': 113, 'min_child_samples': 40, 'n_estimators': 592, 'learning_rate': 0.47185715933474387, 'subsample_for_bin': 79212, 'min_split_gain': 0.4998369886378346, 'min_child_weight': 0.019130358269419688, 'reg_alpha': 11.711884318357518, 'reg_lambda': 56.10093286850605}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,856] Trial 45 finished with value: 0.8541652915594082 and parameters: {'num_leaves': 118, 'min_child_samples': 43, 'n_estimators': 554, 'learning_rate': 0.49926713538856604, 'subsample_for_bin': 98906, 'min_split_gain': 0.3737872817778532, 'min_child_weight': 0.016932730394818157, 'reg_alpha': 10.880897584234141, 'reg_lambda': 56.163696000355216}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,894] Trial 46 finished with value: 0.8563727970781722 and parameters: {'num_leaves': 119, 'min_child_samples': 44, 'n_estimators': 579, 'learning_rate': 0.46660959136977265, 'subsample_for_bin': 78285, 'min_split_gain': 0.3645265610341696, 'min_child_weight': 0.015924477696400447, 'reg_alpha': 9.40595587410668, 'reg_lambda': 55.53875583953252}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,929] Trial 47 finished with value: 0.8441581776711917 and parameters: {'num_leaves': 118, 'min_child_samples': 44, 'n_estimators': 557, 'learning_rate': 0.47204124296382405, 'subsample_for_bin': 94998, 'min_split_gain': 0.372732391533722, 'min_child_weight': 0.01657142673978769, 'reg_alpha': 12.3028651884168, 'reg_lambda': 77.22348726423564}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:46,969] Trial 49 finished with value: 0.8530578718473375 and parameters: {'num_leaves': 120, 'min_child_samples': 32, 'n_estimators': 538, 'learning_rate': 0.45578293774709067, 'subsample_for_bin': 99596, 'min_split_gain': 0.38021063734168126, 'min_child_weight': 0.018183460414962625, 'reg_alpha': 10.598948242102907, 'reg_lambda': 56.32709513664244}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,013] Trial 50 finished with value: 0.8607841411630107 and parameters: {'num_leaves': 117, 'min_child_samples': 44, 'n_estimators': 520, 'learning_rate': 0.4592992989334755, 'subsample_for_bin': 81297, 'min_split_gain': 0.37614428405889694, 'min_child_weight': 0.01949583609130968, 'reg_alpha': 8.447663106308946, 'reg_lambda': 56.47030379627527}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,023] Trial 48 finished with value: 0.8552543765080344 and parameters: {'num_leaves': 125, 'min_child_samples': 32, 'n_estimators': 540, 'learning_rate': 0.46304187934038754, 'subsample_for_bin': 81375, 'min_split_gain': 0.3715798820894082, 'min_child_weight': 0.01725507078855619, 'reg_alpha': 9.26849998182066, 'reg_lambda': 55.473853229144815}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,050] Trial 51 finished with value: 0.8519284504191327 and parameters: {'num_leaves': 122, 'min_child_samples': 44, 'n_estimators': 536, 'learning_rate': 0.4623502881631138, 'subsample_for_bin': 90507, 'min_split_gain': 0.36322988758118807, 'min_child_weight': 0.018080589753041568, 'reg_alpha': 9.201138064103695, 'reg_lambda': 80.5483883949802}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,088] Trial 53 finished with value: 0.8353574912176484 and parameters: {'num_leaves': 122, 'min_child_samples': 44, 'n_estimators': 901, 'learning_rate': 0.4569158592947428, 'subsample_for_bin': 103526, 'min_split_gain': 0.3654082777271061, 'min_child_weight': 0.011091519623516963, 'reg_alpha': 19.702222348991818, 'reg_lambda': 74.31067739024384}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,113] Trial 52 finished with value: 0.8541359559378966 and parameters: {'num_leaves': 122, 'min_child_samples': 43, 'n_estimators': 544, 'learning_rate': 0.45876694429817433, 'subsample_for_bin': 83027, 'min_split_gain': 0.36550750191216524, 'min_child_weight': 0.013594583505574093, 'reg_alpha': 7.0438460689604785, 'reg_lambda': 82.51638211310959}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,146] Trial 54 finished with value: 0.8574545481214201 and parameters: {'num_leaves': 125, 'min_child_samples': 44, 'n_estimators': 536, 'learning_rate': 0.4617333731948696, 'subsample_for_bin': 105244, 'min_split_gain': 0.2704710742872448, 'min_child_weight': 0.01305156822726319, 'reg_alpha': 6.6785460912732395, 'reg_lambda': 81.68664690452424}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,189] Trial 55 finished with value: 0.8574912176483099 and parameters: {'num_leaves': 122, 'min_child_samples': 45, 'n_estimators': 911, 'learning_rate': 0.4570066598609769, 'subsample_for_bin': 101666, 'min_split_gain': 0.4119955497039033, 'min_child_weight': 0.01343813507141002, 'reg_alpha': 7.7519144522269405, 'reg_lambda': 81.2344779063623}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,237] Trial 56 finished with value: 0.8541396228905854 and parameters: {'num_leaves': 124, 'min_child_samples': 44, 'n_estimators': 548, 'learning_rate': 0.4279742774049091, 'subsample_for_bin': 116313, 'min_split_gain': 0.4370802118802207, 'min_child_weight': 0.013127550408090539, 'reg_alpha': 7.042380531876034, 'reg_lambda': 80.800951976715}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,272] Trial 57 finished with value: 0.857480216790243 and parameters: {'num_leaves': 84, 'min_child_samples': 42, 'n_estimators': 561, 'learning_rate': 0.4244404784864846, 'subsample_for_bin': 122127, 'min_split_gain': 0.4406772801388585, 'min_child_weight': 0.011345955846566134, 'reg_alpha': 6.542293889496325, 'reg_lambda': 63.310571043111295}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,295] Trial 58 finished with value: 0.8652174869639832 and parameters: {'num_leaves': 78, 'min_child_samples': 44, 'n_estimators': 540, 'learning_rate': 0.43004527687437555, 'subsample_for_bin': 129850, 'min_split_gain': 0.4379751345491796, 'min_child_weight': 0.04208877405255279, 'reg_alpha': 6.752002734587539, 'reg_lambda': 82.37710455234715}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,335] Trial 59 finished with value: 0.8541726254647862 and parameters: {'num_leaves': 76, 'min_child_samples': 44, 'n_estimators': 524, 'learning_rate': 0.4276706345792722, 'subsample_for_bin': 126811, 'min_split_gain': 0.4348414570765541, 'min_child_weight': 0.010944861515027528, 'reg_alpha': 6.8371892678089345, 'reg_lambda': 73.04319406782069}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,365] Trial 60 finished with value: 0.8641284020153571 and parameters: {'num_leaves': 80, 'min_child_samples': 42, 'n_estimators': 906, 'learning_rate': 0.42550122528893924, 'subsample_for_bin': 118444, 'min_split_gain': 0.44847918185917185, 'min_child_weight': 0.04147178993517599, 'reg_alpha': 4.612100102670027, 'reg_lambda': 62.26269053297971}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,399] Trial 61 finished with value: 0.8420020094900735 and parameters: {'num_leaves': 80, 'min_child_samples': 45, 'n_estimators': 912, 'learning_rate': 0.43362048329283126, 'subsample_for_bin': 129371, 'min_split_gain': 0.41799020130492026, 'min_child_weight': 0.010378938141603795, 'reg_alpha': 5.985519495791552, 'reg_lambda': 72.25370520198436}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,463] Trial 62 finished with value: 0.8707215829501367 and parameters: {'num_leaves': 83, 'min_child_samples': 11, 'n_estimators': 918, 'learning_rate': 0.4029162032233827, 'subsample_for_bin': 195195, 'min_split_gain': 0.42541555938623865, 'min_child_weight': 0.006282013963428153, 'reg_alpha': 0.13891370873747333, 'reg_lambda': 72.0546437521724}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,510] Trial 63 finished with value: 0.8397945039713098 and parameters: {'num_leaves': 81, 'min_child_samples': 11, 'n_estimators': 904, 'learning_rate': 0.4241627359452501, 'subsample_for_bin': 129502, 'min_split_gain': 0.4280724424542201, 'min_child_weight': 0.0028846083854816877, 'reg_alpha': 16.848957788595204, 'reg_lambda': 63.2275178451301}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,561] Trial 64 finished with value: 0.8629953136344635 and parameters: {'num_leaves': 76, 'min_child_samples': 28, 'n_estimators': 901, 'learning_rate': 0.4263683910187668, 'subsample_for_bin': 124652, 'min_split_gain': 0.4305873132118179, 'min_child_weight': 0.006573639437914898, 'reg_alpha': 0.18551096894186037, 'reg_lambda': 71.84763625959053}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,593] Trial 66 finished with value: 0.8707435846662707 and parameters: {'num_leaves': 81, 'min_child_samples': 28, 'n_estimators': 916, 'learning_rate': 0.4370491186109427, 'subsample_for_bin': 134826, 'min_split_gain': 0.4279146835651231, 'min_child_weight': 0.0015799451911961333, 'reg_alpha': 0.018030592431558468, 'reg_lambda': 63.551385243577364}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,625] Trial 65 finished with value: 0.8674176585773691 and parameters: {'num_leaves': 80, 'min_child_samples': 42, 'n_estimators': 850, 'learning_rate': 0.39738554909939994, 'subsample_for_bin': 128821, 'min_split_gain': 0.42857654322388344, 'min_child_weight': 0.0013418248483877105, 'reg_alpha': 0.6645945919150384, 'reg_lambda': 62.93705739586413}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,684] Trial 68 finished with value: 0.8398201726401325 and parameters: {'num_leaves': 84, 'min_child_samples': 28, 'n_estimators': 450, 'learning_rate': 0.4227397075453274, 'subsample_for_bin': 129457, 'min_split_gain': 0.2982182033308689, 'min_child_weight': 0.00602641527851514, 'reg_alpha': 15.6923293728345, 'reg_lambda': 71.31691015315349}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,701] Trial 67 finished with value: 0.868517744384062 and parameters: {'num_leaves': 79, 'min_child_samples': 27, 'n_estimators': 852, 'learning_rate': 0.42239400058647697, 'subsample_for_bin': 129893, 'min_split_gain': 0.43482732663301676, 'min_child_weight': 0.0012935626183115372, 'reg_alpha': 0.12490303384064498, 'reg_lambda': 63.84732043130015}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,737] Trial 69 finished with value: 0.8773661012225619 and parameters: {'num_leaves': 79, 'min_child_samples': 28, 'n_estimators': 467, 'learning_rate': 0.4283413076055178, 'subsample_for_bin': 136267, 'min_split_gain': 0.20099684331628953, 'min_child_weight': 0.002722137614081331, 'reg_alpha': 0.5015504891542657, 'reg_lambda': 71.031463249754}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,790] Trial 71 finished with value: 0.8740365081809714 and parameters: {'num_leaves': 79, 'min_child_samples': 28, 'n_estimators': 845, 'learning_rate': 0.4118122976151482, 'subsample_for_bin': 202589, 'min_split_gain': 0.3008472603760985, 'min_child_weight': 0.002851826507348538, 'reg_alpha': 1.0437153413348224, 'reg_lambda': 72.28482630292882}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,812] Trial 70 finished with value: 0.83975783444442 and parameters: {'num_leaves': 81, 'min_child_samples': 28, 'n_estimators': 463, 'learning_rate': 0.427911864603163, 'subsample_for_bin': 205448, 'min_split_gain': 0.30720244771869193, 'min_child_weight': 0.002797466053853861, 'reg_alpha': 16.53394692711262, 'reg_lambda': 71.08162083133244}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,847] Trial 72 finished with value: 0.8696324980015108 and parameters: {'num_leaves': 78, 'min_child_samples': 28, 'n_estimators': 869, 'learning_rate': 0.403931175559463, 'subsample_for_bin': 198572, 'min_split_gain': 0.46601072604160415, 'min_child_weight': 0.02692668689288713, 'reg_alpha': 0.5275946452383502, 'reg_lambda': 64.40080110431929}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,894] Trial 73 finished with value: 0.8718180018041407 and parameters: {'num_leaves': 78, 'min_child_samples': 28, 'n_estimators': 467, 'learning_rate': 0.4025850389779639, 'subsample_for_bin': 198189, 'min_split_gain': 0.4673445804938383, 'min_child_weight': 0.0010501190583461007, 'reg_alpha': 0.12095600547225294, 'reg_lambda': 64.57927400183434}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,931] Trial 74 finished with value: 0.8718143348514517 and parameters: {'num_leaves': 63, 'min_child_samples': 28, 'n_estimators': 854, 'learning_rate': 0.48565668037320164, 'subsample_for_bin': 199326, 'min_split_gain': 0.46735159546419464, 'min_child_weight': 0.003457354291748956, 'reg_alpha': 0.07171175669181884, 'reg_lambda': 65.59227267778274}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:47,980] Trial 75 finished with value: 0.8717960000880068 and parameters: {'num_leaves': 62, 'min_child_samples': 28, 'n_estimators': 845, 'learning_rate': 0.4015210919810071, 'subsample_for_bin': 202218, 'min_split_gain': 0.3000067963352117, 'min_child_weight': 0.02476103221989589, 'reg_alpha': 4.081550310506148, 'reg_lambda': 64.70253019460837}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,012] Trial 76 finished with value: 0.8409019236833806 and parameters: {'num_leaves': 62, 'min_child_samples': 37, 'n_estimators': 642, 'learning_rate': 0.39545285156520127, 'subsample_for_bin': 198756, 'min_split_gain': 0.4004284040596596, 'min_child_weight': 0.006797430816569396, 'reg_alpha': 15.500130192047601, 'reg_lambda': 64.4729384341672}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,021] Trial 77 finished with value: 0.828720306850601 and parameters: {'num_leaves': 61, 'min_child_samples': 28, 'n_estimators': 852, 'learning_rate': 0.40280503351660324, 'subsample_for_bin': 200640, 'min_split_gain': 0.3985718279238133, 'min_child_weight': 0.005828574349615513, 'reg_alpha': 16.53461149187427, 'reg_lambda': 64.66102185849584}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,079] Trial 79 finished with value: 0.8684957426679282 and parameters: {'num_leaves': 64, 'min_child_samples': 28, 'n_estimators': 478, 'learning_rate': 0.3981211855321186, 'subsample_for_bin': 187700, 'min_split_gain': 0.2991697256594597, 'min_child_weight': 0.023712177500228856, 'reg_alpha': 4.200489898262624, 'reg_lambda': 67.04928616105956}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,092] Trial 78 finished with value: 0.8629879797290855 and parameters: {'num_leaves': 63, 'min_child_samples': 13, 'n_estimators': 833, 'learning_rate': 0.3965799040695714, 'subsample_for_bin': 195896, 'min_split_gain': 0.39584290748611767, 'min_child_weight': 0.0012278286900133835, 'reg_alpha': 4.319327227799657, 'reg_lambda': 66.25908478655751}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,144] Trial 80 finished with value: 0.8563727970781722 and parameters: {'num_leaves': 61, 'min_child_samples': 28, 'n_estimators': 837, 'learning_rate': 0.4875059510640725, 'subsample_for_bin': 206652, 'min_split_gain': 0.39542743834924843, 'min_child_weight': 0.024859075408050813, 'reg_alpha': 4.286210910047688, 'reg_lambda': 66.76084190312342}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,186] Trial 81 finished with value: 0.8751109253188417 and parameters: {'num_leaves': 65, 'min_child_samples': 37, 'n_estimators': 452, 'learning_rate': 0.49142923398404464, 'subsample_for_bin': 206123, 'min_split_gain': 0.39778133098387625, 'min_child_weight': 0.008812041094029898, 'reg_alpha': 4.5047742330041345, 'reg_lambda': 66.4099679653779}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,219] Trial 82 finished with value: 0.8729364223742785 and parameters: {'num_leaves': 65, 'min_child_samples': 37, 'n_estimators': 684, 'learning_rate': 0.48262978302518084, 'subsample_for_bin': 191009, 'min_split_gain': 0.39271527322131494, 'min_child_weight': 0.008993609509196638, 'reg_alpha': 4.033037055249338, 'reg_lambda': 67.8333735027661}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,245] Trial 84 finished with value: 0.8640697307723335 and parameters: {'num_leaves': 133, 'min_child_samples': 37, 'n_estimators': 368, 'learning_rate': 0.48694222904417905, 'subsample_for_bin': 194678, 'min_split_gain': 0.23177185930082175, 'min_child_weight': 0.007972604431895675, 'reg_alpha': 3.8557576096477346, 'reg_lambda': 68.19877096131545}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,304] Trial 83 finished with value: 0.8707582524770264 and parameters: {'num_leaves': 61, 'min_child_samples': 37, 'n_estimators': 488, 'learning_rate': 0.48557891717414636, 'subsample_for_bin': 190818, 'min_split_gain': 0.24323301540700082, 'min_child_weight': 0.007601871318348427, 'reg_alpha': 3.4155380028670796, 'reg_lambda': 67.50154666546462}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,348] Trial 85 finished with value: 0.8707289168555148 and parameters: {'num_leaves': 62, 'min_child_samples': 36, 'n_estimators': 386, 'learning_rate': 0.48612470626680426, 'subsample_for_bin': 219952, 'min_split_gain': 0.2219045552088602, 'min_child_weight': 0.008209613951854995, 'reg_alpha': 4.700061989466322, 'reg_lambda': 68.35533565726327}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,375] Trial 86 finished with value: 0.8740438420863494 and parameters: {'num_leaves': 61, 'min_child_samples': 37, 'n_estimators': 674, 'learning_rate': 0.48242836324662614, 'subsample_for_bin': 185497, 'min_split_gain': 0.21396979477425537, 'min_child_weight': 0.007402582343159979, 'reg_alpha': 3.4821225617401486, 'reg_lambda': 61.03953842760173}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,422] Trial 87 finished with value: 0.8541212881271406 and parameters: {'num_leaves': 65, 'min_child_samples': 34, 'n_estimators': 689, 'learning_rate': 0.480158344508742, 'subsample_for_bin': 182451, 'min_split_gain': 0.3988300129822242, 'min_child_weight': 0.008871087289794414, 'reg_alpha': 4.687708165998261, 'reg_lambda': 60.47069406776555}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,472] Trial 88 finished with value: 0.8651881513424714 and parameters: {'num_leaves': 63, 'min_child_samples': 24, 'n_estimators': 358, 'learning_rate': 0.48263273509262977, 'subsample_for_bin': 182507, 'min_split_gain': 0.2414714485995493, 'min_child_weight': 0.008839577434445798, 'reg_alpha': 2.97199968899177, 'reg_lambda': 59.89549472879365}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,521] Trial 89 finished with value: 0.8640917324884674 and parameters: {'num_leaves': 64, 'min_child_samples': 24, 'n_estimators': 364, 'learning_rate': 0.4838456082043694, 'subsample_for_bin': 146936, 'min_split_gain': 0.21014437967288155, 'min_child_weight': 0.008632146789962297, 'reg_alpha': 4.652951922235173, 'reg_lambda': 60.67775410472181}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,548] Trial 90 finished with value: 0.8419910086320067 and parameters: {'num_leaves': 65, 'min_child_samples': 25, 'n_estimators': 371, 'learning_rate': 0.3469323023353305, 'subsample_for_bin': 220773, 'min_split_gain': 0.22728417342531848, 'min_child_weight': 0.008485573201971984, 'reg_alpha': 13.745946149138245, 'reg_lambda': 60.42600353230072}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,607] Trial 91 finished with value: 0.837564996736412 and parameters: {'num_leaves': 88, 'min_child_samples': 24, 'n_estimators': 358, 'learning_rate': 0.48291383219800343, 'subsample_for_bin': 144768, 'min_split_gain': 0.4740566219784254, 'min_child_weight': 0.00853048321324604, 'reg_alpha': 13.819242167099825, 'reg_lambda': 60.46540514427871}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,638] Trial 93 finished with value: 0.8475244402396721 and parameters: {'num_leaves': 104, 'min_child_samples': 34, 'n_estimators': 332, 'learning_rate': 0.3569888170328723, 'subsample_for_bin': 145532, 'min_split_gain': 0.2341664516749344, 'min_child_weight': 0.008969882524252687, 'reg_alpha': 13.329647840808544, 'reg_lambda': 60.23893845568534}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,680] Trial 92 finished with value: 0.8552433756499674 and parameters: {'num_leaves': 89, 'min_child_samples': 24, 'n_estimators': 361, 'learning_rate': 0.48335121165901557, 'subsample_for_bin': 221396, 'min_split_gain': 0.10944950764049872, 'min_child_weight': 0.00849409838869291, 'reg_alpha': 13.948929801852087, 'reg_lambda': 75.94895709821755}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,718] Trial 95 finished with value: 0.8530578718473375 and parameters: {'num_leaves': 88, 'min_child_samples': 24, 'n_estimators': 364, 'learning_rate': 0.48435829445585565, 'subsample_for_bin': 220453, 'min_split_gain': 0.3498449250831195, 'min_child_weight': 0.030226845765506966, 'reg_alpha': 9.90981215922302, 'reg_lambda': 75.32347198925686}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,765] Trial 94 finished with value: 0.8463986857641563 and parameters: {'num_leaves': 105, 'min_child_samples': 24, 'n_estimators': 328, 'learning_rate': 0.4868661402667113, 'subsample_for_bin': 224184, 'min_split_gain': 0.3506047635683476, 'min_child_weight': 0.03455763342925545, 'reg_alpha': 13.82572628617263, 'reg_lambda': 51.78893974132781}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,803] Trial 96 finished with value: 0.8287166398979121 and parameters: {'num_leaves': 89, 'min_child_samples': 25, 'n_estimators': 415, 'learning_rate': 0.4857881980375002, 'subsample_for_bin': 215177, 'min_split_gain': 0.34912584221927306, 'min_child_weight': 0.02135053968971506, 'reg_alpha': 13.765552268026612, 'reg_lambda': 75.6525112132367}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,840] Trial 97 finished with value: 0.8608061428791446 and parameters: {'num_leaves': 70, 'min_child_samples': 34, 'n_estimators': 675, 'learning_rate': 0.44776852133352746, 'subsample_for_bin': 147918, 'min_split_gain': 0.165583117644108, 'min_child_weight': 0.028831313932275213, 'reg_alpha': 8.446284828496731, 'reg_lambda': 75.697436465165}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,888] Trial 98 finished with value: 0.8541506237486525 and parameters: {'num_leaves': 54, 'min_child_samples': 34, 'n_estimators': 669, 'learning_rate': 0.446212866236945, 'subsample_for_bin': 145087, 'min_split_gain': 0.204832586315847, 'min_child_weight': 0.0213096134485662, 'reg_alpha': 9.212561765565496, 'reg_lambda': 75.29627726754016}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,930] Trial 99 finished with value: 0.8684957426679282 and parameters: {'num_leaves': 54, 'min_child_samples': 34, 'n_estimators': 960, 'learning_rate': 0.446202096894035, 'subsample_for_bin': 220959, 'min_split_gain': 0.1924685777564123, 'min_child_weight': 0.03019937552050245, 'reg_alpha': 2.586657514145873, 'reg_lambda': 74.74770707873994}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:48,971] Trial 100 finished with value: 0.8442351836776602 and parameters: {'num_leaves': 105, 'min_child_samples': 34, 'n_estimators': 751, 'learning_rate': 0.44538165267279206, 'subsample_for_bin': 148795, 'min_split_gain': 0.19366075966861793, 'min_child_weight': 0.029799391483164506, 'reg_alpha': 9.478205528094442, 'reg_lambda': 69.34010341370555}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,016] Trial 102 finished with value: 0.8696031623799989 and parameters: {'num_leaves': 88, 'min_child_samples': 24, 'n_estimators': 954, 'learning_rate': 0.4491362104938278, 'subsample_for_bin': 142635, 'min_split_gain': 0.169559697065394, 'min_child_weight': 0.013643445349463094, 'reg_alpha': 8.595244419926575, 'reg_lambda': 69.94139581646179}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,058] Trial 101 finished with value: 0.8596950562143847 and parameters: {'num_leaves': 37, 'min_child_samples': 34, 'n_estimators': 953, 'learning_rate': 0.4504945052842772, 'subsample_for_bin': 142391, 'min_split_gain': 0.3517939800459359, 'min_child_weight': 0.014425259642090394, 'reg_alpha': 8.493327063176473, 'reg_lambda': 69.30802005576834}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,091] Trial 103 finished with value: 0.8607694733522547 and parameters: {'num_leaves': 88, 'min_child_samples': 24, 'n_estimators': 953, 'learning_rate': 0.4462166639207968, 'subsample_for_bin': 145227, 'min_split_gain': 0.3524030931713548, 'min_child_weight': 0.020827605165971663, 'reg_alpha': 8.894802952977553, 'reg_lambda': 73.1745288417979}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,136] Trial 104 finished with value: 0.8541579576540302 and parameters: {'num_leaves': 53, 'min_child_samples': 34, 'n_estimators': 748, 'learning_rate': 0.4985178799359179, 'subsample_for_bin': 252379, 'min_split_gain': 0.34613276450779284, 'min_child_weight': 0.022321318346665186, 'reg_alpha': 8.819206097531906, 'reg_lambda': 70.16836473962346}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,205] Trial 105 finished with value: 0.8673736551451013 and parameters: {'num_leaves': 88, 'min_child_samples': 39, 'n_estimators': 953, 'learning_rate': 0.44792539568897605, 'subsample_for_bin': 258820, 'min_split_gain': 0.18166867570250794, 'min_child_weight': 0.012694480068688393, 'reg_alpha': 2.46894461861081, 'reg_lambda': 70.9575290595518}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,233] Trial 106 finished with value: 0.8740511759917274 and parameters: {'num_leaves': 52, 'min_child_samples': 34, 'n_estimators': 741, 'learning_rate': 0.4469604316340844, 'subsample_for_bin': 246722, 'min_split_gain': 0.16847135404159952, 'min_child_weight': 0.0150562570543545, 'reg_alpha': 2.001129623212825, 'reg_lambda': 73.26469251993356}. Best is trial 27 with value: 0.878458853123877.
# [I 2023-01-28 15:13:49,285] Trial 107 finished with value: 0.8784698539819439 and parameters: {'num_leaves': 53, 'min_child_samples': 39, 'n_estimators': 685, 'learning_rate': 0.4471802863812099, 'subsample_for_bin': 166481, 'min_split_gain': 0.15793312692544734, 'min_child_weight': 0.013839185713686628, 'reg_alpha': 2.419006358069204, 'reg_lambda': 58.29721239473468}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,324] Trial 108 finished with value: 0.870688580375936 and parameters: {'num_leaves': 52, 'min_child_samples': 39, 'n_estimators': 957, 'learning_rate': 0.44714207564049, 'subsample_for_bin': 248758, 'min_split_gain': 0.057455179359467146, 'min_child_weight': 0.013647067727780952, 'reg_alpha': 1.7986653527112995, 'reg_lambda': 71.1517004280294}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,355] Trial 109 finished with value: 0.8574398803106642 and parameters: {'num_leaves': 41, 'min_child_samples': 39, 'n_estimators': 745, 'learning_rate': 0.4972143163954702, 'subsample_for_bin': 240836, 'min_split_gain': 0.45317851902962475, 'min_child_weight': 0.01469639847505888, 'reg_alpha': 5.814023910542037, 'reg_lambda': 78.73298062018098}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,458] Trial 110 finished with value: 0.868510410478684 and parameters: {'num_leaves': 71, 'min_child_samples': 38, 'n_estimators': 760, 'learning_rate': 0.4985828416270329, 'subsample_for_bin': 253636, 'min_split_gain': 0.31916094883248447, 'min_child_weight': 0.014551639744310748, 'reg_alpha': 2.490670504424539, 'reg_lambda': 58.47108116987202}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,490] Trial 111 finished with value: 0.8784185166442983 and parameters: {'num_leaves': 52, 'min_child_samples': 39, 'n_estimators': 951, 'learning_rate': 0.49999265641666224, 'subsample_for_bin': 236820, 'min_split_gain': 0.4549315311639291, 'min_child_weight': 0.004646764073235466, 'reg_alpha': 2.2496448377043823, 'reg_lambda': 72.93783198183328}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,546] Trial 112 finished with value: 0.8706775795178691 and parameters: {'num_leaves': 52, 'min_child_samples': 39, 'n_estimators': 751, 'learning_rate': 0.49634006692181876, 'subsample_for_bin': 241940, 'min_split_gain': 0.45031545587716115, 'min_child_weight': 0.004479698472770606, 'reg_alpha': 2.332993415737195, 'reg_lambda': 78.68427849558476}. Best is trial 107 with value: 0.8784698539819439.
# [I 2023-01-28 15:13:49,630] Trial 115 finished with value: 0.8718436704729635 and parameters: {'num_leaves': 48, 'min_child_samples': 39, 'n_estimators': 615, 'learning_rate': 0.49813326652680995, 'subsample_for_bin': 235675, 'min_split_gain': 0.44849002587354403, 'min_child_weight': 0.01584243390367991, 'reg_alpha': 5.892630444715509, 'reg_lambda': 53.49111807907106}. Best is trial 107 with value: 0.8784698539819439.
# ...
# [I 2023-01-28 15:15:22,639] Trial 987 finished with value: 0.8773514334118061 and parameters: {'num_leaves': 84, 'min_child_samples': 30, 'n_estimators': 541, 'learning_rate': 0.21656098721461015, 'subsample_for_bin': 131729, 'min_split_gain': 0.018552419990195218, 'min_child_weight': 0.041165792349558465, 'reg_alpha': 3.732834880039722, 'reg_lambda': 42.45694285547286}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:22,706] Trial 988 finished with value: 0.8607548055414989 and parameters: {'num_leaves': 84, 'min_child_samples': 30, 'n_estimators': 517, 'learning_rate': 0.3295700293162294, 'subsample_for_bin': 133581, 'min_split_gain': 0.266568485781491, 'min_child_weight': 0.03938693529199755, 'reg_alpha': 3.769327689045867, 'reg_lambda': 53.69927353855418}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:23,434] Trial 989 finished with value: 0.8276532236181088 and parameters: {'num_leaves': 82, 'min_child_samples': 30, 'n_estimators': 540, 'learning_rate': 0.3297296961606951, 'subsample_for_bin': 108999, 'min_split_gain': 0.01675207338950339, 'min_child_weight': 0.12938729987732345, 'reg_alpha': 54.16096226496676, 'reg_lambda': 92.41000939860736}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:23,508] Trial 991 finished with value: 0.8231685404794907 and parameters: {'num_leaves': 85, 'min_child_samples': 33, 'n_estimators': 543, 'learning_rate': 0.40842072227565435, 'subsample_for_bin': 118127, 'min_split_gain': 0.018497244061574825, 'min_child_weight': 0.03351624285493704, 'reg_alpha': 54.34254483849307, 'reg_lambda': 75.30025965245734}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:23,544] Trial 990 finished with value: 0.8221124581050656 and parameters: {'num_leaves': 39, 'min_child_samples': 33, 'n_estimators': 545, 'learning_rate': 0.240795626182855, 'subsample_for_bin': 134123, 'min_split_gain': 0.43245662296885284, 'min_child_weight': 0.05078713392063629, 'reg_alpha': 37.22167258373649, 'reg_lambda': 13.937722042832178}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:23,733] Trial 992 finished with value: 0.8662662354330305 and parameters: {'num_leaves': 85, 'min_child_samples': 43, 'n_estimators': 590, 'learning_rate': 0.32800313188816865, 'subsample_for_bin': 135237, 'min_split_gain': 0.01684113147386776, 'min_child_weight': 0.08097228964199694, 'reg_alpha': 0.019578338802970496, 'reg_lambda': 93.19970517847167}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,024] Trial 993 finished with value: 0.820953701055349 and parameters: {'num_leaves': 82, 'min_child_samples': 30, 'n_estimators': 540, 'learning_rate': 0.24338934964535566, 'subsample_for_bin': 117077, 'min_split_gain': 0.44680777153005724, 'min_child_weight': 0.06805214956068516, 'reg_alpha': 46.31702247620557, 'reg_lambda': 12.271022250934422}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,133] Trial 994 finished with value: 0.8165753595447112 and parameters: {'num_leaves': 82, 'min_child_samples': 43, 'n_estimators': 584, 'learning_rate': 0.32894196598290776, 'subsample_for_bin': 115287, 'min_split_gain': 0.18449255533614858, 'min_child_weight': 0.043940545407811483, 'reg_alpha': 64.09142533634201, 'reg_lambda': 63.977437819136185}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,402] Trial 995 finished with value: 0.8707215829501367 and parameters: {'num_leaves': 84, 'min_child_samples': 30, 'n_estimators': 537, 'learning_rate': 0.32691695345963573, 'subsample_for_bin': 116295, 'min_split_gain': 0.08570478274593171, 'min_child_weight': 0.05956321205287289, 'reg_alpha': 0.050943783261683306, 'reg_lambda': 67.44774117772612}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,437] Trial 997 finished with value: 0.8375686636891011 and parameters: {'num_leaves': 23, 'min_child_samples': 33, 'n_estimators': 225, 'learning_rate': 0.2415167108912196, 'subsample_for_bin': 146846, 'min_split_gain': 0.3382254594914735, 'min_child_weight': 0.04391011116240641, 'reg_alpha': 14.370230999140947, 'reg_lambda': 64.4079547613912}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,488] Trial 996 finished with value: 0.5502702544131776 and parameters: {'num_leaves': 95, 'min_child_samples': 30, 'n_estimators': 538, 'learning_rate': 0.4454435795721581, 'subsample_for_bin': 108804, 'min_split_gain': 0.1145034620379404, 'min_child_weight': 0.005032697782311903, 'reg_alpha': 91.02381015620719, 'reg_lambda': 62.73702642609057}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,808] Trial 998 finished with value: 0.8165753595447112 and parameters: {'num_leaves': 95, 'min_child_samples': 43, 'n_estimators': 542, 'learning_rate': 0.40312889839506877, 'subsample_for_bin': 115103, 'min_split_gain': 0.1819425648445159, 'min_child_weight': 0.005105911056209253, 'reg_alpha': 50.34047912379634, 'reg_lambda': 67.53411364646101}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:24,957] Trial 999 finished with value: 0.8231905421956246 and parameters: {'num_leaves': 24, 'min_child_samples': 33, 'n_estimators': 226, 'learning_rate': 0.24104931530302373, 'subsample_for_bin': 117813, 'min_split_gain': 0.1828060014349993, 'min_child_weight': 0.04417069910206623, 'reg_alpha': 47.99755443042411, 'reg_lambda': 30.619871556555996}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:25,182] Trial 1001 finished with value: 0.5502739213658665 and parameters: {'num_leaves': 95, 'min_child_samples': 43, 'n_estimators': 278, 'learning_rate': 0.44327255923119463, 'subsample_for_bin': 107621, 'min_split_gain': 0.2345251442668021, 'min_child_weight': 0.04353818556763258, 'reg_alpha': 87.46405646596452, 'reg_lambda': 72.23200252832213}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:25,228] Trial 1002 finished with value: 0.8254090485724553 and parameters: {'num_leaves': 94, 'min_child_samples': 33, 'n_estimators': 297, 'learning_rate': 0.40059386127717345, 'subsample_for_bin': 144003, 'min_split_gain': 0.21234195909763748, 'min_child_weight': 0.0057366015303258605, 'reg_alpha': 28.788452195389763, 'reg_lambda': 44.84426685071875}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:25,325] Trial 1000 finished with value: 0.8640623968669555 and parameters: {'num_leaves': 85, 'min_child_samples': 33, 'n_estimators': 302, 'learning_rate': 0.37767993813337875, 'subsample_for_bin': 141667, 'min_split_gain': 0.11605552312564818, 'min_child_weight': 0.00552249894008984, 'reg_alpha': 1.891029543186986, 'reg_lambda': 86.55304855786716}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:25,406] Trial 1004 finished with value: 0.8198829508701678 and parameters: {'num_leaves': 94, 'min_child_samples': 33, 'n_estimators': 295, 'learning_rate': 0.10326145600888628, 'subsample_for_bin': 119851, 'min_split_gain': 0.4468481880859071, 'min_child_weight': 0.006650947518867981, 'reg_alpha': 22.564268555702398, 'reg_lambda': 96.09701465833888}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:25,469] Trial 1003 finished with value: 0.5502372518389768 and parameters: {'num_leaves': 39, 'min_child_samples': 33, 'n_estimators': 215, 'learning_rate': 0.39968742591750384, 'subsample_for_bin': 144758, 'min_split_gain': 0.3378565061387163, 'min_child_weight': 0.0061128183888658535, 'reg_alpha': 95.15100612945247, 'reg_lambda': 32.35431629405046}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,206] Trial 1005 finished with value: 0.8232125439117585 and parameters: {'num_leaves': 96, 'min_child_samples': 33, 'n_estimators': 220, 'learning_rate': 0.3119368486238477, 'subsample_for_bin': 163504, 'min_split_gain': 0.3204745186191386, 'min_child_weight': 0.118067372602571, 'reg_alpha': 19.818766886652263, 'reg_lambda': 90.13523574425889}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,266] Trial 1006 finished with value: 0.8242979619076954 and parameters: {'num_leaves': 33, 'min_child_samples': 33, 'n_estimators': 293, 'learning_rate': 0.47273482404124506, 'subsample_for_bin': 165895, 'min_split_gain': 0.23332635372192137, 'min_child_weight': 0.10142335601473015, 'reg_alpha': 20.42932373479261, 'reg_lambda': 79.13310291795405}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,552] Trial 1007 finished with value: 0.5502629205077996 and parameters: {'num_leaves': 95, 'min_child_samples': 33, 'n_estimators': 224, 'learning_rate': 0.4469657954910503, 'subsample_for_bin': 123156, 'min_split_gain': 0.3206991910327636, 'min_child_weight': 0.11820480537394373, 'reg_alpha': 98.94848923580776, 'reg_lambda': 49.018197916116755}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,589] Trial 1008 finished with value: 0.8607951420210777 and parameters: {'num_leaves': 96, 'min_child_samples': 33, 'n_estimators': 223, 'learning_rate': 0.3788001239560361, 'subsample_for_bin': 142448, 'min_split_gain': 0.384553069102616, 'min_child_weight': 0.11565276233079243, 'reg_alpha': 1.8188251697329505, 'reg_lambda': 56.79536646182747}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,791] Trial 1009 finished with value: 0.8651844843897823 and parameters: {'num_leaves': 64, 'min_child_samples': 33, 'n_estimators': 90, 'learning_rate': 0.4001783524612459, 'subsample_for_bin': 178024, 'min_split_gain': 0.3797557426413764, 'min_child_weight': 0.11853145801020111, 'reg_alpha': 2.1906598515039457, 'reg_lambda': 80.17025830072521}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:26,902] Trial 1010 finished with value: 0.8751402609403534 and parameters: {'num_leaves': 74, 'min_child_samples': 33, 'n_estimators': 85, 'learning_rate': 0.4223074343556513, 'subsample_for_bin': 163936, 'min_split_gain': 0.13299036934346622, 'min_child_weight': 0.055622243886965766, 'reg_alpha': 3.25789706469026, 'reg_lambda': 74.03121795149376}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,014] Trial 1011 finished with value: 0.8695921615219321 and parameters: {'num_leaves': 95, 'min_child_samples': 33, 'n_estimators': 293, 'learning_rate': 0.47082058875609023, 'subsample_for_bin': 162544, 'min_split_gain': 0.37979710607220807, 'min_child_weight': 0.1179486865957978, 'reg_alpha': 2.092203409372324, 'reg_lambda': 4.951704087053265}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,025] Trial 1013 finished with value: 0.8496879423261682 and parameters: {'num_leaves': 19, 'min_child_samples': 42, 'n_estimators': 292, 'learning_rate': 0.3077442933911609, 'subsample_for_bin': 179002, 'min_split_gain': 0.1545648235581897, 'min_child_weight': 0.05647946282306415, 'reg_alpha': 13.149414033703122, 'reg_lambda': 6.259456018077145}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,075] Trial 1012 finished with value: 0.718363365675856 and parameters: {'num_leaves': 64, 'min_child_samples': 33, 'n_estimators': 291, 'learning_rate': 0.30834354982242956, 'subsample_for_bin': 152924, 'min_split_gain': 0.13732339946838348, 'min_child_weight': 0.11549686918988634, 'reg_alpha': 75.64501313232287, 'reg_lambda': 29.155604233226903}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,198] Trial 1014 finished with value: 0.8243346314345853 and parameters: {'num_leaves': 19, 'min_child_samples': 35, 'n_estimators': 271, 'learning_rate': 0.35691646464171234, 'subsample_for_bin': 176885, 'min_split_gain': 0.13423164656677605, 'min_child_weight': 0.11445749686523828, 'reg_alpha': 33.51670331232482, 'reg_lambda': 27.350363524802347}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,313] Trial 1015 finished with value: 0.8187901989688529 and parameters: {'num_leaves': 63, 'min_child_samples': 35, 'n_estimators': 295, 'learning_rate': 0.35484975266838764, 'subsample_for_bin': 164513, 'min_split_gain': 0.32311854046574645, 'min_child_weight': 0.12563857631893993, 'reg_alpha': 52.57795388485208, 'reg_lambda': 8.77102496230674}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,360] Trial 1017 finished with value: 0.5502702544131776 and parameters: {'num_leaves': 64, 'min_child_samples': 35, 'n_estimators': 329, 'learning_rate': 0.07933752624772289, 'subsample_for_bin': 384009, 'min_split_gain': 0.30050744686608255, 'min_child_weight': 0.05526640475820796, 'reg_alpha': 88.4629265232081, 'reg_lambda': 37.99659634447436}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,366] Trial 1016 finished with value: 0.8265164682845262 and parameters: {'num_leaves': 72, 'min_child_samples': 35, 'n_estimators': 373, 'learning_rate': 0.3070477110870825, 'subsample_for_bin': 154218, 'min_split_gain': 0.15483759783852155, 'min_child_weight': 0.125714251570273, 'reg_alpha': 52.397573832510346, 'reg_lambda': 37.559864641521095}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,372] Trial 1018 finished with value: 0.868499409620617 and parameters: {'num_leaves': 73, 'min_child_samples': 46, 'n_estimators': 815, 'learning_rate': 0.4742877073818108, 'subsample_for_bin': 399249, 'min_split_gain': 0.2989344167731053, 'min_child_weight': 0.12518435113099974, 'reg_alpha': 5.042150685491421, 'reg_lambda': 37.56177818568191}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,390] Trial 1019 finished with value: 0.828720306850601 and parameters: {'num_leaves': 110, 'min_child_samples': 46, 'n_estimators': 323, 'learning_rate': 0.35729276955422495, 'subsample_for_bin': 410430, 'min_split_gain': 0.01031261794138652, 'min_child_weight': 0.07295831569028131, 'reg_alpha': 25.658986178509103, 'reg_lambda': 37.64232180062419}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,419] Trial 1020 finished with value: 0.816593694308156 and parameters: {'num_leaves': 19, 'min_child_samples': 34, 'n_estimators': 818, 'learning_rate': 0.47297919932128984, 'subsample_for_bin': 86838, 'min_split_gain': 0.48895735301885607, 'min_child_weight': 0.008965952479011165, 'reg_alpha': 65.54627251716921, 'reg_lambda': 30.620646829976213}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,458] Trial 1023 finished with value: 0.8464096866222232 and parameters: {'num_leaves': 65, 'min_child_samples': 35, 'n_estimators': 372, 'learning_rate': 0.4721865719726669, 'subsample_for_bin': 395070, 'min_split_gain': 0.2806188604667214, 'min_child_weight': 0.07846383743037358, 'reg_alpha': 11.325546367124295, 'reg_lambda': 71.44075295660537}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,460] Trial 1022 finished with value: 0.8518917808922429 and parameters: {'num_leaves': 74, 'min_child_samples': 35, 'n_estimators': 271, 'learning_rate': 0.35947561048890453, 'subsample_for_bin': 380205, 'min_split_gain': 0.3019580446934706, 'min_child_weight': 0.04862240331181314, 'reg_alpha': 10.793232787910423, 'reg_lambda': 15.559069978853735}. Best is trial 202 with value: 0.8861851224395503.
# [I 2023-01-28 15:15:27,470] Trial 1021 finished with value: 0.8828701972087156 and parameters: {'num_leaves': 18, 'min_child_samples': 35, 'n_estimators': 820, 'learning_rate': 0.30743788387373094, 'subsample_for_bin': 404437, 'min_split_gain': 0.29796239137877284, 'min_child_weight': 0.013745719566661058, 'reg_alpha': 0.01733653571080855, 'reg_lambda': 16.52130510749997}. Best is trial 202 with value: 0.8861851224395503.

# %%
trial = study.best_trial
print('Accuracy: {}'.format(trial.value))
# Out:
# Accuracy: 0.8861851224395503

# %%
print("Best hyperparameters: {}".format(trial.params))
# Out:
# Best hyperparameters: {'num_leaves': 17, 'min_child_samples': 32, 'n_estimators': 451, 'learning_rate': 0.23697231516242356, 'subsample_for_bin': 157918, 'min_split_gain': 0.21586221333901595, 'min_child_weight': 0.03608534323743171, 'reg_alpha': 0.20792918813440409, 'reg_lambda': 73.90460596062752}

# %%
tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

# %%
tracking_Optuna_Accuracy = tracking

# %%
plt.plot(tracking);
#plt.plot(tracking_sorted)

# %%
#optuna.visualization.plot_optimization_history(study)

# %%
#optuna.visualization.plot_slice(study)

# %% [markdown]
# ### F1 Score

# %%
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_fruit, y_fruit, n_jobs=-1, scoring='f1', cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)

trial = study.best_trial

print('F1 Score: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))

tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

tracking_Optuna_F1 = tracking

plt.plot(tracking);
#plt.plot(tracking_sorted)
# Out:
# [I 2023-01-28 15:16:51,424] A new study created in memory with name: no-name-2a96e5da-87be-4f0a-9615-6581d42a5e85
# [I 2023-01-28 15:16:51,468] Trial 0 finished with value: 0.8451885105182262 and parameters: {'num_leaves': 48, 'min_child_samples': 39, 'n_estimators': 506, 'learning_rate': 0.3755082051840919, 'subsample_for_bin': 68136, 'min_split_gain': 0.16442566699326877, 'min_child_weight': 0.11822003613175648, 'reg_alpha': 33.25656550511979, 'reg_lambda': 48.02914554114958}. Best is trial 0 with value: 0.8451885105182262.
# [I 2023-01-28 15:16:51,480] Trial 2 finished with value: 0.8801260950760806 and parameters: {'num_leaves': 149, 'min_child_samples': 38, 'n_estimators': 45, 'learning_rate': 0.4484855531440843, 'subsample_for_bin': 467502, 'min_split_gain': 0.19781590453033973, 'min_child_weight': 0.024977380367712528, 'reg_alpha': 8.393073122769035, 'reg_lambda': 99.91632912751007}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,492] Trial 1 finished with value: 0.8377369707617994 and parameters: {'num_leaves': 81, 'min_child_samples': 27, 'n_estimators': 414, 'learning_rate': 0.3222589896181485, 'subsample_for_bin': 307838, 'min_split_gain': 0.3892114567322139, 'min_child_weight': 0.06466981749517096, 'reg_alpha': 54.96616562562926, 'reg_lambda': 17.49565096229226}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,500] Trial 9 finished with value: 0.7773956807891059 and parameters: {'num_leaves': 44, 'min_child_samples': 21, 'n_estimators': 299, 'learning_rate': 0.30751199664523193, 'subsample_for_bin': 454640, 'min_split_gain': 0.26041344301084196, 'min_child_weight': 0.0435672374980819, 'reg_alpha': 74.87504080407648, 'reg_lambda': 56.47679686085908}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,518] Trial 6 finished with value: 0.7413138529808112 and parameters: {'num_leaves': 161, 'min_child_samples': 27, 'n_estimators': 92, 'learning_rate': 0.03172137903106529, 'subsample_for_bin': 480293, 'min_split_gain': 0.15773969915585948, 'min_child_weight': 0.012150887623318254, 'reg_alpha': 81.71357117092492, 'reg_lambda': 95.14211965723788}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,551] Trial 10 finished with value: 0.8529237868627876 and parameters: {'num_leaves': 101, 'min_child_samples': 48, 'n_estimators': 779, 'learning_rate': 0.4769600786920051, 'subsample_for_bin': 217357, 'min_split_gain': 0.4894386767212088, 'min_child_weight': 0.0263596583769808, 'reg_alpha': 17.313356880414503, 'reg_lambda': 39.46462102326719}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,558] Trial 7 finished with value: 0.8461493539226709 and parameters: {'num_leaves': 77, 'min_child_samples': 35, 'n_estimators': 525, 'learning_rate': 0.2353932812237074, 'subsample_for_bin': 229122, 'min_split_gain': 0.036874703974043965, 'min_child_weight': 0.03693376621733, 'reg_alpha': 34.41997619114714, 'reg_lambda': 16.80174489657772}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,560] Trial 3 finished with value: 0.8357750131687989 and parameters: {'num_leaves': 40, 'min_child_samples': 16, 'n_estimators': 699, 'learning_rate': 0.030552684916711433, 'subsample_for_bin': 227161, 'min_split_gain': 0.26579741103711546, 'min_child_weight': 0.08281976266021317, 'reg_alpha': 71.58495270731653, 'reg_lambda': 48.022365635927656}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,560] Trial 5 finished with value: 0.8387406000217901 and parameters: {'num_leaves': 16, 'min_child_samples': 34, 'n_estimators': 171, 'learning_rate': 0.047980191785318864, 'subsample_for_bin': 256905, 'min_split_gain': 0.012907520603902056, 'min_child_weight': 0.04284565167150401, 'reg_alpha': 68.76465242658355, 'reg_lambda': 23.38473198575418}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,579] Trial 8 finished with value: 0.7093638862009589 and parameters: {'num_leaves': 117, 'min_child_samples': 33, 'n_estimators': 890, 'learning_rate': 0.2781855501280592, 'subsample_for_bin': 278119, 'min_split_gain': 0.28944836071630314, 'min_child_weight': 0.0219263685409018, 'reg_alpha': 89.3122209692556, 'reg_lambda': 57.85742112790493}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,581] Trial 17 finished with value: 0.8396717099018067 and parameters: {'num_leaves': 200, 'min_child_samples': 38, 'n_estimators': 122, 'learning_rate': 0.16883518385845997, 'subsample_for_bin': 214011, 'min_split_gain': 0.08230725308436182, 'min_child_weight': 0.03182093543144882, 'reg_alpha': 22.152053302831646, 'reg_lambda': 35.44739014136011}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,582] Trial 14 finished with value: 0.783607324877866 and parameters: {'num_leaves': 145, 'min_child_samples': 35, 'n_estimators': 944, 'learning_rate': 0.3304630425210949, 'subsample_for_bin': 281797, 'min_split_gain': 0.4998896931916201, 'min_child_weight': 0.09037655855715242, 'reg_alpha': 75.053952599471, 'reg_lambda': 24.941823904412768}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,586] Trial 20 finished with value: 0.8355954971993788 and parameters: {'num_leaves': 161, 'min_child_samples': 13, 'n_estimators': 89, 'learning_rate': 0.17116255831837393, 'subsample_for_bin': 284320, 'min_split_gain': 0.13757470367745267, 'min_child_weight': 0.029661777291402822, 'reg_alpha': 73.46850386513695, 'reg_lambda': 7.086904053081014}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,587] Trial 13 finished with value: 0.8451852608172804 and parameters: {'num_leaves': 89, 'min_child_samples': 17, 'n_estimators': 822, 'learning_rate': 0.34946192031564066, 'subsample_for_bin': 220275, 'min_split_gain': 0.18900781657310295, 'min_child_weight': 0.13251297659265301, 'reg_alpha': 51.29145393350759, 'reg_lambda': 17.01904018267441}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,608] Trial 4 finished with value: 0.836030824119566 and parameters: {'num_leaves': 108, 'min_child_samples': 29, 'n_estimators': 915, 'learning_rate': 0.30115389026635053, 'subsample_for_bin': 199983, 'min_split_gain': 0.04961367525546101, 'min_child_weight': 0.049546136023964446, 'reg_alpha': 67.65931165181583, 'reg_lambda': 55.32978277579607}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,611] Trial 11 finished with value: 0.840548778033584 and parameters: {'num_leaves': 39, 'min_child_samples': 33, 'n_estimators': 711, 'learning_rate': 0.3430664490364764, 'subsample_for_bin': 102281, 'min_split_gain': 0.4357692162746725, 'min_child_weight': 0.03800616013974612, 'reg_alpha': 30.440415112506322, 'reg_lambda': 41.22919837583564}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,676] Trial 16 finished with value: 0.8768338241946262 and parameters: {'num_leaves': 57, 'min_child_samples': 26, 'n_estimators': 326, 'learning_rate': 0.36392308869526563, 'subsample_for_bin': 406782, 'min_split_gain': 0.1612656397294998, 'min_child_weight': 0.0023193036197752355, 'reg_alpha': 5.244382363379336, 'reg_lambda': 81.75620326597179}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,742] Trial 15 finished with value: 0.7466433802126421 and parameters: {'num_leaves': 171, 'min_child_samples': 46, 'n_estimators': 812, 'learning_rate': 0.17523863467142037, 'subsample_for_bin': 429113, 'min_split_gain': 0.11259694900696685, 'min_child_weight': 0.13510361393928597, 'reg_alpha': 78.56065144043207, 'reg_lambda': 5.718015611449823}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,802] Trial 19 finished with value: 0.8422342829558698 and parameters: {'num_leaves': 89, 'min_child_samples': 49, 'n_estimators': 432, 'learning_rate': 0.12973373126459334, 'subsample_for_bin': 181356, 'min_split_gain': 0.08141471343556383, 'min_child_weight': 0.0932532540021328, 'reg_alpha': 19.988813478261967, 'reg_lambda': 82.37387716611863}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,927] Trial 12 finished with value: 0.8387922218494267 and parameters: {'num_leaves': 187, 'min_child_samples': 25, 'n_estimators': 761, 'learning_rate': 0.43597625764283915, 'subsample_for_bin': 454204, 'min_split_gain': 0.2887117582170561, 'min_child_weight': 0.01829878596204941, 'reg_alpha': 58.12243326113664, 'reg_lambda': 42.42559053440869}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,930] Trial 21 finished with value: 0.8431783316050504 and parameters: {'num_leaves': 20, 'min_child_samples': 32, 'n_estimators': 562, 'learning_rate': 0.4868092896932497, 'subsample_for_bin': 490985, 'min_split_gain': 0.4634870543005084, 'min_child_weight': 0.09509100994249481, 'reg_alpha': 27.53891123801561, 'reg_lambda': 28.168616971024367}. Best is trial 2 with value: 0.8801260950760806.
# [I 2023-01-28 15:16:51,932] Trial 24 finished with value: 0.891437683277168 and parameters: {'num_leaves': 122, 'min_child_samples': 49, 'n_estimators': 692, 'learning_rate': 0.4918738697452948, 'subsample_for_bin': 403755, 'min_split_gain': 0.33715541903431345, 'min_child_weight': 0.0018084742155175249, 'reg_alpha': 0.9679767075522596, 'reg_lambda': 96.16810701757771}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:51,932] Trial 18 finished with value: 0.840331191889523 and parameters: {'num_leaves': 64, 'min_child_samples': 47, 'n_estimators': 972, 'learning_rate': 0.004382271469350538, 'subsample_for_bin': 215394, 'min_split_gain': 0.23903132852006062, 'min_child_weight': 0.005672635081146514, 'reg_alpha': 46.766285655466284, 'reg_lambda': 19.6445241990256}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:51,933] Trial 23 finished with value: 0.882075875139459 and parameters: {'num_leaves': 124, 'min_child_samples': 48, 'n_estimators': 721, 'learning_rate': 0.4933639140650657, 'subsample_for_bin': 370138, 'min_split_gain': 0.3116597402162998, 'min_child_weight': 0.0026511351534909827, 'reg_alpha': 0.9954284682682157, 'reg_lambda': 94.66203083320173}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:51,933] Trial 22 finished with value: 0.7098923496144756 and parameters: {'num_leaves': 85, 'min_child_samples': 29, 'n_estimators': 489, 'learning_rate': 0.17224517792104935, 'subsample_for_bin': 368945, 'min_split_gain': 0.06058978757426784, 'min_child_weight': 0.006054469042268786, 'reg_alpha': 99.55315051635674, 'reg_lambda': 50.42035667811527}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:51,935] Trial 26 finished with value: 0.8757179220747812 and parameters: {'num_leaves': 135, 'min_child_samples': 50, 'n_estimators': 274, 'learning_rate': 0.4632390144735883, 'subsample_for_bin': 412054, 'min_split_gain': 0.22165642202337282, 'min_child_weight': 0.001307539798375912, 'reg_alpha': 6.142099409643565, 'reg_lambda': 97.42440896125234}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:52,003] Trial 27 finished with value: 0.8911988286727054 and parameters: {'num_leaves': 136, 'min_child_samples': 44, 'n_estimators': 279, 'learning_rate': 0.44425285373630646, 'subsample_for_bin': 402120, 'min_split_gain': 0.21361340705223825, 'min_child_weight': 0.0010470228194472413, 'reg_alpha': 0.17542682832848389, 'reg_lambda': 97.40027390267302}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:52,040] Trial 29 finished with value: 0.8836542208325705 and parameters: {'num_leaves': 132, 'min_child_samples': 44, 'n_estimators': 226, 'learning_rate': 0.4309127535873115, 'subsample_for_bin': 388360, 'min_split_gain': 0.2063234418802434, 'min_child_weight': 0.0052917004322970175, 'reg_alpha': 0.5739463015226134, 'reg_lambda': 98.92206362165734}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:52,046] Trial 28 finished with value: 0.8864779335321199 and parameters: {'num_leaves': 125, 'min_child_samples': 44, 'n_estimators': 259, 'learning_rate': 0.4438346594745434, 'subsample_for_bin': 389236, 'min_split_gain': 0.1976241611129429, 'min_child_weight': 0.0043020446599861956, 'reg_alpha': 0.6760319497228622, 'reg_lambda': 98.39587593973937}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:52,086] Trial 30 finished with value: 0.8825196636159222 and parameters: {'num_leaves': 133, 'min_child_samples': 41, 'n_estimators': 244, 'learning_rate': 0.4597870066946293, 'subsample_for_bin': 388741, 'min_split_gain': 0.20508188500309868, 'min_child_weight': 0.0036680017207124382, 'reg_alpha': 0.13041580956972698, 'reg_lambda': 94.74133233926395}. Best is trial 24 with value: 0.891437683277168.
# [I 2023-01-28 15:16:52,097] Trial 25 finished with value: 0.892432392856121 and parameters: {'num_leaves': 133, 'min_child_samples': 50, 'n_estimators': 676, 'learning_rate': 0.49416555694794717, 'subsample_for_bin': 404707, 'min_split_gain': 0.21082433581846444, 'min_child_weight': 0.004380215414302217, 'reg_alpha': 0.9096919133704109, 'reg_lambda': 98.61248134803058}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,111] Trial 31 finished with value: 0.8817328306556221 and parameters: {'num_leaves': 123, 'min_child_samples': 42, 'n_estimators': 251, 'learning_rate': 0.43173921280175603, 'subsample_for_bin': 392538, 'min_split_gain': 0.2065176950970875, 'min_child_weight': 0.007797311752552278, 'reg_alpha': 1.699696197783453, 'reg_lambda': 94.12226498549788}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,181] Trial 32 finished with value: 0.8887395655131044 and parameters: {'num_leaves': 123, 'min_child_samples': 43, 'n_estimators': 258, 'learning_rate': 0.42845844706191655, 'subsample_for_bin': 383943, 'min_split_gain': 0.18318784752929332, 'min_child_weight': 0.001102134335513567, 'reg_alpha': 0.932105327704579, 'reg_lambda': 99.15679001976505}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,225] Trial 33 finished with value: 0.8836016756414766 and parameters: {'num_leaves': 135, 'min_child_samples': 23, 'n_estimators': 213, 'learning_rate': 0.42096687290623847, 'subsample_for_bin': 378330, 'min_split_gain': 0.21787146088475462, 'min_child_weight': 0.002408029924833921, 'reg_alpha': 0.6503948687806238, 'reg_lambda': 97.45237843397754}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,282] Trial 34 finished with value: 0.8837877415414296 and parameters: {'num_leaves': 130, 'min_child_samples': 43, 'n_estimators': 263, 'learning_rate': 0.4222118840635405, 'subsample_for_bin': 386376, 'min_split_gain': 0.20840450517609743, 'min_child_weight': 0.011105205345043466, 'reg_alpha': 1.8962269960871567, 'reg_lambda': 97.13680070188512}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,367] Trial 35 finished with value: 0.868808850189083 and parameters: {'num_leaves': 127, 'min_child_samples': 43, 'n_estimators': 645, 'learning_rate': 0.42162120197188513, 'subsample_for_bin': 341019, 'min_split_gain': 0.34122180313389616, 'min_child_weight': 0.016065256980853936, 'reg_alpha': 11.549567226598336, 'reg_lambda': 87.3134847319131}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,406] Trial 36 finished with value: 0.8628134438660754 and parameters: {'num_leaves': 130, 'min_child_samples': 43, 'n_estimators': 658, 'learning_rate': 0.4980798794058429, 'subsample_for_bin': 339454, 'min_split_gain': 0.3338968260179832, 'min_child_weight': 0.016928214869192937, 'reg_alpha': 12.211740571199574, 'reg_lambda': 86.9991984216965}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,442] Trial 38 finished with value: 0.863411859458371 and parameters: {'num_leaves': 130, 'min_child_samples': 43, 'n_estimators': 607, 'learning_rate': 0.4988581830206202, 'subsample_for_bin': 333455, 'min_split_gain': 0.3236955637243869, 'min_child_weight': 0.01628156530962948, 'reg_alpha': 12.501901909890087, 'reg_lambda': 87.09555455340767}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,472] Trial 37 finished with value: 0.8498183592336979 and parameters: {'num_leaves': 131, 'min_child_samples': 42, 'n_estimators': 646, 'learning_rate': 0.4237311605465733, 'subsample_for_bin': 328736, 'min_split_gain': 0.33181942254284336, 'min_child_weight': 0.017456644194139677, 'reg_alpha': 11.47405532652262, 'reg_lambda': 89.21494613130052}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,489] Trial 39 finished with value: 0.8648313869885507 and parameters: {'num_leaves': 133, 'min_child_samples': 43, 'n_estimators': 633, 'learning_rate': 0.49904431102401164, 'subsample_for_bin': 327681, 'min_split_gain': 0.32294963009131583, 'min_child_weight': 0.01732298711677175, 'reg_alpha': 11.537191390464958, 'reg_lambda': 87.00999897786097}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,512] Trial 42 finished with value: 0.8575148328318757 and parameters: {'num_leaves': 126, 'min_child_samples': 44, 'n_estimators': 614, 'learning_rate': 0.4050159344162097, 'subsample_for_bin': 330585, 'min_split_gain': 0.34088056709495784, 'min_child_weight': 0.017775293987396693, 'reg_alpha': 11.649601770051488, 'reg_lambda': 84.14595976173649}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,536] Trial 41 finished with value: 0.8661580911772413 and parameters: {'num_leaves': 129, 'min_child_samples': 44, 'n_estimators': 628, 'learning_rate': 0.39617895243896123, 'subsample_for_bin': 326165, 'min_split_gain': 0.3406786691730648, 'min_child_weight': 0.017041820564568107, 'reg_alpha': 13.140108774009578, 'reg_lambda': 87.85284918112605}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,566] Trial 40 finished with value: 0.8560451341717425 and parameters: {'num_leaves': 128, 'min_child_samples': 44, 'n_estimators': 596, 'learning_rate': 0.4106633240395065, 'subsample_for_bin': 330444, 'min_split_gain': 0.3409793660996699, 'min_child_weight': 0.016876664979584136, 'reg_alpha': 12.394349683618643, 'reg_lambda': 87.9776269416327}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,609] Trial 44 finished with value: 0.8692736170713656 and parameters: {'num_leaves': 108, 'min_child_samples': 42, 'n_estimators': 635, 'learning_rate': 0.3961136103744189, 'subsample_for_bin': 336437, 'min_split_gain': 0.3613779432018973, 'min_child_weight': 0.019953142634731243, 'reg_alpha': 13.203657541079803, 'reg_lambda': 88.96214918810435}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,646] Trial 43 finished with value: 0.8561827905546048 and parameters: {'num_leaves': 111, 'min_child_samples': 43, 'n_estimators': 574, 'learning_rate': 0.4009802769869436, 'subsample_for_bin': 322953, 'min_split_gain': 0.34040915891147144, 'min_child_weight': 0.01690561085484687, 'reg_alpha': 11.366524039597472, 'reg_lambda': 88.07305376202913}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,688] Trial 47 finished with value: 0.8583015438993139 and parameters: {'num_leaves': 107, 'min_child_samples': 44, 'n_estimators': 610, 'learning_rate': 0.401490349853289, 'subsample_for_bin': 334964, 'min_split_gain': 0.3412752369813711, 'min_child_weight': 0.01809074441637073, 'reg_alpha': 10.56168142654645, 'reg_lambda': 87.29988398660952}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,717] Trial 46 finished with value: 0.8600462235304502 and parameters: {'num_leaves': 114, 'min_child_samples': 44, 'n_estimators': 602, 'learning_rate': 0.39955966562638967, 'subsample_for_bin': 324591, 'min_split_gain': 0.34650479111549604, 'min_child_weight': 0.019088439247493524, 'reg_alpha': 11.0310887568778, 'reg_lambda': 87.33576484569703}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,742] Trial 45 finished with value: 0.866133715010502 and parameters: {'num_leaves': 118, 'min_child_samples': 45, 'n_estimators': 622, 'learning_rate': 0.3946959547131756, 'subsample_for_bin': 315845, 'min_split_gain': 0.3499101282005793, 'min_child_weight': 0.017329646860245882, 'reg_alpha': 10.635884839472798, 'reg_lambda': 89.11972065686884}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,767] Trial 49 finished with value: 0.8721735084758676 and parameters: {'num_leaves': 107, 'min_child_samples': 45, 'n_estimators': 627, 'learning_rate': 0.39905102167636286, 'subsample_for_bin': 338330, 'min_split_gain': 0.3365739037844938, 'min_child_weight': 0.01853146225351315, 'reg_alpha': 9.889212749621667, 'reg_lambda': 76.54251301053435}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,812] Trial 48 finished with value: 0.870217221697532 and parameters: {'num_leaves': 108, 'min_child_samples': 45, 'n_estimators': 581, 'learning_rate': 0.3894490545182566, 'subsample_for_bin': 332490, 'min_split_gain': 0.33778564173889275, 'min_child_weight': 0.017737054857480936, 'reg_alpha': 10.740796537144467, 'reg_lambda': 76.05060781268762}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,846] Trial 50 finished with value: 0.8581078146368952 and parameters: {'num_leaves': 105, 'min_child_samples': 40, 'n_estimators': 640, 'learning_rate': 0.38952215402324203, 'subsample_for_bin': 332599, 'min_split_gain': 0.24584897760622956, 'min_child_weight': 0.022455032911916598, 'reg_alpha': 9.181939199189651, 'reg_lambda': 74.514738071883}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,888] Trial 51 finished with value: 0.8738043629974466 and parameters: {'num_leaves': 108, 'min_child_samples': 40, 'n_estimators': 362, 'learning_rate': 0.38255057716738505, 'subsample_for_bin': 433362, 'min_split_gain': 0.2452836249085728, 'min_child_weight': 0.024916175773991973, 'reg_alpha': 6.577960124563523, 'reg_lambda': 77.44909708709592}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,915] Trial 52 finished with value: 0.8792542680007432 and parameters: {'num_leaves': 102, 'min_child_samples': 40, 'n_estimators': 356, 'learning_rate': 0.3871967482888681, 'subsample_for_bin': 434121, 'min_split_gain': 0.17407054947277728, 'min_child_weight': 0.027064653099353055, 'reg_alpha': 6.552300426972989, 'reg_lambda': 76.00506284367168}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,943] Trial 53 finished with value: 0.8753968253968254 and parameters: {'num_leaves': 149, 'min_child_samples': 39, 'n_estimators': 484, 'learning_rate': 0.3945895607614773, 'subsample_for_bin': 437007, 'min_split_gain': 0.17973315184713695, 'min_child_weight': 0.02553961829081218, 'reg_alpha': 6.080854798266068, 'reg_lambda': 78.94386960237776}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:52,979] Trial 54 finished with value: 0.8691427074164099 and parameters: {'num_leaves': 107, 'min_child_samples': 39, 'n_estimators': 374, 'learning_rate': 0.388359877963815, 'subsample_for_bin': 430468, 'min_split_gain': 0.18229955740148754, 'min_child_weight': 0.029513842002175997, 'reg_alpha': 5.796401688200084, 'reg_lambda': 77.43399095869137}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,015] Trial 55 finished with value: 0.8861248738416369 and parameters: {'num_leaves': 106, 'min_child_samples': 39, 'n_estimators': 362, 'learning_rate': 0.4582175425210176, 'subsample_for_bin': 439307, 'min_split_gain': 0.17772780883929448, 'min_child_weight': 0.025710304363954457, 'reg_alpha': 6.502362797228994, 'reg_lambda': 77.51254720392649}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,037] Trial 57 finished with value: 0.8824207793120941 and parameters: {'num_leaves': 111, 'min_child_samples': 38, 'n_estimators': 373, 'learning_rate': 0.4524256477278741, 'subsample_for_bin': 432657, 'min_split_gain': 0.175769745706003, 'min_child_weight': 0.029614142301617987, 'reg_alpha': 6.607925929993018, 'reg_lambda': 92.96694041188238}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,072] Trial 56 finished with value: 0.8785666629532306 and parameters: {'num_leaves': 110, 'min_child_samples': 40, 'n_estimators': 349, 'learning_rate': 0.4696479835037878, 'subsample_for_bin': 427798, 'min_split_gain': 0.1786043057122205, 'min_child_weight': 0.0247687982180712, 'reg_alpha': 5.982976547676117, 'reg_lambda': 99.8516047549105}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,113] Trial 58 finished with value: 0.8686065242016987 and parameters: {'num_leaves': 110, 'min_child_samples': 39, 'n_estimators': 372, 'learning_rate': 0.4513932979389182, 'subsample_for_bin': 433987, 'min_split_gain': 0.17990983073303207, 'min_child_weight': 0.02632438841854581, 'reg_alpha': 4.901550573663782, 'reg_lambda': 93.36595485194584}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,145] Trial 59 finished with value: 0.883271555402703 and parameters: {'num_leaves': 146, 'min_child_samples': 39, 'n_estimators': 352, 'learning_rate': 0.45728851338924, 'subsample_for_bin': 436741, 'min_split_gain': 0.17985714427189836, 'min_child_weight': 0.02499689950128014, 'reg_alpha': 6.412752829046092, 'reg_lambda': 98.9931594011172}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,188] Trial 60 finished with value: 0.8787194973516826 and parameters: {'num_leaves': 147, 'min_child_samples': 46, 'n_estimators': 386, 'learning_rate': 0.46721817279206956, 'subsample_for_bin': 441106, 'min_split_gain': 0.18169199142223502, 'min_child_weight': 0.02579484652175152, 'reg_alpha': 5.200062771544029, 'reg_lambda': 93.15765360973737}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,237] Trial 62 finished with value: 0.8808428438888724 and parameters: {'num_leaves': 145, 'min_child_samples': 40, 'n_estimators': 366, 'learning_rate': 0.45168550509373867, 'subsample_for_bin': 438979, 'min_split_gain': 0.181721307901431, 'min_child_weight': 0.009681361751899875, 'reg_alpha': 4.9543522992098055, 'reg_lambda': 99.81057721892338}. Best is trial 25 with value: 0.892432392856121.
# [I 2023-01-28 15:16:53,262] Trial 61 finished with value: 0.8955827243456141 and parameters: {'num_leaves': 145, 'min_child_samples': 40, 'n_estimators': 370, 'learning_rate': 0.4530997885362801, 'subsample_for_bin': 440598, 'min_split_gain': 0.24114748351990228, 'min_child_weight': 0.009245810697389882, 'reg_alpha': 4.452442464264886, 'reg_lambda': 99.13649946698592}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,285] Trial 63 finished with value: 0.8412609259917292 and parameters: {'num_leaves': 147, 'min_child_samples': 39, 'n_estimators': 355, 'learning_rate': 0.4547261648604632, 'subsample_for_bin': 436052, 'min_split_gain': 0.1847823268414147, 'min_child_weight': 0.007637563701290484, 'reg_alpha': 17.4733738344149, 'reg_lambda': 99.77010751089216}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,337] Trial 64 finished with value: 0.8696240943463147 and parameters: {'num_leaves': 146, 'min_child_samples': 40, 'n_estimators': 377, 'learning_rate': 0.4717659787633209, 'subsample_for_bin': 441507, 'min_split_gain': 0.183776719885244, 'min_child_weight': 0.009900864568380761, 'reg_alpha': 3.8713861362722297, 'reg_lambda': 92.354590890734}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,351] Trial 65 finished with value: 0.8575336967084971 and parameters: {'num_leaves': 147, 'min_child_samples': 39, 'n_estimators': 351, 'learning_rate': 0.4749757698815299, 'subsample_for_bin': 440339, 'min_split_gain': 0.18854799406022132, 'min_child_weight': 0.009954172598713177, 'reg_alpha': 16.469588831159435, 'reg_lambda': 99.46550270862029}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,390] Trial 66 finished with value: 0.8491067640755249 and parameters: {'num_leaves': 147, 'min_child_samples': 50, 'n_estimators': 160, 'learning_rate': 0.45288909333270777, 'subsample_for_bin': 468690, 'min_split_gain': 0.2711218569758853, 'min_child_weight': 0.009778637071639538, 'reg_alpha': 18.924177020978185, 'reg_lambda': 99.92548881887075}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,438] Trial 67 finished with value: 0.8488282742939387 and parameters: {'num_leaves': 145, 'min_child_samples': 37, 'n_estimators': 25, 'learning_rate': 0.45155936537029584, 'subsample_for_bin': 466320, 'min_split_gain': 0.1565014958636147, 'min_child_weight': 0.0099585357708346, 'reg_alpha': 19.125799333129883, 'reg_lambda': 91.90543206552184}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,480] Trial 68 finished with value: 0.8441869173675446 and parameters: {'num_leaves': 154, 'min_child_samples': 37, 'n_estimators': 174, 'learning_rate': 0.450459811829488, 'subsample_for_bin': 466070, 'min_split_gain': 0.26657537957213645, 'min_child_weight': 0.009930980902303602, 'reg_alpha': 17.097638879285427, 'reg_lambda': 95.372263898297}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,519] Trial 69 finished with value: 0.8543728405863877 and parameters: {'num_leaves': 158, 'min_child_samples': 36, 'n_estimators': 169, 'learning_rate': 0.44934152712946807, 'subsample_for_bin': 498125, 'min_split_gain': 0.14580395391266296, 'min_child_weight': 0.01023695954280626, 'reg_alpha': 17.701783677600954, 'reg_lambda': 92.68574353675422}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,562] Trial 70 finished with value: 0.8516896413497418 and parameters: {'num_leaves': 146, 'min_child_samples': 50, 'n_estimators': 188, 'learning_rate': 0.4728784372257955, 'subsample_for_bin': 471792, 'min_split_gain': 0.1480544142984862, 'min_child_weight': 0.0073038190470557755, 'reg_alpha': 16.282518984001978, 'reg_lambda': 92.66302805931724}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,672] Trial 71 finished with value: 0.8526396313958537 and parameters: {'num_leaves': 144, 'min_child_samples': 37, 'n_estimators': 168, 'learning_rate': 0.4473365868800092, 'subsample_for_bin': 478743, 'min_split_gain': 0.26996817908014736, 'min_child_weight': 0.010576043389417887, 'reg_alpha': 17.433081830733684, 'reg_lambda': 95.05309552903354}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,706] Trial 72 finished with value: 0.8587714461553243 and parameters: {'num_leaves': 147, 'min_child_samples': 50, 'n_estimators': 188, 'learning_rate': 0.48084903823648245, 'subsample_for_bin': 466434, 'min_split_gain': 0.1488937508942464, 'min_child_weight': 0.010645144576608723, 'reg_alpha': 16.310850005868165, 'reg_lambda': 95.746240447077}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,744] Trial 73 finished with value: 0.8898249693323566 and parameters: {'num_leaves': 98, 'min_child_samples': 50, 'n_estimators': 170, 'learning_rate': 0.4777175450817456, 'subsample_for_bin': 471446, 'min_split_gain': 0.14138462858888756, 'min_child_weight': 0.010337032509251321, 'reg_alpha': 0.20244315663502888, 'reg_lambda': 96.05573636677276}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,784] Trial 74 finished with value: 0.88850551222226 and parameters: {'num_leaves': 144, 'min_child_samples': 50, 'n_estimators': 153, 'learning_rate': 0.4418221631517324, 'subsample_for_bin': 466909, 'min_split_gain': 0.2692531399689851, 'min_child_weight': 0.010499250518460615, 'reg_alpha': 0.1233296059472877, 'reg_lambda': 95.39872583524762}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,811] Trial 75 finished with value: 0.8836777500655285 and parameters: {'num_leaves': 97, 'min_child_samples': 50, 'n_estimators': 161, 'learning_rate': 0.4760046989763034, 'subsample_for_bin': 481590, 'min_split_gain': 0.23014798506644218, 'min_child_weight': 0.0012937912296303866, 'reg_alpha': 0.21540811142608085, 'reg_lambda': 95.79262123845025}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,862] Trial 76 finished with value: 0.878756966700229 and parameters: {'num_leaves': 159, 'min_child_samples': 50, 'n_estimators': 153, 'learning_rate': 0.4783561396574606, 'subsample_for_bin': 463017, 'min_split_gain': 0.14722121594468193, 'min_child_weight': 0.011838302281155634, 'reg_alpha': 2.6299357004685913, 'reg_lambda': 95.6781993278671}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,896] Trial 77 finished with value: 0.8810014575575192 and parameters: {'num_leaves': 95, 'min_child_samples': 49, 'n_estimators': 437, 'learning_rate': 0.47860112766252216, 'subsample_for_bin': 468375, 'min_split_gain': 0.2381559160414394, 'min_child_weight': 0.003109357287939289, 'reg_alpha': 1.977156995227166, 'reg_lambda': 96.40452700772367}. Best is trial 61 with value: 0.8955827243456141.
# [I 2023-01-28 15:16:53,913] Trial 78 finished with value: 0.8955868196448497 and parameters: {'num_leaves': 97, 'min_child_samples': 36, 'n_estimators': 163, 'learning_rate': 0.48605926198152427, 'subsample_for_bin': 413668, 'min_split_gain': 0.2282738654737707, 'min_child_weight': 0.0013353879753271146, 'reg_alpha': 0.1364664725266429, 'reg_lambda': 96.92216362928767}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:53,981] Trial 79 finished with value: 0.8849990839227435 and parameters: {'num_leaves': 95, 'min_child_samples': 36, 'n_estimators': 168, 'learning_rate': 0.48452876647401555, 'subsample_for_bin': 358204, 'min_split_gain': 0.23196065762338391, 'min_child_weight': 0.0010366428116695765, 'reg_alpha': 0.09559566305729905, 'reg_lambda': 97.35444124394041}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,024] Trial 80 finished with value: 0.8840549905226521 and parameters: {'num_leaves': 159, 'min_child_samples': 36, 'n_estimators': 306, 'learning_rate': 0.4805070011537624, 'subsample_for_bin': 357296, 'min_split_gain': 0.23142505067246638, 'min_child_weight': 0.001827983160819763, 'reg_alpha': 1.7603800168224235, 'reg_lambda': 96.62116990866637}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,052] Trial 81 finished with value: 0.889558854269203 and parameters: {'num_leaves': 174, 'min_child_samples': 36, 'n_estimators': 307, 'learning_rate': 0.4815612224525607, 'subsample_for_bin': 404936, 'min_split_gain': 0.22796118887032515, 'min_child_weight': 0.001023395990074495, 'reg_alpha': 2.0505009244895422, 'reg_lambda': 96.09864770478148}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,098] Trial 82 finished with value: 0.8926909476573041 and parameters: {'num_leaves': 94, 'min_child_samples': 48, 'n_estimators': 424, 'learning_rate': 0.4868595413662322, 'subsample_for_bin': 408785, 'min_split_gain': 0.2290566539359953, 'min_child_weight': 0.0011101384342340334, 'reg_alpha': 1.9551754209449472, 'reg_lambda': 96.84360462332597}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,136] Trial 83 finished with value: 0.8830380297420971 and parameters: {'num_leaves': 96, 'min_child_samples': 48, 'n_estimators': 434, 'learning_rate': 0.4825418657229835, 'subsample_for_bin': 359173, 'min_split_gain': 0.22710885262632316, 'min_child_weight': 0.0011052386842102298, 'reg_alpha': 2.7231778254432975, 'reg_lambda': 97.10924281764166}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,165] Trial 84 finished with value: 0.8917600373482726 and parameters: {'num_leaves': 95, 'min_child_samples': 48, 'n_estimators': 292, 'learning_rate': 0.48351920386155595, 'subsample_for_bin': 404236, 'min_split_gain': 0.22585024960744512, 'min_child_weight': 0.0025704568766333788, 'reg_alpha': 2.843730707857927, 'reg_lambda': 91.35189528543428}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,201] Trial 85 finished with value: 0.8854643728282658 and parameters: {'num_leaves': 96, 'min_child_samples': 48, 'n_estimators': 307, 'learning_rate': 0.48541658333338183, 'subsample_for_bin': 409998, 'min_split_gain': 0.2264585150968584, 'min_child_weight': 0.0051303226768352325, 'reg_alpha': 2.700509145987607, 'reg_lambda': 90.60260680462287}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,241] Trial 86 finished with value: 0.8752282582225194 and parameters: {'num_leaves': 97, 'min_child_samples': 47, 'n_estimators': 306, 'learning_rate': 0.4344640265119481, 'subsample_for_bin': 409635, 'min_split_gain': 0.22515823069758342, 'min_child_weight': 0.0013225117098899035, 'reg_alpha': 3.0832078055793106, 'reg_lambda': 90.90599704762376}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,289] Trial 87 finished with value: 0.8743975050824365 and parameters: {'num_leaves': 95, 'min_child_samples': 48, 'n_estimators': 303, 'learning_rate': 0.48556626127301705, 'subsample_for_bin': 409334, 'min_split_gain': 0.23159346344583148, 'min_child_weight': 0.0011218686341027337, 'reg_alpha': 3.2568890116357476, 'reg_lambda': 90.40767721569321}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,317] Trial 88 finished with value: 0.8732653643345176 and parameters: {'num_leaves': 97, 'min_child_samples': 48, 'n_estimators': 300, 'learning_rate': 0.4824660154561588, 'subsample_for_bin': 408697, 'min_split_gain': 0.23565115097119965, 'min_child_weight': 0.005074046716931639, 'reg_alpha': 8.123665769254622, 'reg_lambda': 90.47497963098992}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,351] Trial 89 finished with value: 0.8738950158655272 and parameters: {'num_leaves': 95, 'min_child_samples': 48, 'n_estimators': 296, 'learning_rate': 0.434682255687343, 'subsample_for_bin': 404468, 'min_split_gain': 0.22189550046460063, 'min_child_weight': 0.005659577562388564, 'reg_alpha': 3.698367067515572, 'reg_lambda': 90.65302206245106}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,388] Trial 90 finished with value: 0.8859834573418034 and parameters: {'num_leaves': 96, 'min_child_samples': 48, 'n_estimators': 286, 'learning_rate': 0.43582124839602143, 'subsample_for_bin': 408439, 'min_split_gain': 0.22178015892241695, 'min_child_weight': 0.0056081811972898896, 'reg_alpha': 3.8312395264099277, 'reg_lambda': 91.06083361587574}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,434] Trial 91 finished with value: 0.8835646107834053 and parameters: {'num_leaves': 170, 'min_child_samples': 48, 'n_estimators': 291, 'learning_rate': 0.48947843046855655, 'subsample_for_bin': 408794, 'min_split_gain': 0.21679884906153551, 'min_child_weight': 0.005519219725038108, 'reg_alpha': 3.213797482936241, 'reg_lambda': 91.22296380123}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,501] Trial 93 finished with value: 0.8859764731860308 and parameters: {'num_leaves': 173, 'min_child_samples': 47, 'n_estimators': 298, 'learning_rate': 0.4324654514473505, 'subsample_for_bin': 417214, 'min_split_gain': 0.21253143108486744, 'min_child_weight': 0.005502856880394277, 'reg_alpha': 4.2480334065965115, 'reg_lambda': 84.82558486433298}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,534] Trial 94 finished with value: 0.8653997996130353 and parameters: {'num_leaves': 74, 'min_child_samples': 47, 'n_estimators': 82, 'learning_rate': 0.43524617249832265, 'subsample_for_bin': 410497, 'min_split_gain': 0.21614253494834018, 'min_child_weight': 0.005749737272933981, 'reg_alpha': 9.201506036763966, 'reg_lambda': 84.56808117244701}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,550] Trial 92 finished with value: 0.8745353551550119 and parameters: {'num_leaves': 170, 'min_child_samples': 47, 'n_estimators': 77, 'learning_rate': 0.4367617249263392, 'subsample_for_bin': 411375, 'min_split_gain': 0.21032455149452312, 'min_child_weight': 0.005766865861441824, 'reg_alpha': 8.877999629751843, 'reg_lambda': 82.69861847525956}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,582] Trial 95 finished with value: 0.8676364465917933 and parameters: {'num_leaves': 167, 'min_child_samples': 47, 'n_estimators': 101, 'learning_rate': 0.43139748817499246, 'subsample_for_bin': 409601, 'min_split_gain': 0.21106661175962055, 'min_child_weight': 0.01380469021530393, 'reg_alpha': 8.666097540769554, 'reg_lambda': 85.51182040768474}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,667] Trial 96 finished with value: 0.8733618330398003 and parameters: {'num_leaves': 138, 'min_child_samples': 48, 'n_estimators': 95, 'learning_rate': 0.493755480583966, 'subsample_for_bin': 409829, 'min_split_gain': 0.20723738256679763, 'min_child_weight': 0.006486005335844935, 'reg_alpha': 9.057540463779567, 'reg_lambda': 84.70300649462642}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,702] Trial 97 finished with value: 0.8679732959480692 and parameters: {'num_leaves': 139, 'min_child_samples': 48, 'n_estimators': 109, 'learning_rate': 0.4987587635842138, 'subsample_for_bin': 399762, 'min_split_gain': 0.21337110357489059, 'min_child_weight': 0.014670000277237485, 'reg_alpha': 8.779215939655447, 'reg_lambda': 84.3546535919996}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,739] Trial 98 finished with value: 0.8747727272727271 and parameters: {'num_leaves': 173, 'min_child_samples': 47, 'n_estimators': 71, 'learning_rate': 0.4932250735150931, 'subsample_for_bin': 395585, 'min_split_gain': 0.2511367256955955, 'min_child_weight': 0.006005381218872879, 'reg_alpha': 8.66223730542777, 'reg_lambda': 98.10717803360498}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,831] Trial 99 finished with value: 0.8699723692533041 and parameters: {'num_leaves': 169, 'min_child_samples': 47, 'n_estimators': 86, 'learning_rate': 0.4989014816186066, 'subsample_for_bin': 453356, 'min_split_gain': 0.2524087083010555, 'min_child_weight': 0.006857283384854449, 'reg_alpha': 8.67923591903254, 'reg_lambda': 97.47221381122516}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,885] Trial 100 finished with value: 0.8733788996077431 and parameters: {'num_leaves': 80, 'min_child_samples': 47, 'n_estimators': 748, 'learning_rate': 0.49745707811193507, 'subsample_for_bin': 419584, 'min_split_gain': 0.2534184724541777, 'min_child_weight': 0.014035096597847312, 'reg_alpha': 7.977858514653177, 'reg_lambda': 97.75699878227206}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,909] Trial 101 finished with value: 0.8705491834859665 and parameters: {'num_leaves': 74, 'min_child_samples': 31, 'n_estimators': 104, 'learning_rate': 0.49731741500815707, 'subsample_for_bin': 422516, 'min_split_gain': 0.19953061766071634, 'min_child_weight': 0.013540439544999783, 'reg_alpha': 8.278057118378706, 'reg_lambda': 94.19280802817752}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,943] Trial 102 finished with value: 0.8721501435013784 and parameters: {'num_leaves': 179, 'min_child_samples': 32, 'n_estimators': 120, 'learning_rate': 0.49185922493857787, 'subsample_for_bin': 396007, 'min_split_gain': 0.1970912061605653, 'min_child_weight': 0.013729453415215948, 'reg_alpha': 8.244429564352739, 'reg_lambda': 98.07072963058168}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:54,972] Trial 104 finished with value: 0.8640489990727324 and parameters: {'num_leaves': 75, 'min_child_samples': 47, 'n_estimators': 94, 'learning_rate': 0.49702405214115597, 'subsample_for_bin': 395495, 'min_split_gain': 0.20008524335022965, 'min_child_weight': 0.013760569967138418, 'reg_alpha': 7.760167917093961, 'reg_lambda': 93.44676126279944}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,022] Trial 103 finished with value: 0.8793148469789068 and parameters: {'num_leaves': 77, 'min_child_samples': 30, 'n_estimators': 66, 'learning_rate': 0.4979396511300315, 'subsample_for_bin': 397504, 'min_split_gain': 0.25366129405561455, 'min_child_weight': 0.014095308195033867, 'reg_alpha': 8.02174966691257, 'reg_lambda': 93.90249057422331}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,053] Trial 105 finished with value: 0.8852648376137404 and parameters: {'num_leaves': 69, 'min_child_samples': 46, 'n_estimators': 96, 'learning_rate': 0.4650068380809803, 'subsample_for_bin': 378736, 'min_split_gain': 0.25341548777614975, 'min_child_weight': 0.014691433583894718, 'reg_alpha': 0.4132720922438052, 'reg_lambda': 94.10750947037388}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,073] Trial 106 finished with value: 0.8843807386905951 and parameters: {'num_leaves': 76, 'min_child_samples': 31, 'n_estimators': 108, 'learning_rate': 0.4997400796958669, 'subsample_for_bin': 373949, 'min_split_gain': 0.20485391738047548, 'min_child_weight': 0.013793317911440112, 'reg_alpha': 0.3117573462695269, 'reg_lambda': 93.67253973472916}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,137] Trial 107 finished with value: 0.8820756019115331 and parameters: {'num_leaves': 84, 'min_child_samples': 46, 'n_estimators': 79, 'learning_rate': 0.4995831716649296, 'subsample_for_bin': 396749, 'min_split_gain': 0.19574180813135933, 'min_child_weight': 0.014216228877702373, 'reg_alpha': 1.179518927992227, 'reg_lambda': 93.94809812238411}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,192] Trial 109 finished with value: 0.8903410691398713 and parameters: {'num_leaves': 138, 'min_child_samples': 31, 'n_estimators': 230, 'learning_rate': 0.4955015791346009, 'subsample_for_bin': 375100, 'min_split_gain': 0.1995405475323835, 'min_child_weight': 0.008336723665551535, 'reg_alpha': 0.42420386600005733, 'reg_lambda': 94.15193935931515}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,237] Trial 108 finished with value: 0.8846258022728611 and parameters: {'num_leaves': 77, 'min_child_samples': 32, 'n_estimators': 683, 'learning_rate': 0.49942082726889153, 'subsample_for_bin': 89444, 'min_split_gain': 0.19802956922077747, 'min_child_weight': 0.013052235477748848, 'reg_alpha': 0.6625838527126948, 'reg_lambda': 94.77793510211919}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,265] Trial 111 finished with value: 0.8867642909920934 and parameters: {'num_leaves': 121, 'min_child_samples': 32, 'n_estimators': 694, 'learning_rate': 0.464693718972988, 'subsample_for_bin': 378138, 'min_split_gain': 0.19716170503373232, 'min_child_weight': 0.013190831132195139, 'reg_alpha': 0.11765194460776619, 'reg_lambda': 94.15198526873294}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,317] Trial 110 finished with value: 0.8864090416732421 and parameters: {'num_leaves': 119, 'min_child_samples': 32, 'n_estimators': 233, 'learning_rate': 0.49799999579745063, 'subsample_for_bin': 452808, 'min_split_gain': 0.2516931428243375, 'min_child_weight': 0.0130780732803818, 'reg_alpha': 0.6045749530983844, 'reg_lambda': 96.09456782548038}. Best is trial 78 with value: 0.8955868196448497.
# [I 2023-01-28 15:16:55,352] Trial 112 finished with value: 0.8897177140803268 and parameters: {'num_leaves': 120, 'min_child_samples': 31, 'n_estimators': 692, 'learning_rate': 0.46655011272346913, 'subsample_for_bin': 379406, 'min_split_gain': 0.1991969422319365, 'min_child_weight': 0.013078545101145863, 'reg_alpha': 0.17545800719373073, 'reg_lambda': 99.91306390530754}. Best is trial 78 with value: 0.8955868196448497.
# ...
# [I 2023-01-28 15:18:20,358] Trial 987 finished with value: 0.8771488555481591 and parameters: {'num_leaves': 136, 'min_child_samples': 46, 'n_estimators': 802, 'learning_rate': 0.3690813536615761, 'subsample_for_bin': 87226, 'min_split_gain': 0.19091861217761102, 'min_child_weight': 0.008530189018255103, 'reg_alpha': 0.1097484260494782, 'reg_lambda': 16.225876786615824}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:20,465] Trial 988 finished with value: 0.853965653707735 and parameters: {'num_leaves': 117, 'min_child_samples': 46, 'n_estimators': 727, 'learning_rate': 0.3922277756949709, 'subsample_for_bin': 98251, 'min_split_gain': 0.0971189458208207, 'min_child_weight': 0.09710277661079161, 'reg_alpha': 26.87499351739894, 'reg_lambda': 9.840020381486617}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:20,578] Trial 989 finished with value: 0.8866118442022056 and parameters: {'num_leaves': 135, 'min_child_samples': 46, 'n_estimators': 714, 'learning_rate': 0.3134478779138925, 'subsample_for_bin': 93635, 'min_split_gain': 0.18613372330992725, 'min_child_weight': 0.09258779189480577, 'reg_alpha': 1.9956002959702992, 'reg_lambda': 22.01960904039566}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:20,782] Trial 991 finished with value: 0.8941936565717602 and parameters: {'num_leaves': 144, 'min_child_samples': 31, 'n_estimators': 802, 'learning_rate': 0.3735774890949013, 'subsample_for_bin': 84742, 'min_split_gain': 0.09685225157060534, 'min_child_weight': 0.10643382676051018, 'reg_alpha': 2.609603623043804, 'reg_lambda': 45.77335656473173}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:20,843] Trial 990 finished with value: 0.883025320310121 and parameters: {'num_leaves': 173, 'min_child_samples': 46, 'n_estimators': 821, 'learning_rate': 0.4420146736706538, 'subsample_for_bin': 413051, 'min_split_gain': 0.23552588175434255, 'min_child_weight': 0.1354646696916198, 'reg_alpha': 2.963946311575832, 'reg_lambda': 10.857011199847122}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:21,103] Trial 992 finished with value: 0.8903073155188204 and parameters: {'num_leaves': 117, 'min_child_samples': 46, 'n_estimators': 611, 'learning_rate': 0.37425508916909606, 'subsample_for_bin': 80652, 'min_split_gain': 0.18557174802218743, 'min_child_weight': 0.10203424095430136, 'reg_alpha': 3.288795241858484, 'reg_lambda': 53.813256363602264}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:21,192] Trial 993 finished with value: 0.8932918116087087 and parameters: {'num_leaves': 136, 'min_child_samples': 44, 'n_estimators': 804, 'learning_rate': 0.4359856998407007, 'subsample_for_bin': 77308, 'min_split_gain': 0.23494785537616603, 'min_child_weight': 0.1426259672664585, 'reg_alpha': 3.1970644027577304, 'reg_lambda': 29.68546541343289}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:21,628] Trial 994 finished with value: 0.868027942253628 and parameters: {'num_leaves': 134, 'min_child_samples': 44, 'n_estimators': 720, 'learning_rate': 0.11703395603470848, 'subsample_for_bin': 97892, 'min_split_gain': 0.18926784685415246, 'min_child_weight': 0.02124873326526216, 'reg_alpha': 8.970628872439775, 'reg_lambda': 26.151468871423276}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:21,664] Trial 995 finished with value: 0.8785705784698413 and parameters: {'num_leaves': 144, 'min_child_samples': 32, 'n_estimators': 715, 'learning_rate': 0.42241295856894134, 'subsample_for_bin': 53228, 'min_split_gain': 0.20855315081090264, 'min_child_weight': 0.01152529231299166, 'reg_alpha': 9.36285752263778, 'reg_lambda': 3.124849216709751}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:21,879] Trial 996 finished with value: 0.8521465578809604 and parameters: {'num_leaves': 116, 'min_child_samples': 44, 'n_estimators': 761, 'learning_rate': 0.4389064775799979, 'subsample_for_bin': 78054, 'min_split_gain': 0.10884012649399308, 'min_child_weight': 0.024331568401305015, 'reg_alpha': 17.233628189375327, 'reg_lambda': 32.751912411384104}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,011] Trial 998 finished with value: 0.8418894380328231 and parameters: {'num_leaves': 119, 'min_child_samples': 17, 'n_estimators': 175, 'learning_rate': 0.03423792472666545, 'subsample_for_bin': 413799, 'min_split_gain': 0.41563783619418543, 'min_child_weight': 0.11031120579928341, 'reg_alpha': 36.64022512196833, 'reg_lambda': 52.55672802207165}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,052] Trial 997 finished with value: 0.8661315787199899 and parameters: {'num_leaves': 135, 'min_child_samples': 14, 'n_estimators': 725, 'learning_rate': 0.39424730204119535, 'subsample_for_bin': 101146, 'min_split_gain': 0.471062299894864, 'min_child_weight': 0.10722451261164793, 'reg_alpha': 9.643649829839898, 'reg_lambda': 28.597280025887855}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,253] Trial 999 finished with value: 0.8443932297393401 and parameters: {'num_leaves': 135, 'min_child_samples': 40, 'n_estimators': 610, 'learning_rate': 0.44064497520932144, 'subsample_for_bin': 412044, 'min_split_gain': 0.06403503761842949, 'min_child_weight': 0.07956777174858765, 'reg_alpha': 36.73758069349419, 'reg_lambda': 24.309027981301735}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,378] Trial 1000 finished with value: 0.8404582265806756 and parameters: {'num_leaves': 15, 'min_child_samples': 31, 'n_estimators': 606, 'learning_rate': 0.13765303948600235, 'subsample_for_bin': 77424, 'min_split_gain': 0.2334494366584969, 'min_child_weight': 0.10862123318197728, 'reg_alpha': 51.633194305982855, 'reg_lambda': 30.950821171592477}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,502] Trial 1001 finished with value: 0.7094666233906741 and parameters: {'num_leaves': 134, 'min_child_samples': 44, 'n_estimators': 764, 'learning_rate': 0.4672171232972307, 'subsample_for_bin': 91493, 'min_split_gain': 0.23275213414578894, 'min_child_weight': 0.11499586992851155, 'reg_alpha': 99.79527383526971, 'reg_lambda': 22.94144061817657}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,699] Trial 1003 finished with value: 0.7828845481837741 and parameters: {'num_leaves': 116, 'min_child_samples': 44, 'n_estimators': 836, 'learning_rate': 0.38533713623642707, 'subsample_for_bin': 92625, 'min_split_gain': 0.10721846635653853, 'min_child_weight': 0.10801534959842851, 'reg_alpha': 73.94504496409883, 'reg_lambda': 51.50466103871603}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,816] Trial 1002 finished with value: 0.8859602402940164 and parameters: {'num_leaves': 63, 'min_child_samples': 44, 'n_estimators': 170, 'learning_rate': 0.36180196758574307, 'subsample_for_bin': 100765, 'min_split_gain': 0.11516296454415303, 'min_child_weight': 0.14374440293849483, 'reg_alpha': 5.53132264936746, 'reg_lambda': 20.123132981055097}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:22,927] Trial 1004 finished with value: 0.7098249219899119 and parameters: {'num_leaves': 105, 'min_child_samples': 47, 'n_estimators': 824, 'learning_rate': 0.38352160067129687, 'subsample_for_bin': 78160, 'min_split_gain': 0.09692273997210829, 'min_child_weight': 0.14379856148707104, 'reg_alpha': 81.26149426098321, 'reg_lambda': 45.977245503321015}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:23,088] Trial 1005 finished with value: 0.7093638862009589 and parameters: {'num_leaves': 144, 'min_child_samples': 31, 'n_estimators': 763, 'learning_rate': 0.384410033291395, 'subsample_for_bin': 76509, 'min_split_gain': 0.12070105644210609, 'min_child_weight': 0.1458250420262463, 'reg_alpha': 95.80144684391354, 'reg_lambda': 46.224484678535774}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:23,373] Trial 1006 finished with value: 0.7796731301318457 and parameters: {'num_leaves': 141, 'min_child_samples': 32, 'n_estimators': 834, 'learning_rate': 0.4306044601961142, 'subsample_for_bin': 79705, 'min_split_gain': 0.09071553310041376, 'min_child_weight': 0.14546633596608963, 'reg_alpha': 72.05418780315286, 'reg_lambda': 35.04733110209973}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:23,400] Trial 1007 finished with value: 0.8890496971498022 and parameters: {'num_leaves': 139, 'min_child_samples': 40, 'n_estimators': 815, 'learning_rate': 0.43300551440733104, 'subsample_for_bin': 72076, 'min_split_gain': 0.07849076668894067, 'min_child_weight': 0.1427448921958371, 'reg_alpha': 5.73480696404976, 'reg_lambda': 47.40854816896311}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:23,568] Trial 1008 finished with value: 0.8845962905595934 and parameters: {'num_leaves': 143, 'min_child_samples': 44, 'n_estimators': 612, 'learning_rate': 0.4271147680377934, 'subsample_for_bin': 77792, 'min_split_gain': 0.11882378423121394, 'min_child_weight': 0.1462700295785001, 'reg_alpha': 5.656118634338469, 'reg_lambda': 25.42397631731524}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:23,740] Trial 1009 finished with value: 0.8775444181241282 and parameters: {'num_leaves': 142, 'min_child_samples': 44, 'n_estimators': 837, 'learning_rate': 0.43721412369931134, 'subsample_for_bin': 76776, 'min_split_gain': 0.10564427417595104, 'min_child_weight': 0.13651646241872628, 'reg_alpha': 5.166525924666414, 'reg_lambda': 38.495233947365044}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,212] Trial 1012 finished with value: 0.8350321807560416 and parameters: {'num_leaves': 144, 'min_child_samples': 30, 'n_estimators': 856, 'learning_rate': 0.4021555786961375, 'subsample_for_bin': 73275, 'min_split_gain': 0.06369856413356446, 'min_child_weight': 0.14746123276127163, 'reg_alpha': 48.44663996127076, 'reg_lambda': 15.921243963710772}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,222] Trial 1010 finished with value: 0.8816336961567147 and parameters: {'num_leaves': 146, 'min_child_samples': 44, 'n_estimators': 841, 'learning_rate': 0.3510702520146029, 'subsample_for_bin': 82299, 'min_split_gain': 0.10501642220550386, 'min_child_weight': 0.11778545424172103, 'reg_alpha': 4.359827928483172, 'reg_lambda': 18.468777396388596}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,257] Trial 1011 finished with value: 0.8831560317190384 and parameters: {'num_leaves': 144, 'min_child_samples': 32, 'n_estimators': 828, 'learning_rate': 0.3598398599059999, 'subsample_for_bin': 79714, 'min_split_gain': 0.07684841957755845, 'min_child_weight': 0.11927612624500261, 'reg_alpha': 4.461070227171522, 'reg_lambda': 20.713046865442777}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,388] Trial 1014 finished with value: 0.8423824239412502 and parameters: {'num_leaves': 140, 'min_child_samples': 30, 'n_estimators': 852, 'learning_rate': 0.38586169034609497, 'subsample_for_bin': 73581, 'min_split_gain': 0.08778376622070774, 'min_child_weight': 0.07394935119343754, 'reg_alpha': 49.398312299587595, 'reg_lambda': 19.586354984641723}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,402] Trial 1015 finished with value: 0.8805617483237412 and parameters: {'num_leaves': 146, 'min_child_samples': 31, 'n_estimators': 829, 'learning_rate': 0.4333853377665749, 'subsample_for_bin': 67073, 'min_split_gain': 0.0464640707487019, 'min_child_weight': 0.1378052237827965, 'reg_alpha': 3.7297582758029564, 'reg_lambda': 20.418358151637953}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,405] Trial 1013 finished with value: 0.8354720666777404 and parameters: {'num_leaves': 142, 'min_child_samples': 44, 'n_estimators': 837, 'learning_rate': 0.36173440292649844, 'subsample_for_bin': 77572, 'min_split_gain': 0.09426547354451431, 'min_child_weight': 0.10001873039226206, 'reg_alpha': 68.62965894851646, 'reg_lambda': 35.92966496839223}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,459] Trial 1016 finished with value: 0.8793442049723169 and parameters: {'num_leaves': 147, 'min_child_samples': 44, 'n_estimators': 814, 'learning_rate': 0.35146892881738706, 'subsample_for_bin': 84379, 'min_split_gain': 0.07734064456265684, 'min_child_weight': 0.09764572659885691, 'reg_alpha': 4.163445258857253, 'reg_lambda': 18.408096393905318}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,478] Trial 1017 finished with value: 0.8805011527727219 and parameters: {'num_leaves': 142, 'min_child_samples': 27, 'n_estimators': 833, 'learning_rate': 0.34886327025341224, 'subsample_for_bin': 81129, 'min_split_gain': 0.10034487207840817, 'min_child_weight': 0.14956879549098817, 'reg_alpha': 3.8424517849318636, 'reg_lambda': 39.79708090047477}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,538] Trial 1021 finished with value: 0.8489934603744018 and parameters: {'num_leaves': 140, 'min_child_samples': 30, 'n_estimators': 860, 'learning_rate': 0.44193062690576784, 'subsample_for_bin': 88639, 'min_split_gain': 0.04396234378205842, 'min_child_weight': 0.14783542870090494, 'reg_alpha': 24.637134516465075, 'reg_lambda': 42.51066405626193}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,540] Trial 1020 finished with value: 0.8321962705419578 and parameters: {'num_leaves': 139, 'min_child_samples': 27, 'n_estimators': 842, 'learning_rate': 0.3460170089177688, 'subsample_for_bin': 101996, 'min_split_gain': 0.13690393634023282, 'min_child_weight': 0.1488319686330878, 'reg_alpha': 66.7991007049271, 'reg_lambda': 50.05343127355274}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,543] Trial 1019 finished with value: 0.8860822131658653 and parameters: {'num_leaves': 146, 'min_child_samples': 44, 'n_estimators': 809, 'learning_rate': 0.3483378385402333, 'subsample_for_bin': 87325, 'min_split_gain': 0.26734598830956907, 'min_child_weight': 0.10077035258582458, 'reg_alpha': 7.235743905901314, 'reg_lambda': 29.181945877014048}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,544] Trial 1018 finished with value: 0.8803670927564733 and parameters: {'num_leaves': 145, 'min_child_samples': 35, 'n_estimators': 808, 'learning_rate': 0.3506959919112083, 'subsample_for_bin': 62501, 'min_split_gain': 0.08576707146880855, 'min_child_weight': 0.1169213002474304, 'reg_alpha': 7.819641699520132, 'reg_lambda': 44.3505177692673}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,564] Trial 1022 finished with value: 0.8518809067232972 and parameters: {'num_leaves': 141, 'min_child_samples': 35, 'n_estimators': 819, 'learning_rate': 0.3466002910812014, 'subsample_for_bin': 65113, 'min_split_gain': 0.0914087602206616, 'min_child_weight': 0.12531986088390976, 'reg_alpha': 27.32310663998137, 'reg_lambda': 43.509068287679646}. Best is trial 342 with value: 0.8960280287803327.
# [I 2023-01-28 15:18:24,566] Trial 1023 finished with value: 0.7883642044932367 and parameters: {'num_leaves': 146, 'min_child_samples': 30, 'n_estimators': 817, 'learning_rate': 0.1460084539161215, 'subsample_for_bin': 87830, 'min_split_gain': 0.13816767382186135, 'min_child_weight': 0.1486537186392373, 'reg_alpha': 75.74584372969359, 'reg_lambda': 30.778711047434893}. Best is trial 342 with value: 0.8960280287803327.
# F1 Score: 0.8960280287803327
# Best hyperparameters: {'num_leaves': 167, 'min_child_samples': 44, 'n_estimators': 565, 'learning_rate': 0.4009220084820603, 'subsample_for_bin': 114830, 'min_split_gain': 0.21158523780523883, 'min_child_weight': 0.07766367154473436, 'reg_alpha': 0.025288096921344067, 'reg_lambda': 51.919326856985634}

# %% [markdown]
# ### AUC

# %%
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_fruit, y_fruit, n_jobs=-1, scoring='roc_auc', cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)

trial = study.best_trial

print('AUC: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))

tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

tracking_Optuna_AUC = tracking

plt.plot(tracking);
#plt.plot(tracking_sorted)
# Out:
# [I 2023-01-28 15:19:48,594] A new study created in memory with name: no-name-5b0bccad-7fd5-4491-b97f-e33fbb6ddfe4
# [I 2023-01-28 15:19:48,646] Trial 2 finished with value: 0.9288130624393022 and parameters: {'num_leaves': 33, 'min_child_samples': 49, 'n_estimators': 278, 'learning_rate': 0.424291733087443, 'subsample_for_bin': 189145, 'min_split_gain': 0.28579572967383216, 'min_child_weight': 0.06875492471306964, 'reg_alpha': 2.8429156820473334, 'reg_lambda': 85.46591415321707}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,669] Trial 4 finished with value: 0.9257146517600693 and parameters: {'num_leaves': 132, 'min_child_samples': 36, 'n_estimators': 205, 'learning_rate': 0.23578258742175562, 'subsample_for_bin': 216864, 'min_split_gain': 0.13828248482259384, 'min_child_weight': 0.06184005410331746, 'reg_alpha': 7.676566804040976, 'reg_lambda': 16.215323839541504}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,692] Trial 7 finished with value: 0.8162818469526253 and parameters: {'num_leaves': 75, 'min_child_samples': 44, 'n_estimators': 367, 'learning_rate': 0.17329234548528902, 'subsample_for_bin': 172690, 'min_split_gain': 0.1782564858512074, 'min_child_weight': 0.03701675842951858, 'reg_alpha': 64.53066442033352, 'reg_lambda': 19.690033375624637}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,697] Trial 0 finished with value: 0.813103105136257 and parameters: {'num_leaves': 74, 'min_child_samples': 40, 'n_estimators': 870, 'learning_rate': 0.031721159261394204, 'subsample_for_bin': 223447, 'min_split_gain': 0.4772219274717297, 'min_child_weight': 0.14297918906530957, 'reg_alpha': 70.0481330620216, 'reg_lambda': 78.60546289339487}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,697] Trial 1 finished with value: 0.9239833250330619 and parameters: {'num_leaves': 80, 'min_child_samples': 11, 'n_estimators': 195, 'learning_rate': 0.23292286884923888, 'subsample_for_bin': 233644, 'min_split_gain': 0.4076057030283788, 'min_child_weight': 0.002544193341471858, 'reg_alpha': 7.726248702683978, 'reg_lambda': 17.12747622976157}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,704] Trial 8 finished with value: 0.9019702232104737 and parameters: {'num_leaves': 72, 'min_child_samples': 14, 'n_estimators': 730, 'learning_rate': 0.11578315569445838, 'subsample_for_bin': 446116, 'min_split_gain': 0.348434076208253, 'min_child_weight': 0.08854596007609723, 'reg_alpha': 23.474485179532703, 'reg_lambda': 64.51692451465242}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,707] Trial 9 finished with value: 0.8995477171463229 and parameters: {'num_leaves': 15, 'min_child_samples': 24, 'n_estimators': 54, 'learning_rate': 0.42856644014842354, 'subsample_for_bin': 319566, 'min_split_gain': 0.11089766366524216, 'min_child_weight': 0.005583754309612228, 'reg_alpha': 24.579020629283296, 'reg_lambda': 92.9715523585471}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,729] Trial 3 finished with value: 0.8127068299215897 and parameters: {'num_leaves': 115, 'min_child_samples': 43, 'n_estimators': 638, 'learning_rate': 0.2506974801879416, 'subsample_for_bin': 264440, 'min_split_gain': 0.39264568769759906, 'min_child_weight': 0.12097451120963966, 'reg_alpha': 70.29181441930183, 'reg_lambda': 51.710475479115665}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,740] Trial 6 finished with value: 0.9142927369013737 and parameters: {'num_leaves': 196, 'min_child_samples': 23, 'n_estimators': 379, 'learning_rate': 0.4274856333095277, 'subsample_for_bin': 262880, 'min_split_gain': 0.34829841701743236, 'min_child_weight': 0.09105072232627391, 'reg_alpha': 10.609783426958689, 'reg_lambda': 77.84702310181144}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,757] Trial 18 finished with value: 0.8132063875509977 and parameters: {'num_leaves': 11, 'min_child_samples': 31, 'n_estimators': 276, 'learning_rate': 0.1855503220512612, 'subsample_for_bin': 153998, 'min_split_gain': 0.30009293964250183, 'min_child_weight': 0.03957801796117005, 'reg_alpha': 76.30887222876724, 'reg_lambda': 64.89853552204941}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,759] Trial 12 finished with value: 0.8425878460248136 and parameters: {'num_leaves': 185, 'min_child_samples': 24, 'n_estimators': 796, 'learning_rate': 0.3291555108063433, 'subsample_for_bin': 340453, 'min_split_gain': 0.1543062921424117, 'min_child_weight': 0.12000086623393412, 'reg_alpha': 59.08329401543402, 'reg_lambda': 50.32869343762949}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,760] Trial 17 finished with value: 0.9097900436168923 and parameters: {'num_leaves': 32, 'min_child_samples': 25, 'n_estimators': 201, 'learning_rate': 0.19914701023134518, 'subsample_for_bin': 126351, 'min_split_gain': 0.010372807146419588, 'min_child_weight': 0.03270032076204718, 'reg_alpha': 0.2681589002207419, 'reg_lambda': 0.6735473311516847}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,760] Trial 14 finished with value: 0.812779657690985 and parameters: {'num_leaves': 196, 'min_child_samples': 41, 'n_estimators': 761, 'learning_rate': 0.38440593831356074, 'subsample_for_bin': 265597, 'min_split_gain': 0.24493395661324843, 'min_child_weight': 0.004555513734982415, 'reg_alpha': 90.56309595873363, 'reg_lambda': 57.18781867571369}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,761] Trial 5 finished with value: 0.8127226650060738 and parameters: {'num_leaves': 177, 'min_child_samples': 13, 'n_estimators': 836, 'learning_rate': 0.013757008699272637, 'subsample_for_bin': 332048, 'min_split_gain': 0.44938987767310357, 'min_child_weight': 0.07840468730822707, 'reg_alpha': 92.24906578650588, 'reg_lambda': 53.65329609868926}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,762] Trial 13 finished with value: 0.8132985992252348 and parameters: {'num_leaves': 136, 'min_child_samples': 25, 'n_estimators': 619, 'learning_rate': 0.0799060052795009, 'subsample_for_bin': 462986, 'min_split_gain': 0.2661329025574145, 'min_child_weight': 0.031681229034677, 'reg_alpha': 94.94169134006884, 'reg_lambda': 88.7135446229362}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,763] Trial 11 finished with value: 0.8973491310796918 and parameters: {'num_leaves': 22, 'min_child_samples': 36, 'n_estimators': 179, 'learning_rate': 0.03760586704857898, 'subsample_for_bin': 240928, 'min_split_gain': 0.18054050367495889, 'min_child_weight': 0.0692777228960064, 'reg_alpha': 27.721766032600833, 'reg_lambda': 17.250704734540186}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,765] Trial 15 finished with value: 0.9019389180653158 and parameters: {'num_leaves': 71, 'min_child_samples': 16, 'n_estimators': 725, 'learning_rate': 0.39138517676060447, 'subsample_for_bin': 125567, 'min_split_gain': 0.04420221266174405, 'min_child_weight': 0.07861194436308558, 'reg_alpha': 32.56408943168537, 'reg_lambda': 29.86844098326879}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,765] Trial 10 finished with value: 0.9133913191326796 and parameters: {'num_leaves': 177, 'min_child_samples': 35, 'n_estimators': 398, 'learning_rate': 0.07873040127716292, 'subsample_for_bin': 113859, 'min_split_gain': 0.02049241944857709, 'min_child_weight': 0.00780976723950419, 'reg_alpha': 14.175187738329212, 'reg_lambda': 48.44861631387076}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,766] Trial 16 finished with value: 0.8702421074187487 and parameters: {'num_leaves': 171, 'min_child_samples': 40, 'n_estimators': 83, 'learning_rate': 0.4494343532855941, 'subsample_for_bin': 280360, 'min_split_gain': 0.2205280521907241, 'min_child_weight': 0.04807850901396377, 'reg_alpha': 51.915742543589225, 'reg_lambda': 52.369518520960035}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:48,856] Trial 23 finished with value: 0.8991469204361519 and parameters: {'num_leaves': 25, 'min_child_samples': 14, 'n_estimators': 73, 'learning_rate': 0.4108370981865938, 'subsample_for_bin': 439192, 'min_split_gain': 0.06199131547176376, 'min_child_weight': 0.11084916325465038, 'reg_alpha': 32.10445153740637, 'reg_lambda': 63.20476974721028}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,043] Trial 19 finished with value: 0.8201832679644238 and parameters: {'num_leaves': 193, 'min_child_samples': 34, 'n_estimators': 185, 'learning_rate': 0.14850752276347118, 'subsample_for_bin': 457437, 'min_split_gain': 0.16102734209481565, 'min_child_weight': 0.10662932075653812, 'reg_alpha': 72.31710870358067, 'reg_lambda': 61.38172047687684}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,083] Trial 20 finished with value: 0.8125907604631167 and parameters: {'num_leaves': 160, 'min_child_samples': 39, 'n_estimators': 560, 'learning_rate': 0.28429869458965323, 'subsample_for_bin': 105384, 'min_split_gain': 0.10344964316433086, 'min_child_weight': 0.06957640923946018, 'reg_alpha': 86.92013079843822, 'reg_lambda': 50.540259501611665}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,104] Trial 26 finished with value: 0.8897620341463884 and parameters: {'num_leaves': 149, 'min_child_samples': 50, 'n_estimators': 504, 'learning_rate': 0.49501876156354624, 'subsample_for_bin': 54365, 'min_split_gain': 0.10844625083463319, 'min_child_weight': 0.0632660572851721, 'reg_alpha': 38.98389626153256, 'reg_lambda': 37.12239970232675}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,084] Trial 21 finished with value: 0.8122938779155257 and parameters: {'num_leaves': 136, 'min_child_samples': 10, 'n_estimators': 665, 'learning_rate': 0.3060668246385879, 'subsample_for_bin': 307683, 'min_split_gain': 0.12427258676492127, 'min_child_weight': 0.011414782132246084, 'reg_alpha': 77.34648310095251, 'reg_lambda': 68.08577910331358}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,092] Trial 24 finished with value: 0.8660866457336835 and parameters: {'num_leaves': 187, 'min_child_samples': 21, 'n_estimators': 168, 'learning_rate': 0.3773601338495806, 'subsample_for_bin': 311521, 'min_split_gain': 0.022594243748363448, 'min_child_weight': 0.14931625221828287, 'reg_alpha': 46.21185723580965, 'reg_lambda': 32.09187858379193}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,093] Trial 25 finished with value: 0.8888457718927466 and parameters: {'num_leaves': 151, 'min_child_samples': 50, 'n_estimators': 498, 'learning_rate': 0.3083094173909814, 'subsample_for_bin': 78021, 'min_split_gain': 0.12493383300856298, 'min_child_weight': 0.05984619856550801, 'reg_alpha': 37.33991277353409, 'reg_lambda': 39.59068848145678}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,122] Trial 28 finished with value: 0.8905950216970809 and parameters: {'num_leaves': 139, 'min_child_samples': 50, 'n_estimators': 993, 'learning_rate': 0.47860786946304934, 'subsample_for_bin': 55926, 'min_split_gain': 0.09848590687568523, 'min_child_weight': 0.06886177146311509, 'reg_alpha': 41.743953182380906, 'reg_lambda': 36.587940470944616}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,084] Trial 22 finished with value: 0.8130042369615719 and parameters: {'num_leaves': 179, 'min_child_samples': 22, 'n_estimators': 732, 'learning_rate': 0.32361120611976185, 'subsample_for_bin': 408532, 'min_split_gain': 0.40656991265219583, 'min_child_weight': 0.05749635218772123, 'reg_alpha': 92.43003460710062, 'reg_lambda': 68.15653814843029}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,131] Trial 30 finished with value: 0.8903331206855566 and parameters: {'num_leaves': 147, 'min_child_samples': 49, 'n_estimators': 456, 'learning_rate': 0.4997071136677201, 'subsample_for_bin': 56094, 'min_split_gain': 0.11890313159164395, 'min_child_weight': 0.060446885611850826, 'reg_alpha': 36.60032817162383, 'reg_lambda': 98.25601614522114}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,132] Trial 27 finished with value: 0.8904491055249307 and parameters: {'num_leaves': 145, 'min_child_samples': 46, 'n_estimators': 524, 'learning_rate': 0.48006751277767445, 'subsample_for_bin': 54807, 'min_split_gain': 0.08694244717469579, 'min_child_weight': 0.062303290501975014, 'reg_alpha': 39.397904272247075, 'reg_lambda': 98.27435603915302}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,197] Trial 31 finished with value: 0.8820668389080746 and parameters: {'num_leaves': 133, 'min_child_samples': 49, 'n_estimators': 970, 'learning_rate': 0.4707729609395757, 'subsample_for_bin': 62822, 'min_split_gain': 0.10510433229419655, 'min_child_weight': 0.05677542487232557, 'reg_alpha': 42.437817877284346, 'reg_lambda': 97.62528088470329}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,255] Trial 29 finished with value: 0.9276118643767011 and parameters: {'num_leaves': 145, 'min_child_samples': 48, 'n_estimators': 974, 'learning_rate': 0.3136124855027047, 'subsample_for_bin': 81060, 'min_split_gain': 0.09924829897979792, 'min_child_weight': 0.0648332482562877, 'reg_alpha': 1.5220060123590475, 'reg_lambda': 38.687270163066245}. Best is trial 2 with value: 0.9288130624393022.
# [I 2023-01-28 15:19:49,277] Trial 33 finished with value: 0.9337030212983435 and parameters: {'num_leaves': 138, 'min_child_samples': 50, 'n_estimators': 510, 'learning_rate': 0.4940825032069996, 'subsample_for_bin': 61314, 'min_split_gain': 0.09781765800429215, 'min_child_weight': 0.057719330234985475, 'reg_alpha': 0.35821487031152355, 'reg_lambda': 97.00766182817863}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,290] Trial 32 finished with value: 0.8879281452059681 and parameters: {'num_leaves': 141, 'min_child_samples': 49, 'n_estimators': 500, 'learning_rate': 0.3185261037105385, 'subsample_for_bin': 53709, 'min_split_gain': 0.11576222894825589, 'min_child_weight': 0.05892623001385077, 'reg_alpha': 41.12009460876352, 'reg_lambda': 99.10458788933501}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,333] Trial 35 finished with value: 0.8788545925275439 and parameters: {'num_leaves': 150, 'min_child_samples': 48, 'n_estimators': 494, 'learning_rate': 0.49293159978048284, 'subsample_for_bin': 57181, 'min_split_gain': 0.1082656421446033, 'min_child_weight': 0.05960376425987288, 'reg_alpha': 44.290395618783066, 'reg_lambda': 98.49153707262275}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,397] Trial 36 finished with value: 0.9325863602787733 and parameters: {'num_leaves': 46, 'min_child_samples': 49, 'n_estimators': 446, 'learning_rate': 0.2725688993951858, 'subsample_for_bin': 55950, 'min_split_gain': 0.2905830862329343, 'min_child_weight': 0.05600832762611478, 'reg_alpha': 0.12027289520889894, 'reg_lambda': 35.56639182853894}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,409] Trial 34 finished with value: 0.8908196816653584 and parameters: {'num_leaves': 149, 'min_child_samples': 48, 'n_estimators': 999, 'learning_rate': 0.4806252495835337, 'subsample_for_bin': 56369, 'min_split_gain': 0.10047211567878166, 'min_child_weight': 0.05925696728469896, 'reg_alpha': 40.71467321617049, 'reg_lambda': 38.114553233285164}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,634] Trial 39 finished with value: 0.9276141750032766 and parameters: {'num_leaves': 50, 'min_child_samples': 28, 'n_estimators': 300, 'learning_rate': 0.22125542157003686, 'subsample_for_bin': 183751, 'min_split_gain': 0.06923700243121654, 'min_child_weight': 0.08042860346790498, 'reg_alpha': 0.21935851218237623, 'reg_lambda': 85.76519252921318}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,637] Trial 38 finished with value: 0.9306644373739976 and parameters: {'num_leaves': 44, 'min_child_samples': 28, 'n_estimators': 298, 'learning_rate': 0.23706870877076408, 'subsample_for_bin': 196427, 'min_split_gain': 0.07488226871418266, 'min_child_weight': 0.04767128946989247, 'reg_alpha': 0.40865033726946776, 'reg_lambda': 84.12290922368034}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,648] Trial 41 finished with value: 0.9271679954821029 and parameters: {'num_leaves': 44, 'min_child_samples': 27, 'n_estimators': 290, 'learning_rate': 0.21602848366420366, 'subsample_for_bin': 193167, 'min_split_gain': 0.0681918419894527, 'min_child_weight': 0.04843686626820229, 'reg_alpha': 2.9518051395713605, 'reg_lambda': 82.21699465188442}. Best is trial 33 with value: 0.9337030212983435.
# [I 2023-01-28 15:19:49,651] Trial 40 finished with value: 0.9381958061859166 and parameters: {'num_leaves': 44, 'min_child_samples': 29, 'n_estimators': 306, 'learning_rate': 0.23150892243019722, 'subsample_for_bin': 196856, 'min_split_gain': 0.062294206893920026, 'min_child_weight': 0.07704742554056895, 'reg_alpha': 1.6670248318424967, 'reg_lambda': 84.89861646856632}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,721] Trial 42 finished with value: 0.9296693757199086 and parameters: {'num_leaves': 49, 'min_child_samples': 29, 'n_estimators': 299, 'learning_rate': 0.22924526163441183, 'subsample_for_bin': 182240, 'min_split_gain': 0.19442719473821374, 'min_child_weight': 0.04611356620026192, 'reg_alpha': 0.18118616496166928, 'reg_lambda': 84.44518930169029}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,734] Trial 46 finished with value: 0.9285520240174399 and parameters: {'num_leaves': 48, 'min_child_samples': 30, 'n_estimators': 277, 'learning_rate': 0.34940680261287066, 'subsample_for_bin': 197408, 'min_split_gain': 0.06996073080964473, 'min_child_weight': 0.04747602999013092, 'reg_alpha': 1.1045872492026956, 'reg_lambda': 86.70007933226245}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,770] Trial 43 finished with value: 0.9300185992571987 and parameters: {'num_leaves': 48, 'min_child_samples': 29, 'n_estimators': 295, 'learning_rate': 0.22837668889008023, 'subsample_for_bin': 211997, 'min_split_gain': 0.057873026956812346, 'min_child_weight': 0.04841216455885203, 'reg_alpha': 0.6525583559446415, 'reg_lambda': 79.78139593152828}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,794] Trial 37 finished with value: 0.9306045449904453 and parameters: {'num_leaves': 52, 'min_child_samples': 28, 'n_estimators': 275, 'learning_rate': 0.23026957782668234, 'subsample_for_bin': 185975, 'min_split_gain': 0.06005460683431607, 'min_child_weight': 0.0495081561585297, 'reg_alpha': 0.08634272930949358, 'reg_lambda': 88.37523646491056}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,832] Trial 44 finished with value: 0.9319002117515445 and parameters: {'num_leaves': 46, 'min_child_samples': 30, 'n_estimators': 296, 'learning_rate': 0.24331588829843276, 'subsample_for_bin': 185402, 'min_split_gain': 0.053617089324139375, 'min_child_weight': 0.048408568941148304, 'reg_alpha': 1.0867547990662647, 'reg_lambda': 84.47924722360887}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,851] Trial 45 finished with value: 0.9271594401662382 and parameters: {'num_leaves': 46, 'min_child_samples': 29, 'n_estimators': 295, 'learning_rate': 0.25402965727950483, 'subsample_for_bin': 200634, 'min_split_gain': 0.059570553938387553, 'min_child_weight': 0.04781059971899285, 'reg_alpha': 4.0957828448762275, 'reg_lambda': 82.08930231486742}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,871] Trial 48 finished with value: 0.928781690769394 and parameters: {'num_leaves': 114, 'min_child_samples': 46, 'n_estimators': 291, 'learning_rate': 0.3576040941494418, 'subsample_for_bin': 168746, 'min_split_gain': 0.20873616186372665, 'min_child_weight': 0.049009724531314455, 'reg_alpha': 1.1805568102190716, 'reg_lambda': 85.38457005133687}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,890] Trial 47 finished with value: 0.9320867069693266 and parameters: {'num_leaves': 105, 'min_child_samples': 46, 'n_estimators': 297, 'learning_rate': 0.24815699618145975, 'subsample_for_bin': 185174, 'min_split_gain': 0.19770245119717333, 'min_child_weight': 0.04797007262534641, 'reg_alpha': 0.9203135518199226, 'reg_lambda': 85.31646676811076}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,939] Trial 49 finished with value: 0.9350044504314613 and parameters: {'num_leaves': 112, 'min_child_samples': 45, 'n_estimators': 291, 'learning_rate': 0.24422717447342834, 'subsample_for_bin': 186272, 'min_split_gain': 0.21369669597483956, 'min_child_weight': 0.04748187596216117, 'reg_alpha': 0.7727445296360386, 'reg_lambda': 85.3300672726816}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:49,988] Trial 52 finished with value: 0.932964011863821 and parameters: {'num_leaves': 112, 'min_child_samples': 45, 'n_estimators': 405, 'learning_rate': 0.3665992432848199, 'subsample_for_bin': 188987, 'min_split_gain': 0.21389686634089372, 'min_child_weight': 0.04794790518829416, 'reg_alpha': 0.30646270156684197, 'reg_lambda': 84.17516386253521}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,025] Trial 50 finished with value: 0.9350120934699837 and parameters: {'num_leaves': 107, 'min_child_samples': 45, 'n_estimators': 265, 'learning_rate': 0.3598244060694749, 'subsample_for_bin': 177036, 'min_split_gain': 0.20285015275948384, 'min_child_weight': 0.04814283023741057, 'reg_alpha': 0.7093838854621212, 'reg_lambda': 82.20944055025606}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,059] Trial 51 finished with value: 0.9235099785533712 and parameters: {'num_leaves': 47, 'min_child_samples': 45, 'n_estimators': 315, 'learning_rate': 0.3513314384462449, 'subsample_for_bin': 180959, 'min_split_gain': 0.20484134290779396, 'min_child_weight': 0.04698399357253535, 'reg_alpha': 6.868220181949416, 'reg_lambda': 77.70617861612561}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,100] Trial 53 finished with value: 0.9172186671677629 and parameters: {'num_leaves': 109, 'min_child_samples': 45, 'n_estimators': 424, 'learning_rate': 0.25624043793335544, 'subsample_for_bin': 163024, 'min_split_gain': 0.19741281971495445, 'min_child_weight': 0.07402861767182145, 'reg_alpha': 8.976354805231137, 'reg_lambda': 74.64874227731681}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,129] Trial 54 finished with value: 0.9217344676371019 and parameters: {'num_leaves': 108, 'min_child_samples': 45, 'n_estimators': 425, 'learning_rate': 0.2543366643204349, 'subsample_for_bin': 150423, 'min_split_gain': 0.038209548370339505, 'min_child_weight': 0.07608266913670939, 'reg_alpha': 10.686489408219547, 'reg_lambda': 75.85221837437845}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,176] Trial 56 finished with value: 0.9173924477053634 and parameters: {'num_leaves': 104, 'min_child_samples': 45, 'n_estimators': 417, 'learning_rate': 0.2798051482756099, 'subsample_for_bin': 154225, 'min_split_gain': 0.0508866690541452, 'min_child_weight': 0.07115527002701737, 'reg_alpha': 10.694036813014264, 'reg_lambda': 75.18920582960745}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,215] Trial 55 finished with value: 0.9183692701153205 and parameters: {'num_leaves': 102, 'min_child_samples': 44, 'n_estimators': 421, 'learning_rate': 0.24970268057818723, 'subsample_for_bin': 155575, 'min_split_gain': 0.0371878536563125, 'min_child_weight': 0.07382750245242059, 'reg_alpha': 9.419195024396421, 'reg_lambda': 75.87845235349599}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,235] Trial 57 finished with value: 0.9134699621014043 and parameters: {'num_leaves': 59, 'min_child_samples': 32, 'n_estimators': 416, 'learning_rate': 0.2539908785430092, 'subsample_for_bin': 159593, 'min_split_gain': 0.03967630028970902, 'min_child_weight': 0.07474766376043138, 'reg_alpha': 11.375354144402698, 'reg_lambda': 91.76569233474632}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,291] Trial 58 finished with value: 0.918722055208734 and parameters: {'num_leaves': 108, 'min_child_samples': 32, 'n_estimators': 358, 'learning_rate': 0.24965621968683133, 'subsample_for_bin': 152506, 'min_split_gain': 0.03501772950240296, 'min_child_weight': 0.07511753626982214, 'reg_alpha': 10.84229207944496, 'reg_lambda': 92.69800966382205}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,323] Trial 59 finished with value: 0.9175931144355056 and parameters: {'num_leaves': 91, 'min_child_samples': 32, 'n_estimators': 423, 'learning_rate': 0.2624531151784013, 'subsample_for_bin': 144148, 'min_split_gain': 0.15319571251759107, 'min_child_weight': 0.07512744623585127, 'reg_alpha': 12.248723339291864, 'reg_lambda': 91.9521762803523}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,349] Trial 60 finished with value: 0.9234094615727778 and parameters: {'num_leaves': 106, 'min_child_samples': 32, 'n_estimators': 415, 'learning_rate': 0.2596181071129051, 'subsample_for_bin': 234367, 'min_split_gain': 0.14905305094607754, 'min_child_weight': 0.08644368141935874, 'reg_alpha': 8.902937700186481, 'reg_lambda': 90.2729890054292}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,388] Trial 62 finished with value: 0.9106486695343659 and parameters: {'num_leaves': 117, 'min_child_samples': 32, 'n_estimators': 406, 'learning_rate': 0.264195780092163, 'subsample_for_bin': 239739, 'min_split_gain': 0.2312926278011821, 'min_child_weight': 0.038531340983380895, 'reg_alpha': 13.517246732104763, 'reg_lambda': 90.9818172013844}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,438] Trial 61 finished with value: 0.9109696626596749 and parameters: {'num_leaves': 89, 'min_child_samples': 32, 'n_estimators': 440, 'learning_rate': 0.26356791598397133, 'subsample_for_bin': 147331, 'min_split_gain': 0.15472789343528737, 'min_child_weight': 0.0744859805693178, 'reg_alpha': 13.938619814648572, 'reg_lambda': 92.7936645657764}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,457] Trial 63 finished with value: 0.9075173046102 and parameters: {'num_leaves': 88, 'min_child_samples': 32, 'n_estimators': 402, 'learning_rate': 0.27041450899321795, 'subsample_for_bin': 239478, 'min_split_gain': 0.2326931636272687, 'min_child_weight': 0.07506316447439768, 'reg_alpha': 17.57684379956794, 'reg_lambda': 92.08568514467065}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,500] Trial 64 finished with value: 0.9156986432029521 and parameters: {'num_leaves': 88, 'min_child_samples': 43, 'n_estimators': 424, 'learning_rate': 0.27181226465434694, 'subsample_for_bin': 151324, 'min_split_gain': 0.14862025080480035, 'min_child_weight': 0.03973827873355363, 'reg_alpha': 12.549448938975637, 'reg_lambda': 91.16096605503904}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,530] Trial 65 finished with value: 0.910455015982026 and parameters: {'num_leaves': 93, 'min_child_samples': 43, 'n_estimators': 418, 'learning_rate': 0.27551910501053906, 'subsample_for_bin': 240495, 'min_split_gain': 0.23294473977892868, 'min_child_weight': 0.03776038450909631, 'reg_alpha': 14.846967496821796, 'reg_lambda': 93.42747193438119}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,574] Trial 66 finished with value: 0.9042548342159978 and parameters: {'num_leaves': 98, 'min_child_samples': 43, 'n_estimators': 422, 'learning_rate': 0.2826301458464886, 'subsample_for_bin': 239775, 'min_split_gain': 0.23287770902190255, 'min_child_weight': 0.038315184918886955, 'reg_alpha': 17.789107623512287, 'reg_lambda': 90.27815663342724}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,612] Trial 67 finished with value: 0.909355357963696 and parameters: {'num_leaves': 88, 'min_child_samples': 43, 'n_estimators': 420, 'learning_rate': 0.26987037035527206, 'subsample_for_bin': 238713, 'min_split_gain': 0.23647978335800438, 'min_child_weight': 0.040038193447826165, 'reg_alpha': 14.265770865973602, 'reg_lambda': 95.13279843935032}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,639] Trial 68 finished with value: 0.9103258331142481 and parameters: {'num_leaves': 88, 'min_child_samples': 42, 'n_estimators': 382, 'learning_rate': 0.2760394782884472, 'subsample_for_bin': 223766, 'min_split_gain': 0.2354446020027243, 'min_child_weight': 0.03912671249486331, 'reg_alpha': 17.68704041849569, 'reg_lambda': 94.74348811901486}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,698] Trial 69 finished with value: 0.9212667966671453 and parameters: {'num_leaves': 96, 'min_child_samples': 43, 'n_estimators': 360, 'learning_rate': 0.43483035500127243, 'subsample_for_bin': 230077, 'min_split_gain': 0.24307292858943497, 'min_child_weight': 0.03946927982637545, 'reg_alpha': 5.249769439894331, 'reg_lambda': 95.35314440478611}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,727] Trial 70 finished with value: 0.924279746348267 and parameters: {'num_leaves': 96, 'min_child_samples': 43, 'n_estimators': 361, 'learning_rate': 0.41712131875556313, 'subsample_for_bin': 101356, 'min_split_gain': 0.22660331551346116, 'min_child_weight': 0.041273935045832884, 'reg_alpha': 5.7344405457674945, 'reg_lambda': 94.9115900805455}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,762] Trial 71 finished with value: 0.9219877836482695 and parameters: {'num_leaves': 93, 'min_child_samples': 42, 'n_estimators': 347, 'learning_rate': 0.4508098418795891, 'subsample_for_bin': 228721, 'min_split_gain': 0.24364512177700795, 'min_child_weight': 0.05303296298751371, 'reg_alpha': 5.622915965922938, 'reg_lambda': 71.40400393179112}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,788] Trial 72 finished with value: 0.9197865844989451 and parameters: {'num_leaves': 93, 'min_child_samples': 42, 'n_estimators': 347, 'learning_rate': 0.4355899953770958, 'subsample_for_bin': 248815, 'min_split_gain': 0.2356796402429171, 'min_child_weight': 0.05450189955534421, 'reg_alpha': 6.821560155294188, 'reg_lambda': 81.1301082568794}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,844] Trial 73 finished with value: 0.9235955745876012 and parameters: {'num_leaves': 95, 'min_child_samples': 42, 'n_estimators': 225, 'learning_rate': 0.4109420504332625, 'subsample_for_bin': 94654, 'min_split_gain': 0.17549692809557424, 'min_child_weight': 0.054771031756950854, 'reg_alpha': 5.430035598515138, 'reg_lambda': 94.94109889709556}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,870] Trial 74 finished with value: 0.9217454691124275 and parameters: {'num_leaves': 85, 'min_child_samples': 41, 'n_estimators': 227, 'learning_rate': 0.2819248914301863, 'subsample_for_bin': 106026, 'min_split_gain': 0.1764261137982158, 'min_child_weight': 0.054600850456945786, 'reg_alpha': 5.664984446953568, 'reg_lambda': 80.75327835674044}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,916] Trial 76 finished with value: 0.9236699680433244 and parameters: {'num_leaves': 121, 'min_child_samples': 41, 'n_estimators': 225, 'learning_rate': 0.39972132482616984, 'subsample_for_bin': 111513, 'min_split_gain': 0.2616672764985674, 'min_child_weight': 0.054396484523093876, 'reg_alpha': 5.572792617357863, 'reg_lambda': 87.53503075338539}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,951] Trial 75 finished with value: 0.9264298669693184 and parameters: {'num_leaves': 120, 'min_child_samples': 42, 'n_estimators': 360, 'learning_rate': 0.29565501068234834, 'subsample_for_bin': 101278, 'min_split_gain': 0.2635666450780718, 'min_child_weight': 0.02900349996754525, 'reg_alpha': 4.021946118925667, 'reg_lambda': 87.75466941795644}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:50,979] Trial 77 finished with value: 0.927493822096559 and parameters: {'num_leaves': 80, 'min_child_samples': 42, 'n_estimators': 237, 'learning_rate': 0.287712731307982, 'subsample_for_bin': 98923, 'min_split_gain': 0.17147750285460925, 'min_child_weight': 0.054065891442100125, 'reg_alpha': 5.363356599580579, 'reg_lambda': 87.56084256991318}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,016] Trial 78 finished with value: 0.9260885205475954 and parameters: {'num_leaves': 122, 'min_child_samples': 42, 'n_estimators': 243, 'learning_rate': 0.4156412504665684, 'subsample_for_bin': 113624, 'min_split_gain': 0.2599310442594902, 'min_child_weight': 0.05269695910659982, 'reg_alpha': 5.753416071344641, 'reg_lambda': 87.1307495230983}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,065] Trial 79 finished with value: 0.9245620082768888 and parameters: {'num_leaves': 67, 'min_child_samples': 42, 'n_estimators': 360, 'learning_rate': 0.2936177029134903, 'subsample_for_bin': 105184, 'min_split_gain': 0.17507395244460652, 'min_child_weight': 0.05473270164408383, 'reg_alpha': 4.3333022040709634, 'reg_lambda': 86.62120134784666}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,098] Trial 80 finished with value: 0.9312299595338781 and parameters: {'num_leaves': 125, 'min_child_samples': 38, 'n_estimators': 354, 'learning_rate': 0.2991457332625104, 'subsample_for_bin': 99926, 'min_split_gain': 0.1752100640929211, 'min_child_weight': 0.05423746714452535, 'reg_alpha': 4.624924144727297, 'reg_lambda': 85.27969597183501}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,155] Trial 81 finished with value: 0.9227597870157301 and parameters: {'num_leaves': 126, 'min_child_samples': 38, 'n_estimators': 233, 'learning_rate': 0.3002780786160988, 'subsample_for_bin': 96388, 'min_split_gain': 0.17695983905712268, 'min_child_weight': 0.05312157943442973, 'reg_alpha': 3.7912208925680275, 'reg_lambda': 88.04143557289036}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,187] Trial 82 finished with value: 0.9270032046614723 and parameters: {'num_leaves': 119, 'min_child_samples': 41, 'n_estimators': 134, 'learning_rate': 0.4519691465028659, 'subsample_for_bin': 129241, 'min_split_gain': 0.2641694891166492, 'min_child_weight': 0.032909010342847086, 'reg_alpha': 3.771196151440256, 'reg_lambda': 83.44681179051587}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,225] Trial 84 finished with value: 0.9306145210656732 and parameters: {'num_leaves': 126, 'min_child_samples': 38, 'n_estimators': 146, 'learning_rate': 0.20933953925588136, 'subsample_for_bin': 85154, 'min_split_gain': 0.26376587313591965, 'min_child_weight': 0.06469034646707818, 'reg_alpha': 3.0525963943962373, 'reg_lambda': 82.88754278742509}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,252] Trial 83 finished with value: 0.9238944622998307 and parameters: {'num_leaves': 124, 'min_child_samples': 39, 'n_estimators': 230, 'learning_rate': 0.2948407114840351, 'subsample_for_bin': 122536, 'min_split_gain': 0.17241740735704175, 'min_child_weight': 0.06595343193496839, 'reg_alpha': 3.7315085029682744, 'reg_lambda': 82.59431143159348}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,281] Trial 85 finished with value: 0.9242010855593 and parameters: {'num_leaves': 123, 'min_child_samples': 39, 'n_estimators': 247, 'learning_rate': 0.29924179942062096, 'subsample_for_bin': 126143, 'min_split_gain': 0.2646343242331792, 'min_child_weight': 0.06422165145293102, 'reg_alpha': 3.1988269702564978, 'reg_lambda': 83.26300173448851}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,316] Trial 86 finished with value: 0.9269462597183412 and parameters: {'num_leaves': 67, 'min_child_samples': 38, 'n_estimators': 545, 'learning_rate': 0.29850875277694716, 'subsample_for_bin': 122833, 'min_split_gain': 0.2622598605929151, 'min_child_weight': 0.04385286469071164, 'reg_alpha': 2.8237487163420516, 'reg_lambda': 78.27156242504952}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,369] Trial 87 finished with value: 0.9269401736395634 and parameters: {'num_leaves': 126, 'min_child_samples': 39, 'n_estimators': 238, 'learning_rate': 0.30476603064519897, 'subsample_for_bin': 132881, 'min_split_gain': 0.2658707937262953, 'min_child_weight': 0.06607877144532345, 'reg_alpha': 2.8780875327100395, 'reg_lambda': 82.32639873814637}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,414] Trial 88 finished with value: 0.925146019903726 and parameters: {'num_leaves': 63, 'min_child_samples': 47, 'n_estimators': 223, 'learning_rate': 0.3000913846015736, 'subsample_for_bin': 127968, 'min_split_gain': 0.2811154803034349, 'min_child_weight': 0.064146318251651, 'reg_alpha': 2.5775245104405524, 'reg_lambda': 83.05231375936215}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,435] Trial 89 finished with value: 0.9274433615878968 and parameters: {'num_leaves': 65, 'min_child_samples': 39, 'n_estimators': 136, 'learning_rate': 0.337458279685482, 'subsample_for_bin': 130970, 'min_split_gain': 0.2935963232665143, 'min_child_weight': 0.06447820751597863, 'reg_alpha': 3.224153083722104, 'reg_lambda': 84.19508835983878}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,556] Trial 90 finished with value: 0.9134462508461324 and parameters: {'num_leaves': 128, 'min_child_samples': 37, 'n_estimators': 140, 'learning_rate': 0.20573521461619762, 'subsample_for_bin': 135399, 'min_split_gain': 0.21490368270607535, 'min_child_weight': 0.06484702566851044, 'reg_alpha': 8.228201447169623, 'reg_lambda': 78.2191420290146}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,596] Trial 91 finished with value: 0.9268416860129861 and parameters: {'num_leaves': 65, 'min_child_samples': 47, 'n_estimators': 144, 'learning_rate': 0.20626332314227966, 'subsample_for_bin': 134751, 'min_split_gain': 0.18761529534955626, 'min_child_weight': 0.06422297624235218, 'reg_alpha': 8.279666885324206, 'reg_lambda': 79.11154555142394}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,635] Trial 92 finished with value: 0.9209797338046318 and parameters: {'num_leaves': 63, 'min_child_samples': 38, 'n_estimators': 590, 'learning_rate': 0.3274597193176081, 'subsample_for_bin': 137514, 'min_split_gain': 0.217859396291473, 'min_child_weight': 0.06635891868881688, 'reg_alpha': 8.255027707470024, 'reg_lambda': 99.7420177741171}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,668] Trial 93 finished with value: 0.9245989831542879 and parameters: {'num_leaves': 127, 'min_child_samples': 38, 'n_estimators': 469, 'learning_rate': 0.20799741515367073, 'subsample_for_bin': 134173, 'min_split_gain': 0.1901187717242631, 'min_child_weight': 0.04384397850935529, 'reg_alpha': 8.162550996506114, 'reg_lambda': 77.54904585029544}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,682] Trial 94 finished with value: 0.9227177324269435 and parameters: {'num_leaves': 67, 'min_child_samples': 47, 'n_estimators': 592, 'learning_rate': 0.3283990821592564, 'subsample_for_bin': 77330, 'min_split_gain': 0.2830527827052159, 'min_child_weight': 0.04388989297159138, 'reg_alpha': 8.182386963619994, 'reg_lambda': 77.38782512343246}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,718] Trial 95 finished with value: 0.9235357589098618 and parameters: {'num_leaves': 128, 'min_child_samples': 39, 'n_estimators': 607, 'learning_rate': 0.3329142451735674, 'subsample_for_bin': 70931, 'min_split_gain': 0.21792197387016699, 'min_child_weight': 0.06042890207152843, 'reg_alpha': 8.722379315978982, 'reg_lambda': 99.93027649979605}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,753] Trial 96 finished with value: 0.9217070801726338 and parameters: {'num_leaves': 128, 'min_child_samples': 39, 'n_estimators': 128, 'learning_rate': 0.32627675778411147, 'subsample_for_bin': 73023, 'min_split_gain': 0.21704515279699896, 'min_child_weight': 0.05961110023286029, 'reg_alpha': 7.631824739109417, 'reg_lambda': 79.49868683084577}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,817] Trial 97 finished with value: 0.9189844251773248 and parameters: {'num_leaves': 128, 'min_child_samples': 47, 'n_estimators': 465, 'learning_rate': 0.33171933788259345, 'subsample_for_bin': 211389, 'min_split_gain': 0.21358617682738337, 'min_child_weight': 0.0449772674090228, 'reg_alpha': 8.169335402016312, 'reg_lambda': 85.04814707746839}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,856] Trial 98 finished with value: 0.9178600432496277 and parameters: {'num_leaves': 31, 'min_child_samples': 47, 'n_estimators': 585, 'learning_rate': 0.3214129931497065, 'subsample_for_bin': 67322, 'min_split_gain': 0.21064873166477763, 'min_child_weight': 0.05946943856532397, 'reg_alpha': 8.417601087306558, 'reg_lambda': 89.55123195251761}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,926] Trial 99 finished with value: 0.9289036365123023 and parameters: {'num_leaves': 29, 'min_child_samples': 47, 'n_estimators': 475, 'learning_rate': 0.3146329013436082, 'subsample_for_bin': 212808, 'min_split_gain': 0.13315170198219212, 'min_child_weight': 0.04478723222232012, 'reg_alpha': 0.6652602177671394, 'reg_lambda': 89.82782022797345}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,941] Trial 100 finished with value: 0.9346854100370274 and parameters: {'num_leaves': 34, 'min_child_samples': 47, 'n_estimators': 460, 'learning_rate': 0.3175241701514244, 'subsample_for_bin': 213934, 'min_split_gain': 0.21685969541431535, 'min_child_weight': 0.04374354230051877, 'reg_alpha': 0.13986062458559678, 'reg_lambda': 85.98726328685646}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:51,993] Trial 101 finished with value: 0.9350728573664804 and parameters: {'num_leaves': 33, 'min_child_samples': 46, 'n_estimators': 460, 'learning_rate': 0.3400905494506626, 'subsample_for_bin': 67376, 'min_split_gain': 0.18753507526510257, 'min_child_weight': 0.04349224151491611, 'reg_alpha': 0.7398457920188032, 'reg_lambda': 84.9532434578139}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,019] Trial 103 finished with value: 0.9318062903905148 and parameters: {'num_leaves': 32, 'min_child_samples': 47, 'n_estimators': 328, 'learning_rate': 0.36809743098942505, 'subsample_for_bin': 284626, 'min_split_gain': 0.08234909122055546, 'min_child_weight': 0.050971435116037175, 'reg_alpha': 0.39178572759238184, 'reg_lambda': 86.03397129997427}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,056] Trial 102 finished with value: 0.9354219730189232 and parameters: {'num_leaves': 33, 'min_child_samples': 47, 'n_estimators': 476, 'learning_rate': 0.3181596012135788, 'subsample_for_bin': 66387, 'min_split_gain': 0.0789961875420274, 'min_child_weight': 0.05916847208940026, 'reg_alpha': 0.018489546078934715, 'reg_lambda': 84.80277050411907}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,082] Trial 104 finished with value: 0.933898878137259 and parameters: {'num_leaves': 36, 'min_child_samples': 46, 'n_estimators': 460, 'learning_rate': 0.23867503208572582, 'subsample_for_bin': 73594, 'min_split_gain': 0.13505307425926602, 'min_child_weight': 0.057499091385992754, 'reg_alpha': 0.2597282548493643, 'reg_lambda': 89.68926837568894}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,129] Trial 105 finished with value: 0.9275396161739676 and parameters: {'num_leaves': 39, 'min_child_samples': 47, 'n_estimators': 470, 'learning_rate': 0.24289880908689615, 'subsample_for_bin': 209014, 'min_split_gain': 0.08922025012245452, 'min_child_weight': 0.05838261324698933, 'reg_alpha': 0.10414805782749831, 'reg_lambda': 89.06221559771282}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,174] Trial 106 finished with value: 0.933237154154389 and parameters: {'num_leaves': 36, 'min_child_samples': 47, 'n_estimators': 476, 'learning_rate': 0.23814690135866173, 'subsample_for_bin': 201584, 'min_split_gain': 0.13143863593670005, 'min_child_weight': 0.0491650854517735, 'reg_alpha': 0.06820052186837644, 'reg_lambda': 85.39235307833555}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,287] Trial 107 finished with value: 0.9354066723853619 and parameters: {'num_leaves': 33, 'min_child_samples': 25, 'n_estimators': 326, 'learning_rate': 0.2352715533983853, 'subsample_for_bin': 208909, 'min_split_gain': 0.08833293788815612, 'min_child_weight': 0.05017735173743481, 'reg_alpha': 0.47536468565650564, 'reg_lambda': 89.40582232148262}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,322] Trial 108 finished with value: 0.9258154811581799 and parameters: {'num_leaves': 35, 'min_child_samples': 34, 'n_estimators': 469, 'learning_rate': 0.2362072980378176, 'subsample_for_bin': 173658, 'min_split_gain': 0.08118839318063764, 'min_child_weight': 0.050955085998272254, 'reg_alpha': 0.6995260148717134, 'reg_lambda': 96.35342903420455}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,349] Trial 109 finished with value: 0.932366301528479 and parameters: {'num_leaves': 36, 'min_child_samples': 25, 'n_estimators': 326, 'learning_rate': 0.24061985168564448, 'subsample_for_bin': 208085, 'min_split_gain': 0.1315267607319892, 'min_child_weight': 0.05774598247783829, 'reg_alpha': 0.3222194556926783, 'reg_lambda': 97.71951076394613}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,399] Trial 110 finished with value: 0.9344188942418455 and parameters: {'num_leaves': 40, 'min_child_samples': 34, 'n_estimators': 324, 'learning_rate': 0.24201992327933786, 'subsample_for_bin': 174032, 'min_split_gain': 0.08292929365115762, 'min_child_weight': 0.057307327649310576, 'reg_alpha': 0.8676768471625238, 'reg_lambda': 96.14548554527353}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,429] Trial 112 finished with value: 0.9332874275519876 and parameters: {'num_leaves': 38, 'min_child_samples': 26, 'n_estimators': 334, 'learning_rate': 0.24104395361666683, 'subsample_for_bin': 203417, 'min_split_gain': 0.2029765753892287, 'min_child_weight': 0.05064266610467072, 'reg_alpha': 0.30199008921939213, 'reg_lambda': 89.36655244474869}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,463] Trial 111 finished with value: 0.9315646050662733 and parameters: {'num_leaves': 36, 'min_child_samples': 27, 'n_estimators': 325, 'learning_rate': 0.24514096747471265, 'subsample_for_bin': 170513, 'min_split_gain': 0.08187732162605338, 'min_child_weight': 0.05115757476965885, 'reg_alpha': 1.9903427727263798, 'reg_lambda': 80.6979482855047}. Best is trial 40 with value: 0.9381958061859166.
# [I 2023-01-28 15:19:52,493] Trial 113 finished with value: 0.9289713899489621 and parameters: {'num_leaves': 34, 'min_child_samples': 26, 'n_estimators': 318, 'learning_rate': 0.2394173620208273, 'subsample_for_bin': 175648, 'min_split_gain': 0.09459440381869814, 'min_child_weight': 0.04929695691217932, 'reg_alpha': 1.8915088836936191, 'reg_lambda': 89.63568840776819}. Best is trial 40 with value: 0.9381958061859166.
# ...
# [I 2023-01-28 15:21:23,774] Trial 987 finished with value: 0.8952018082103027 and parameters: {'num_leaves': 49, 'min_child_samples': 32, 'n_estimators': 216, 'learning_rate': 0.1269361973007611, 'subsample_for_bin': 78674, 'min_split_gain': 0.31160824306728385, 'min_child_weight': 0.011379774127920878, 'reg_alpha': 28.271385408700183, 'reg_lambda': 51.115494603663}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,028] Trial 989 finished with value: 0.9109763196063098 and parameters: {'num_leaves': 44, 'min_child_samples': 20, 'n_estimators': 369, 'learning_rate': 0.3109207064638839, 'subsample_for_bin': 195267, 'min_split_gain': 0.061959690936308806, 'min_child_weight': 0.05896064641962587, 'reg_alpha': 14.684842644146851, 'reg_lambda': 82.58478514736869}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,159] Trial 988 finished with value: 0.9131556214745805 and parameters: {'num_leaves': 45, 'min_child_samples': 23, 'n_estimators': 367, 'learning_rate': 0.46116880709688823, 'subsample_for_bin': 224371, 'min_split_gain': 0.38060064304202534, 'min_child_weight': 0.010206350402793192, 'reg_alpha': 11.080294753375082, 'reg_lambda': 87.46397813742408}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,188] Trial 990 finished with value: 0.8754760362245478 and parameters: {'num_leaves': 43, 'min_child_samples': 20, 'n_estimators': 347, 'learning_rate': 0.12490120930362039, 'subsample_for_bin': 224700, 'min_split_gain': 0.05337271141512357, 'min_child_weight': 0.11191461119903146, 'reg_alpha': 45.91718046554335, 'reg_lambda': 24.513730829146866}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,317] Trial 991 finished with value: 0.8125555647148958 and parameters: {'num_leaves': 24, 'min_child_samples': 20, 'n_estimators': 213, 'learning_rate': 0.1251279328400272, 'subsample_for_bin': 223003, 'min_split_gain': 0.06560912438137177, 'min_child_weight': 0.011339994230408719, 'reg_alpha': 80.39091030705008, 'reg_lambda': 83.11104979611747}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,428] Trial 992 finished with value: 0.9185901262889722 and parameters: {'num_leaves': 17, 'min_child_samples': 23, 'n_estimators': 210, 'learning_rate': 0.46424224975012623, 'subsample_for_bin': 225444, 'min_split_gain': 0.05915043036878727, 'min_child_weight': 0.012366268911020661, 'reg_alpha': 13.010042658856307, 'reg_lambda': 74.10316443706685}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:24,630] Trial 993 finished with value: 0.9299712178681433 and parameters: {'num_leaves': 47, 'min_child_samples': 30, 'n_estimators': 214, 'learning_rate': 0.3837171874039886, 'subsample_for_bin': 133316, 'min_split_gain': 0.07771421472200693, 'min_child_weight': 0.010324346808400844, 'reg_alpha': 3.381350003745882, 'reg_lambda': 73.58888095966554}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,109] Trial 994 finished with value: 0.9258675809892073 and parameters: {'num_leaves': 43, 'min_child_samples': 27, 'n_estimators': 421, 'learning_rate': 0.02579801191182176, 'subsample_for_bin': 225418, 'min_split_gain': 0.16752968707484914, 'min_child_weight': 0.05838461120088425, 'reg_alpha': 3.3689674745616767, 'reg_lambda': 53.84496913073755}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,150] Trial 995 finished with value: 0.8186757796322451 and parameters: {'num_leaves': 31, 'min_child_samples': 20, 'n_estimators': 223, 'learning_rate': 0.3116623817701344, 'subsample_for_bin': 77245, 'min_split_gain': 0.16610034189456174, 'min_child_weight': 0.05803382023591047, 'reg_alpha': 66.57043450451545, 'reg_lambda': 80.12396462329245}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,582] Trial 997 finished with value: 0.695132506629009 and parameters: {'num_leaves': 43, 'min_child_samples': 47, 'n_estimators': 216, 'learning_rate': 0.3817216657911669, 'subsample_for_bin': 192132, 'min_split_gain': 0.1672719888504449, 'min_child_weight': 0.053953946640797563, 'reg_alpha': 99.85148516921736, 'reg_lambda': 18.22732789358715}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,686] Trial 996 finished with value: 0.8134400558012874 and parameters: {'num_leaves': 42, 'min_child_samples': 23, 'n_estimators': 219, 'learning_rate': 0.347558452723815, 'subsample_for_bin': 194342, 'min_split_gain': 0.010945931976899609, 'min_child_weight': 0.1434404128597563, 'reg_alpha': 79.21404168639378, 'reg_lambda': 18.677016998799328}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,791] Trial 998 finished with value: 0.9310874198877293 and parameters: {'num_leaves': 44, 'min_child_samples': 21, 'n_estimators': 220, 'learning_rate': 0.34836479523849656, 'subsample_for_bin': 446398, 'min_split_gain': 0.08634495692052747, 'min_child_weight': 0.05255236108730747, 'reg_alpha': 2.0018439170050772, 'reg_lambda': 60.066930669129}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,867] Trial 999 finished with value: 0.9256419837031865 and parameters: {'num_leaves': 51, 'min_child_samples': 20, 'n_estimators': 214, 'learning_rate': 0.3826765072625727, 'subsample_for_bin': 57700, 'min_split_gain': 0.07850724160286082, 'min_child_weight': 0.0930443966122321, 'reg_alpha': 2.642829763333791, 'reg_lambda': 17.643296797880154}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:25,869] Trial 1000 finished with value: 0.8223592384576355 and parameters: {'num_leaves': 73, 'min_child_samples': 27, 'n_estimators': 425, 'learning_rate': 0.3486056152366434, 'subsample_for_bin': 170080, 'min_split_gain': 0.16830601803570777, 'min_child_weight': 0.13004661274421941, 'reg_alpha': 65.40692257815472, 'reg_lambda': 6.334487093699065}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,159] Trial 1001 finished with value: 0.8515347906015722 and parameters: {'num_leaves': 31, 'min_child_samples': 27, 'n_estimators': 649, 'learning_rate': 0.3470832194154817, 'subsample_for_bin': 170125, 'min_split_gain': 0.1625866634797807, 'min_child_weight': 0.10176574243871529, 'reg_alpha': 52.74875935610862, 'reg_lambda': 96.1855438802972}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,231] Trial 1002 finished with value: 0.9280594229923839 and parameters: {'num_leaves': 33, 'min_child_samples': 47, 'n_estimators': 414, 'learning_rate': 0.38359495169649394, 'subsample_for_bin': 169975, 'min_split_gain': 0.16485513189077738, 'min_child_weight': 0.09321130226925631, 'reg_alpha': 2.0522747271356176, 'reg_lambda': 39.65902807230897}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,313] Trial 1003 finished with value: 0.9241327741211474 and parameters: {'num_leaves': 31, 'min_child_samples': 23, 'n_estimators': 496, 'learning_rate': 0.38103382594991464, 'subsample_for_bin': 171436, 'min_split_gain': 0.3255045180495595, 'min_child_weight': 0.09289744821624733, 'reg_alpha': 1.9519214186270213, 'reg_lambda': 96.50107659835697}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,467] Trial 1004 finished with value: 0.9265068455409291 and parameters: {'num_leaves': 31, 'min_child_samples': 47, 'n_estimators': 681, 'learning_rate': 0.3484932113606533, 'subsample_for_bin': 187180, 'min_split_gain': 0.011645704150079091, 'min_child_weight': 0.048915067131893204, 'reg_alpha': 4.943289227296243, 'reg_lambda': 94.6648273747486}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,538] Trial 1005 finished with value: 0.8132782344435205 and parameters: {'num_leaves': 31, 'min_child_samples': 27, 'n_estimators': 423, 'learning_rate': 0.34834768442922154, 'subsample_for_bin': 168348, 'min_split_gain': 0.14688118783613097, 'min_child_weight': 0.04811483326200962, 'reg_alpha': 97.61755432642774, 'reg_lambda': 68.46389759424568}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,914] Trial 1006 finished with value: 0.81245712017096 and parameters: {'num_leaves': 116, 'min_child_samples': 27, 'n_estimators': 418, 'learning_rate': 0.34753540535644273, 'subsample_for_bin': 143917, 'min_split_gain': 0.011817516201544587, 'min_child_weight': 0.04918336964986598, 'reg_alpha': 94.14146049013141, 'reg_lambda': 9.81258717020943}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,948] Trial 1007 finished with value: 0.9039492344914365 and parameters: {'num_leaves': 32, 'min_child_samples': 47, 'n_estimators': 421, 'learning_rate': 0.34606686251591706, 'subsample_for_bin': 447526, 'min_split_gain': 0.08601501886785558, 'min_child_weight': 0.04885006069063727, 'reg_alpha': 23.52978714556054, 'reg_lambda': 55.748495829121325}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:26,988] Trial 1008 finished with value: 0.9271552111117692 and parameters: {'num_leaves': 117, 'min_child_samples': 47, 'n_estimators': 415, 'learning_rate': 0.34698825489536655, 'subsample_for_bin': 171415, 'min_split_gain': 0.46942575589866786, 'min_child_weight': 0.14912257679355523, 'reg_alpha': 4.646747731277042, 'reg_lambda': 70.6082875926184}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,311] Trial 1009 finished with value: 0.8554191405952652 and parameters: {'num_leaves': 31, 'min_child_samples': 47, 'n_estimators': 489, 'learning_rate': 0.34721423454465783, 'subsample_for_bin': 446346, 'min_split_gain': 0.22686695791436118, 'min_child_weight': 0.04880497871816342, 'reg_alpha': 50.65227976878447, 'reg_lambda': 85.70861263001835}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,582] Trial 1011 finished with value: 0.9150983983534573 and parameters: {'num_leaves': 108, 'min_child_samples': 13, 'n_estimators': 486, 'learning_rate': 0.3332641014293043, 'subsample_for_bin': 172465, 'min_split_gain': 0.1485122067495188, 'min_child_weight': 0.04852671904532774, 'reg_alpha': 7.505262125868074, 'reg_lambda': 44.48367429254915}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,626] Trial 1010 finished with value: 0.9178057791688365 and parameters: {'num_leaves': 31, 'min_child_samples': 43, 'n_estimators': 449, 'learning_rate': 0.33092523663040224, 'subsample_for_bin': 148610, 'min_split_gain': 0.32961504995188307, 'min_child_weight': 0.048337318828770716, 'reg_alpha': 7.481360646272123, 'reg_lambda': 67.32471533571174}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,926] Trial 1012 finished with value: 0.9251534225114338 and parameters: {'num_leaves': 108, 'min_child_samples': 47, 'n_estimators': 491, 'learning_rate': 0.2672982413360606, 'subsample_for_bin': 145429, 'min_split_gain': 0.24959842476310096, 'min_child_weight': 0.07179019105576454, 'reg_alpha': 7.502005252757818, 'reg_lambda': 35.09254453955755}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,953] Trial 1013 finished with value: 0.8130718280973684 and parameters: {'num_leaves': 30, 'min_child_samples': 47, 'n_estimators': 540, 'learning_rate': 0.42109269070872696, 'subsample_for_bin': 206890, 'min_split_gain': 0.2536236580850157, 'min_child_weight': 0.041085608846284566, 'reg_alpha': 92.8056921340761, 'reg_lambda': 42.242331843459716}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:27,998] Trial 1014 finished with value: 0.8134913702614298 and parameters: {'num_leaves': 32, 'min_child_samples': 47, 'n_estimators': 494, 'learning_rate': 0.33275293750025176, 'subsample_for_bin': 206116, 'min_split_gain': 0.23168458702440514, 'min_child_weight': 0.04206182451181439, 'reg_alpha': 89.80521459557099, 'reg_lambda': 90.77916979194079}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,009] Trial 1015 finished with value: 0.9261342687905336 and parameters: {'num_leaves': 108, 'min_child_samples': 47, 'n_estimators': 483, 'learning_rate': 0.3301235709753843, 'subsample_for_bin': 148651, 'min_split_gain': 0.12644436483958885, 'min_child_weight': 0.04271534594109929, 'reg_alpha': 8.125623978435797, 'reg_lambda': 65.56205498074749}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,059] Trial 1017 finished with value: 0.9096407832260401 and parameters: {'num_leaves': 32, 'min_child_samples': 43, 'n_estimators': 388, 'learning_rate': 0.07793622978204047, 'subsample_for_bin': 182586, 'min_split_gain': 0.2541386997005685, 'min_child_weight': 0.07063127858666093, 'reg_alpha': 18.330361137923365, 'reg_lambda': 23.17488356778697}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,062] Trial 1016 finished with value: 0.9302473545592337 and parameters: {'num_leaves': 106, 'min_child_samples': 24, 'n_estimators': 545, 'learning_rate': 0.41093808338126203, 'subsample_for_bin': 109974, 'min_split_gain': 0.13076195037066246, 'min_child_weight': 0.10996435413966571, 'reg_alpha': 1.7423126164041753, 'reg_lambda': 61.497141596913465}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,083] Trial 1018 finished with value: 0.9037374248729976 and parameters: {'num_leaves': 37, 'min_child_samples': 43, 'n_estimators': 388, 'learning_rate': 0.3325789479528405, 'subsample_for_bin': 204743, 'min_split_gain': 0.302558128128367, 'min_child_weight': 0.04335085081881714, 'reg_alpha': 18.001353112316675, 'reg_lambda': 61.783743120143264}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,094] Trial 1019 finished with value: 0.8128683578995336 and parameters: {'num_leaves': 109, 'min_child_samples': 47, 'n_estimators': 449, 'learning_rate': 0.2678645075271566, 'subsample_for_bin': 422625, 'min_split_gain': 0.031242790302818596, 'min_child_weight': 0.1311253443242601, 'reg_alpha': 78.55687479750777, 'reg_lambda': 72.52832389234383}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,114] Trial 1020 finished with value: 0.8131540916588319 and parameters: {'num_leaves': 108, 'min_child_samples': 43, 'n_estimators': 543, 'learning_rate': 0.264037813014359, 'subsample_for_bin': 206636, 'min_split_gain': 0.12383603311248591, 'min_child_weight': 0.13096797671970484, 'reg_alpha': 89.79763271843838, 'reg_lambda': 46.884913236026925}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,123] Trial 1022 finished with value: 0.8205646670831329 and parameters: {'num_leaves': 104, 'min_child_samples': 13, 'n_estimators': 377, 'learning_rate': 0.33129845895646215, 'subsample_for_bin': 205813, 'min_split_gain': 0.12911041768590525, 'min_child_weight': 0.04410771074096218, 'reg_alpha': 68.4001104082271, 'reg_lambda': 25.760204350272176}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,129] Trial 1023 finished with value: 0.9301462482973636 and parameters: {'num_leaves': 107, 'min_child_samples': 43, 'n_estimators': 442, 'learning_rate': 0.33096740345947206, 'subsample_for_bin': 184527, 'min_split_gain': 0.13005763834512712, 'min_child_weight': 0.13101013069242307, 'reg_alpha': 1.856999500735254, 'reg_lambda': 46.70013931225291}. Best is trial 928 with value: 0.9382805026243557.
# [I 2023-01-28 15:21:28,130] Trial 1021 finished with value: 0.9327445136308089 and parameters: {'num_leaves': 105, 'min_child_samples': 43, 'n_estimators': 478, 'learning_rate': 0.2680573819631491, 'subsample_for_bin': 205144, 'min_split_gain': 0.1285351469525434, 'min_child_weight': 0.13152143698084678, 'reg_alpha': 1.9571934446786114, 'reg_lambda': 85.16927450764615}. Best is trial 928 with value: 0.9382805026243557.
# AUC: 0.9382805026243557
# Best hyperparameters: {'num_leaves': 135, 'min_child_samples': 40, 'n_estimators': 269, 'learning_rate': 0.16684813731426978, 'subsample_for_bin': 186335, 'min_split_gain': 0.14812050704142085, 'min_child_weight': 0.13370420011536233, 'reg_alpha': 0.08358553189858921, 'reg_lambda': 12.104002117555359}

# %% [markdown]
# # Análise Comparativa

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))

ax1.set_title('PSO X Gerações')
ax2.set_title('PSO X Avaliações')

ax1.plot(tracking_PSO_Accuracy)
ax2.plot(Accuracy_PSO)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))

ax1.set_title('GA X Gerações')
ax2.set_title('GA X Avaliações')

ax1.plot(tracking_GA_Accuracy)
ax2.plot(Accuracy_GA)
plt.show()

# %% [markdown]
# Gráficos Comparativos Acurácia

# %%
from IPython.core.pylabtools import figsize
from matplotlib.pyplot import figure
import matplotlib.patches as mpatches

plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch])
plt.plot(Accuracy_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(Accuracy_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_Accuracy, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_Accuracy, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_Accuracy, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_Accuracy, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_Accuracy, color = 'green', linewidth=3, linestyle='-')

# %% [markdown]
# F1 score

# %%
plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch])
plt.plot(F1_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(F1_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_F1, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_F1, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_F1, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_F1, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_F1, color = 'green', linewidth=3, linestyle='-')

# %% [markdown]
# ROC AUC

# %%
plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch])
plt.plot(AUC_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(AUC_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_AUC, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_AUC, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_AUC, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_AUC, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_AUC, color = 'green', linewidth=3, linestyle='-')
