# %% [markdown]
# ### Gráficos

# %%
import pandas as pd
import plotly.express as px

# %%
from VD_A import VD_A

# %%
heart_ga = pd.read_csv('./final_results_heart/FINAL_RESULT_GA_HEART.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
heart_pso = pd.read_csv('./final_results_heart/FINAL_RESULT_PSO_HEART.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
heart_optuna = pd.read_csv('./final_results_heart/FINAL_RESULT_OPTUNA_HEART.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
heart_rs = pd.read_csv('./final_results_heart/FINAL_RESULT_RS_HEART.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
### fruit
fruit_ga = pd.read_csv('./final_results_fruit/FINAL_RESULT_GA_FRUIT.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
fruit_pso = pd.read_csv('./final_results_fruit/FINAL_RESULT_PSO_FRUIT.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
fruit_optuna = pd.read_csv('./final_results_fruit/FINAL_RESULT_OPTUNA_FRUIT.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
fruit_rs = pd.read_csv('./final_results_fruit/FINAL_RESULT_RS_FRUIT.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
### WINE
wine_ga = pd.read_csv('./final_results_wine/FINAL_RESULT_GA_WINE.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
wine_pso = pd.read_csv('./final_results_wine/FINAL_RESULT_PSO_WINE.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
wine_optuna = pd.read_csv('./final_results_wine/FINAL_RESULT_OPTUNA_WINE.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]
wine_rs = pd.read_csv('./final_results_wine/FINAL_RESULT_RS_WINE.csv')[['Algorithm', 'Accuracy', 'F1', 'AUC']]

# %%
len(wine_ga), len(wine_optuna), len(wine_pso), len(wine_rs)
# Out:
# (30, 30, 30, 30)

# %%
fig = px.histogram(heart_ga, x='F1', nbins=8, labels={'x':'F1 Score', 'y':'count'},color_discrete_sequence=['teal'],
                   title="Histogram F1 Score Obtained by Genetic Algorithm Optimization")
mean = heart_ga['F1'].mean()
median = heart_ga['F1'].median()
fig.update_layout(bargap=0.2, width=800, height=600)
fig.update_layout(template = 'plotly_dark')
fig.add_vline(x=mean, line_width=3, line_dash="solid", line_color='turquoise', annotation_text='Mean', annotation_x=0.8993)
#fig.add_scatter(x = heart_ga['F1'], y=heart_ga['F1'], mode='lines')
#['solid', 'dot', 'dash', 'longdash', 'dashdot', 'longdashdot']
'''
sandybrown, seagreen, seashell, sienna, silver,
            skyblue, slateblue, slategray, slategrey, snow,
            springgreen, steelblue, tan, teal, thistle, tomato,
            turquoise, violet, wheat, white, whitesmoke,
            yellow, yellowgreen
'''
fig.add_vline(x=median, line_width=3, line_dash="dash", line_color="wheat",annotation_text='Median', annotation_x=0.898)
fig.show()

# %%
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

metrics = ['F1','AUC', 'Accuracy']
for metric in metrics:
    hist_data = [heart_ga[metric], heart_pso[metric], heart_optuna[metric], heart_rs[metric]]
    group_labels = ['GA', 'PSO', 'Optuna', 'Random Search'] # name of the dataset


    fig = ff.create_distplot(hist_data, group_labels, curve_type='kde', bin_size=.005, show_hist=True)
    fig.update_layout(template = 'plotly_dark')
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'Distribution Plot Heart Dataset {metric} Score')
    fig.show()

# %%
metrics = ['F1','AUC', 'Accuracy']
for metric in metrics:
    hist_data = [wine_ga[metric], wine_pso[metric], wine_optuna[metric], wine_rs[metric]]
    group_labels = ['GA', 'PSO', 'Optuna', 'Random Search'] # name of the dataset


    fig = ff.create_distplot(hist_data, group_labels, curve_type='kde', bin_size=.005, show_hist=True)
    fig.update_layout(template = 'plotly_dark')
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'Distribution Plot Wine Dataset {metric} Score')
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:223, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     222 try:
# --> 223     self.set_bandwidth(bw_method=bw_method)
#     224 except linalg.LinAlgError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:571, in gaussian_kde.set_bandwidth(self, bw_method)
#     569     raise ValueError(msg)
# --> 571 self._compute_covariance()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:583, in gaussian_kde._compute_covariance(self)
#     580     self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     581                                        bias=False,
#     582                                        aweights=self.weights))
# --> 583     self._data_cho_cov = linalg.cholesky(self._data_covariance,
#     584                                          lower=True)
#     586 self.covariance = self._data_covariance * self.factor**2
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\linalg\_decomp_cholesky.py:89, in cholesky(a, lower, overwrite_a, check_finite)
#      46 """
#      47 Compute the Cholesky decomposition of a matrix.
#      48
#    (...)
#      87
#      88 """
# ---> 89 c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      90                      check_finite=check_finite)
#      91 return c
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\linalg\_decomp_cholesky.py:37, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      36 if info > 0:
# ---> 37     raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                       "definite" % info)
#      39 if info < 0:
#
# LinAlgError: 1-th leading minor of the array is not positive definite
#
# The above exception was the direct cause of the following exception:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[12], line 7
#       3 hist_data = [wine_ga[metric], wine_pso[metric], wine_optuna[metric], wine_rs[metric]]
#       4 group_labels = ['GA', 'PSO', 'Optuna', 'Random Search'] # name of the dataset
# ----> 7 fig = ff.create_distplot(hist_data, group_labels, curve_type='kde', bin_size=.005, show_hist=True)
#       8 fig.update_layout(template = 'plotly_dark')
#       9 fig.update_layout(bargap=0.1, width=800, height=600, title=f'Distribution Plot Wine Dataset {metric} Score')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\figure_factory\_distplot.py:228, in create_distplot(hist_data, group_labels, bin_size, curve_type, colors, rug_text, histnorm, show_hist, show_curve, show_rug)
#     206         curve = _Distplot(
#     207             hist_data,
#     208             histnorm,
#    (...)
#     215             show_curve,
#     216         ).make_normal()
#     217     else:
#     218         curve = _Distplot(
#     219             hist_data,
#     220             histnorm,
#     221             group_labels,
#     222             bin_size,
#     223             curve_type,
#     224             colors,
#     225             rug_text,
#     226             show_hist,
#     227             show_curve,
# --> 228         ).make_kde()
#     230     data.append(curve)
#     232 if show_rug:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\figure_factory\_distplot.py:363, in _Distplot.make_kde(self)
#     358 for index in range(self.trace_number):
#     359     self.curve_x[index] = [
#     360         self.start[index] + x * (self.end[index] - self.start[index]) / 500
#     361         for x in range(500)
#     362     ]
# --> 363     self.curve_y[index] = scipy_stats.gaussian_kde(self.hist_data[index])(
#     364         self.curve_x[index]
#     365     )
#     367     if self.histnorm == ALTERNATIVE_HISTNORM:
#     368         self.curve_y[index] *= self.bin_size[index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:232, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     224 except linalg.LinAlgError as e:
#     225     msg = ("The data appears to lie in a lower-dimensional subspace "
#     226            "of the space in which it is expressed. This has resulted "
#     227            "in a singular data covariance matrix, which cannot be "
#    (...)
#     230            "analysis / dimensionality reduction and using "
#     231            "`gaussian_kde` with the transformed data.")
# --> 232     raise linalg.LinAlgError(msg) from e
#
# LinAlgError: The data appears to lie in a lower-dimensional subspace of the space in which it is expressed. This has resulted in a singular data covariance matrix, which cannot be treated using the algorithms implemented in `gaussian_kde`. Consider performing principle component analysis / dimensionality reduction and using `gaussian_kde` with the transformed data.

# %%
metrics = ['F1','AUC', 'Accuracy']
for metric in metrics:
    hist_data = [fruit_ga[metric], fruit_pso[metric], fruit_optuna[metric], fruit_rs[metric]]
    group_labels = ['GA', 'PSO', 'Optuna', 'Random Search'] # name of the dataset


    fig = ff.create_distplot(hist_data, group_labels, curve_type='kde', bin_size=.05, show_hist=True)
    fig.update_layout(template = 'plotly_dark')
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'Distribution Plot Wine Dataset {metric} Score')
    fig.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:223, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     222 try:
# --> 223     self.set_bandwidth(bw_method=bw_method)
#     224 except linalg.LinAlgError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:571, in gaussian_kde.set_bandwidth(self, bw_method)
#     569     raise ValueError(msg)
# --> 571 self._compute_covariance()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:583, in gaussian_kde._compute_covariance(self)
#     580     self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     581                                        bias=False,
#     582                                        aweights=self.weights))
# --> 583     self._data_cho_cov = linalg.cholesky(self._data_covariance,
#     584                                          lower=True)
#     586 self.covariance = self._data_covariance * self.factor**2
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\linalg\_decomp_cholesky.py:89, in cholesky(a, lower, overwrite_a, check_finite)
#      46 """
#      47 Compute the Cholesky decomposition of a matrix.
#      48
#    (...)
#      87
#      88 """
# ---> 89 c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      90                      check_finite=check_finite)
#      91 return c
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\linalg\_decomp_cholesky.py:37, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      36 if info > 0:
# ---> 37     raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                       "definite" % info)
#      39 if info < 0:
#
# LinAlgError: 1-th leading minor of the array is not positive definite
#
# The above exception was the direct cause of the following exception:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[21], line 7
#       3 hist_data = [fruit_ga[metric], fruit_pso[metric], fruit_optuna[metric], fruit_rs[metric]]
#       4 group_labels = ['GA', 'PSO', 'Optuna', 'Random Search'] # name of the dataset
# ----> 7 fig = ff.create_distplot(hist_data, group_labels, curve_type='kde', bin_size=.05, show_hist=True)
#       8 fig.update_layout(template = 'plotly_dark')
#       9 fig.update_layout(bargap=0.1, width=800, height=600, title=f'Distribution Plot Wine Dataset {metric} Score')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\figure_factory\_distplot.py:228, in create_distplot(hist_data, group_labels, bin_size, curve_type, colors, rug_text, histnorm, show_hist, show_curve, show_rug)
#     206         curve = _Distplot(
#     207             hist_data,
#     208             histnorm,
#    (...)
#     215             show_curve,
#     216         ).make_normal()
#     217     else:
#     218         curve = _Distplot(
#     219             hist_data,
#     220             histnorm,
#     221             group_labels,
#     222             bin_size,
#     223             curve_type,
#     224             colors,
#     225             rug_text,
#     226             show_hist,
#     227             show_curve,
# --> 228         ).make_kde()
#     230     data.append(curve)
#     232 if show_rug:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\plotly\figure_factory\_distplot.py:363, in _Distplot.make_kde(self)
#     358 for index in range(self.trace_number):
#     359     self.curve_x[index] = [
#     360         self.start[index] + x * (self.end[index] - self.start[index]) / 500
#     361         for x in range(500)
#     362     ]
# --> 363     self.curve_y[index] = scipy_stats.gaussian_kde(self.hist_data[index])(
#     364         self.curve_x[index]
#     365     )
#     367     if self.histnorm == ALTERNATIVE_HISTNORM:
#     368         self.curve_y[index] *= self.bin_size[index]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_kde.py:232, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     224 except linalg.LinAlgError as e:
#     225     msg = ("The data appears to lie in a lower-dimensional subspace "
#     226            "of the space in which it is expressed. This has resulted "
#     227            "in a singular data covariance matrix, which cannot be "
#    (...)
#     230            "analysis / dimensionality reduction and using "
#     231            "`gaussian_kde` with the transformed data.")
# --> 232     raise linalg.LinAlgError(msg) from e
#
# LinAlgError: The data appears to lie in a lower-dimensional subspace of the space in which it is expressed. This has resulted in a singular data covariance matrix, which cannot be treated using the algorithms implemented in `gaussian_kde`. Consider performing principle component analysis / dimensionality reduction and using `gaussian_kde` with the transformed data.

# %%
for metric in metrics:
    df = pd.DataFrame(dict(
        GA=heart_ga[metric],
        PSO=heart_pso[metric],
        Optuna=heart_optuna[metric],
        RS = heart_rs[metric]
    )).melt(var_name="Algorithm")


    fig = px.box(df, y="value", facet_col="Algorithm", color="Algorithm",
                boxmode="overlay", points='all')
    fig.update_layout(template = 'plotly_dark')
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=1)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=2)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=3)
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'BoxPlot Fruit Dataset {metric} Score')
    fig.show()

# %%
for metric in metrics:
    df = pd.DataFrame(dict(
        GA=wine_ga[metric],
        PSO=wine_pso[metric],
        Optuna=wine_optuna[metric],
        RS = wine_rs[metric]
    )).melt(var_name="Algorithm")


    fig = px.box(df, y="value", facet_col="Algorithm", color="Algorithm",
                boxmode="overlay", points='all')
    fig.update_layout(template = 'plotly_dark')
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=1)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=2)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=3)
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'BoxPlot Fruit Dataset {metric} Score')
    fig.show()

# %%
for metric in metrics:
    df = pd.DataFrame(dict(
        GA=fruit_ga[metric],
        PSO=fruit_pso[metric],
        Optuna=fruit_optuna[metric],
        RS = fruit_rs[metric]
    )).melt(var_name="Algorithm")


    fig = px.box(df, y="value", facet_col="Algorithm", color="Algorithm",
                boxmode="overlay", points='all')
    fig.update_layout(template = 'plotly_dark')
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=1)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=2)
    fig.update_traces(quartilemethod="exclusive", jitter=0, col=3)
    fig.update_layout(bargap=0.1, width=800, height=600, title=f'BoxPlot Fruit Dataset {metric} Score')
    fig.show()

# %% [markdown]
# ### Teste Mann-Whitney U Test

# %%
import pandas as pd


testes = pd.DataFrame(columns=["Dataset", "Amostras","metrica", "U1", "Pvalue", "U2"])

# %%
from scipy.stats import mannwhitneyu

# Teste entre GA e PSO com a métrica F1

#Hipotese nula: as duas distribuições não tem diferença estatística
#Hipótese alternativa: as duas distribuções são diferentes
def realiza_teste(amostra1, amostra2, metrica, dataset_name, str_amostra1, str_amostra2):
    U1, p = mannwhitneyu(amostra1[str(metrica)], amostra2[str(metrica)], method="asymptotic")
    print('=='*22)
    print(f'GA x Optuna - {str(metrica)} score - {dataset_name} Dataset')
    print('=='*22)
    print(f'U1, sendo 1 o algoritmo genético: {U1}, \np-value correspondente: {p}')

    nx, ny = len(amostra1[str(metrica)]), len(amostra2[str(metrica)])
    U2 = nx*ny - U1
    print(f'U2, sendo 2 optuna: {U2}')
    #temp = pd.DataFrame(columns=["Dataset", "Amostras","metrica", "U1", "Pvalue", "U2"])
    #temp = pd.DataFrame()
    #testes = pd.concat([testes, temp], ignore_index=True)
    estimate, magnitude = VD_A(amostra1[str(metrica)].to_list(),amostra2[str(metrica)].to_list())
    
    temp_dict = {
                'Dataset' :dataset_name, 
                'Amostras' : str_amostra1 + "_" + str_amostra2, 
                'metrica' :metrica, 
                'U1' : U1, 
                'U2' : U2, 
                'Pvalue' : p,
                'magnitude' : magnitude,
                "estimate" : estimate
                }
    
    filename = './final_testes_CatBoost.csv'

    try:
        final_df = pd.read_csv(filename)
    except:
        open(filename, "a")
        final_df = pd.DataFrame(columns=["Dataset", "Amostras","metrica", "U1", "Pvalue", "U2", "magnitude", "estimate"])
    
    temp = pd.DataFrame(temp_dict,index=[0])
    final_df = pd.concat([final_df, temp], ignore_index=True)
    
    final_df[["Dataset", "Amostras","metrica", "U1", "Pvalue", "U2", "magnitude", "estimate"]].to_csv(filename)

# %%
import itertools

strings = ["GA", "OPTUNA", "PSO", "Random Search"]

combinations = list(itertools.combinations(strings, 2))

for combination in combinations:
    print(combination)
# Out:
# ('GA', 'OPTUNA')
# ('GA', 'PSO')
# ('GA', 'Random Search')
# ('OPTUNA', 'PSO')
# ('OPTUNA', 'Random Search')
# ('PSO', 'Random Search')

# %%
#('GA', 'OPTUNA')
realiza_teste(heart_ga, heart_optuna, 'F1', 'Heart', "GA", "OPTUNA")
realiza_teste(heart_ga, heart_optuna, 'Accuracy', 'Heart', "GA", "OPTUNA")
realiza_teste(heart_ga, heart_optuna, 'AUC', 'Heart', "GA", "OPTUNA")
#('GA', 'PSO')
realiza_teste(heart_ga, heart_pso, 'F1', 'Heart', "GA", "PSO")
realiza_teste(heart_ga, heart_pso, 'Accuracy', 'Heart', "GA", "PSO")
realiza_teste(heart_ga, heart_pso, 'AUC', 'Heart', "GA", "PSO")
#('GA', 'Random Search')
realiza_teste(heart_ga, heart_rs, 'F1', 'Heart', "GA", "Random Search")
realiza_teste(heart_ga, heart_rs, 'Accuracy', 'Heart', "GA", "Random Search")
realiza_teste(heart_ga, heart_rs, 'AUC', 'Heart', "GA", "Random Search")
#('OPTUNA', 'PSO')
realiza_teste(heart_optuna, heart_rs, 'F1', 'Heart', "OPTUNA", "Random Search")
realiza_teste(heart_optuna, heart_rs, 'Accuracy', 'Heart', "OPTUNA", "Random Search")
realiza_teste(heart_optuna, heart_rs, 'AUC', 'Heart', "OPTUNA", "Random Search")
#('OPTUNA', 'Random Search')
realiza_teste(heart_optuna, heart_pso, 'F1', 'Heart', "OPTUNA", "PSO")
realiza_teste(heart_optuna, heart_pso, 'Accuracy', 'Heart', "OPTUNA", "PSO")
realiza_teste(heart_optuna, heart_pso, 'AUC', 'Heart', "OPTUNA", "PSO")
#('PSO', 'Random Search')
realiza_teste(heart_pso, heart_rs, 'F1', 'Heart', "PSO", "Random Search")
realiza_teste(heart_pso, heart_rs, 'Accuracy', 'Heart', "PSO", "Random Search")
realiza_teste(heart_pso, heart_rs, 'AUC', 'Heart', "PSO", "Random Search")
# Out:
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 667.0,
# p-value correspondente: 0.0013703325610487653
# U2, sendo 2 optuna: 233.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 602.5,
# p-value correspondente: 0.024583295829587553
# U2, sendo 2 optuna: 297.5
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 646.0,
# p-value correspondente: 0.003848067983551401
# U2, sendo 2 optuna: 254.0
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 3.019859359162157e-11
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 806.0,
# p-value correspondente: 1.4657342855122823e-07
# U2, sendo 2 optuna: 94.0
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 609.0,
# p-value correspondente: 0.019110728917403726
# U2, sendo 2 optuna: 291.0
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 836.0,
# p-value correspondente: 1.2023264598302062e-08
# U2, sendo 2 optuna: 64.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 816.5,
# p-value correspondente: 6.211481494974285e-08
# U2, sendo 2 optuna: 83.5
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 899.0,
# p-value correspondente: 3.3383888204287995e-11
# U2, sendo 2 optuna: 1.0
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 769.0,
# p-value correspondente: 2.491311449611175e-06
# U2, sendo 2 optuna: 131.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 788.5,
# p-value correspondente: 5.795813695342622e-07
# U2, sendo 2 optuna: 111.5
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 890.0,
# p-value correspondente: 8.152744512218774e-11
# U2, sendo 2 optuna: 10.0
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 3.019859359162157e-11
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 779.0,
# p-value correspondente: 1.1916487084908247e-06
# U2, sendo 2 optuna: 121.0
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 551.0,
# p-value correspondente: 0.13731737344568412
# U2, sendo 2 optuna: 349.0
# ============================================
# GA x Optuna - F1 score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 4.0,
# p-value correspondente: 4.504322112705282e-11
# U2, sendo 2 optuna: 896.0
# ============================================
# GA x Optuna - Accuracy score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 283.0,
# p-value correspondente: 0.013825027073263307
# U2, sendo 2 optuna: 617.0
# ============================================
# GA x Optuna - AUC score - Heart Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 445.0,
# p-value correspondente: 0.9469552063691843
# U2, sendo 2 optuna: 455.0

# %%
#('GA', 'OPTUNA')
realiza_teste(fruit_ga, fruit_optuna, 'F1', 'Fruit', "GA", "OPTUNA")
realiza_teste(fruit_ga, fruit_optuna, 'Accuracy', 'Fruit', "GA", "OPTUNA")
realiza_teste(fruit_ga, fruit_optuna, 'AUC', 'Fruit', "GA", "OPTUNA")
#('GA', 'PSO')
realiza_teste(fruit_ga, fruit_pso, 'F1', 'Fruit', "GA", "PSO")
realiza_teste(fruit_ga, fruit_pso, 'Accuracy', 'Fruit', "GA", "PSO")
realiza_teste(fruit_ga, fruit_pso, 'AUC', 'Fruit', "GA", "PSO")
#('GA', 'Random Search')
realiza_teste(fruit_ga, fruit_rs, 'F1', 'Fruit', "GA", "Random Search")
realiza_teste(fruit_ga, fruit_rs, 'Accuracy', 'Fruit', "GA", "Random Search")
realiza_teste(fruit_ga, fruit_rs, 'AUC', 'Fruit', "GA", "Random Search")
#('OPTUNA', 'PSO')
realiza_teste(fruit_optuna, fruit_rs, 'F1', 'Fruit', "OPTUNA", "Random Search")
realiza_teste(fruit_optuna, fruit_rs, 'Accuracy', 'Fruit', "OPTUNA", "Random Search")
realiza_teste(fruit_optuna, fruit_rs, 'AUC', 'Fruit', "OPTUNA", "Random Search")
#('OPTUNA', 'Random Search')
realiza_teste(fruit_optuna, fruit_pso, 'F1', 'Fruit', "OPTUNA", "PSO")
realiza_teste(fruit_optuna, fruit_pso, 'Accuracy', 'Fruit', "OPTUNA", "PSO")
realiza_teste(fruit_optuna, fruit_pso, 'AUC', 'Fruit', "OPTUNA", "PSO")
#('PSO', 'Random Search')
realiza_teste(fruit_pso, fruit_rs, 'F1', 'Fruit', "PSO", "Random Search")
realiza_teste(fruit_pso, fruit_rs, 'Accuracy', 'Fruit', "PSO", "Random Search")
realiza_teste(fruit_pso, fruit_rs, 'AUC', 'Fruit', "PSO", "Random Search")
# Out:
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 239.0,
# p-value correspondente: 0.0018569359734827975
# U2, sendo 2 optuna: 661.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 311.0,
# p-value correspondente: 0.04048624721862026
# U2, sendo 2 optuna: 589.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 342.0,
# p-value correspondente: 0.10971655302259795
# U2, sendo 2 optuna: 558.0
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 726.0,
# p-value correspondente: 4.6367113100491495e-05
# U2, sendo 2 optuna: 174.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 879.0,
# p-value correspondente: 2.3125765440099112e-10
# U2, sendo 2 optuna: 21.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 690.0,
# p-value correspondente: 5.374951270022975e-06
# U2, sendo 2 optuna: 210.0
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 328.0,
# p-value correspondente: 0.07243766229032923
# U2, sendo 2 optuna: 572.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 459.0,
# p-value correspondente: 0.8999410938488778
# U2, sendo 2 optuna: 441.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 457.0,
# p-value correspondente: 0.9229550733987187
# U2, sendo 2 optuna: 443.0
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 827.0,
# p-value correspondente: 2.6015113749963406e-08
# U2, sendo 2 optuna: 73.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 863.0,
# p-value correspondente: 1.0701785878647307e-09
# U2, sendo 2 optuna: 37.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 875.0,
# p-value correspondente: 3.4741966068317727e-10
# U2, sendo 2 optuna: 25.0
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 891.0,
# p-value correspondente: 7.389082518022347e-11
# U2, sendo 2 optuna: 9.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 3.0104073709630884e-11
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 1.2117803970059759e-12
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - F1 score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 0.0,
# p-value correspondente: 3.019859359162157e-11
# U2, sendo 2 optuna: 900.0
# ============================================
# GA x Optuna - Accuracy score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 0.0,
# p-value correspondente: 3.0104073709630884e-11
# U2, sendo 2 optuna: 900.0
# ============================================
# GA x Optuna - AUC score - Fruit Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 0.0,
# p-value correspondente: 1.2117803970059759e-12
# U2, sendo 2 optuna: 900.0

# %%
#('GA', 'OPTUNA')
realiza_teste(wine_ga, wine_optuna, 'F1', 'Wine', "GA", "OPTUNA")
realiza_teste(wine_ga, wine_optuna, 'Accuracy', 'Wine', "GA", "OPTUNA")
realiza_teste(wine_ga, wine_optuna, 'AUC', 'Wine', "GA", "OPTUNA")
#('GA', 'PSO')
realiza_teste(wine_ga, wine_pso, 'F1', 'Wine', "GA", "PSO")
realiza_teste(wine_ga, wine_pso, 'Accuracy', 'Wine', "GA", "PSO")
realiza_teste(wine_ga, wine_pso, 'AUC', 'Wine', "GA", "PSO")
#('GA', 'Random Search')
realiza_teste(wine_ga, wine_rs, 'F1', 'Wine', "GA", "Random Search")
realiza_teste(wine_ga, wine_rs, 'Accuracy', 'Wine', "GA", "Random Search")
realiza_teste(wine_ga, wine_rs, 'AUC', 'Wine', "GA", "Random Search")
#('OPTUNA', 'PSO')
realiza_teste(wine_optuna, wine_rs, 'F1', 'Wine', "OPTUNA", "Random Search")
realiza_teste(wine_optuna, wine_rs, 'Accuracy', 'Wine', "OPTUNA", "Random Search")
realiza_teste(wine_optuna, wine_rs, 'AUC', 'Wine', "OPTUNA", "Random Search")
#('OPTUNA', 'Random Search')
realiza_teste(wine_optuna, wine_pso, 'F1', 'Wine', "OPTUNA", "PSO")
realiza_teste(wine_optuna, wine_pso, 'Accuracy', 'Wine', "OPTUNA", "PSO")
realiza_teste(wine_optuna, wine_pso, 'AUC', 'Wine', "OPTUNA", "PSO")
#('PSO', 'Random Search')
realiza_teste(wine_pso, wine_rs, 'F1', 'Wine', "PSO", "Random Search")
realiza_teste(wine_pso, wine_rs, 'Accuracy', 'Wine', "PSO", "Random Search")
realiza_teste(wine_pso, wine_rs, 'AUC', 'Wine', "PSO", "Random Search")
# Out:
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 172.0,
# p-value correspondente: 4.08294712583794e-05
# U2, sendo 2 optuna: 728.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 212.0,
# p-value correspondente: 0.0004435503746773581
# U2, sendo 2 optuna: 688.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 348.0,
# p-value correspondente: 0.1322657735255026
# U2, sendo 2 optuna: 552.0
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 771.0,
# p-value correspondente: 2.15333462179913e-06
# U2, sendo 2 optuna: 129.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 843.0,
# p-value correspondente: 6.424816123795613e-09
# U2, sendo 2 optuna: 57.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 735.0,
# p-value correspondente: 3.45263236009729e-07
# U2, sendo 2 optuna: 165.0
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 252.0,
# p-value correspondente: 0.0035007116368698174
# U2, sendo 2 optuna: 648.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 429.0,
# p-value correspondente: 0.7617352367884301
# U2, sendo 2 optuna: 471.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 491.0,
# p-value correspondente: 0.5481012790921818
# U2, sendo 2 optuna: 409.0
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 792.0,
# p-value correspondente: 4.4440478739951943e-07
# U2, sendo 2 optuna: 108.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 794.0,
# p-value correspondente: 3.805262810100767e-07
# U2, sendo 2 optuna: 106.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 888.0,
# p-value correspondente: 9.918628618948002e-11
# U2, sendo 2 optuna: 12.0
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 3.019859359162157e-11
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 892.0,
# p-value correspondente: 6.69146781811368e-11
# U2, sendo 2 optuna: 8.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 900.0,
# p-value correspondente: 1.2117803970059759e-12
# U2, sendo 2 optuna: 0.0
# ============================================
# GA x Optuna - F1 score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 0.0,
# p-value correspondente: 3.019859359162157e-11
# U2, sendo 2 optuna: 900.0
# ============================================
# GA x Optuna - Accuracy score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 24.0,
# p-value correspondente: 3.157111311247434e-10
# U2, sendo 2 optuna: 876.0
# ============================================
# GA x Optuna - AUC score - Wine Dataset
# ============================================
# U1, sendo 1 o algoritmo genético: 0.0,
# p-value correspondente: 1.2117803970059759e-12
# U2, sendo 2 optuna: 900.0
