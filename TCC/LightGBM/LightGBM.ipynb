# %% [markdown]
# ## Definindo o Problema

# %%
#!pip install lightgbm;
#!pip install pymoo;
#!pip install -U pyrecorder;

# %%
import pickle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from yellowbrick.classifier import ConfusionMatrix
import numpy as np
from tqdm.notebook import tqdm as tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, KFold
#from google.colab import drive
import pickle
from pymoo.algorithms.soo.nonconvex.pso import PSO, PSOAnimation
#from pymoo.factory import Rastrigin
from pymoo.optimize import minimize
import matplotlib.pyplot as plt
from pymoo.factory import get_termination
#from pymoo.util.display import Display
from pymoo.core.callback import Callback

# %%
import lightgbm as lgb

# %%
#drive.mount('/content/gdrive')

# %%
#with open('/content/gdrive/MyDrive/datasets/credit.pkl', 'rb') as f:
#    x_credit_train, x_credit_test, y_credit_train, y_credit_test = pickle.load(f)
    
with open('./credit.pkl', 'rb') as f:
    x_credit_train, x_credit_test, y_credit_train, y_credit_test = pickle.load(f)

# %%
x_credit = np.concatenate((x_credit_train, x_credit_test), axis = 0)
y_credit = np.concatenate((y_credit_train, y_credit_test), axis = 0)

# %% [markdown]
# Definindo as restrições

# %%
OBJECTIVE = ['Accuracy']
DIMENSIONS = 9 #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, subsample, reg_alpha, reg_lambda
ITERATIONS = 10
POPULATION = 15
num_leaves_min = 10
num_leaves_max = 200
min_child_samples_min = 10
min_child_samples_max = 50
n_estimators_min = 20
n_estimators_max = 1000

learning_rate_min = 0.001
learning_rate_max = 0.5
subsample_for_bin_min = 50000
subsample_for_bin_max = 500000
min_split_gain_min = 0.01
min_split_gain_max = 0.5
min_child_weight_min = 0.001
min_child_weight_max = 0.15
subsample_min = 1.0
subsample_max = 2.0
reg_alpha_min =0.01
reg_alpha_max = 100.0 
reg_lambda_min = 0.01
reg_lambda_max = 100.0

BOUNDS = []
SEED = 1
INDIVIDUALS = []

# %% [markdown]
# Definindo o problema

# %%
import numpy as np
from pymoo.core.problem import ElementwiseProblem

class OptimizeWithAccuracy(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.floor(x[0])), 
                                       min_child_samples = int(np.floor(x[1])), 
                                       n_estimators      = int(np.floor(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.floor(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_credit, y_credit, cv = kfold, n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemAccuracy = OptimizeWithAccuracy()

# %%
class OptimizeWithF1(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.round(x[0])), 
                                       min_child_samples = int(np.round(x[1])), 
                                       n_estimators      = int(np.round(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.round(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_credit, y_credit, cv = kfold, scoring='f1', n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemF1 = OptimizeWithF1()

# %%
class OptimizeWithAUC(ElementwiseProblem):

    def __init__(self):
        super().__init__(n_var= DIMENSIONS,
                         n_obj=1,
                         n_constr=9,
                         xl=np.array([num_leaves_min, min_child_samples_min, n_estimators_min, learning_rate_min, subsample_for_bin_min,
                                      min_split_gain_min, min_child_weight_min, reg_alpha_min, reg_lambda_min]),
                         xu=np.array([num_leaves_max, min_child_samples_max, n_estimators_max, learning_rate_max, subsample_for_bin_max,
                                      min_split_gain_max, min_child_weight_max, reg_alpha_max, reg_lambda_max])
                        )

    def _evaluate(self, x, out, *args, **kwargs):
        #num_leaves, min_child_samples, n_estimators, learning_rate, subsample_for_bin, min_split_gain, min_child_weight, reg_alpha, reg_lambda
        
        model_lgb = lgb.LGBMClassifier(num_leaves        = int(np.round(x[0])), 
                                       min_child_samples = int(np.round(x[1])), 
                                       n_estimators      = int(np.round(x[2])),
                                       learning_rate     = x[3] ,
                                       subsample_for_bin = int(np.round(x[4])),
                                       min_split_gain    = x[5],
                                       min_child_weight  = x[6],
                                       reg_alpha         = x[7],
                                       reg_lambda        = x[8],
                                       max_depth=- 1,
                                       n_jobs = -1
                                       )
        
        kfold = KFold(n_splits = 3, shuffle = True)
        
        scores = cross_val_score(model_lgb, x_credit, y_credit, cv = kfold, scoring='roc_auc', n_jobs=-1)  
        
        result = scores.mean()
        out['F'] = -1 * result

problemAUC = OptimizeWithAUC()

# %%
from pymoo.util.display.column import Column
from pymoo.util.display.output import Output

# %%
class MyOutput(Output):

    def __init__(self):
        super().__init__()
        global pbar 
        pbar = tqdm(total=ITERATIONS)
        self.score = Column("score", width=13)
        self.Parameters = Column("Parameters", width=35)
        self.columns += [self.score, self.Parameters]

    def update(self, algorithm):
        super().update(algorithm)
        self.score.set(-np.min(algorithm.pop.get("F")))
        #self.Parameters.set(algorithm.pop.get("X")[0])
        pbar.update(1)
        if pbar.n == ITERATIONS: pbar.close()

# %% [markdown]
# ## Particle Swarm Optimization (PSO)

# %% [markdown]
# ### Acurácia

# %%
ITERATIONS = 32
POPULATION = 32

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAccuracy,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best Accuracy Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\2417788545.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8410117067 |                                   -
#      2 |       64 |  0.8410117067 |                                   -
#      3 |       96 |  0.8410117067 |                                   -
#      4 |      128 |  0.8410117067 |                                   -
#      5 |      160 |  0.8410117067 |                                   -
#      6 |      192 |  0.8410117067 |                                   -
#      7 |      224 |  0.8410117067 |                                   -
#      8 |      256 |  0.8410117067 |                                   -
#      9 |      288 |  0.8410117067 |                                   -
#     10 |      320 |  0.8410117067 |                                   -
#     11 |      352 |  0.8410117067 |                                   -
#     12 |      384 |  0.8410117067 |                                   -
#     13 |      416 |  0.8410117067 |                                   -
#     14 |      448 |  0.8410117067 |                                   -
#     15 |      480 |  0.8410117067 |                                   -
#     16 |      512 |  0.8410117067 |                                   -
#     17 |      544 |  0.8410117067 |                                   -
#     18 |      576 |  0.8410117067 |                                   -
#     19 |      608 |  0.8410117067 |                                   -
#     20 |      640 |  0.8410117067 |                                   -
#     21 |      672 |  0.8410117067 |                                   -
#     22 |      704 |  0.8410117067 |                                   -
#     23 |      736 |  0.8410117067 |                                   -
#     24 |      768 |  0.8410117067 |                                   -
#     25 |      800 |  0.8410117067 |                                   -
#     26 |      832 |  0.8410117067 |                                   -
#     27 |      864 |  0.8410117067 |                                   -
#     28 |      896 |  0.8410117067 |                                   -
#     29 |      928 |  0.8410117067 |                                   -
#     30 |      960 |  0.8410117067 |                                   -
#     31 |      992 |  0.8410117067 |                                   -
#     32 |     1024 |  0.8410117067 |                                   -
# Best Accuracy Score [0.84101171]
# Model parameters:
#  [9.51294427e+01 2.74057851e+01 4.32703512e+02 3.48640829e-01
#  3.12256980e+05 2.13942944e-01 6.10921471e-02 1.70826374e+00
#  6.63977806e+01]

# %%
final_model = lgb.LGBMClassifier(num_leaves       = int(np.floor(parameters_best_individual[0])), 
                                min_child_samples = int(np.floor(parameters_best_individual[1])), 
                                n_estimators      = int(np.floor(parameters_best_individual[2])),
                                learning_rate     = parameters_best_individual[3] ,
                                subsample_for_bin = int(np.floor(parameters_best_individual[4])),
                                min_split_gain    = parameters_best_individual[5],
                                min_child_weight  = parameters_best_individual[6],
                                reg_alpha         = parameters_best_individual[7],
                                reg_lambda        = parameters_best_individual[8],
                                max_depth=- 1
                                )


kfold = KFold(n_splits = 3, shuffle = True)

scores = cross_val_score(final_model, x_credit, y_credit, cv = kfold, n_jobs=-1)  

result = scores.mean()
#print(result)

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1))

# %%
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
Accuracy_PSO = scorelist

# %%
plt.plot(Accuracy_PSO);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_Accuracy = tracking
plt.plot(tracking)

# %% [markdown]
# ### F1 Score

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemF1,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best F1 Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\2645485919.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.5478841336 |                                   -
#      2 |       64 |  0.5478841336 |                                   -
#      3 |       96 |  0.5478841336 |                                   -
#      4 |      128 |  0.5478841336 |                                   -
#      5 |      160 |  0.5478841336 |                                   -
#      6 |      192 |  0.5478841336 |                                   -
#      7 |      224 |  0.5478841336 |                                   -
#      8 |      256 |  0.5478841336 |                                   -
#      9 |      288 |  0.5478841336 |                                   -
#     10 |      320 |  0.5478841336 |                                   -
#     11 |      352 |  0.5478841336 |                                   -
#     12 |      384 |  0.5478841336 |                                   -
#     13 |      416 |  0.5478841336 |                                   -
#     14 |      448 |  0.5478841336 |                                   -
#     15 |      480 |  0.5478841336 |                                   -
#     16 |      512 |  0.5478841336 |                                   -
#     17 |      544 |  0.5478841336 |                                   -
#     18 |      576 |  0.5478841336 |                                   -
#     19 |      608 |  0.5478841336 |                                   -
#     20 |      640 |  0.5478841336 |                                   -
#     21 |      672 |  0.5478841336 |                                   -
#     22 |      704 |  0.5478841336 |                                   -
#     23 |      736 |  0.5478841336 |                                   -
#     24 |      768 |  0.5478841336 |                                   -
#     25 |      800 |  0.5478841336 |                                   -
#     26 |      832 |  0.5478841336 |                                   -
#     27 |      864 |  0.5478841336 |                                   -
#     28 |      896 |  0.5478841336 |                                   -
#     29 |      928 |  0.5478841336 |                                   -
#     30 |      960 |  0.5478841336 |                                   -
#     31 |      992 |  0.5478841336 |                                   -
#     32 |     1024 |  0.5478841336 |                                   -
# Best F1 Score [0.54788413]
# Model parameters:
#  [1.68393401e+02 3.53507203e+01 3.41863433e+02 3.88327836e-01
#  4.52655845e+05 2.69643337e-01 5.87952880e-02 3.73012379e+00
#  1.16411770e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
F1_PSO = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_F1 = tracking
plt.plot(tracking)

# %% [markdown]
# ### AUC

# %%
algorithm = PSO(#pop_size=POPULATION, 
                #w=0.3, c1=4.0, c2=1.0, 
                #adaptive=False, initial_velocity='random', 
                #max_velocity_rate=0.75, pertube_best=False,
                max_velocity_rate=0.25,
                pop_size=POPULATION)
term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAUC,
               algorithm,
               #seed=SEED,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best AUC Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\4093374697.py:7: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8382579611 |                                   -
#      2 |       64 |  0.8382579611 |                                   -
#      3 |       96 |  0.8382579611 |                                   -
#      4 |      128 |  0.8382579611 |                                   -
#      5 |      160 |  0.8382579611 |                                   -
#      6 |      192 |  0.8382579611 |                                   -
#      7 |      224 |  0.8382579611 |                                   -
#      8 |      256 |  0.8382579611 |                                   -
#      9 |      288 |  0.8382579611 |                                   -
#     10 |      320 |  0.8382579611 |                                   -
#     11 |      352 |  0.8382579611 |                                   -
#     12 |      384 |  0.8382579611 |                                   -
#     13 |      416 |  0.8382579611 |                                   -
#     14 |      448 |  0.8382579611 |                                   -
#     15 |      480 |  0.8382579611 |                                   -
#     16 |      512 |  0.8382579611 |                                   -
#     17 |      544 |  0.8382579611 |                                   -
#     18 |      576 |  0.8382579611 |                                   -
#     19 |      608 |  0.8382579611 |                                   -
#     20 |      640 |  0.8382579611 |                                   -
#     21 |      672 |  0.8382579611 |                                   -
#     22 |      704 |  0.8382579611 |                                   -
#     23 |      736 |  0.8382579611 |                                   -
#     24 |      768 |  0.8382579611 |                                   -
#     25 |      800 |  0.8382579611 |                                   -
#     26 |      832 |  0.8382579611 |                                   -
#     27 |      864 |  0.8382579611 |                                   -
#     28 |      896 |  0.8382579611 |                                   -
#     29 |      928 |  0.8382579611 |                                   -
#     30 |      960 |  0.8382579611 |                                   -
#     31 |      992 |  0.8382579611 |                                   -
#     32 |     1024 |  0.8382579611 |                                   -
# Best AUC Score [0.83825796]
# Model parameters:
#  [1.37101201e+02 2.26528062e+01 5.84915576e+01 3.22231791e-01
#  1.71132822e+05 2.32356204e-01 1.31628936e-01 9.51818141e-01
#  6.67800380e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
AUC_PSO = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_PSO_AUC = tracking
plt.plot(tracking)

# %% [markdown]
# ## Algoritmo Genético (GA)

# %% [markdown]
# ### Acurácia

# %%
ITERATIONS = 32
POPULATION = 32

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAccuracy,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best Accuracy Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\3390466977.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8394154998 |                                   -
#      2 |       64 |  0.8394154998 |                                   -
#      3 |       96 |  0.8405513411 |                                   -
#      4 |      128 |  0.8405818680 |                                   -
#      5 |      160 |  0.8409502317 |                                   -
#      6 |      192 |  0.8409810215 |                                   -
#      7 |      224 |  0.8417483775 |                                   -
#      8 |      256 |  0.8417483775 |                                   -
#      9 |      288 |  0.8418711522 |                                   -
#     10 |      320 |  0.8431293556 |                                   -
#     11 |      352 |  0.8431293556 |                                   -
#     12 |      384 |  0.8431293556 |                                   -
#     13 |      416 |  0.8431293556 |                                   -
#     14 |      448 |  0.8432828777 |                                   -
#     15 |      480 |  0.8432828777 |                                   -
#     16 |      512 |  0.8432828777 |                                   -
#     17 |      544 |  0.8432828777 |                                   -
#     18 |      576 |  0.8432828777 |                                   -
#     19 |      608 |  0.8432828777 |                                   -
#     20 |      640 |  0.8432828777 |                                   -
#     21 |      672 |  0.8432828777 |                                   -
#     22 |      704 |  0.8437433224 |                                   -
#     23 |      736 |  0.8437433224 |                                   -
#     24 |      768 |  0.8437433224 |                                   -
#     25 |      800 |  0.8437433224 |                                   -
#     26 |      832 |  0.8437433224 |                                   -
#     27 |      864 |  0.8437433224 |                                   -
#     28 |      896 |  0.8437433224 |                                   -
#     29 |      928 |  0.8437433224 |                                   -
#     30 |      960 |  0.8437433224 |                                   -
#     31 |      992 |  0.8437433224 |                                   -
#     32 |     1024 |  0.8437433224 |                                   -
# Best Accuracy Score [0.84374332]
# Model parameters:
#  [6.22523840e+01 1.67178775e+01 1.36800051e+02 2.44593679e-01
#  7.63373712e+04 5.28716118e-02 6.55411493e-02 1.11457023e+00
#  1.46307924e+01]

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_Accuracy = tracking
plt.plot(tracking)

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1))

# %%
scorelist = []

for i in range(len(trlist)):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
Accuracy_GA = scorelist

# %%
plt.plot(scorelist);

# %% [markdown]
# ### F1 Score

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemF1,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best F1 Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\1745594656.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.5582819984 |                                   -
#      2 |       64 |  0.5582819984 |                                   -
#      3 |       96 |  0.5582819984 |                                   -
#      4 |      128 |  0.5611743976 |                                   -
#      5 |      160 |  0.5611743976 |                                   -
#      6 |      192 |  0.5620141955 |                                   -
#      7 |      224 |  0.5639618482 |                                   -
#      8 |      256 |  0.5639618482 |                                   -
#      9 |      288 |  0.5662779871 |                                   -
#     10 |      320 |  0.5686952487 |                                   -
#     11 |      352 |  0.5686952487 |                                   -
#     12 |      384 |  0.5718870509 |                                   -
#     13 |      416 |  0.5718870509 |                                   -
#     14 |      448 |  0.5718870509 |                                   -
#     15 |      480 |  0.5718870509 |                                   -
#     16 |      512 |  0.5738911381 |                                   -
#     17 |      544 |  0.5738911381 |                                   -
#     18 |      576 |  0.5738911381 |                                   -
#     19 |      608 |  0.5738911381 |                                   -
#     20 |      640 |  0.5738911381 |                                   -
#     21 |      672 |  0.5738911381 |                                   -
#     22 |      704 |  0.5738911381 |                                   -
#     23 |      736 |  0.5738911381 |                                   -
#     24 |      768 |  0.5738911381 |                                   -
#     25 |      800 |  0.5746323555 |                                   -
#     26 |      832 |  0.5746323555 |                                   -
#     27 |      864 |  0.5747922183 |                                   -
#     28 |      896 |  0.5747922183 |                                   -
#     29 |      928 |  0.5747922183 |                                   -
#     30 |      960 |  0.5761498915 |                                   -
#     31 |      992 |  0.5761498915 |                                   -
#     32 |     1024 |  0.5761498915 |                                   -
# Best F1 Score [0.57614989]
# Model parameters:
#  [1.52349267e+02 1.20905908e+01 7.54952760e+02 3.49644315e-01
#  4.70864488e+05 1.04692705e-02 8.84094332e-02 1.04271204e-01
#  3.26993801e+00]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
F1_GA = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_F1 = tracking
plt.plot(tracking)

# %% [markdown]
# ### AUC

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA

algorithm = GA(pop_size=POPULATION)

term = get_termination("n_gen", ITERATIONS)

res = minimize(problemAUC,
               algorithm,
               save_history=True,
               verbose=True,
               output=MyOutput(),
               termination = term)


index_best_individual = np.where(res.pop.get('F') == np.min(res.pop.get('F')))[0][0]
score_best_individual = res.pop.get('F')[index_best_individual]
parameters_best_individual = res.pop.get('X')[index_best_individual]

print(f'Best AUC Score {-score_best_individual}')
print(f'Model parameters: \n {parameters_best_individual}')
# Out:
# C:\Users\Felps\AppData\Local\Temp\ipykernel_13696\365482116.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) get_termination. (Please use `from pymoo.termination import get_termination`)
#   term = get_termination("n_gen", ITERATIONS)
#   0%|          | 0/32 [00:00<?, ?it/s]
# =======================================================================
# n_gen  |  n_eval  |     score     |              Parameters
# =======================================================================
#      1 |       32 |  0.8366327377 |                                   -
#      2 |       64 |  0.8366327377 |                                   -
#      3 |       96 |  0.8366327377 |                                   -
#      4 |      128 |  0.8430291146 |                                   -
#      5 |      160 |  0.8430291146 |                                   -
#      6 |      192 |  0.8430291146 |                                   -
#      7 |      224 |  0.8430291146 |                                   -
#      8 |      256 |  0.8436413653 |                                   -
#      9 |      288 |  0.8443489960 |                                   -
#     10 |      320 |  0.8445609911 |                                   -
#     11 |      352 |  0.8453407990 |                                   -
#     12 |      384 |  0.8453407990 |                                   -
#     13 |      416 |  0.8453407990 |                                   -
#     14 |      448 |  0.8458668513 |                                   -
#     15 |      480 |  0.8458668513 |                                   -
#     16 |      512 |  0.8458668513 |                                   -
#     17 |      544 |  0.8459442215 |                                   -
#     18 |      576 |  0.8459442215 |                                   -
#     19 |      608 |  0.8463382656 |                                   -
#     20 |      640 |  0.8469289124 |                                   -
#     21 |      672 |  0.8469289124 |                                   -
#     22 |      704 |  0.8469289124 |                                   -
#     23 |      736 |  0.8469289124 |                                   -
#     24 |      768 |  0.8469289124 |                                   -
#     25 |      800 |  0.8469289124 |                                   -
#     26 |      832 |  0.8469289124 |                                   -
#     27 |      864 |  0.8469289124 |                                   -
#     28 |      896 |  0.8471740628 |                                   -
#     29 |      928 |  0.8471740628 |                                   -
#     30 |      960 |  0.8471740628 |                                   -
#     31 |      992 |  0.8475218508 |                                   -
#     32 |     1024 |  0.8475218508 |                                   -
# Best AUC Score [0.84752185]
# Model parameters:
#  [6.90104461e+01 1.45443786e+01 4.22323373e+02 9.90577293e-02
#  1.82467882e+05 1.54263413e-01 5.76349041e-02 1.58182941e-02
#  1.28116839e+01]

# %%
trlist = np.array([])
for i in range(len(res.history)):
  trlist = np.append(trlist, -res.history[i].pop.get('F').reshape(-1)) 
  
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
AUC_GA = scorelist

plt.plot(scorelist);

# %%
tracking = [-np.min(individual.pop.get('F')) for individual in res.history ]
tracking_GA_AUC = tracking
plt.plot(tracking)

# %% [markdown]
# ## Grid Search

# %% [markdown]
# ### Acurácia

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_possibilities = 2

#num_leaves_grid = [i for i in range(num_leaves_min,num_leaves_max, int((num_leaves_max)/13))]
num_leaves_grid = [i for i in map(lambda x: int(x), np.linspace(num_leaves_min, num_leaves_max, n_possibilities))]
num_leaves_grid = num_leaves_grid + [100, 50, 75, 125, 11,150]
print('Num_Leaves_Grid: ')
print(num_leaves_grid, len(num_leaves_grid))
print('\n')


min_child_samples_grid = [i for i in map(lambda x: int(x), np.linspace(min_child_samples_min, min_child_samples_max, n_possibilities))]
print('min_child_samples_grid:')
print(min_child_samples_grid, len(min_child_samples_grid))
print('\n')

n_estimators_grid = [i for i in map(lambda x: int(x), np.linspace(n_estimators_min, n_estimators_max, n_possibilities))]
print('n_estimators_grid:')
print(n_estimators_grid, len(n_estimators_grid))
print('\n')

learning_rate_grid = np.linspace(learning_rate_min, learning_rate_max, n_possibilities)
print('learning_rate_grid:')
print(learning_rate_grid, len(learning_rate_grid))
print('\n')

subsample_for_bin_grid = [i for i in map(lambda x: int(x), np.linspace(subsample_for_bin_min, subsample_for_bin_max, n_possibilities))]
print('subsample_for_bin_grid:')
print(subsample_for_bin_grid, len(subsample_for_bin_grid))
print('\n')

min_split_gain_grid = np.linspace(min_split_gain_min, min_split_gain_max, n_possibilities)
print('min_split_gain_grid:')
print(min_split_gain_grid, len(min_split_gain_grid))
print('\n')

min_child_weight_grid = np.linspace(min_child_weight_min, min_child_weight_max, n_possibilities)
print('min_child_weight_grid:')
print(min_child_weight_grid, len(min_child_weight_grid))
print('\n')

reg_alpha_grid = np.linspace(reg_alpha_min, reg_alpha_max, n_possibilities)
print('reg_alpha_grid:')
print(reg_alpha_grid, len(reg_alpha_grid))
print('\n')
# Out:
# Num_Leaves_Grid:
# [10, 200, 100, 50, 75, 125, 11, 150] 8
#
#
# min_child_samples_grid:
# [10, 50] 2
#
#
# n_estimators_grid:
# [20, 1000] 2
#
#
# learning_rate_grid:
# [0.001 0.5  ] 2
#
#
# subsample_for_bin_grid:
# [50000, 500000] 2
#
#
# min_split_gain_grid:
# [0.01 0.5 ] 2
#
#
# min_child_weight_grid:
# [0.001 0.15 ] 2
#
#
# reg_alpha_grid:
# [1.e-02 1.e+02] 2

# %%
parametros = {'num_leaves': num_leaves_grid, #int
              'min_child_samples': min_child_samples_grid,#int
              'n_estimators': n_estimators_grid, #int
              'learning_rate': learning_rate_grid,
              'subsample_for_bin': subsample_for_bin_grid, # int
              'min_split_gain': min_split_gain_grid,
              'min_child_weight': min_child_weight_grid,
              'reg_alpha': reg_alpha_grid,
              'max_depth': [-1],
              'n_jobs': [-1]}

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, verbose = 3)
grid_search.fit(x_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# c:\Users\Felps\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 50, 'min_child_weight': 0.001, 'min_split_gain': 0.5, 'n_estimators': 20, 'n_jobs': -1, 'num_leaves': 75, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.8408274033013522

# %%
grid_search.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_learning_rate', 'param_max_depth', 'param_min_child_samples', 'param_min_child_weight', 'param_min_split_gain', 'param_n_estimators', 'param_n_jobs', 'param_num_leaves', 'param_reg_alpha', 'param_subsample_for_bin', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %%
trlist = grid_search.cv_results_['mean_test_score']

# %%
scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])

# %%
tracking_GS_Accuracy = scorelist
plt.plot(scorelist);

# %% [markdown]
# ### F1 Score

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, scoring='f1', verbose = 3)
grid_search.fit(x_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)

trlist = grid_search.cv_results_['mean_test_score']


scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
tracking_GS_F1 = scorelist
plt.plot(scorelist);
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 50, 'min_child_weight': 0.15, 'min_split_gain': 0.01, 'n_estimators': 1000, 'n_jobs': -1, 'num_leaves': 150, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.5646888200150082

# %% [markdown]
# ### AUC

# %%
kfold = KFold(n_splits = 3, shuffle = True)
grid_search = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid = parametros, cv = kfold, n_jobs= -1, scoring='roc_auc', verbose = 3)
grid_search.fit(x_credit, y_credit)
melhores_parametros = grid_search.best_params_
melhor_resultado = grid_search.best_score_
print(melhores_parametros)
print(melhor_resultado)

trlist = grid_search.cv_results_['mean_test_score']


scorelist = []

for i in range(len(trlist)):
#for i in range(1):
  if i == 0:
    scorelist.append(trlist[i])
  elif trlist[i] > scorelist[i-1]:
    scorelist.append(trlist[i])
  else:
    scorelist.append(scorelist[i-1])
    
tracking_GS_AUC = scorelist
plt.plot(scorelist);
# Out:
# Fitting 3 folds for each of 1024 candidates, totalling 3072 fits
# {'learning_rate': 0.5, 'max_depth': -1, 'min_child_samples': 50, 'min_child_weight': 0.001, 'min_split_gain': 0.5, 'n_estimators': 20, 'n_jobs': -1, 'num_leaves': 50, 'reg_alpha': 0.01, 'subsample_for_bin': 50000}
# 0.8396421475535306

# %% [markdown]
# ## Optuna

# %% [markdown]
# ### Acurácia

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (3.1.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.9.2)
# Requirement already satisfied: cmaes>=0.9.1 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.7.0)
# Requirement already satisfied: numpy in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (23.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (2.0.0)
# Requirement already satisfied: tqdm in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (4.64.1)
# Requirement already satisfied: PyYAML in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: Mako in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (2.0.1)
# Requirement already satisfied: colorama in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\felps\appdata\local\programs\python\python311\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %%
import optuna
import sklearn
from sklearn import datasets
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_credit, y_credit, n_jobs=-1, cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)
# Out:
# [I 2023-01-28 11:52:46,194] A new study created in memory with name: no-name-0d9297d4-884e-44be-b842-b2e879dfa652
# [I 2023-01-28 11:52:46,316] Trial 0 finished with value: 0.8307910400123352 and parameters: {'num_leaves': 93, 'min_child_samples': 46, 'n_estimators': 339, 'learning_rate': 0.47837958328948266, 'subsample_for_bin': 99508, 'min_split_gain': 0.34329921214568004, 'min_child_weight': 0.14079814742233873, 'reg_alpha': 58.76627593528829, 'reg_lambda': 40.1071183447435}. Best is trial 0 with value: 0.8307910400123352.
# [I 2023-01-28 11:52:46,463] Trial 1 finished with value: 0.8347808986925528 and parameters: {'num_leaves': 109, 'min_child_samples': 16, 'n_estimators': 424, 'learning_rate': 0.24365841728321438, 'subsample_for_bin': 479065, 'min_split_gain': 0.3615776762283977, 'min_child_weight': 0.14040255821731903, 'reg_alpha': 45.46296536910834, 'reg_lambda': 83.14086594797254}. Best is trial 1 with value: 0.8347808986925528.
# [I 2023-01-28 11:52:46,517] Trial 2 finished with value: 0.8393542028859686 and parameters: {'num_leaves': 70, 'min_child_samples': 44, 'n_estimators': 21, 'learning_rate': 0.25471175161349885, 'subsample_for_bin': 123163, 'min_split_gain': 0.3520185927116716, 'min_child_weight': 0.0960138130117726, 'reg_alpha': 6.975156125026463, 'reg_lambda': 12.175015549678495}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:46,703] Trial 3 finished with value: 0.8333997312657081 and parameters: {'num_leaves': 197, 'min_child_samples': 26, 'n_estimators': 571, 'learning_rate': 0.459591002533476, 'subsample_for_bin': 206712, 'min_split_gain': 0.27657354311792615, 'min_child_weight': 0.04858173021007906, 'reg_alpha': 66.90169884784522, 'reg_lambda': 36.40990604992816}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:46,773] Trial 4 finished with value: 0.8365611856593578 and parameters: {'num_leaves': 20, 'min_child_samples': 21, 'n_estimators': 137, 'learning_rate': 0.33814793909846824, 'subsample_for_bin': 285117, 'min_split_gain': 0.24673476918626253, 'min_child_weight': 0.12400929162030656, 'reg_alpha': 24.559431625034325, 'reg_lambda': 24.37705286349767}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:46,805] Trial 5 finished with value: 0.829471172332294 and parameters: {'num_leaves': 154, 'min_child_samples': 24, 'n_estimators': 20, 'learning_rate': 0.3958279491617296, 'subsample_for_bin': 408456, 'min_split_gain': 0.13715317411252, 'min_child_weight': 0.017029134128180655, 'reg_alpha': 83.26757510983235, 'reg_lambda': 5.101385719676399}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:46,917] Trial 6 finished with value: 0.8368067152938615 and parameters: {'num_leaves': 123, 'min_child_samples': 13, 'n_estimators': 296, 'learning_rate': 0.336432220229244, 'subsample_for_bin': 226944, 'min_split_gain': 0.27132788951353815, 'min_child_weight': 0.1266530906146765, 'reg_alpha': 21.98052493990829, 'reg_lambda': 22.72741028239678}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:47,083] Trial 7 finished with value: 0.8365611941374936 and parameters: {'num_leaves': 108, 'min_child_samples': 33, 'n_estimators': 452, 'learning_rate': 0.36542283824800503, 'subsample_for_bin': 260217, 'min_split_gain': 0.01413609638379009, 'min_child_weight': 0.1499972587732713, 'reg_alpha': 28.334177620930035, 'reg_lambda': 38.74808028216706}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:47,261] Trial 8 finished with value: 0.8358244752359028 and parameters: {'num_leaves': 54, 'min_child_samples': 22, 'n_estimators': 508, 'learning_rate': 0.4148484603285116, 'subsample_for_bin': 82554, 'min_split_gain': 0.07257728939360215, 'min_child_weight': 0.12821378791370097, 'reg_alpha': 32.893259560989414, 'reg_lambda': 31.196076662774573}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:47,347] Trial 9 finished with value: 0.8363463892665898 and parameters: {'num_leaves': 170, 'min_child_samples': 15, 'n_estimators': 171, 'learning_rate': 0.3776168587131192, 'subsample_for_bin': 327191, 'min_split_gain': 0.14882752780268393, 'min_child_weight': 0.12155179524427247, 'reg_alpha': 21.758066397764313, 'reg_lambda': 30.309539300459818}. Best is trial 2 with value: 0.8393542028859686.
# [I 2023-01-28 11:52:47,683] Trial 10 finished with value: 0.8415027800654613 and parameters: {'num_leaves': 59, 'min_child_samples': 49, 'n_estimators': 836, 'learning_rate': 0.12431834909485101, 'subsample_for_bin': 146755, 'min_split_gain': 0.468765696631426, 'min_child_weight': 0.0890939482266778, 'reg_alpha': 0.15339068413756785, 'reg_lambda': 0.5976604904850813}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:48,030] Trial 11 finished with value: 0.8409502712692544 and parameters: {'num_leaves': 62, 'min_child_samples': 50, 'n_estimators': 887, 'learning_rate': 0.10920497553600444, 'subsample_for_bin': 159328, 'min_split_gain': 0.4783366421372096, 'min_child_weight': 0.08962741654336165, 'reg_alpha': 4.528359248263792, 'reg_lambda': 0.3115549914862304}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:48,400] Trial 12 finished with value: 0.8414105125151695 and parameters: {'num_leaves': 25, 'min_child_samples': 39, 'n_estimators': 906, 'learning_rate': 0.0780915405587024, 'subsample_for_bin': 177926, 'min_split_gain': 0.4739778070846321, 'min_child_weight': 0.08013868984361587, 'reg_alpha': 0.4236231994120736, 'reg_lambda': 4.433146049450084}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:48,895] Trial 13 finished with value: 0.8411958319902553 and parameters: {'num_leaves': 19, 'min_child_samples': 39, 'n_estimators': 983, 'learning_rate': 0.032731220946342315, 'subsample_for_bin': 167622, 'min_split_gain': 0.46980586707108296, 'min_child_weight': 0.06368280996302285, 'reg_alpha': 1.5911190361652199, 'reg_lambda': 1.6731866150732448}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:49,217] Trial 14 finished with value: 0.8411344559402312 and parameters: {'num_leaves': 40, 'min_child_samples': 38, 'n_estimators': 761, 'learning_rate': 0.11590574322576366, 'subsample_for_bin': 338048, 'min_split_gain': 0.43704402174609114, 'min_child_weight': 0.09394274900364111, 'reg_alpha': 1.093855157672901, 'reg_lambda': 15.754769203187474}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:49,970] Trial 15 finished with value: 0.8341363879943042 and parameters: {'num_leaves': 10, 'min_child_samples': 35, 'n_estimators': 690, 'learning_rate': 0.007124503902156451, 'subsample_for_bin': 161199, 'min_split_gain': 0.41207483762010944, 'min_child_weight': 0.06953486318400334, 'reg_alpha': 13.451436971451283, 'reg_lambda': 57.26222603866928}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:50,293] Trial 16 finished with value: 0.8394154235035058 and parameters: {'num_leaves': 40, 'min_child_samples': 43, 'n_estimators': 820, 'learning_rate': 0.11236280476531071, 'subsample_for_bin': 58756, 'min_split_gain': 0.41696424095834617, 'min_child_weight': 0.04751664448319755, 'reg_alpha': 13.159315956216478, 'reg_lambda': 13.077147118458175}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:50,656] Trial 17 finished with value: 0.8344127299998095 and parameters: {'num_leaves': 88, 'min_child_samples': 50, 'n_estimators': 973, 'learning_rate': 0.15529160159668948, 'subsample_for_bin': 187786, 'min_split_gain': 0.46181492595638646, 'min_child_weight': 0.10799682469034066, 'reg_alpha': 38.753313333149435, 'reg_lambda': 13.754534512423433}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:51,096] Trial 18 finished with value: 0.8378195953340638 and parameters: {'num_leaves': 38, 'min_child_samples': 30, 'n_estimators': 640, 'learning_rate': 0.052895783980165784, 'subsample_for_bin': 117293, 'min_split_gain': 0.49792189765871775, 'min_child_weight': 0.07239866835702277, 'reg_alpha': 12.372335065475852, 'reg_lambda': 50.82659852807926}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:51,420] Trial 19 finished with value: 0.8352721444805443 and parameters: {'num_leaves': 81, 'min_child_samples': 40, 'n_estimators': 873, 'learning_rate': 0.18551157611426272, 'subsample_for_bin': 249870, 'min_split_gain': 0.4942793476995713, 'min_child_weight': 0.08531071358590268, 'reg_alpha': 36.20535893571452, 'reg_lambda': 1.1625344869623264}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:51,802] Trial 20 finished with value: 0.8386482991814247 and parameters: {'num_leaves': 54, 'min_child_samples': 47, 'n_estimators': 747, 'learning_rate': 0.050137684126628904, 'subsample_for_bin': 330361, 'min_split_gain': 0.39170861429262205, 'min_child_weight': 0.10344714242476909, 'reg_alpha': 18.65083563123619, 'reg_lambda': 21.675120168556425}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:52,537] Trial 21 finished with value: 0.841410636861159 and parameters: {'num_leaves': 28, 'min_child_samples': 40, 'n_estimators': 995, 'learning_rate': 0.019820828589859393, 'subsample_for_bin': 156548, 'min_split_gain': 0.4482117206662629, 'min_child_weight': 0.06274951596662727, 'reg_alpha': 0.5035853748831656, 'reg_lambda': 0.6399330645043807}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:52,975] Trial 22 finished with value: 0.8412879384559698 and parameters: {'num_leaves': 30, 'min_child_samples': 42, 'n_estimators': 914, 'learning_rate': 0.06309084440544113, 'subsample_for_bin': 136755, 'min_split_gain': 0.4397824737320832, 'min_child_weight': 0.07941245822914489, 'reg_alpha': 0.5886508718502165, 'reg_lambda': 8.577019117194306}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:54,132] Trial 23 finished with value: 0.8328472789904056 and parameters: {'num_leaves': 50, 'min_child_samples': 35, 'n_estimators': 812, 'learning_rate': 0.002230623625676942, 'subsample_for_bin': 209403, 'min_split_gain': 0.4401582555867333, 'min_child_weight': 0.0584498057383468, 'reg_alpha': 11.251031537812768, 'reg_lambda': 8.944024930738758}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:54,514] Trial 24 finished with value: 0.8400600133310205 and parameters: {'num_leaves': 73, 'min_child_samples': 29, 'n_estimators': 991, 'learning_rate': 0.0870326471902319, 'subsample_for_bin': 288672, 'min_split_gain': 0.49828514456656203, 'min_child_weight': 0.08418366978873093, 'reg_alpha': 8.979063643022814, 'reg_lambda': 0.4047326811159717}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:54,802] Trial 25 finished with value: 0.8384643575503365 and parameters: {'num_leaves': 24, 'min_child_samples': 47, 'n_estimators': 648, 'learning_rate': 0.07564597523612054, 'subsample_for_bin': 74812, 'min_split_gain': 0.38789390663900025, 'min_child_weight': 0.07635741475468232, 'reg_alpha': 16.062488113732066, 'reg_lambda': 17.785496259227912}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:55,125] Trial 26 finished with value: 0.8395690868861384 and parameters: {'num_leaves': 11, 'min_child_samples': 37, 'n_estimators': 910, 'learning_rate': 0.1544662800014373, 'subsample_for_bin': 186492, 'min_split_gain': 0.45936570952706235, 'min_child_weight': 0.1079285871384239, 'reg_alpha': 0.15064093003901685, 'reg_lambda': 8.392915115607108}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:55,686] Trial 27 finished with value: 0.8405819188835718 and parameters: {'num_leaves': 127, 'min_child_samples': 32, 'n_estimators': 818, 'learning_rate': 0.02581202288427866, 'subsample_for_bin': 146798, 'min_split_gain': 0.4099777378418802, 'min_child_weight': 0.05676728808242224, 'reg_alpha': 7.96039816113477, 'reg_lambda': 8.11039485844889}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:56,558] Trial 28 finished with value: 0.834105764968332 and parameters: {'num_leaves': 37, 'min_child_samples': 42, 'n_estimators': 731, 'learning_rate': 0.004059785155069648, 'subsample_for_bin': 104472, 'min_split_gain': 0.4538014106777338, 'min_child_weight': 0.035712599802515406, 'reg_alpha': 27.622896182450493, 'reg_lambda': 18.30536670071717}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:56,925] Trial 29 finished with value: 0.8393542028859686 and parameters: {'num_leaves': 97, 'min_child_samples': 47, 'n_estimators': 927, 'learning_rate': 0.08753793216073506, 'subsample_for_bin': 50368, 'min_split_gain': 0.32512091942043597, 'min_child_weight': 0.06868343849473171, 'reg_alpha': 15.975691963180076, 'reg_lambda': 24.23891995594957}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:57,413] Trial 30 finished with value: 0.8413186180028461 and parameters: {'num_leaves': 49, 'min_child_samples': 45, 'n_estimators': 842, 'learning_rate': 0.03605821163687437, 'subsample_for_bin': 246214, 'min_split_gain': 0.3691109784290758, 'min_child_weight': 0.07913312385898211, 'reg_alpha': 6.788105948868598, 'reg_lambda': 6.392023559720808}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:57,825] Trial 31 finished with value: 0.8400294016092293 and parameters: {'num_leaves': 49, 'min_child_samples': 46, 'n_estimators': 801, 'learning_rate': 0.04818474987262481, 'subsample_for_bin': 224207, 'min_split_gain': 0.38007368250770734, 'min_child_weight': 0.0774395632942469, 'reg_alpha': 7.04313679160564, 'reg_lambda': 6.418658336889785}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:58,338] Trial 32 finished with value: 0.8402442630010373 and parameters: {'num_leaves': 66, 'min_child_samples': 45, 'n_estimators': 848, 'learning_rate': 0.03538389248128074, 'subsample_for_bin': 188677, 'min_split_gain': 0.42352030636277493, 'min_child_weight': 0.08582304828856475, 'reg_alpha': 5.712584784788975, 'reg_lambda': 14.701075876989732}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:58,690] Trial 33 finished with value: 0.8387402756490592 and parameters: {'num_leaves': 30, 'min_child_samples': 50, 'n_estimators': 944, 'learning_rate': 0.07649800796519884, 'subsample_for_bin': 244954, 'min_split_gain': 0.3739718482932344, 'min_child_weight': 0.09671271450998584, 'reg_alpha': 18.49981577137322, 'reg_lambda': 0.3212153615030633}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:59,127] Trial 34 finished with value: 0.8413185643079872 and parameters: {'num_leaves': 75, 'min_child_samples': 41, 'n_estimators': 575, 'learning_rate': 0.03244311587613086, 'subsample_for_bin': 476889, 'min_split_gain': 0.46599948039174255, 'min_child_weight': 0.0784621665149868, 'reg_alpha': 6.384556750267899, 'reg_lambda': 10.863199384437234}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:59,428] Trial 35 finished with value: 0.8337067810785421 and parameters: {'num_leaves': 61, 'min_child_samples': 44, 'n_estimators': 870, 'learning_rate': 0.13150573580461036, 'subsample_for_bin': 125392, 'min_split_gain': 0.3359748458451259, 'min_child_weight': 0.06949891574530896, 'reg_alpha': 48.57388791294304, 'reg_lambda': 5.686187824160741}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:52:59,683] Trial 36 finished with value: 0.8322335693589777 and parameters: {'num_leaves': 23, 'min_child_samples': 48, 'n_estimators': 693, 'learning_rate': 0.09443452920461853, 'subsample_for_bin': 94957, 'min_split_gain': 0.3585823111457724, 'min_child_weight': 0.09786878207843355, 'reg_alpha': 55.62959608121445, 'reg_lambda': 17.57969892835036}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:53:00,095] Trial 37 finished with value: 0.8398146391290039 and parameters: {'num_leaves': 45, 'min_child_samples': 37, 'n_estimators': 989, 'learning_rate': 0.06424283341579065, 'subsample_for_bin': 290841, 'min_split_gain': 0.4065631431959273, 'min_child_weight': 0.09122976277559226, 'reg_alpha': 8.745781007143771, 'reg_lambda': 6.0758222562107385}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:53:00,376] Trial 38 finished with value: 0.8359473234214884 and parameters: {'num_leaves': 118, 'min_child_samples': 10, 'n_estimators': 764, 'learning_rate': 0.137420478083748, 'subsample_for_bin': 204201, 'min_split_gain': 0.43350708356188505, 'min_child_weight': 0.06125034702132108, 'reg_alpha': 24.104936931479067, 'reg_lambda': 28.40424983159815}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:53:00,529] Trial 39 finished with value: 0.8402750047209085 and parameters: {'num_leaves': 31, 'min_child_samples': 45, 'n_estimators': 267, 'learning_rate': 0.1911325690772658, 'subsample_for_bin': 366472, 'min_split_gain': 0.47877168822758676, 'min_child_weight': 0.05044890054579137, 'reg_alpha': 4.518551175867674, 'reg_lambda': 20.337988748086367}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:53:00,930] Trial 40 finished with value: 0.8413799007933783 and parameters: {'num_leaves': 197, 'min_child_samples': 40, 'n_estimators': 574, 'learning_rate': 0.09583555854868397, 'subsample_for_bin': 236589, 'min_split_gain': 0.31990981488535253, 'min_child_weight': 0.08529621006883668, 'reg_alpha': 0.3034968450669491, 'reg_lambda': 11.744471607527046}. Best is trial 10 with value: 0.8415027800654613.
# [I 2023-01-28 11:53:01,408] Trial 41 finished with value: 0.8421471579395847 and parameters: {'num_leaves': 200, 'min_child_samples': 40, 'n_estimators': 422, 'learning_rate': 0.06755707975977922, 'subsample_for_bin': 231123, 'min_split_gain': 0.30403672407631277, 'min_child_weight': 0.08246107620530978, 'reg_alpha': 0.0984731274962116, 'reg_lambda': 13.108401261964547}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:01,779] Trial 42 finished with value: 0.840704758591022 and parameters: {'num_leaves': 196, 'min_child_samples': 35, 'n_estimators': 383, 'learning_rate': 0.08722678511250417, 'subsample_for_bin': 172724, 'min_split_gain': 0.2974392277364165, 'min_child_weight': 0.08659223065284419, 'reg_alpha': 0.3539350074593929, 'reg_lambda': 12.740190796225638}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:02,023] Trial 43 finished with value: 0.8396918220299155 and parameters: {'num_leaves': 186, 'min_child_samples': 27, 'n_estimators': 480, 'learning_rate': 0.10968915090757653, 'subsample_for_bin': 272533, 'min_split_gain': 0.23917080270112806, 'min_child_weight': 0.10121022689004233, 'reg_alpha': 12.496923540142427, 'reg_lambda': 4.141496349749054}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:02,257] Trial 44 finished with value: 0.837696812147518 and parameters: {'num_leaves': 145, 'min_child_samples': 40, 'n_estimators': 390, 'learning_rate': 0.0638239715356778, 'subsample_for_bin': 221510, 'min_split_gain': 0.3500627588233676, 'min_child_weight': 0.09349405319806646, 'reg_alpha': 18.63379813921133, 'reg_lambda': 10.683305565889375}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:02,501] Trial 45 finished with value: 0.8406432581950082 and parameters: {'num_leaves': 175, 'min_child_samples': 33, 'n_estimators': 591, 'learning_rate': 0.25892855799690395, 'subsample_for_bin': 152731, 'min_split_gain': 0.3113590307867443, 'min_child_weight': 0.06787348827649926, 'reg_alpha': 4.097033060822311, 'reg_lambda': 25.311795367984004}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:03,029] Trial 46 finished with value: 0.8386788882948543 and parameters: {'num_leaves': 160, 'min_child_samples': 37, 'n_estimators': 307, 'learning_rate': 0.018275145194048326, 'subsample_for_bin': 206752, 'min_split_gain': 0.2482967036650049, 'min_child_weight': 0.07414378176274594, 'reg_alpha': 11.095085512034865, 'reg_lambda': 34.59743441829755}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:03,311] Trial 47 finished with value: 0.8407967322326114 and parameters: {'num_leaves': 189, 'min_child_samples': 43, 'n_estimators': 522, 'learning_rate': 0.10067794359012947, 'subsample_for_bin': 312634, 'min_split_gain': 0.3487847276089844, 'min_child_weight': 0.11359113854193097, 'reg_alpha': 3.179473078990571, 'reg_lambda': 3.6627306545889122}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:03,642] Trial 48 finished with value: 0.8418095727081805 and parameters: {'num_leaves': 141, 'min_child_samples': 19, 'n_estimators': 184, 'learning_rate': 0.0705169587313342, 'subsample_for_bin': 173242, 'min_split_gain': 0.39887057773370616, 'min_child_weight': 0.08197315808042376, 'reg_alpha': 0.12950592106754308, 'reg_lambda': 13.716935532224335}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:03,808] Trial 49 finished with value: 0.83932349507864 and parameters: {'num_leaves': 148, 'min_child_samples': 18, 'n_estimators': 86, 'learning_rate': 0.05319615125668507, 'subsample_for_bin': 140479, 'min_split_gain': 0.39631961775077523, 'min_child_weight': 0.09125229727402022, 'reg_alpha': 10.014621912295961, 'reg_lambda': 16.00093104411249}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:03,952] Trial 50 finished with value: 0.8365304185050797 and parameters: {'num_leaves': 134, 'min_child_samples': 23, 'n_estimators': 238, 'learning_rate': 0.12657404918687942, 'subsample_for_bin': 178357, 'min_split_gain': 0.44983546665546414, 'min_child_weight': 0.0656266139192065, 'reg_alpha': 21.69121646083124, 'reg_lambda': 21.146599632724282}. Best is trial 41 with value: 0.8421471579395847.
# [I 2023-01-28 11:53:04,233] Trial 51 finished with value: 0.842147279459529 and parameters: {'num_leaves': 179, 'min_child_samples': 39, 'n_estimators': 178, 'learning_rate': 0.07366294817140377, 'subsample_for_bin': 227919, 'min_split_gain': 0.42258306823207037, 'min_child_weight': 0.08438764348755409, 'reg_alpha': 0.13749833321529512, 'reg_lambda': 0.202080972576816}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:04,514] Trial 52 finished with value: 0.8407352148803263 and parameters: {'num_leaves': 180, 'min_child_samples': 26, 'n_estimators': 187, 'learning_rate': 0.04535389406412356, 'subsample_for_bin': 118145, 'min_split_gain': 0.4315384738885647, 'min_child_weight': 0.08141382707072696, 'reg_alpha': 4.148505521106779, 'reg_lambda': 4.379551470580136}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:04,725] Trial 53 finished with value: 0.837175028114911 and parameters: {'num_leaves': 157, 'min_child_samples': 20, 'n_estimators': 134, 'learning_rate': 0.02347475186000403, 'subsample_for_bin': 264450, 'min_split_gain': 0.4796082758449068, 'min_child_weight': 0.07338324980192557, 'reg_alpha': 14.50326110594761, 'reg_lambda': 0.6341038324111656}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:04,893] Trial 54 finished with value: 0.8399988237999807 and parameters: {'num_leaves': 165, 'min_child_samples': 31, 'n_estimators': 68, 'learning_rate': 0.0698045664571349, 'subsample_for_bin': 199382, 'min_split_gain': 0.4217901235807252, 'min_child_weight': 0.08744117783623823, 'reg_alpha': 4.066628641345786, 'reg_lambda': 14.491226389834093}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:05,244] Trial 55 finished with value: 0.8397225383153798 and parameters: {'num_leaves': 101, 'min_child_samples': 38, 'n_estimators': 210, 'learning_rate': 0.017432657894507358, 'subsample_for_bin': 159727, 'min_split_gain': 0.45061967542585596, 'min_child_weight': 0.08149635352310246, 'reg_alpha': 9.068888224833783, 'reg_lambda': 3.680918507414226}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:05,608] Trial 56 finished with value: 0.8417482757874223 and parameters: {'num_leaves': 190, 'min_child_samples': 34, 'n_estimators': 318, 'learning_rate': 0.06665572130494368, 'subsample_for_bin': 220989, 'min_split_gain': 0.397383286971498, 'min_child_weight': 0.09303880088672939, 'reg_alpha': 0.6458005931892562, 'reg_lambda': 7.672205334904499}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:05,910] Trial 57 finished with value: 0.8406433288461388 and parameters: {'num_leaves': 200, 'min_child_samples': 28, 'n_estimators': 340, 'learning_rate': 0.05997285466936897, 'subsample_for_bin': 225679, 'min_split_gain': 0.4012473394924664, 'min_child_weight': 0.09503088556516281, 'reg_alpha': 3.356783933592456, 'reg_lambda': 10.19909581389679}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:06,103] Trial 58 finished with value: 0.8395382801672273 and parameters: {'num_leaves': 184, 'min_child_samples': 36, 'n_estimators': 340, 'learning_rate': 0.10959131762824911, 'subsample_for_bin': 134839, 'min_split_gain': 0.3680434663133753, 'min_child_weight': 0.10095031886648276, 'reg_alpha': 11.48881333886078, 'reg_lambda': 0.5600205015276872}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:06,412] Trial 59 finished with value: 0.8415333946132977 and parameters: {'num_leaves': 169, 'min_child_samples': 33, 'n_estimators': 148, 'learning_rate': 0.07735548834573194, 'subsample_for_bin': 260558, 'min_split_gain': 0.3842175258201043, 'min_child_weight': 0.09001795228006793, 'reg_alpha': 0.4454894352191139, 'reg_lambda': 9.767465140061859}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:06,604] Trial 60 finished with value: 0.8404285041929186 and parameters: {'num_leaves': 171, 'min_child_samples': 34, 'n_estimators': 139, 'learning_rate': 0.07697469204129832, 'subsample_for_bin': 304224, 'min_split_gain': 0.38604274145239137, 'min_child_weight': 0.0878144621571503, 'reg_alpha': 6.979655158937423, 'reg_lambda': 19.264065764827706}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:07,005] Trial 61 finished with value: 0.8419630863104165 and parameters: {'num_leaves': 179, 'min_child_samples': 31, 'n_estimators': 425, 'learning_rate': 0.0485769222448214, 'subsample_for_bin': 260672, 'min_split_gain': 0.41486465190046895, 'min_child_weight': 0.09097892205161248, 'reg_alpha': 2.195343245872536, 'reg_lambda': 9.070825458092823}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:07,378] Trial 62 finished with value: 0.8406741836078186 and parameters: {'num_leaves': 192, 'min_child_samples': 31, 'n_estimators': 436, 'learning_rate': 0.04723318454211655, 'subsample_for_bin': 258599, 'min_split_gain': 0.4150740175536458, 'min_child_weight': 0.09170722561958189, 'reg_alpha': 3.2167846044026005, 'reg_lambda': 12.460224599123}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:07,702] Trial 63 finished with value: 0.8417482927436938 and parameters: {'num_leaves': 178, 'min_child_samples': 29, 'n_estimators': 382, 'learning_rate': 0.0837165392034357, 'subsample_for_bin': 276065, 'min_split_gain': 0.40184637036497456, 'min_child_weight': 0.10469330379962463, 'reg_alpha': 0.4629404901857803, 'reg_lambda': 9.086390614043683}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:08,080] Trial 64 finished with value: 0.8416254869487862 and parameters: {'num_leaves': 178, 'min_child_samples': 25, 'n_estimators': 379, 'learning_rate': 0.08494617367443387, 'subsample_for_bin': 269820, 'min_split_gain': 0.3987887045026685, 'min_child_weight': 0.10407293742620766, 'reg_alpha': 0.01970852836004769, 'reg_lambda': 15.853716912710604}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:08,317] Trial 65 finished with value: 0.8399681244707877 and parameters: {'num_leaves': 183, 'min_child_samples': 25, 'n_estimators': 416, 'learning_rate': 0.09432408971584555, 'subsample_for_bin': 278608, 'min_split_gain': 0.40615767123459345, 'min_child_weight': 0.10570500122891432, 'reg_alpha': 9.114215758448822, 'reg_lambda': 16.904937847153377}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:08,616] Trial 66 finished with value: 0.8386175772438701 and parameters: {'num_leaves': 177, 'min_child_samples': 29, 'n_estimators': 305, 'learning_rate': 0.03833432354215217, 'subsample_for_bin': 370612, 'min_split_gain': 0.36255566794501204, 'min_child_weight': 0.11227904701914766, 'reg_alpha': 14.53587875283939, 'reg_lambda': 14.56937240161775}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:09,217] Trial 67 finished with value: 0.8177771978732992 and parameters: {'num_leaves': 163, 'min_child_samples': 18, 'n_estimators': 370, 'learning_rate': 0.0030226023444280964, 'subsample_for_bin': 302509, 'min_split_gain': 0.42259518428075, 'min_child_weight': 0.09908356338509304, 'reg_alpha': 6.0704991936332044, 'reg_lambda': 22.885574241472785}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:09,579] Trial 68 finished with value: 0.8410423692568333 and parameters: {'num_leaves': 149, 'min_child_samples': 24, 'n_estimators': 514, 'learning_rate': 0.05873441332680265, 'subsample_for_bin': 236910, 'min_split_gain': 0.40107545626542207, 'min_child_weight': 0.10446564339496131, 'reg_alpha': 2.7382125759388733, 'reg_lambda': 9.016460458179697}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:09,831] Trial 69 finished with value: 0.8401215448135316 and parameters: {'num_leaves': 139, 'min_child_samples': 21, 'n_estimators': 465, 'learning_rate': 0.10577729104507622, 'subsample_for_bin': 350170, 'min_split_gain': 0.3768036242197317, 'min_child_weight': 0.0965897088618225, 'reg_alpha': 10.062656369180255, 'reg_lambda': 26.713866728304808}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:10,064] Trial 70 finished with value: 0.8418095246654117 and parameters: {'num_leaves': 191, 'min_child_samples': 14, 'n_estimators': 425, 'learning_rate': 0.11856675610892654, 'subsample_for_bin': 214413, 'min_split_gain': 0.3403368787944513, 'min_child_weight': 0.09843097173166938, 'reg_alpha': 5.800036670406257, 'reg_lambda': 6.793686136354873}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:10,335] Trial 71 finished with value: 0.8409503164859778 and parameters: {'num_leaves': 193, 'min_child_samples': 13, 'n_estimators': 420, 'learning_rate': 0.08144324767995098, 'subsample_for_bin': 220854, 'min_split_gain': 0.35482572135467194, 'min_child_weight': 0.11093513800204133, 'reg_alpha': 5.370558834015126, 'reg_lambda': 7.2424368404659045}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:10,788] Trial 72 finished with value: 0.8408275530817485 and parameters: {'num_leaves': 174, 'min_child_samples': 16, 'n_estimators': 488, 'learning_rate': 0.06778393326169872, 'subsample_for_bin': 250272, 'min_split_gain': 0.3900729192196123, 'min_child_weight': 0.1164412479987482, 'reg_alpha': 0.05481252987813401, 'reg_lambda': 11.979854904261275}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:10,972] Trial 73 finished with value: 0.839415581762038 and parameters: {'num_leaves': 189, 'min_child_samples': 13, 'n_estimators': 260, 'learning_rate': 0.11592705593942396, 'subsample_for_bin': 270916, 'min_split_gain': 0.3431992005082105, 'min_child_weight': 0.10283774597762137, 'reg_alpha': 7.825149784444775, 'reg_lambda': 3.3890209244451146}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:11,330] Trial 74 finished with value: 0.840674240128723 and parameters: {'num_leaves': 179, 'min_child_samples': 28, 'n_estimators': 403, 'learning_rate': 0.043524983832337424, 'subsample_for_bin': 195924, 'min_split_gain': 0.4328078806896771, 'min_child_weight': 0.10749975426634614, 'reg_alpha': 4.102873769656609, 'reg_lambda': 7.46537628151566}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:11,678] Trial 75 finished with value: 0.8404285296273254 and parameters: {'num_leaves': 154, 'min_child_samples': 16, 'n_estimators': 349, 'learning_rate': 0.05676854039052935, 'subsample_for_bin': 216707, 'min_split_gain': 0.3744807529117792, 'min_child_weight': 0.09540785008555233, 'reg_alpha': 2.6191294750892014, 'reg_lambda': 19.41834687789277}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:11,912] Trial 76 finished with value: 0.8382800061426918 and parameters: {'num_leaves': 169, 'min_child_samples': 11, 'n_estimators': 443, 'learning_rate': 0.09226606913160514, 'subsample_for_bin': 236397, 'min_split_gain': 0.39825045033079537, 'min_child_weight': 0.08266762679165299, 'reg_alpha': 13.871897510318352, 'reg_lambda': 16.54551596979365}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:12,139] Trial 77 finished with value: 0.8413184173536359 and parameters: {'num_leaves': 200, 'min_child_samples': 19, 'n_estimators': 278, 'learning_rate': 0.08000272719636022, 'subsample_for_bin': 295501, 'min_split_gain': 0.36279175750740505, 'min_child_weight': 0.09868671676109414, 'reg_alpha': 6.250033625867407, 'reg_lambda': 6.137378731553877}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:12,295] Trial 78 finished with value: 0.8392621275067516 and parameters: {'num_leaves': 190, 'min_child_samples': 30, 'n_estimators': 222, 'learning_rate': 0.13901453793414137, 'subsample_for_bin': 277088, 'min_split_gain': 0.41131051216834263, 'min_child_weight': 0.10202374607066335, 'reg_alpha': 11.484856403120695, 'reg_lambda': 13.59571546107966}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:12,536] Trial 79 finished with value: 0.8415027461529188 and parameters: {'num_leaves': 184, 'min_child_samples': 32, 'n_estimators': 370, 'learning_rate': 0.11979629490644617, 'subsample_for_bin': 249180, 'min_split_gain': 0.3363029485294421, 'min_child_weight': 0.07750941881409043, 'reg_alpha': 2.4234193762203353, 'reg_lambda': 2.9685354524470737}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:13,101] Trial 80 finished with value: 0.8397840245811673 and parameters: {'num_leaves': 115, 'min_child_samples': 22, 'n_estimators': 548, 'learning_rate': 0.025860818218938205, 'subsample_for_bin': 314663, 'min_split_gain': 0.4232034352756124, 'min_child_weight': 0.09390142958201877, 'reg_alpha': 7.56543736988306, 'reg_lambda': 22.917739010575822}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:13,366] Trial 81 finished with value: 0.8413491845079141 and parameters: {'num_leaves': 167, 'min_child_samples': 33, 'n_estimators': 97, 'learning_rate': 0.0719188170818104, 'subsample_for_bin': 259978, 'min_split_gain': 0.3933424944636127, 'min_child_weight': 0.0896913604199713, 'reg_alpha': 1.0508811321038767, 'reg_lambda': 9.90094024081733}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:13,658] Trial 82 finished with value: 0.841686846042539 and parameters: {'num_leaves': 173, 'min_child_samples': 31, 'n_estimators': 155, 'learning_rate': 0.08346491757603214, 'subsample_for_bin': 235303, 'min_split_gain': 0.38368177919880064, 'min_child_weight': 0.08362034556219726, 'reg_alpha': 0.45438357193895246, 'reg_lambda': 8.47087274181327}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:13,879] Trial 83 finished with value: 0.8407968424483748 and parameters: {'num_leaves': 180, 'min_child_samples': 14, 'n_estimators': 318, 'learning_rate': 0.10290101320519263, 'subsample_for_bin': 234710, 'min_split_gain': 0.3825315103791481, 'min_child_weight': 0.08598240988377417, 'reg_alpha': 5.558400900567894, 'reg_lambda': 7.707837744486843}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:14,089] Trial 84 finished with value: 0.8411652654851877 and parameters: {'num_leaves': 194, 'min_child_samples': 26, 'n_estimators': 180, 'learning_rate': 0.08798832454754321, 'subsample_for_bin': 210667, 'min_split_gain': 0.436430382547564, 'min_child_weight': 0.08264568515793333, 'reg_alpha': 2.310208650552337, 'reg_lambda': 5.303467751897127}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:14,400] Trial 85 finished with value: 0.839139451709924 and parameters: {'num_leaves': 174, 'min_child_samples': 30, 'n_estimators': 244, 'learning_rate': 0.038860343133658104, 'subsample_for_bin': 283105, 'min_split_gain': 0.3713579591973745, 'min_child_weight': 0.07670470231871428, 'reg_alpha': 9.151530675244258, 'reg_lambda': 11.76908676905619}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:14,513] Trial 86 finished with value: 0.8365305202427075 and parameters: {'num_leaves': 186, 'min_child_samples': 28, 'n_estimators': 39, 'learning_rate': 0.05444511667947533, 'subsample_for_bin': 213571, 'min_split_gain': 0.41037870410470906, 'min_child_weight': 0.09304917701482221, 'reg_alpha': 4.992274867426082, 'reg_lambda': 15.232137073507808}. Best is trial 51 with value: 0.842147279459529.
# [I 2023-01-28 11:53:14,824] Trial 87 finished with value: 0.8435284610165996 and parameters: {'num_leaves': 162, 'min_child_samples': 31, 'n_estimators': 459, 'learning_rate': 0.10159807183696541, 'subsample_for_bin': 183904, 'min_split_gain': 0.39423544843866193, 'min_child_weight': 0.09760749004750287, 'reg_alpha': 0.09989230215122614, 'reg_lambda': 2.3121135649923126}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:15,087] Trial 88 finished with value: 0.840520361966654 and parameters: {'num_leaves': 163, 'min_child_samples': 34, 'n_estimators': 466, 'learning_rate': 0.09755284130619492, 'subsample_for_bin': 184459, 'min_split_gain': 0.4447517776795533, 'min_child_weight': 0.08285988657168752, 'reg_alpha': 2.9236017762950213, 'reg_lambda': 2.1233586700962492}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:15,306] Trial 89 finished with value: 0.8407660781201418 and parameters: {'num_leaves': 155, 'min_child_samples': 36, 'n_estimators': 194, 'learning_rate': 0.06541255307249011, 'subsample_for_bin': 170564, 'min_split_gain': 0.3560972844549468, 'min_child_weight': 0.09727894286943162, 'reg_alpha': 7.279276930948429, 'reg_lambda': 2.679454812174966}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:15,530] Trial 90 finished with value: 0.839691751378785 and parameters: {'num_leaves': 171, 'min_child_samples': 38, 'n_estimators': 487, 'learning_rate': 0.12424119789812678, 'subsample_for_bin': 193869, 'min_split_gain': 0.3338573834401053, 'min_child_weight': 0.07249681885130717, 'reg_alpha': 15.2882344743483, 'reg_lambda': 5.654509790894933}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:15,842] Trial 91 finished with value: 0.8411036040045965 and parameters: {'num_leaves': 180, 'min_child_samples': 32, 'n_estimators': 363, 'learning_rate': 0.08228744188031686, 'subsample_for_bin': 227323, 'min_split_gain': 0.3918366566533258, 'min_child_weight': 0.10025360860687363, 'reg_alpha': 0.5744613219795844, 'reg_lambda': 8.768411138573503}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:16,163] Trial 92 finished with value: 0.841134427679779 and parameters: {'num_leaves': 159, 'min_child_samples': 31, 'n_estimators': 403, 'learning_rate': 0.06638035001204866, 'subsample_for_bin': 243100, 'min_split_gain': 0.4164251762683116, 'min_child_weight': 0.08887159227522075, 'reg_alpha': 2.1976967170017248, 'reg_lambda': 10.55550809747355}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:16,459] Trial 93 finished with value: 0.8420553595127989 and parameters: {'num_leaves': 175, 'min_child_samples': 27, 'n_estimators': 325, 'learning_rate': 0.10383989388424164, 'subsample_for_bin': 202913, 'min_split_gain': 0.37987733656149464, 'min_child_weight': 0.10768386168439739, 'reg_alpha': 0.20525501972307253, 'reg_lambda': 13.397422044832537}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:16,641] Trial 94 finished with value: 0.8411651496173337 and parameters: {'num_leaves': 188, 'min_child_samples': 29, 'n_estimators': 160, 'learning_rate': 0.10428404049647377, 'subsample_for_bin': 206971, 'min_split_gain': 0.38264992213180354, 'min_child_weight': 0.08520990725377713, 'reg_alpha': 5.396619873624788, 'reg_lambda': 12.88512539963257}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:16,855] Trial 95 finished with value: 0.8395076797496168 and parameters: {'num_leaves': 195, 'min_child_samples': 39, 'n_estimators': 121, 'learning_rate': 0.05187892577949747, 'subsample_for_bin': 178009, 'min_split_gain': 0.36572520461665087, 'min_child_weight': 0.08011881715424549, 'reg_alpha': 11.623038191225223, 'reg_lambda': 5.253841424167432}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:17,448] Trial 96 finished with value: 0.8390778891409156 and parameters: {'num_leaves': 173, 'min_child_samples': 27, 'n_estimators': 324, 'learning_rate': 0.012290092117015684, 'subsample_for_bin': 198025, 'min_split_gain': 0.4298711544376421, 'min_child_weight': 0.09269350657169519, 'reg_alpha': 8.62772835315521, 'reg_lambda': 1.890578026411868}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:17,690] Trial 97 finished with value: 0.8430373310964621 and parameters: {'num_leaves': 183, 'min_child_samples': 34, 'n_estimators': 293, 'learning_rate': 0.11458556785553359, 'subsample_for_bin': 229838, 'min_split_gain': 0.4070604149042912, 'min_child_weight': 0.10744424525760138, 'reg_alpha': 2.0682267847512614, 'reg_lambda': 18.284204044767872}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:17,898] Trial 98 finished with value: 0.8395999275175923 and parameters: {'num_leaves': 183, 'min_child_samples': 34, 'n_estimators': 286, 'learning_rate': 0.11377931756249612, 'subsample_for_bin': 165257, 'min_split_gain': 0.4559157693247657, 'min_child_weight': 0.10860575306570719, 'reg_alpha': 4.436112826464584, 'reg_lambda': 19.241822569396952}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:18,140] Trial 99 finished with value: 0.8403670631438543 and parameters: {'num_leaves': 190, 'min_child_samples': 41, 'n_estimators': 433, 'learning_rate': 0.14487865730258556, 'subsample_for_bin': 228541, 'min_split_gain': 0.4085771972288084, 'min_child_weight': 0.11745999251449268, 'reg_alpha': 2.300378369096119, 'reg_lambda': 18.252278443152267}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:18,360] Trial 100 finished with value: 0.84006013767701 and parameters: {'num_leaves': 197, 'min_child_samples': 36, 'n_estimators': 403, 'learning_rate': 0.12732858091790944, 'subsample_for_bin': 190295, 'min_split_gain': 0.4191798062488629, 'min_child_weight': 0.10616974123059103, 'reg_alpha': 7.096484931194074, 'reg_lambda': 13.655574609346354}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:18,695] Trial 101 finished with value: 0.8433136194071081 and parameters: {'num_leaves': 162, 'min_child_samples': 31, 'n_estimators': 455, 'learning_rate': 0.09333778442647463, 'subsample_for_bin': 255097, 'min_split_gain': 0.3815448807611288, 'min_child_weight': 0.09957930763596715, 'reg_alpha': 0.14145424455772468, 'reg_lambda': 8.869004165239435}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:18,983] Trial 102 finished with value: 0.840980863208729 and parameters: {'num_leaves': 165, 'min_child_samples': 32, 'n_estimators': 456, 'learning_rate': 0.09696172042142699, 'subsample_for_bin': 493564, 'min_split_gain': 0.40240604704612093, 'min_child_weight': 0.09932874544405482, 'reg_alpha': 2.0935811365832273, 'reg_lambda': 11.021203965130775}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:19,487] Trial 103 finished with value: 0.8406126012564936 and parameters: {'num_leaves': 150, 'min_child_samples': 30, 'n_estimators': 357, 'learning_rate': 0.02930096895199453, 'subsample_for_bin': 215824, 'min_split_gain': 0.3491325563896341, 'min_child_weight': 0.0956451061763304, 'reg_alpha': 4.817772875070164, 'reg_lambda': 7.0686715486789}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:19,717] Trial 104 finished with value: 0.8403058255700459 and parameters: {'num_leaves': 177, 'min_child_samples': 27, 'n_estimators': 325, 'learning_rate': 0.07192485100805811, 'subsample_for_bin': 251235, 'min_split_gain': 0.3767174236322878, 'min_child_weight': 0.10969590248753794, 'reg_alpha': 10.284872777977235, 'reg_lambda': 3.570783785569442}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:19,993] Trial 105 finished with value: 0.8408581365430877 and parameters: {'num_leaves': 141, 'min_child_samples': 34, 'n_estimators': 544, 'learning_rate': 0.11466667363306372, 'subsample_for_bin': 453614, 'min_split_gain': 0.39202449710388054, 'min_child_weight': 0.10327294543943859, 'reg_alpha': 3.7964261563619894, 'reg_lambda': 9.345604033800658}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:20,276] Trial 106 finished with value: 0.8415333946132978 and parameters: {'num_leaves': 161, 'min_child_samples': 29, 'n_estimators': 421, 'learning_rate': 0.09164139503901564, 'subsample_for_bin': 203649, 'min_split_gain': 0.4270058074185059, 'min_child_weight': 0.08875358164304391, 'reg_alpha': 1.7048687936283773, 'reg_lambda': 5.129529379916897}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:20,478] Trial 107 finished with value: 0.8402441782196809 and parameters: {'num_leaves': 200, 'min_child_samples': 33, 'n_estimators': 250, 'learning_rate': 0.10305112379057355, 'subsample_for_bin': 184226, 'min_split_gain': 0.44453803761178207, 'min_child_weight': 0.10576510825176785, 'reg_alpha': 6.322659155592866, 'reg_lambda': 17.011140603297186}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:20,790] Trial 108 finished with value: 0.840213741712693 and parameters: {'num_leaves': 186, 'min_child_samples': 35, 'n_estimators': 388, 'learning_rate': 0.045786646860051475, 'subsample_for_bin': 242496, 'min_split_gain': 0.3693531860121738, 'min_child_weight': 0.10221440779502507, 'reg_alpha': 8.438336764161553, 'reg_lambda': 0.42414463910112676}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:21,062] Trial 109 finished with value: 0.8392621501151133 and parameters: {'num_leaves': 182, 'min_child_samples': 42, 'n_estimators': 489, 'learning_rate': 0.07563886936440789, 'subsample_for_bin': 253592, 'min_split_gain': 0.35811461626952434, 'min_child_weight': 0.09128638508951091, 'reg_alpha': 12.851330098196197, 'reg_lambda': 12.267887451910045}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:21,252] Trial 110 finished with value: 0.8411957048182206 and parameters: {'num_leaves': 168, 'min_child_samples': 37, 'n_estimators': 227, 'learning_rate': 0.12101460905423453, 'subsample_for_bin': 266731, 'min_split_gain': 0.4055288894615106, 'min_child_weight': 0.09758662576584436, 'reg_alpha': 4.18404253704532, 'reg_lambda': 14.370487936499698}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:21,528] Trial 111 finished with value: 0.8410731477152922 and parameters: {'num_leaves': 176, 'min_child_samples': 31, 'n_estimators': 208, 'learning_rate': 0.08722371211259711, 'subsample_for_bin': 230320, 'min_split_gain': 0.3840331744943519, 'min_child_weight': 0.08523848727812773, 'reg_alpha': 0.3951346035982187, 'reg_lambda': 7.453375401501513}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:53:21,879] Trial 112 finished with value: 0.8402442601749921 and parameters: {'num_leaves': 193, 'min_child_samples': 33, 'n_estimators': 115, 'learning_rate': 0.06555200674707722, 'subsample_for_bin': 220291, 'min_split_gain': 0.39763563353807846, 'min_child_weight': 0.07957759255091248, 'reg_alpha': 0.0501624704847059, 'reg_lambda': 9.130076693942438}. Best is trial 87 with value: 0.8435284610165996.
# ...
# [I 2023-01-28 11:58:08,657] Trial 987 finished with value: 0.8409196115046944 and parameters: {'num_leaves': 73, 'min_child_samples': 19, 'n_estimators': 468, 'learning_rate': 0.4702948589424457, 'subsample_for_bin': 188494, 'min_split_gain': 0.11055077174602261, 'min_child_weight': 0.10738517953925024, 'reg_alpha': 3.9543519362464647, 'reg_lambda': 86.75344277885726}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:09,053] Trial 988 finished with value: 0.8419016339571715 and parameters: {'num_leaves': 92, 'min_child_samples': 30, 'n_estimators': 499, 'learning_rate': 0.13674615395501932, 'subsample_for_bin': 169890, 'min_split_gain': 0.40028604433828335, 'min_child_weight': 0.044386999710767365, 'reg_alpha': 1.81895082785405, 'reg_lambda': 27.577903075871234}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:09,391] Trial 989 finished with value: 0.8402442827833538 and parameters: {'num_leaves': 138, 'min_child_samples': 34, 'n_estimators': 176, 'learning_rate': 0.09849424205529791, 'subsample_for_bin': 499072, 'min_split_gain': 0.3005937853164575, 'min_child_weight': 0.05444876630834022, 'reg_alpha': 3.6935029173524176, 'reg_lambda': 16.99822239847509}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:09,679] Trial 990 finished with value: 0.8341364416891635 and parameters: {'num_leaves': 83, 'min_child_samples': 21, 'n_estimators': 241, 'learning_rate': 0.08566334850516905, 'subsample_for_bin': 88185, 'min_split_gain': 0.09530284902216161, 'min_child_weight': 0.06370704285041744, 'reg_alpha': 60.22939764536649, 'reg_lambda': 57.61031705371339}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:09,932] Trial 991 finished with value: 0.8334919027304627 and parameters: {'num_leaves': 43, 'min_child_samples': 33, 'n_estimators': 287, 'learning_rate': 0.3634198360399367, 'subsample_for_bin': 430747, 'min_split_gain': 0.28465295440163263, 'min_child_weight': 0.09561766472827041, 'reg_alpha': 37.757586029659855, 'reg_lambda': 19.702750193950042}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:10,368] Trial 992 finished with value: 0.8392009747142996 and parameters: {'num_leaves': 128, 'min_child_samples': 18, 'n_estimators': 210, 'learning_rate': 0.04045437822791238, 'subsample_for_bin': 107726, 'min_split_gain': 0.35666541835015503, 'min_child_weight': 0.09094388765663661, 'reg_alpha': 11.106341019575746, 'reg_lambda': 43.5810732495015}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:10,861] Trial 993 finished with value: 0.8411344813746382 and parameters: {'num_leaves': 115, 'min_child_samples': 20, 'n_estimators': 406, 'learning_rate': 0.05698508542106888, 'subsample_for_bin': 253377, 'min_split_gain': 0.14672791915241523, 'min_child_weight': 0.02731410417844355, 'reg_alpha': 6.159915997531485, 'reg_lambda': 9.726875627134937}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:11,146] Trial 994 finished with value: 0.8307908591454413 and parameters: {'num_leaves': 123, 'min_child_samples': 31, 'n_estimators': 330, 'learning_rate': 0.10428075022991615, 'subsample_for_bin': 149131, 'min_split_gain': 0.3721377407991274, 'min_child_weight': 0.0362910461484601, 'reg_alpha': 71.67477714093259, 'reg_lambda': 23.786700354734265}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:11,479] Trial 995 finished with value: 0.841564068508084 and parameters: {'num_leaves': 85, 'min_child_samples': 17, 'n_estimators': 454, 'learning_rate': 0.2810092188829165, 'subsample_for_bin': 289070, 'min_split_gain': 0.321261901577573, 'min_child_weight': 0.13753910240059078, 'reg_alpha': 1.7975439691669446, 'reg_lambda': 1.7113002130005013}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:11,748] Trial 996 finished with value: 0.8305148449611811 and parameters: {'num_leaves': 72, 'min_child_samples': 38, 'n_estimators': 270, 'learning_rate': 0.12109051171989399, 'subsample_for_bin': 280781, 'min_split_gain': 0.07914757802482315, 'min_child_weight': 0.12111134986957105, 'reg_alpha': 73.02793856090437, 'reg_lambda': 14.996878128077952}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:12,065] Trial 997 finished with value: 0.8348118071490918 and parameters: {'num_leaves': 62, 'min_child_samples': 32, 'n_estimators': 429, 'learning_rate': 0.130725789001819, 'subsample_for_bin': 176185, 'min_split_gain': 0.33899558075912156, 'min_child_weight': 0.0870131510580798, 'reg_alpha': 46.440304022311025, 'reg_lambda': 7.571744821887567}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:12,330] Trial 998 finished with value: 0.8388017421325303 and parameters: {'num_leaves': 159, 'min_child_samples': 33, 'n_estimators': 149, 'learning_rate': 0.18367300325256086, 'subsample_for_bin': 272460, 'min_split_gain': 0.23232656463214968, 'min_child_weight': 0.09976137208268589, 'reg_alpha': 12.821172054727294, 'reg_lambda': 55.64659369265047}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:12,983] Trial 999 finished with value: 0.8422086809439602 and parameters: {'num_leaves': 148, 'min_child_samples': 36, 'n_estimators': 481, 'learning_rate': 0.07201354212579271, 'subsample_for_bin': 209989, 'min_split_gain': 0.2145530660971755, 'min_child_weight': 0.07467404502636604, 'reg_alpha': 0.09415560049325095, 'reg_lambda': 11.898126494469665}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:13,317] Trial 1000 finished with value: 0.8338295444827714 and parameters: {'num_leaves': 109, 'min_child_samples': 29, 'n_estimators': 310, 'learning_rate': 0.051058617255741054, 'subsample_for_bin': 155154, 'min_split_gain': 0.3914943894903735, 'min_child_weight': 0.11088760692668899, 'reg_alpha': 41.93152070570285, 'reg_lambda': 51.328531510365316}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:13,638] Trial 1001 finished with value: 0.8273841153311313 and parameters: {'num_leaves': 118, 'min_child_samples': 17, 'n_estimators': 195, 'learning_rate': 0.019081617413961895, 'subsample_for_bin': 299597, 'min_split_gain': 0.2661263762743816, 'min_child_weight': 0.10240405753867232, 'reg_alpha': 76.85969624160965, 'reg_lambda': 5.046893007253614}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:13,939] Trial 1002 finished with value: 0.8411959111195214 and parameters: {'num_leaves': 27, 'min_child_samples': 34, 'n_estimators': 236, 'learning_rate': 0.2901694383203726, 'subsample_for_bin': 264399, 'min_split_gain': 0.12282342132256402, 'min_child_weight': 0.02290610935873015, 'reg_alpha': 4.021682503622504, 'reg_lambda': 91.45262994381302}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:14,302] Trial 1003 finished with value: 0.8390166402629262 and parameters: {'num_leaves': 132, 'min_child_samples': 19, 'n_estimators': 505, 'learning_rate': 0.27152847105483224, 'subsample_for_bin': 232962, 'min_split_gain': 0.30781625023843817, 'min_child_weight': 0.050048185868801574, 'reg_alpha': 2.1835064733179204, 'reg_lambda': 62.00516707409227}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:14,713] Trial 1004 finished with value: 0.8395998314320549 and parameters: {'num_leaves': 81, 'min_child_samples': 41, 'n_estimators': 464, 'learning_rate': 0.09017938768709582, 'subsample_for_bin': 128380, 'min_split_gain': 0.3773502381502371, 'min_child_weight': 0.09668942374575001, 'reg_alpha': 7.425887223037307, 'reg_lambda': 82.30710148152116}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:15,008] Trial 1005 finished with value: 0.8293484824052403 and parameters: {'num_leaves': 88, 'min_child_samples': 31, 'n_estimators': 416, 'learning_rate': 0.33287010471407863, 'subsample_for_bin': 182792, 'min_split_gain': 0.2771638174611375, 'min_child_weight': 0.11602511533226204, 'reg_alpha': 88.42846572467317, 'reg_lambda': 29.945864586248923}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:15,348] Trial 1006 finished with value: 0.841134427679779 and parameters: {'num_leaves': 76, 'min_child_samples': 30, 'n_estimators': 445, 'learning_rate': 0.19634948391228055, 'subsample_for_bin': 169079, 'min_split_gain': 0.4543521745049659, 'min_child_weight': 0.004445055593061707, 'reg_alpha': 4.617949921981461, 'reg_lambda': 21.875454147977024}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:15,602] Trial 1007 finished with value: 0.8262484888429714 and parameters: {'num_leaves': 115, 'min_child_samples': 33, 'n_estimators': 257, 'learning_rate': 0.21557837182617998, 'subsample_for_bin': 305326, 'min_split_gain': 0.4227669766995628, 'min_child_weight': 0.04149458241538719, 'reg_alpha': 90.85956083621272, 'reg_lambda': 82.84898216683744}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:15,837] Trial 1008 finished with value: 0.8312820173260311 and parameters: {'num_leaves': 92, 'min_child_samples': 28, 'n_estimators': 170, 'learning_rate': 0.41717718241342394, 'subsample_for_bin': 281675, 'min_split_gain': 0.1059475106176448, 'min_child_weight': 0.016108996504193205, 'reg_alpha': 76.73028222191304, 'reg_lambda': 0.077590521757116}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:16,507] Trial 1009 finished with value: 0.8427918805912246 and parameters: {'num_leaves': 67, 'min_child_samples': 17, 'n_estimators': 486, 'learning_rate': 0.11101080462438287, 'subsample_for_bin': 248588, 'min_split_gain': 0.06385598617074073, 'min_child_weight': 0.10766274505452238, 'reg_alpha': 1.691494206997313, 'reg_lambda': 39.17747085120979}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:16,848] Trial 1010 finished with value: 0.8341364982100677 and parameters: {'num_leaves': 69, 'min_child_samples': 17, 'n_estimators': 492, 'learning_rate': 0.11307752388508346, 'subsample_for_bin': 248278, 'min_split_gain': 0.13925534826785815, 'min_child_weight': 0.1050098353813141, 'reg_alpha': 54.53749403580501, 'reg_lambda': 39.148933148571444}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:17,174] Trial 1011 finished with value: 0.8292563928957971 and parameters: {'num_leaves': 66, 'min_child_samples': 18, 'n_estimators': 517, 'learning_rate': 0.12424859788501572, 'subsample_for_bin': 271327, 'min_split_gain': 0.4749247395931024, 'min_child_weight': 0.10810307364415081, 'reg_alpha': 83.20955898670134, 'reg_lambda': 36.881643118273225}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:17,966] Trial 1012 finished with value: 0.8409809027733622 and parameters: {'num_leaves': 58, 'min_child_samples': 17, 'n_estimators': 476, 'learning_rate': 0.10236012153764805, 'subsample_for_bin': 245876, 'min_split_gain': 0.041014318492109174, 'min_child_weight': 0.019665976413953158, 'reg_alpha': 1.6304677722067773, 'reg_lambda': 39.550377346364264}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:18,316] Trial 1013 finished with value: 0.8340445754372924 and parameters: {'num_leaves': 61, 'min_child_samples': 18, 'n_estimators': 472, 'learning_rate': 0.112885941632562, 'subsample_for_bin': 238110, 'min_split_gain': 0.06120629484332352, 'min_child_weight': 0.11282570034650304, 'reg_alpha': 51.360751366013766, 'reg_lambda': 41.00381125288877}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:18,721] Trial 1014 finished with value: 0.8410422986057028 and parameters: {'num_leaves': 62, 'min_child_samples': 17, 'n_estimators': 493, 'learning_rate': 0.44366147418942037, 'subsample_for_bin': 245966, 'min_split_gain': 0.048419211552262226, 'min_child_weight': 0.10956625046168764, 'reg_alpha': 1.4275269350725495, 'reg_lambda': 42.538412689402286}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:19,316] Trial 1015 finished with value: 0.8403670970563969 and parameters: {'num_leaves': 68, 'min_child_samples': 16, 'n_estimators': 509, 'learning_rate': 0.14726286571166514, 'subsample_for_bin': 254275, 'min_split_gain': 0.06774403198771897, 'min_child_weight': 0.10251168728539894, 'reg_alpha': 0.07166718442570028, 'reg_lambda': 18.852942651394102}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:19,639] Trial 1016 finished with value: 0.8299621920366681 and parameters: {'num_leaves': 60, 'min_child_samples': 19, 'n_estimators': 457, 'learning_rate': 0.10851773910620462, 'subsample_for_bin': 264933, 'min_split_gain': 0.060682923774252065, 'min_child_weight': 0.11490677202132925, 'reg_alpha': 91.5315000273701, 'reg_lambda': 13.823301058997826}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:20,091] Trial 1017 finished with value: 0.8387404197773652 and parameters: {'num_leaves': 65, 'min_child_samples': 18, 'n_estimators': 499, 'learning_rate': 0.13187320396466112, 'subsample_for_bin': 243654, 'min_split_gain': 0.034418569404946614, 'min_child_weight': 0.10682436268703555, 'reg_alpha': 15.892623846384993, 'reg_lambda': 92.05040063698615}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:20,416] Trial 1018 finished with value: 0.8380957932112629 and parameters: {'num_leaves': 71, 'min_child_samples': 20, 'n_estimators': 488, 'learning_rate': 0.4267360096427728, 'subsample_for_bin': 257887, 'min_split_gain': 0.056487944894474715, 'min_child_weight': 0.07780503664008664, 'reg_alpha': 20.229984485528647, 'reg_lambda': 34.90723537151264}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:21,288] Trial 1019 finished with value: 0.8418709741926116 and parameters: {'num_leaves': 68, 'min_child_samples': 16, 'n_estimators': 444, 'learning_rate': 0.12191651299689145, 'subsample_for_bin': 250370, 'min_split_gain': 0.02950682264799867, 'min_child_weight': 0.09930821358260754, 'reg_alpha': 3.0856591307186623, 'reg_lambda': 94.44510559398506}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:21,607] Trial 1020 finished with value: 0.8295018801396224 and parameters: {'num_leaves': 72, 'min_child_samples': 17, 'n_estimators': 470, 'learning_rate': 0.16292919709389744, 'subsample_for_bin': 256370, 'min_split_gain': 0.044264027136786836, 'min_child_weight': 0.12681389180367952, 'reg_alpha': 86.36338260521362, 'reg_lambda': 89.55881791586756}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:22,062] Trial 1021 finished with value: 0.8421780098752194 and parameters: {'num_leaves': 124, 'min_child_samples': 19, 'n_estimators': 520, 'learning_rate': 0.10482662029886683, 'subsample_for_bin': 265902, 'min_split_gain': 0.47814891678706917, 'min_child_weight': 0.08262776658235542, 'reg_alpha': 0.08209418944020186, 'reg_lambda': 37.054673035493735}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:22,630] Trial 1022 finished with value: 0.8347196611187443 and parameters: {'num_leaves': 52, 'min_child_samples': 17, 'n_estimators': 854, 'learning_rate': 0.02881504432289619, 'subsample_for_bin': 234547, 'min_split_gain': 0.2541878205297898, 'min_child_weight': 0.017716814978221022, 'reg_alpha': 40.03699751172984, 'reg_lambda': 38.84304256832086}. Best is trial 87 with value: 0.8435284610165996.
# [I 2023-01-28 11:58:22,977] Trial 1023 finished with value: 0.8328166870509307 and parameters: {'num_leaves': 111, 'min_child_samples': 18, 'n_estimators': 427, 'learning_rate': 0.09607394835067855, 'subsample_for_bin': 257903, 'min_split_gain': 0.017216034142751996, 'min_child_weight': 0.11116450349419314, 'reg_alpha': 56.1315211957655, 'reg_lambda': 60.198570860572616}. Best is trial 87 with value: 0.8435284610165996.

# %%
trial = study.best_trial
print('Accuracy: {}'.format(trial.value))
# Out:
# Accuracy: 0.8435284610165996

# %%
print("Best hyperparameters: {}".format(trial.params))
# Out:
# Best hyperparameters: {'num_leaves': 162, 'min_child_samples': 31, 'n_estimators': 459, 'learning_rate': 0.10159807183696541, 'subsample_for_bin': 183904, 'min_split_gain': 0.39423544843866193, 'min_child_weight': 0.09760749004750287, 'reg_alpha': 0.09989230215122614, 'reg_lambda': 2.3121135649923126}

# %%
tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

# %%
tracking_Optuna_Accuracy = tracking

# %%
plt.plot(tracking);
#plt.plot(tracking_sorted)

# %%
#optuna.visualization.plot_optimization_history(study)

# %%
#optuna.visualization.plot_slice(study)

# %% [markdown]
# ### F1 Score

# %%
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_credit, y_credit, n_jobs=-1, scoring='f1', cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)

trial = study.best_trial

print('F1 Score: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))

tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

tracking_Optuna_F1 = tracking

plt.plot(tracking);
#plt.plot(tracking_sorted)
# Out:
# [I 2023-01-28 11:59:51,076] A new study created in memory with name: no-name-d275f049-d11c-4542-abf2-a7f2d081f854
# [I 2023-01-28 11:59:51,230] Trial 0 finished with value: 0.4790960027693092 and parameters: {'num_leaves': 96, 'min_child_samples': 27, 'n_estimators': 439, 'learning_rate': 0.28232964938484634, 'subsample_for_bin': 273906, 'min_split_gain': 0.4300146866843064, 'min_child_weight': 0.03789551744423893, 'reg_alpha': 64.9809706916445, 'reg_lambda': 35.2569604877119}. Best is trial 0 with value: 0.4790960027693092.
# [I 2023-01-28 11:59:51,310] Trial 1 finished with value: 0.49491511026197516 and parameters: {'num_leaves': 59, 'min_child_samples': 40, 'n_estimators': 133, 'learning_rate': 0.1563045485163464, 'subsample_for_bin': 326877, 'min_split_gain': 0.432502987723435, 'min_child_weight': 0.03206833073912237, 'reg_alpha': 34.346059485774965, 'reg_lambda': 21.36233447632185}. Best is trial 1 with value: 0.49491511026197516.
# [I 2023-01-28 11:59:51,367] Trial 2 finished with value: 0.5043118934285499 and parameters: {'num_leaves': 193, 'min_child_samples': 48, 'n_estimators': 60, 'learning_rate': 0.48179828578921113, 'subsample_for_bin': 317478, 'min_split_gain': 0.18885601119244091, 'min_child_weight': 0.1436780288129243, 'reg_alpha': 47.492775119047266, 'reg_lambda': 23.47693188112037}. Best is trial 2 with value: 0.5043118934285499.
# [I 2023-01-28 11:59:51,636] Trial 3 finished with value: 0.43544907089124707 and parameters: {'num_leaves': 39, 'min_child_samples': 31, 'n_estimators': 886, 'learning_rate': 0.4588370028041434, 'subsample_for_bin': 184939, 'min_split_gain': 0.49246197251611923, 'min_child_weight': 0.06211314059128538, 'reg_alpha': 99.84127962967221, 'reg_lambda': 79.89594930907919}. Best is trial 2 with value: 0.5043118934285499.
# [I 2023-01-28 11:59:51,820] Trial 4 finished with value: 0.49128401457010645 and parameters: {'num_leaves': 169, 'min_child_samples': 15, 'n_estimators': 479, 'learning_rate': 0.12426536639697494, 'subsample_for_bin': 266735, 'min_split_gain': 0.1845687304740508, 'min_child_weight': 0.038747356310412755, 'reg_alpha': 49.5771224103774, 'reg_lambda': 60.053961018985746}. Best is trial 2 with value: 0.5043118934285499.
# [I 2023-01-28 11:59:51,968] Trial 5 finished with value: 0.5153505817098746 and parameters: {'num_leaves': 15, 'min_child_samples': 28, 'n_estimators': 226, 'learning_rate': 0.14651464744771123, 'subsample_for_bin': 308058, 'min_split_gain': 0.03642429216262141, 'min_child_weight': 0.004088180976437946, 'reg_alpha': 30.481688443284995, 'reg_lambda': 58.160384512062905}. Best is trial 5 with value: 0.5153505817098746.
# [I 2023-01-28 11:59:52,082] Trial 6 finished with value: 0.5169751964196968 and parameters: {'num_leaves': 56, 'min_child_samples': 35, 'n_estimators': 159, 'learning_rate': 0.21971602616332814, 'subsample_for_bin': 210219, 'min_split_gain': 0.028744177131134453, 'min_child_weight': 0.11616968846497369, 'reg_alpha': 26.062113387951683, 'reg_lambda': 48.700792893968604}. Best is trial 6 with value: 0.5169751964196968.
# [I 2023-01-28 11:59:52,450] Trial 7 finished with value: 0.5143240924447429 and parameters: {'num_leaves': 162, 'min_child_samples': 21, 'n_estimators': 908, 'learning_rate': 0.07845632275541622, 'subsample_for_bin': 427524, 'min_split_gain': 0.18610423330478346, 'min_child_weight': 0.12004508018731791, 'reg_alpha': 26.389227876890068, 'reg_lambda': 16.09241457090895}. Best is trial 6 with value: 0.5169751964196968.
# [I 2023-01-28 11:59:52,734] Trial 8 finished with value: 0.5306742662775232 and parameters: {'num_leaves': 163, 'min_child_samples': 42, 'n_estimators': 828, 'learning_rate': 0.38416006258720015, 'subsample_for_bin': 284442, 'min_split_gain': 0.10374011693560499, 'min_child_weight': 0.1041422084226213, 'reg_alpha': 12.456138776184194, 'reg_lambda': 30.072335818424165}. Best is trial 8 with value: 0.5306742662775232.
# [I 2023-01-28 11:59:52,785] Trial 9 finished with value: 0.524845196245497 and parameters: {'num_leaves': 183, 'min_child_samples': 19, 'n_estimators': 56, 'learning_rate': 0.4129057170698606, 'subsample_for_bin': 455541, 'min_split_gain': 0.3405701728251528, 'min_child_weight': 0.07947194722632828, 'reg_alpha': 13.749882199113035, 'reg_lambda': 20.810439801673073}. Best is trial 8 with value: 0.5306742662775232.
# [I 2023-01-28 11:59:54,958] Trial 10 finished with value: 0.5608029055904062 and parameters: {'num_leaves': 122, 'min_child_samples': 49, 'n_estimators': 706, 'learning_rate': 0.018341722561409785, 'subsample_for_bin': 65031, 'min_split_gain': 0.0819824764662539, 'min_child_weight': 0.09208515877222404, 'reg_alpha': 0.4967994894035712, 'reg_lambda': 9.001328375816122}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:56,621] Trial 11 finished with value: 0.5281819145811316 and parameters: {'num_leaves': 129, 'min_child_samples': 50, 'n_estimators': 716, 'learning_rate': 0.003939826536565466, 'subsample_for_bin': 80845, 'min_split_gain': 0.10114053328653741, 'min_child_weight': 0.0928910134397187, 'reg_alpha': 4.888099567807263, 'reg_lambda': 2.122462429989702}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:56,893] Trial 12 finished with value: 0.5423467758225571 and parameters: {'num_leaves': 130, 'min_child_samples': 42, 'n_estimators': 698, 'learning_rate': 0.3317870843462237, 'subsample_for_bin': 54492, 'min_split_gain': 0.10386545738653341, 'min_child_weight': 0.09690237084108252, 'reg_alpha': 8.54995293603195, 'reg_lambda': 0.39768697635217976}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:57,154] Trial 13 finished with value: 0.556306223343255 and parameters: {'num_leaves': 114, 'min_child_samples': 43, 'n_estimators': 650, 'learning_rate': 0.3006442235232881, 'subsample_for_bin': 51803, 'min_split_gain': 0.27379170344999537, 'min_child_weight': 0.07695853765795231, 'reg_alpha': 1.9082809510062333, 'reg_lambda': 2.1205629464437834}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:57,416] Trial 14 finished with value: 0.5511978226191481 and parameters: {'num_leaves': 98, 'min_child_samples': 46, 'n_estimators': 626, 'learning_rate': 0.2542373404854751, 'subsample_for_bin': 128848, 'min_split_gain': 0.287219169539935, 'min_child_weight': 0.07051741000548616, 'reg_alpha': 2.626596400922615, 'reg_lambda': 7.783414421091034}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:57,610] Trial 15 finished with value: 0.5431647054471741 and parameters: {'num_leaves': 130, 'min_child_samples': 36, 'n_estimators': 372, 'learning_rate': 0.20992795738870837, 'subsample_for_bin': 132744, 'min_split_gain': 0.2600541660346994, 'min_child_weight': 0.07797017269428302, 'reg_alpha': 4.458628818383266, 'reg_lambda': 9.846350895436338}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:57,945] Trial 16 finished with value: 0.5312628207227338 and parameters: {'num_leaves': 84, 'min_child_samples': 43, 'n_estimators': 995, 'learning_rate': 0.3091049985254468, 'subsample_for_bin': 143449, 'min_split_gain': 0.317931434358835, 'min_child_weight': 0.06154829097747341, 'reg_alpha': 17.363477452810972, 'reg_lambda': 0.5522590606184821}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:59,309] Trial 17 finished with value: 0.49843934318900546 and parameters: {'num_leaves': 118, 'min_child_samples': 38, 'n_estimators': 596, 'learning_rate': 0.0033327148420875616, 'subsample_for_bin': 92425, 'min_split_gain': 0.2280738697805712, 'min_child_weight': 0.13532745279704933, 'reg_alpha': 1.9599226689346878, 'reg_lambda': 14.290327656619777}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:59,578] Trial 18 finished with value: 0.5203616835534883 and parameters: {'num_leaves': 76, 'min_child_samples': 46, 'n_estimators': 772, 'learning_rate': 0.3374640238019316, 'subsample_for_bin': 197679, 'min_split_gain': 0.34439841542364763, 'min_child_weight': 0.09293780851066503, 'reg_alpha': 19.367358318557983, 'reg_lambda': 36.41466245994414}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 11:59:59,817] Trial 19 finished with value: 0.5584211250260483 and parameters: {'num_leaves': 147, 'min_child_samples': 50, 'n_estimators': 348, 'learning_rate': 0.21063221320572953, 'subsample_for_bin': 54270, 'min_split_gain': 0.2356091043394766, 'min_child_weight': 0.12053684162455569, 'reg_alpha': 0.026292085156019884, 'reg_lambda': 11.787240349674654}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:00,026] Trial 20 finished with value: 0.5063101019908477 and parameters: {'num_leaves': 155, 'min_child_samples': 50, 'n_estimators': 318, 'learning_rate': 0.06728053239200005, 'subsample_for_bin': 107090, 'min_split_gain': 0.14624515772501812, 'min_child_weight': 0.12686959050680072, 'reg_alpha': 37.30079318608749, 'reg_lambda': 28.837327869228986}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:00,313] Trial 21 finished with value: 0.5568652359915786 and parameters: {'num_leaves': 144, 'min_child_samples': 46, 'n_estimators': 582, 'learning_rate': 0.22080606882475867, 'subsample_for_bin': 51110, 'min_split_gain': 0.22353364391806724, 'min_child_weight': 0.14935468905244256, 'reg_alpha': 0.6746745086540118, 'reg_lambda': 9.235160788101359}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:00,541] Trial 22 finished with value: 0.5337236611867784 and parameters: {'num_leaves': 145, 'min_child_samples': 47, 'n_estimators': 545, 'learning_rate': 0.19105055560059908, 'subsample_for_bin': 170157, 'min_split_gain': 0.21682726425489646, 'min_child_weight': 0.14377862729937646, 'reg_alpha': 14.488980858653221, 'reg_lambda': 11.017311577613775}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:00,785] Trial 23 finished with value: 0.559557978089016 and parameters: {'num_leaves': 147, 'min_child_samples': 45, 'n_estimators': 344, 'learning_rate': 0.2446765046337771, 'subsample_for_bin': 80139, 'min_split_gain': 0.14665652073086627, 'min_child_weight': 0.12874040388867597, 'reg_alpha': 0.6132856223043723, 'reg_lambda': 14.526347360701195}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:00,937] Trial 24 finished with value: 0.5303549110188346 and parameters: {'num_leaves': 180, 'min_child_samples': 33, 'n_estimators': 303, 'learning_rate': 0.26174348757470506, 'subsample_for_bin': 234836, 'min_split_gain': 0.12020354544417983, 'min_child_weight': 0.11903188219838909, 'reg_alpha': 18.398192548358235, 'reg_lambda': 17.719198198438264}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:01,153] Trial 25 finished with value: 0.5258356015054848 and parameters: {'num_leaves': 146, 'min_child_samples': 50, 'n_estimators': 408, 'learning_rate': 0.1906700118418662, 'subsample_for_bin': 91592, 'min_split_gain': 0.07611970308996781, 'min_child_weight': 0.10610142101558248, 'reg_alpha': 12.852569842063515, 'reg_lambda': 26.821160102378904}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:01,351] Trial 26 finished with value: 0.5434595442024658 and parameters: {'num_leaves': 112, 'min_child_samples': 39, 'n_estimators': 248, 'learning_rate': 0.24962118109944875, 'subsample_for_bin': 390160, 'min_split_gain': 0.010686094485926667, 'min_child_weight': 0.13617179411436733, 'reg_alpha': 8.618956801619978, 'reg_lambda': 14.471245918757162}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:01,633] Trial 27 finished with value: 0.5204030417607574 and parameters: {'num_leaves': 197, 'min_child_samples': 45, 'n_estimators': 508, 'learning_rate': 0.07976465133940341, 'subsample_for_bin': 159304, 'min_split_gain': 0.14834487751182251, 'min_child_weight': 0.12863072624117625, 'reg_alpha': 21.938307441879175, 'reg_lambda': 40.12692869366998}. Best is trial 10 with value: 0.5608029055904062.
# [I 2023-01-28 12:00:02,086] Trial 28 finished with value: 0.5629948641008641 and parameters: {'num_leaves': 132, 'min_child_samples': 10, 'n_estimators': 341, 'learning_rate': 0.1684598722284869, 'subsample_for_bin': 110558, 'min_split_gain': 0.06184763569103978, 'min_child_weight': 0.10949981887798005, 'reg_alpha': 0.46962167553163425, 'reg_lambda': 21.942475713406857}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:02,380] Trial 29 finished with value: 0.5391180653871963 and parameters: {'num_leaves': 96, 'min_child_samples': 11, 'n_estimators': 465, 'learning_rate': 0.13481242616828132, 'subsample_for_bin': 116828, 'min_split_gain': 0.06341327728260997, 'min_child_weight': 0.10952828276873153, 'reg_alpha': 9.87687878388192, 'reg_lambda': 33.65268507997514}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:02,647] Trial 30 finished with value: 0.5031758981081793 and parameters: {'num_leaves': 81, 'min_child_samples': 23, 'n_estimators': 428, 'learning_rate': 0.05417043930190779, 'subsample_for_bin': 244835, 'min_split_gain': 0.056047460117368164, 'min_child_weight': 0.1065541225541068, 'reg_alpha': 40.466790819335486, 'reg_lambda': 24.817085504621147}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:02,990] Trial 31 finished with value: 0.5609506863302893 and parameters: {'num_leaves': 131, 'min_child_samples': 25, 'n_estimators': 334, 'learning_rate': 0.1716525905416315, 'subsample_for_bin': 89745, 'min_split_gain': 0.0790537574629796, 'min_child_weight': 0.12287234224492158, 'reg_alpha': 1.0567166368051675, 'reg_lambda': 19.187101692129836}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:03,191] Trial 32 finished with value: 0.5420336990133201 and parameters: {'num_leaves': 123, 'min_child_samples': 10, 'n_estimators': 261, 'learning_rate': 0.17448430485741773, 'subsample_for_bin': 90758, 'min_split_gain': 0.07403111066134785, 'min_child_weight': 0.13288363052647903, 'reg_alpha': 8.092100959608082, 'reg_lambda': 19.21501740987294}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:03,371] Trial 33 finished with value: 0.5239838690077895 and parameters: {'num_leaves': 138, 'min_child_samples': 24, 'n_estimators': 169, 'learning_rate': 0.11104995335951515, 'subsample_for_bin': 150605, 'min_split_gain': 0.05810870791804194, 'min_child_weight': 0.11475337678292476, 'reg_alpha': 20.88652204809914, 'reg_lambda': 22.549669390861627}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:03,591] Trial 34 finished with value: 0.545773360717878 and parameters: {'num_leaves': 100, 'min_child_samples': 16, 'n_estimators': 393, 'learning_rate': 0.1677911879482735, 'subsample_for_bin': 77148, 'min_split_gain': 0.1443849258107516, 'min_child_weight': 0.12764409378501412, 'reg_alpha': 6.946648253969187, 'reg_lambda': 6.308508386652658}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:03,859] Trial 35 finished with value: 0.5358427096470697 and parameters: {'num_leaves': 174, 'min_child_samples': 28, 'n_estimators': 209, 'learning_rate': 0.10980290858312533, 'subsample_for_bin': 110794, 'min_split_gain': 0.010625718697171299, 'min_child_weight': 0.09850554917045834, 'reg_alpha': 12.636668958883288, 'reg_lambda': 25.103697610124936}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:04,012] Trial 36 finished with value: 0.4859190342879202 and parameters: {'num_leaves': 108, 'min_child_samples': 14, 'n_estimators': 298, 'learning_rate': 0.1530399712091095, 'subsample_for_bin': 351723, 'min_split_gain': 0.08551401726637618, 'min_child_weight': 0.11283686840856369, 'reg_alpha': 62.433534130645654, 'reg_lambda': 17.99371182942181}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:04,141] Trial 37 finished with value: 0.52333376801423 and parameters: {'num_leaves': 155, 'min_child_samples': 31, 'n_estimators': 91, 'learning_rate': 0.1285391298878648, 'subsample_for_bin': 176772, 'min_split_gain': 0.0416089861269812, 'min_child_weight': 0.14051671190312687, 'reg_alpha': 23.900128589004975, 'reg_lambda': 5.900974137469712}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:04,357] Trial 38 finished with value: 0.5045815846500613 and parameters: {'num_leaves': 134, 'min_child_samples': 25, 'n_estimators': 516, 'learning_rate': 0.17588186351784996, 'subsample_for_bin': 75069, 'min_split_gain': 0.1288413426675092, 'min_child_weight': 0.08685245856195406, 'reg_alpha': 31.298130549683872, 'reg_lambda': 40.77723897166575}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:04,609] Trial 39 finished with value: 0.5360127881972834 and parameters: {'num_leaves': 123, 'min_child_samples': 17, 'n_estimators': 459, 'learning_rate': 0.15420454288012825, 'subsample_for_bin': 495822, 'min_split_gain': 0.16488023183554357, 'min_child_weight': 0.12325281056925413, 'reg_alpha': 7.2186651007108225, 'reg_lambda': 20.965045395663296}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:04,973] Trial 40 finished with value: 0.5623171411549267 and parameters: {'num_leaves': 156, 'min_child_samples': 13, 'n_estimators': 341, 'learning_rate': 0.23583411772873886, 'subsample_for_bin': 127338, 'min_split_gain': 0.09724620447802355, 'min_child_weight': 0.11294301746828771, 'reg_alpha': 0.05541131316860448, 'reg_lambda': 30.949910107314164}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:05,283] Trial 41 finished with value: 0.5621475828732345 and parameters: {'num_leaves': 154, 'min_child_samples': 12, 'n_estimators': 328, 'learning_rate': 0.23631349778357902, 'subsample_for_bin': 115768, 'min_split_gain': 0.09106140405027421, 'min_child_weight': 0.10263795838038463, 'reg_alpha': 0.6446908384327488, 'reg_lambda': 29.776027896646234}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:05,441] Trial 42 finished with value: 0.5291438308910525 and parameters: {'num_leaves': 160, 'min_child_samples': 12, 'n_estimators': 272, 'learning_rate': 0.26752913089845204, 'subsample_for_bin': 214551, 'min_split_gain': 0.09422213584033086, 'min_child_weight': 0.10278237682473296, 'reg_alpha': 14.448314896934281, 'reg_lambda': 32.385535646091824}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:05,639] Trial 43 finished with value: 0.5462663759364792 and parameters: {'num_leaves': 184, 'min_child_samples': 13, 'n_estimators': 156, 'learning_rate': 0.22761730235705235, 'subsample_for_bin': 118193, 'min_split_gain': 0.04072002952429657, 'min_child_weight': 0.11456658556964938, 'reg_alpha': 6.408559483945705, 'reg_lambda': 28.558649258286188}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:05,837] Trial 44 finished with value: 0.5324235700019471 and parameters: {'num_leaves': 169, 'min_child_samples': 19, 'n_estimators': 386, 'learning_rate': 0.2804946593619258, 'subsample_for_bin': 142229, 'min_split_gain': 0.12140299645625588, 'min_child_weight': 0.10212701735242252, 'reg_alpha': 10.051037749311211, 'reg_lambda': 23.422880278490183}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:05,946] Trial 45 finished with value: 0.5151664804587878 and parameters: {'num_leaves': 122, 'min_child_samples': 19, 'n_estimators': 97, 'learning_rate': 0.19860008581991023, 'subsample_for_bin': 185734, 'min_split_gain': 0.0807635968207304, 'min_child_weight': 0.11123243654710466, 'reg_alpha': 27.933885901673094, 'reg_lambda': 46.369887920821654}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:06,137] Trial 46 finished with value: 0.5486266308603412 and parameters: {'num_leaves': 138, 'min_child_samples': 10, 'n_estimators': 212, 'learning_rate': 0.23265213631086054, 'subsample_for_bin': 97777, 'min_split_gain': 0.09822332433734451, 'min_child_weight': 0.09025844906147068, 'reg_alpha': 3.8145258878966932, 'reg_lambda': 30.22170925357094}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:06,457] Trial 47 finished with value: 0.5520508197241938 and parameters: {'num_leaves': 155, 'min_child_samples': 15, 'n_estimators': 430, 'learning_rate': 0.18334287586135972, 'subsample_for_bin': 127163, 'min_split_gain': 0.029514637826577816, 'min_child_weight': 0.09710950961035582, 'reg_alpha': 4.976347730714857, 'reg_lambda': 19.545566929439005}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:07,188] Trial 48 finished with value: 0.5306818310012432 and parameters: {'num_leaves': 166, 'min_child_samples': 21, 'n_estimators': 709, 'learning_rate': 0.030311116721396542, 'subsample_for_bin': 159334, 'min_split_gain': 0.0575359993151806, 'min_child_weight': 0.08507520612028847, 'reg_alpha': 15.836399120224481, 'reg_lambda': 37.0758039232424}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:07,428] Trial 49 finished with value: 0.5316338512593918 and parameters: {'num_leaves': 130, 'min_child_samples': 17, 'n_estimators': 349, 'learning_rate': 0.10228401305160145, 'subsample_for_bin': 70616, 'min_split_gain': 0.17583941074825302, 'min_child_weight': 0.10702616536952525, 'reg_alpha': 12.08697272176818, 'reg_lambda': 26.57643956203633}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:07,497] Trial 50 finished with value: 0.5017654112681352 and parameters: {'num_leaves': 11, 'min_child_samples': 13, 'n_estimators': 24, 'learning_rate': 0.13499353448575618, 'subsample_for_bin': 272028, 'min_split_gain': 0.11994017175074438, 'min_child_weight': 0.1190315302509285, 'reg_alpha': 0.3337411442142866, 'reg_lambda': 32.30514767512555}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:07,709] Trial 51 finished with value: 0.5521278288692303 and parameters: {'num_leaves': 150, 'min_child_samples': 12, 'n_estimators': 331, 'learning_rate': 0.24605982584109373, 'subsample_for_bin': 67804, 'min_split_gain': 0.10271074793073803, 'min_child_weight': 0.12357740279626216, 'reg_alpha': 4.70556860881064, 'reg_lambda': 13.643853987851722}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:07,978] Trial 52 finished with value: 0.5590814525940992 and parameters: {'num_leaves': 32, 'min_child_samples': 48, 'n_estimators': 365, 'learning_rate': 0.23460431717809135, 'subsample_for_bin': 104585, 'min_split_gain': 0.07644738222359307, 'min_child_weight': 0.11430339922481314, 'reg_alpha': 0.37187935999940724, 'reg_lambda': 15.803464186371915}. Best is trial 28 with value: 0.5629948641008641.
# [I 2023-01-28 12:00:08,397] Trial 53 finished with value: 0.5631119342810331 and parameters: {'num_leaves': 141, 'min_child_samples': 37, 'n_estimators': 837, 'learning_rate': 0.210514789154907, 'subsample_for_bin': 127196, 'min_split_gain': 0.10618493709981035, 'min_child_weight': 0.09984733073621188, 'reg_alpha': 0.013950791702832754, 'reg_lambda': 4.717618330371159}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:08,853] Trial 54 finished with value: 0.5543846402503112 and parameters: {'num_leaves': 139, 'min_child_samples': 35, 'n_estimators': 913, 'learning_rate': 0.1558312565960957, 'subsample_for_bin': 141324, 'min_split_gain': 0.046462224050682475, 'min_child_weight': 0.09895625525377429, 'reg_alpha': 4.9656043607376565, 'reg_lambda': 5.356994821117861}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:09,188] Trial 55 finished with value: 0.5362042242707609 and parameters: {'num_leaves': 115, 'min_child_samples': 30, 'n_estimators': 821, 'learning_rate': 0.2026154814351978, 'subsample_for_bin': 127198, 'min_split_gain': 0.10845476161199152, 'min_child_weight': 0.09092650297445294, 'reg_alpha': 10.821233314926024, 'reg_lambda': 10.51794233733667}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:09,477] Trial 56 finished with value: 0.530901085551213 and parameters: {'num_leaves': 105, 'min_child_samples': 41, 'n_estimators': 751, 'learning_rate': 0.21255838867988056, 'subsample_for_bin': 204598, 'min_split_gain': 0.08382867890164859, 'min_child_weight': 0.0956438188733976, 'reg_alpha': 17.520772664187536, 'reg_lambda': 22.470206033059213}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:09,889] Trial 57 finished with value: 0.555971972182943 and parameters: {'num_leaves': 127, 'min_child_samples': 37, 'n_estimators': 867, 'learning_rate': 0.16586498575443762, 'subsample_for_bin': 300923, 'min_split_gain': 0.06157915613646821, 'min_child_weight': 0.10185939231650577, 'reg_alpha': 3.6791484253797204, 'reg_lambda': 3.929571777676157}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:10,170] Trial 58 finished with value: 0.5443611738549748 and parameters: {'num_leaves': 139, 'min_child_samples': 33, 'n_estimators': 645, 'learning_rate': 0.27740572567102795, 'subsample_for_bin': 60169, 'min_split_gain': 0.022122160195662738, 'min_child_weight': 0.10805733801117542, 'reg_alpha': 9.150041750736708, 'reg_lambda': 8.879507973645845}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:10,519] Trial 59 finished with value: 0.5342859032732147 and parameters: {'num_leaves': 88, 'min_child_samples': 26, 'n_estimators': 929, 'learning_rate': 0.29725600005348785, 'subsample_for_bin': 91673, 'min_split_gain': 0.03267130765029397, 'min_child_weight': 0.08508228032537203, 'reg_alpha': 15.492304793393693, 'reg_lambda': 2.734417300843379}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:10,888] Trial 60 finished with value: 0.5534223081389263 and parameters: {'num_leaves': 67, 'min_child_samples': 22, 'n_estimators': 789, 'learning_rate': 0.22027557267756726, 'subsample_for_bin': 164224, 'min_split_gain': 0.09335436882650724, 'min_child_weight': 0.11734566810565127, 'reg_alpha': 2.8214810713887446, 'reg_lambda': 17.28716227281584}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:11,159] Trial 61 finished with value: 0.5588918064249543 and parameters: {'num_leaves': 159, 'min_child_samples': 44, 'n_estimators': 290, 'learning_rate': 0.19369295598256223, 'subsample_for_bin': 82350, 'min_split_gain': 0.13726392115976715, 'min_child_weight': 0.12348638281305595, 'reg_alpha': 0.7078531112806205, 'reg_lambda': 13.010258921453104}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:11,329] Trial 62 finished with value: 0.5465980570606209 and parameters: {'num_leaves': 151, 'min_child_samples': 48, 'n_estimators': 244, 'learning_rate': 0.24597555023280787, 'subsample_for_bin': 109719, 'min_split_gain': 0.11615288682694964, 'min_child_weight': 0.11055940706026464, 'reg_alpha': 6.639056758496002, 'reg_lambda': 14.434073395008053}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:11,528] Trial 63 finished with value: 0.552001640493463 and parameters: {'num_leaves': 175, 'min_child_samples': 40, 'n_estimators': 327, 'learning_rate': 0.25946345281936545, 'subsample_for_bin': 126475, 'min_split_gain': 0.15909586020823957, 'min_child_weight': 0.13085023781431343, 'reg_alpha': 3.0678738086898987, 'reg_lambda': 8.550691077503135}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:11,895] Trial 64 finished with value: 0.540796002316878 and parameters: {'num_leaves': 147, 'min_child_samples': 10, 'n_estimators': 963, 'learning_rate': 0.20760877195575103, 'subsample_for_bin': 50285, 'min_split_gain': 0.13123498616128523, 'min_child_weight': 0.10244640383028694, 'reg_alpha': 9.978951690491831, 'reg_lambda': 0.9366059189921483}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:12,336] Trial 65 finished with value: 0.5626507690428036 and parameters: {'num_leaves': 190, 'min_child_samples': 28, 'n_estimators': 860, 'learning_rate': 0.18531712527718597, 'subsample_for_bin': 79604, 'min_split_gain': 0.11024346664773473, 'min_child_weight': 0.11866916346848562, 'reg_alpha': 1.0214207922774377, 'reg_lambda': 11.80693892604802}. Best is trial 53 with value: 0.5631119342810331.
# [I 2023-01-28 12:00:12,882] Trial 66 finished with value: 0.5657111883424722 and parameters: {'num_leaves': 190, 'min_child_samples': 27, 'n_estimators': 812, 'learning_rate': 0.18284402554982399, 'subsample_for_bin': 101756, 'min_split_gain': 0.11172447185437888, 'min_child_weight': 0.10775854737862754, 'reg_alpha': 0.028227301586383684, 'reg_lambda': 19.924525820116592}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:13,242] Trial 67 finished with value: 0.5409069355610784 and parameters: {'num_leaves': 200, 'min_child_samples': 28, 'n_estimators': 860, 'learning_rate': 0.19048219072943912, 'subsample_for_bin': 149466, 'min_split_gain': 0.10831590031252747, 'min_child_weight': 0.11856262725356528, 'reg_alpha': 6.764902016675258, 'reg_lambda': 21.041616979600988}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:13,565] Trial 68 finished with value: 0.5330925371194835 and parameters: {'num_leaves': 190, 'min_child_samples': 32, 'n_estimators': 819, 'learning_rate': 0.1760439487489075, 'subsample_for_bin': 189423, 'min_split_gain': 0.19387964899879154, 'min_child_weight': 0.10836995186942035, 'reg_alpha': 12.788526200986365, 'reg_lambda': 26.072192849988426}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:14,301] Trial 69 finished with value: 0.5644313310853067 and parameters: {'num_leaves': 190, 'min_child_samples': 30, 'n_estimators': 739, 'learning_rate': 0.14027105163185816, 'subsample_for_bin': 101270, 'min_split_gain': 0.06650153603496822, 'min_child_weight': 0.12302559535844831, 'reg_alpha': 0.023422618550886787, 'reg_lambda': 17.777648940725225}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:14,669] Trial 70 finished with value: 0.5469781541417856 and parameters: {'num_leaves': 188, 'min_child_samples': 29, 'n_estimators': 676, 'learning_rate': 0.14145752756862892, 'subsample_for_bin': 116432, 'min_split_gain': 0.06640319607665174, 'min_child_weight': 0.10507540693441053, 'reg_alpha': 5.962973483435261, 'reg_lambda': 12.669858554457804}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:15,235] Trial 71 finished with value: 0.5655220458024178 and parameters: {'num_leaves': 193, 'min_child_samples': 27, 'n_estimators': 775, 'learning_rate': 0.166282951663576, 'subsample_for_bin': 99612, 'min_split_gain': 0.09012703360742584, 'min_child_weight': 0.12188042702744617, 'reg_alpha': 0.11348823445799978, 'reg_lambda': 18.286754297665368}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:15,664] Trial 72 finished with value: 0.5615148485044122 and parameters: {'num_leaves': 176, 'min_child_samples': 34, 'n_estimators': 781, 'learning_rate': 0.1495888836217478, 'subsample_for_bin': 100510, 'min_split_gain': 0.09248775731068151, 'min_child_weight': 0.11542491247907835, 'reg_alpha': 2.1998000871039247, 'reg_lambda': 16.50910267669918}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:16,020] Trial 73 finished with value: 0.5344745790225026 and parameters: {'num_leaves': 196, 'min_child_samples': 27, 'n_estimators': 748, 'learning_rate': 0.22018404431208866, 'subsample_for_bin': 135008, 'min_split_gain': 0.05211127831931968, 'min_child_weight': 0.1258172560340339, 'reg_alpha': 9.00473438478513, 'reg_lambda': 22.978238551931756}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:16,420] Trial 74 finished with value: 0.5506560555527132 and parameters: {'num_leaves': 185, 'min_child_samples': 29, 'n_estimators': 855, 'learning_rate': 0.18629182205698971, 'subsample_for_bin': 103476, 'min_split_gain': 0.0718128090027001, 'min_child_weight': 0.11088382167766338, 'reg_alpha': 3.736640169807461, 'reg_lambda': 11.617797329024071}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:16,989] Trial 75 finished with value: 0.5600172155687232 and parameters: {'num_leaves': 169, 'min_child_samples': 31, 'n_estimators': 801, 'learning_rate': 0.16461681441731288, 'subsample_for_bin': 119337, 'min_split_gain': 0.11622702288855671, 'min_child_weight': 0.12107556560064292, 'reg_alpha': 0.0927441796572338, 'reg_lambda': 27.807298674491463}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:17,298] Trial 76 finished with value: 0.5352851349097151 and parameters: {'num_leaves': 190, 'min_child_samples': 26, 'n_estimators': 739, 'learning_rate': 0.2065177873336725, 'subsample_for_bin': 80000, 'min_split_gain': 0.10465564209688268, 'min_child_weight': 0.13244790264474618, 'reg_alpha': 11.376765679849628, 'reg_lambda': 19.413900838251035}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:17,739] Trial 77 finished with value: 0.5497036993044538 and parameters: {'num_leaves': 194, 'min_child_samples': 30, 'n_estimators': 949, 'learning_rate': 0.14418863243949098, 'subsample_for_bin': 175762, 'min_split_gain': 0.13370513863458613, 'min_child_weight': 0.11722209625629804, 'reg_alpha': 3.4111474387907372, 'reg_lambda': 7.140484636286377}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:18,114] Trial 78 finished with value: 0.5439056866447268 and parameters: {'num_leaves': 180, 'min_child_samples': 14, 'n_estimators': 901, 'learning_rate': 0.2336160074083406, 'subsample_for_bin': 68492, 'min_split_gain': 0.08990386590207493, 'min_child_weight': 0.11383204040226871, 'reg_alpha': 7.151177949191053, 'reg_lambda': 24.53029800046755}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:18,933] Trial 79 finished with value: 0.563353953652447 and parameters: {'num_leaves': 200, 'min_child_samples': 24, 'n_estimators': 841, 'learning_rate': 0.12461562458527754, 'subsample_for_bin': 346136, 'min_split_gain': 0.0734885230812149, 'min_child_weight': 0.12978060467480607, 'reg_alpha': 0.06805137438533235, 'reg_lambda': 16.181835716308612}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:19,433] Trial 80 finished with value: 0.5389578046000154 and parameters: {'num_leaves': 199, 'min_child_samples': 23, 'n_estimators': 997, 'learning_rate': 0.11509743258281349, 'subsample_for_bin': 388918, 'min_split_gain': 0.04788696887212688, 'min_child_weight': 0.12746675080798436, 'reg_alpha': 8.369833870594471, 'reg_lambda': 16.63850231685532}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:19,903] Trial 81 finished with value: 0.5562290214149244 and parameters: {'num_leaves': 182, 'min_child_samples': 27, 'n_estimators': 838, 'learning_rate': 0.17913087013133444, 'subsample_for_bin': 420737, 'min_split_gain': 0.06974148428563201, 'min_child_weight': 0.12147405384224579, 'reg_alpha': 2.541046859010092, 'reg_lambda': 21.408206362564446}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:20,602] Trial 82 finished with value: 0.564688632520685 and parameters: {'num_leaves': 192, 'min_child_samples': 25, 'n_estimators': 887, 'learning_rate': 0.12776479899832457, 'subsample_for_bin': 260076, 'min_split_gain': 0.0860647881543692, 'min_child_weight': 0.13510758484371888, 'reg_alpha': 0.05545863283020713, 'reg_lambda': 10.663585184274748}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:21,005] Trial 83 finished with value: 0.5483277765562972 and parameters: {'num_leaves': 193, 'min_child_samples': 25, 'n_estimators': 881, 'learning_rate': 0.16252657474033055, 'subsample_for_bin': 335965, 'min_split_gain': 0.060391170293697644, 'min_child_weight': 0.1366028397659454, 'reg_alpha': 5.243670385359875, 'reg_lambda': 12.009750364418537}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:21,564] Trial 84 finished with value: 0.5622230231463939 and parameters: {'num_leaves': 188, 'min_child_samples': 21, 'n_estimators': 838, 'learning_rate': 0.12167801150639702, 'subsample_for_bin': 242485, 'min_split_gain': 0.03853116832309951, 'min_child_weight': 0.1287212869432419, 'reg_alpha': 3.274060082770903, 'reg_lambda': 10.128815243536256}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:21,971] Trial 85 finished with value: 0.5407430139430747 and parameters: {'num_leaves': 177, 'min_child_samples': 28, 'n_estimators': 805, 'learning_rate': 0.13119128978699138, 'subsample_for_bin': 387270, 'min_split_gain': 0.08030158457219869, 'min_child_weight': 0.13766445309590297, 'reg_alpha': 5.786253148284411, 'reg_lambda': 15.772466534754159}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:22,475] Trial 86 finished with value: 0.5627434399315702 and parameters: {'num_leaves': 171, 'min_child_samples': 26, 'n_estimators': 762, 'learning_rate': 0.14267408143597754, 'subsample_for_bin': 359236, 'min_split_gain': 0.12661076110923863, 'min_child_weight': 0.13211232507529427, 'reg_alpha': 0.043997599666441956, 'reg_lambda': 6.882241245763721}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:22,835] Trial 87 finished with value: 0.5355066359159482 and parameters: {'num_leaves': 172, 'min_child_samples': 24, 'n_estimators': 756, 'learning_rate': 0.09844571565476626, 'subsample_for_bin': 374388, 'min_split_gain': 0.12071499143162522, 'min_child_weight': 0.1327086407044066, 'reg_alpha': 11.036837932482852, 'reg_lambda': 4.946884874566744}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:23,181] Trial 88 finished with value: 0.5431265698322982 and parameters: {'num_leaves': 193, 'min_child_samples': 32, 'n_estimators': 728, 'learning_rate': 0.1496922350158411, 'subsample_for_bin': 351102, 'min_split_gain': 0.0721158021771785, 'min_child_weight': 0.13971279804878492, 'reg_alpha': 8.140955941881051, 'reg_lambda': 7.242363623615232}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:23,558] Trial 89 finished with value: 0.5348435751801196 and parameters: {'num_leaves': 165, 'min_child_samples': 29, 'n_estimators': 895, 'learning_rate': 0.12604637184389916, 'subsample_for_bin': 319199, 'min_split_gain': 0.10830254104322712, 'min_child_weight': 0.14544110556736525, 'reg_alpha': 13.401987318762242, 'reg_lambda': 0.07215081513159216}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:24,119] Trial 90 finished with value: 0.5608889382882052 and parameters: {'num_leaves': 185, 'min_child_samples': 26, 'n_estimators': 675, 'learning_rate': 0.14346886964105893, 'subsample_for_bin': 422965, 'min_split_gain': 0.024225021568491018, 'min_child_weight': 0.13375180353265675, 'reg_alpha': 2.4046478279109853, 'reg_lambda': 9.706116310269696}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:24,620] Trial 91 finished with value: 0.5616444444118404 and parameters: {'num_leaves': 200, 'min_child_samples': 24, 'n_estimators': 604, 'learning_rate': 0.16418616190746194, 'subsample_for_bin': 256150, 'min_split_gain': 0.09734090069124159, 'min_child_weight': 0.12483875328745492, 'reg_alpha': 0.19525854957343247, 'reg_lambda': 17.968999075470137}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:25,077] Trial 92 finished with value: 0.5636735244062934 and parameters: {'num_leaves': 161, 'min_child_samples': 27, 'n_estimators': 773, 'learning_rate': 0.18190216857384092, 'subsample_for_bin': 369968, 'min_split_gain': 0.08805014672520024, 'min_child_weight': 0.1301329739118685, 'reg_alpha': 0.011117535853864546, 'reg_lambda': 3.578836762899482}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:25,401] Trial 93 finished with value: 0.5506940405780563 and parameters: {'num_leaves': 182, 'min_child_samples': 27, 'n_estimators': 684, 'learning_rate': 0.18216938619293652, 'subsample_for_bin': 291281, 'min_split_gain': 0.08474473697330029, 'min_child_weight': 0.13015628306826316, 'reg_alpha': 5.4205917863404025, 'reg_lambda': 3.0670005996583782}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:25,814] Trial 94 finished with value: 0.5617723002496268 and parameters: {'num_leaves': 190, 'min_child_samples': 25, 'n_estimators': 770, 'learning_rate': 0.1560346601292021, 'subsample_for_bin': 364059, 'min_split_gain': 0.04774924706037022, 'min_child_weight': 0.12660002318670668, 'reg_alpha': 3.291403073257106, 'reg_lambda': 5.551791742506517}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:26,235] Trial 95 finished with value: 0.5558780934420321 and parameters: {'num_leaves': 171, 'min_child_samples': 23, 'n_estimators': 873, 'learning_rate': 0.19629755246932787, 'subsample_for_bin': 407048, 'min_split_gain': 0.06771884537948163, 'min_child_weight': 0.13539100835582255, 'reg_alpha': 2.126597078137081, 'reg_lambda': 3.8231287670035528}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:26,636] Trial 96 finished with value: 0.5383506627443188 and parameters: {'num_leaves': 179, 'min_child_samples': 28, 'n_estimators': 925, 'learning_rate': 0.1307617458246456, 'subsample_for_bin': 329260, 'min_split_gain': 0.1446804716702937, 'min_child_weight': 0.1201442038346469, 'reg_alpha': 8.064913842647222, 'reg_lambda': 8.15656190043469}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:27,006] Trial 97 finished with value: 0.5484663292192998 and parameters: {'num_leaves': 164, 'min_child_samples': 20, 'n_estimators': 850, 'learning_rate': 0.16799971668206734, 'subsample_for_bin': 458536, 'min_split_gain': 0.13027803671013014, 'min_child_weight': 0.14080336934657348, 'reg_alpha': 5.184912367052783, 'reg_lambda': 13.890028912910278}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:27,507] Trial 98 finished with value: 0.5651679853354229 and parameters: {'num_leaves': 196, 'min_child_samples': 26, 'n_estimators': 807, 'learning_rate': 0.1811967435160294, 'subsample_for_bin': 355297, 'min_split_gain': 0.11171982574507494, 'min_child_weight': 0.12942518012893556, 'reg_alpha': 0.09343304506401727, 'reg_lambda': 10.577986063007643}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:28,258] Trial 99 finished with value: 0.5605569283083921 and parameters: {'num_leaves': 196, 'min_child_samples': 26, 'n_estimators': 804, 'learning_rate': 0.13859157246723264, 'subsample_for_bin': 345161, 'min_split_gain': 0.05462724501926264, 'min_child_weight': 0.13113042926685767, 'reg_alpha': 0.05513929586676701, 'reg_lambda': 6.325221905732473}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:28,589] Trial 100 finished with value: 0.5372915832373036 and parameters: {'num_leaves': 187, 'min_child_samples': 30, 'n_estimators': 780, 'learning_rate': 0.17340509150107683, 'subsample_for_bin': 360804, 'min_split_gain': 0.08439531078039361, 'min_child_weight': 0.1252356594426374, 'reg_alpha': 10.066090422257215, 'reg_lambda': 1.7528909746100219}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:28,967] Trial 101 finished with value: 0.5562980075428203 and parameters: {'num_leaves': 193, 'min_child_samples': 29, 'n_estimators': 724, 'learning_rate': 0.1896987089993847, 'subsample_for_bin': 371715, 'min_split_gain': 0.11115707070444296, 'min_child_weight': 0.12184306379577677, 'reg_alpha': 2.66965803390306, 'reg_lambda': 11.232660148711137}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:29,364] Trial 102 finished with value: 0.5465681069304295 and parameters: {'num_leaves': 196, 'min_child_samples': 27, 'n_estimators': 824, 'learning_rate': 0.15471688086741384, 'subsample_for_bin': 400052, 'min_split_gain': 0.09797916822788134, 'min_child_weight': 0.12893381252060185, 'reg_alpha': 5.153120449673412, 'reg_lambda': 9.11582086997184}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:29,760] Trial 103 finished with value: 0.558251489748898 and parameters: {'num_leaves': 184, 'min_child_samples': 24, 'n_estimators': 770, 'learning_rate': 0.17941470523174127, 'subsample_for_bin': 308741, 'min_split_gain': 0.12639741240194352, 'min_child_weight': 0.13393300719657478, 'reg_alpha': 1.9934813268012064, 'reg_lambda': 14.999380757897567}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:30,146] Trial 104 finished with value: 0.5424872883612281 and parameters: {'num_leaves': 200, 'min_child_samples': 31, 'n_estimators': 966, 'learning_rate': 0.19979270096244678, 'subsample_for_bin': 373143, 'min_split_gain': 0.11709749169466735, 'min_child_weight': 0.1166528279192996, 'reg_alpha': 7.3883686779507, 'reg_lambda': 18.17446469639932}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:30,598] Trial 105 finished with value: 0.5509479307535893 and parameters: {'num_leaves': 190, 'min_child_samples': 22, 'n_estimators': 878, 'learning_rate': 0.12286155679241606, 'subsample_for_bin': 337451, 'min_split_gain': 0.10109847578550299, 'min_child_weight': 0.12385843724770795, 'reg_alpha': 4.407879524705161, 'reg_lambda': 12.011037099853057}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:31,026] Trial 106 finished with value: 0.5593249371561911 and parameters: {'num_leaves': 175, 'min_child_samples': 26, 'n_estimators': 794, 'learning_rate': 0.1620702053912908, 'subsample_for_bin': 87430, 'min_split_gain': 0.07900263429292785, 'min_child_weight': 0.11945788210585996, 'reg_alpha': 1.7832070584454962, 'reg_lambda': 3.596056352560449}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:31,419] Trial 107 finished with value: 0.5462682745202622 and parameters: {'num_leaves': 159, 'min_child_samples': 28, 'n_estimators': 841, 'learning_rate': 0.1482767668952571, 'subsample_for_bin': 218470, 'min_split_gain': 0.06549933626252483, 'min_child_weight': 0.13751882808149168, 'reg_alpha': 6.515880203015536, 'reg_lambda': 7.5950268866530175}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:31,852] Trial 108 finished with value: 0.5502373336441826 and parameters: {'num_leaves': 180, 'min_child_samples': 30, 'n_estimators': 818, 'learning_rate': 0.1381651541551129, 'subsample_for_bin': 283905, 'min_split_gain': 0.08654098959029335, 'min_child_weight': 0.11221689754343676, 'reg_alpha': 3.980673073567213, 'reg_lambda': 13.609349013475626}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:32,210] Trial 109 finished with value: 0.5531448169610057 and parameters: {'num_leaves': 169, 'min_child_samples': 32, 'n_estimators': 715, 'learning_rate': 0.20987805687096395, 'subsample_for_bin': 320522, 'min_split_gain': 0.1383524585202282, 'min_child_weight': 0.1275147555113573, 'reg_alpha': 2.079037927587908, 'reg_lambda': 19.89266622301448}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:32,519] Trial 110 finished with value: 0.5371204123544522 and parameters: {'num_leaves': 193, 'min_child_samples': 25, 'n_estimators': 699, 'learning_rate': 0.18467506964420055, 'subsample_for_bin': 62352, 'min_split_gain': 0.10970972075549838, 'min_child_weight': 0.13060761838299567, 'reg_alpha': 9.594185877107336, 'reg_lambda': 15.677836525778762}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:32,918] Trial 111 finished with value: 0.5637359764446762 and parameters: {'num_leaves': 144, 'min_child_samples': 11, 'n_estimators': 754, 'learning_rate': 0.21441977264466705, 'subsample_for_bin': 97966, 'min_split_gain': 0.09406356471067627, 'min_child_weight': 0.10950701102533157, 'reg_alpha': 0.7295482741298158, 'reg_lambda': 10.44518738530588}. Best is trial 66 with value: 0.5657111883424722.
# [I 2023-01-28 12:00:33,338] Trial 112 finished with value: 0.5632515988546664 and parameters: {'num_leaves': 187, 'min_child_samples': 36, 'n_estimators': 735, 'learning_rate': 0.21617671641060557, 'subsample_for_bin': 108480, 'min_split_gain': 0.09654641930454619, 'min_child_weight': 0.10798909487693747, 'reg_alpha': 0.39931199468607537, 'reg_lambda': 10.37686463088502}. Best is trial 66 with value: 0.5657111883424722.
# ...
# [I 2023-01-28 12:08:17,750] Trial 987 finished with value: 0.5228482637171834 and parameters: {'num_leaves': 169, 'min_child_samples': 25, 'n_estimators': 804, 'learning_rate': 0.11995816276999098, 'subsample_for_bin': 84656, 'min_split_gain': 0.3095980934643801, 'min_child_weight': 0.1369435698461745, 'reg_alpha': 17.874508215703575, 'reg_lambda': 56.508120762904625}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:17,960] Trial 988 finished with value: 0.5575150796040792 and parameters: {'num_leaves': 194, 'min_child_samples': 21, 'n_estimators': 39, 'learning_rate': 0.4995538449768789, 'subsample_for_bin': 78281, 'min_split_gain': 0.060190575294494446, 'min_child_weight': 0.003491949985893722, 'reg_alpha': 3.102784551863343, 'reg_lambda': 19.61242072362221}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:18,289] Trial 989 finished with value: 0.5455067327283841 and parameters: {'num_leaves': 180, 'min_child_samples': 22, 'n_estimators': 518, 'learning_rate': 0.45206867531050626, 'subsample_for_bin': 111792, 'min_split_gain': 0.23130777691234553, 'min_child_weight': 0.04531638544574999, 'reg_alpha': 2.221384836318103, 'reg_lambda': 53.05933981650495}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:18,755] Trial 990 finished with value: 0.5501280774950413 and parameters: {'num_leaves': 189, 'min_child_samples': 27, 'n_estimators': 764, 'learning_rate': 0.27274664349423877, 'subsample_for_bin': 336251, 'min_split_gain': 0.4040494409959954, 'min_child_weight': 0.1056906598485515, 'reg_alpha': 0.0909948975517913, 'reg_lambda': 22.478311926582208}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:19,145] Trial 991 finished with value: 0.4759922930716917 and parameters: {'num_leaves': 185, 'min_child_samples': 26, 'n_estimators': 727, 'learning_rate': 0.15414896295245217, 'subsample_for_bin': 90352, 'min_split_gain': 0.03938068711450774, 'min_child_weight': 0.07239219063459394, 'reg_alpha': 71.17847515163625, 'reg_lambda': 5.154213868446459}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:19,509] Trial 992 finished with value: 0.562146935156766 and parameters: {'num_leaves': 200, 'min_child_samples': 24, 'n_estimators': 394, 'learning_rate': 0.2511636242485496, 'subsample_for_bin': 101741, 'min_split_gain': 0.05121213967443143, 'min_child_weight': 0.1340654538003122, 'reg_alpha': 1.97780268564702, 'reg_lambda': 3.339932160397135}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:19,996] Trial 993 finished with value: 0.5508432990459119 and parameters: {'num_leaves': 191, 'min_child_samples': 11, 'n_estimators': 818, 'learning_rate': 0.3388416253960121, 'subsample_for_bin': 112727, 'min_split_gain': 0.02018839700582891, 'min_child_weight': 0.06449474143967876, 'reg_alpha': 5.843290232665934, 'reg_lambda': 78.78198996158557}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:20,370] Trial 994 finished with value: 0.4875419459707646 and parameters: {'num_leaves': 182, 'min_child_samples': 25, 'n_estimators': 798, 'learning_rate': 0.4371819544985723, 'subsample_for_bin': 164798, 'min_split_gain': 0.12368765097761258, 'min_child_weight': 0.08132768760155212, 'reg_alpha': 65.37267703391137, 'reg_lambda': 61.336772681067465}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:20,796] Trial 995 finished with value: 0.4999093040603186 and parameters: {'num_leaves': 194, 'min_child_samples': 13, 'n_estimators': 834, 'learning_rate': 0.12821452221233626, 'subsample_for_bin': 92005, 'min_split_gain': 0.010698864444675604, 'min_child_weight': 0.09892165265125503, 'reg_alpha': 46.448435573604996, 'reg_lambda': 12.08547495472258}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:21,208] Trial 996 finished with value: 0.5396884365895462 and parameters: {'num_leaves': 177, 'min_child_samples': 12, 'n_estimators': 682, 'learning_rate': 0.35735424692827134, 'subsample_for_bin': 390237, 'min_split_gain': 0.03167040482306215, 'min_child_weight': 0.02108802058416013, 'reg_alpha': 10.08048407542386, 'reg_lambda': 42.563263478330455}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:21,659] Trial 997 finished with value: 0.5515824272692633 and parameters: {'num_leaves': 188, 'min_child_samples': 27, 'n_estimators': 782, 'learning_rate': 0.20310925670626603, 'subsample_for_bin': 376057, 'min_split_gain': 0.36702947739783215, 'min_child_weight': 0.12833572686959085, 'reg_alpha': 0.0177720797701972, 'reg_lambda': 36.135095058227414}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:22,976] Trial 998 finished with value: 0.5489621110510229 and parameters: {'num_leaves': 195, 'min_child_samples': 24, 'n_estimators': 709, 'learning_rate': 0.03611556212108455, 'subsample_for_bin': 105163, 'min_split_gain': 0.06806633491320392, 'min_child_weight': 0.0682094109947817, 'reg_alpha': 3.6294836674186075, 'reg_lambda': 38.833552774845}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:23,345] Trial 999 finished with value: 0.47909574114343517 and parameters: {'num_leaves': 197, 'min_child_samples': 17, 'n_estimators': 753, 'learning_rate': 0.28805451392233866, 'subsample_for_bin': 68752, 'min_split_gain': 0.31609505199608884, 'min_child_weight': 0.12354454098061013, 'reg_alpha': 77.07544464184377, 'reg_lambda': 46.36694050436489}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:23,716] Trial 1000 finished with value: 0.48649605171995763 and parameters: {'num_leaves': 185, 'min_child_samples': 42, 'n_estimators': 768, 'learning_rate': 0.40232997735527687, 'subsample_for_bin': 116340, 'min_split_gain': 0.1720583491717895, 'min_child_weight': 0.03593595784073401, 'reg_alpha': 48.33145420698697, 'reg_lambda': 9.46742889180648}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:24,168] Trial 1001 finished with value: 0.5460322440242568 and parameters: {'num_leaves': 191, 'min_child_samples': 28, 'n_estimators': 737, 'learning_rate': 0.19445811429207926, 'subsample_for_bin': 82826, 'min_split_gain': 0.26413740665914043, 'min_child_weight': 0.13225955797035518, 'reg_alpha': 1.903948881038088, 'reg_lambda': 72.22908810504566}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:24,607] Trial 1002 finished with value: 0.5107443412473006 and parameters: {'num_leaves': 140, 'min_child_samples': 23, 'n_estimators': 861, 'learning_rate': 0.16744190971439407, 'subsample_for_bin': 97173, 'min_split_gain': 0.04502458225243702, 'min_child_weight': 0.07822580813991468, 'reg_alpha': 35.98881710011489, 'reg_lambda': 24.23288521231243}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:25,024] Trial 1003 finished with value: 0.538414789690583 and parameters: {'num_leaves': 172, 'min_child_samples': 26, 'n_estimators': 815, 'learning_rate': 0.23062090428662846, 'subsample_for_bin': 105432, 'min_split_gain': 0.3283364224166918, 'min_child_weight': 0.05920175713918476, 'reg_alpha': 7.3601417635913, 'reg_lambda': 21.069554200310424}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:25,424] Trial 1004 finished with value: 0.5435843723264723 and parameters: {'num_leaves': 181, 'min_child_samples': 26, 'n_estimators': 796, 'learning_rate': 0.4199120961445988, 'subsample_for_bin': 290242, 'min_split_gain': 0.16931068733392657, 'min_child_weight': 0.09575329305272612, 'reg_alpha': 4.308882357497589, 'reg_lambda': 14.278669733614585}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:26,099] Trial 1005 finished with value: 0.560937111154586 and parameters: {'num_leaves': 200, 'min_child_samples': 25, 'n_estimators': 833, 'learning_rate': 0.14070574851289097, 'subsample_for_bin': 119511, 'min_split_gain': 0.05533848339543809, 'min_child_weight': 0.12016790425536983, 'reg_alpha': 1.8931433162400437, 'reg_lambda': 16.88615615733192}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:26,425] Trial 1006 finished with value: 0.47332365433145934 and parameters: {'num_leaves': 188, 'min_child_samples': 27, 'n_estimators': 577, 'learning_rate': 0.249272668899965, 'subsample_for_bin': 75348, 'min_split_gain': 0.09744896014503895, 'min_child_weight': 0.12714454134406525, 'reg_alpha': 75.90526940793242, 'reg_lambda': 10.89882498637893}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:26,861] Trial 1007 finished with value: 0.4745978644001216 and parameters: {'num_leaves': 194, 'min_child_samples': 22, 'n_estimators': 781, 'learning_rate': 0.10727860061687051, 'subsample_for_bin': 267519, 'min_split_gain': 0.07933020940280996, 'min_child_weight': 0.04899234272272415, 'reg_alpha': 67.40652662506753, 'reg_lambda': 95.8640222476565}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:27,240] Trial 1008 finished with value: 0.5193476554582958 and parameters: {'num_leaves': 176, 'min_child_samples': 15, 'n_estimators': 717, 'learning_rate': 0.33032190241720855, 'subsample_for_bin': 316968, 'min_split_gain': 0.027130077171269935, 'min_child_weight': 0.07376852168186014, 'reg_alpha': 30.362441450596304, 'reg_lambda': 7.154104172348153}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:27,672] Trial 1009 finished with value: 0.5597309703692682 and parameters: {'num_leaves': 184, 'min_child_samples': 36, 'n_estimators': 656, 'learning_rate': 0.34838803918157796, 'subsample_for_bin': 153525, 'min_split_gain': 0.03971693030500485, 'min_child_weight': 0.13965154786140768, 'reg_alpha': 1.8172974524914218, 'reg_lambda': 3.0160721877260843}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:28,147] Trial 1010 finished with value: 0.5458530178746973 and parameters: {'num_leaves': 197, 'min_child_samples': 25, 'n_estimators': 749, 'learning_rate': 0.12603593355950807, 'subsample_for_bin': 182251, 'min_split_gain': 0.15587339554829172, 'min_child_weight': 0.033000616758283516, 'reg_alpha': 4.366264842444732, 'reg_lambda': 12.965292821529617}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:29,181] Trial 1011 finished with value: 0.5603789748785459 and parameters: {'num_leaves': 156, 'min_child_samples': 24, 'n_estimators': 808, 'learning_rate': 0.1743305424168701, 'subsample_for_bin': 58139, 'min_split_gain': 0.06281272288389252, 'min_child_weight': 0.028361645374475473, 'reg_alpha': 0.09275445050605956, 'reg_lambda': 76.86849712165537}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:29,585] Trial 1012 finished with value: 0.5331372735608996 and parameters: {'num_leaves': 54, 'min_child_samples': 28, 'n_estimators': 849, 'learning_rate': 0.2635554724194847, 'subsample_for_bin': 88881, 'min_split_gain': 0.29557187050863803, 'min_child_weight': 0.1299282555517683, 'reg_alpha': 11.32033813569574, 'reg_lambda': 5.6117468765175325}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:29,966] Trial 1013 finished with value: 0.5001326179487441 and parameters: {'num_leaves': 191, 'min_child_samples': 20, 'n_estimators': 779, 'learning_rate': 0.21728209425623085, 'subsample_for_bin': 109251, 'min_split_gain': 0.2848672159179474, 'min_child_weight': 0.12463620317559218, 'reg_alpha': 40.66984566945592, 'reg_lambda': 81.68996215506021}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:30,335] Trial 1014 finished with value: 0.49921960141561766 and parameters: {'num_leaves': 188, 'min_child_samples': 26, 'n_estimators': 551, 'learning_rate': 0.15101575372701356, 'subsample_for_bin': 129091, 'min_split_gain': 0.010152942457323101, 'min_child_weight': 0.13547811474164587, 'reg_alpha': 44.6461050506939, 'reg_lambda': 99.12871791438437}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:31,283] Trial 1015 finished with value: 0.5481932196834415 and parameters: {'num_leaves': 197, 'min_child_samples': 27, 'n_estimators': 879, 'learning_rate': 0.09875166048869306, 'subsample_for_bin': 97668, 'min_split_gain': 0.04742717102551593, 'min_child_weight': 0.11267184344497629, 'reg_alpha': 3.2324613691155903, 'reg_lambda': 84.25838560543231}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:31,556] Trial 1016 finished with value: 0.5346329475597273 and parameters: {'num_leaves': 180, 'min_child_samples': 23, 'n_estimators': 84, 'learning_rate': 0.11373836047180197, 'subsample_for_bin': 120271, 'min_split_gain': 0.3872187752122116, 'min_child_weight': 0.13279622918109177, 'reg_alpha': 5.638555296698393, 'reg_lambda': 43.527099739622294}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:31,897] Trial 1017 finished with value: 0.4500170978508076 and parameters: {'num_leaves': 193, 'min_child_samples': 29, 'n_estimators': 632, 'learning_rate': 0.18466635403321466, 'subsample_for_bin': 228500, 'min_split_gain': 0.07001755898500032, 'min_child_weight': 0.11679042624002695, 'reg_alpha': 99.24475008422864, 'reg_lambda': 64.95689014209414}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:32,439] Trial 1018 finished with value: 0.5263115763845553 and parameters: {'num_leaves': 185, 'min_child_samples': 25, 'n_estimators': 491, 'learning_rate': 0.28143102376021717, 'subsample_for_bin': 141975, 'min_split_gain': 0.02209876236003637, 'min_child_weight': 0.1451409551722222, 'reg_alpha': 16.162900953791443, 'reg_lambda': 58.91247672466623}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:32,840] Trial 1019 finished with value: 0.5546149581679249 and parameters: {'num_leaves': 200, 'min_child_samples': 30, 'n_estimators': 764, 'learning_rate': 0.36435853929433365, 'subsample_for_bin': 112646, 'min_split_gain': 0.2547198521949694, 'min_child_weight': 0.041048817612024766, 'reg_alpha': 1.6840964702136354, 'reg_lambda': 25.36005471486171}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:33,200] Trial 1020 finished with value: 0.49403789923354496 and parameters: {'num_leaves': 190, 'min_child_samples': 24, 'n_estimators': 702, 'learning_rate': 0.39272782301392917, 'subsample_for_bin': 90558, 'min_split_gain': 0.213276472022279, 'min_child_weight': 0.024958963964200623, 'reg_alpha': 53.585374421313716, 'reg_lambda': 69.74059299408168}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:33,581] Trial 1021 finished with value: 0.46618129280569226 and parameters: {'num_leaves': 196, 'min_child_samples': 22, 'n_estimators': 729, 'learning_rate': 0.13412422794111847, 'subsample_for_bin': 303262, 'min_split_gain': 0.03541812967909509, 'min_child_weight': 0.12207672836275534, 'reg_alpha': 85.9555670421014, 'reg_lambda': 10.13744834787359}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:33,982] Trial 1022 finished with value: 0.4739735605557827 and parameters: {'num_leaves': 183, 'min_child_samples': 26, 'n_estimators': 816, 'learning_rate': 0.24122156284815094, 'subsample_for_bin': 456079, 'min_split_gain': 0.056252738046114546, 'min_child_weight': 0.012943709416624607, 'reg_alpha': 64.65688682865134, 'reg_lambda': 86.92998781384414}. Best is trial 477 with value: 0.5705119267528898.
# [I 2023-01-28 12:08:34,392] Trial 1023 finished with value: 0.45760653925103817 and parameters: {'num_leaves': 193, 'min_child_samples': 31, 'n_estimators': 791, 'learning_rate': 0.1597803520233516, 'subsample_for_bin': 101928, 'min_split_gain': 0.3767289844557046, 'min_child_weight': 0.06678232623019587, 'reg_alpha': 79.64480573728201, 'reg_lambda': 7.585047032826093}. Best is trial 477 with value: 0.5705119267528898.
# F1 Score: 0.5705119267528898
# Best hyperparameters: {'num_leaves': 200, 'min_child_samples': 11, 'n_estimators': 642, 'learning_rate': 0.2700039159425268, 'subsample_for_bin': 78816, 'min_split_gain': 0.010205805771753236, 'min_child_weight': 0.07461172658814842, 'reg_alpha': 0.10447213904638447, 'reg_lambda': 9.877032396270753}

# %% [markdown]
# ### AUC

# %%
def objective(trial):
  
      num_leaves = trial.suggest_int('num_leaves', num_leaves_min, num_leaves_max) #int
      min_child_samples = trial.suggest_int('min_child_samples', min_child_samples_min, min_child_samples_max) #int
      n_estimators      = trial.suggest_int('n_estimators', n_estimators_min, n_estimators_max)#int
      learning_rate     = trial.suggest_float('learning_rate', learning_rate_min, learning_rate_max)
      subsample_for_bin = trial.suggest_int('subsample_for_bin', subsample_for_bin_min, subsample_for_bin_max) #int
      min_split_gain    = trial.suggest_float('min_split_gain', min_split_gain_min, min_split_gain_max)
      min_child_weight  = trial.suggest_float('min_child_weight', min_child_weight_min, min_child_weight_max)
      reg_alpha         = trial.suggest_float('reg_alpha', reg_alpha_min, reg_alpha_max)
      reg_lambda        = trial.suggest_float('reg_lambda', reg_lambda_min, reg_lambda_max)

      final_model = lgb.LGBMClassifier(num_leaves       = num_leaves, 
                                      min_child_samples = min_child_samples, 
                                      n_estimators      = n_estimators,
                                      learning_rate     = learning_rate,
                                      subsample_for_bin = subsample_for_bin,
                                      min_split_gain    = min_split_gain,
                                      min_child_weight  = min_child_weight,
                                      reg_alpha         = reg_alpha,
                                      reg_lambda        = reg_lambda,
                                      max_depth= -1,
                                      n_jobs = -1
                                      )
      
      kfold = KFold(n_splits = 3, shuffle = True)

      return sklearn.model_selection.cross_val_score(final_model, x_credit, y_credit, n_jobs=-1, scoring='roc_auc', cv=kfold).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1024, n_jobs = -1)

trial = study.best_trial

print('AUC: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))

tracking = []
for i in range(len(study.trials)):
  if i == 0: 
    tracking.append(study.trials[i].value)
  elif tracking[i-1] > study.trials[i].value:
    tracking.append(tracking[i-1])
  else:
    tracking.append(study.trials[i].value)
#tracking_sorted = sorted(tracking)

tracking_Optuna_AUC = tracking

plt.plot(tracking);
#plt.plot(tracking_sorted)
# Out:
# [I 2023-01-28 12:22:09,484] A new study created in memory with name: no-name-172e3fcc-b88d-4eb8-9023-ac3e8c322bd9
# [I 2023-01-28 12:22:09,605] Trial 0 finished with value: 0.8024390832484244 and parameters: {'num_leaves': 189, 'min_child_samples': 25, 'n_estimators': 79, 'learning_rate': 0.32899117678536255, 'subsample_for_bin': 329006, 'min_split_gain': 0.05100203990993896, 'min_child_weight': 0.04404839506514925, 'reg_alpha': 34.49696879104376, 'reg_lambda': 29.490747748975284}. Best is trial 0 with value: 0.8024390832484244.
# [I 2023-01-28 12:22:09,797] Trial 4 finished with value: 0.781216501087735 and parameters: {'num_leaves': 83, 'min_child_samples': 45, 'n_estimators': 265, 'learning_rate': 0.24249800544855535, 'subsample_for_bin': 410076, 'min_split_gain': 0.3468360526568591, 'min_child_weight': 0.049959025888577126, 'reg_alpha': 90.57292115543159, 'reg_lambda': 28.61298728974741}. Best is trial 0 with value: 0.8024390832484244.
# [I 2023-01-28 12:22:09,870] Trial 5 finished with value: 0.798498117337728 and parameters: {'num_leaves': 128, 'min_child_samples': 37, 'n_estimators': 347, 'learning_rate': 0.293439145239974, 'subsample_for_bin': 305865, 'min_split_gain': 0.11628836608089281, 'min_child_weight': 0.03876929526810216, 'reg_alpha': 34.75690564464711, 'reg_lambda': 38.79870006490504}. Best is trial 0 with value: 0.8024390832484244.
# [I 2023-01-28 12:22:09,953] Trial 3 finished with value: 0.7847466372585981 and parameters: {'num_leaves': 112, 'min_child_samples': 26, 'n_estimators': 510, 'learning_rate': 0.18361462807188025, 'subsample_for_bin': 139825, 'min_split_gain': 0.3393028156819172, 'min_child_weight': 0.11372856531789532, 'reg_alpha': 67.04632666762613, 'reg_lambda': 31.463051391032394}. Best is trial 0 with value: 0.8024390832484244.
# [I 2023-01-28 12:22:09,965] Trial 6 finished with value: 0.8318898644927661 and parameters: {'num_leaves': 175, 'min_child_samples': 24, 'n_estimators': 197, 'learning_rate': 0.46574034395976044, 'subsample_for_bin': 394108, 'min_split_gain': 0.4879737875675375, 'min_child_weight': 0.009227741029382244, 'reg_alpha': 5.49973583075521, 'reg_lambda': 35.7033330666481}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,050] Trial 7 finished with value: 0.7885908958411104 and parameters: {'num_leaves': 149, 'min_child_samples': 36, 'n_estimators': 306, 'learning_rate': 0.2287533899758224, 'subsample_for_bin': 129314, 'min_split_gain': 0.46174658586937994, 'min_child_weight': 0.12452132390181093, 'reg_alpha': 45.28936609038139, 'reg_lambda': 97.99803566767989}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,102] Trial 2 finished with value: 0.7911411658049371 and parameters: {'num_leaves': 197, 'min_child_samples': 31, 'n_estimators': 948, 'learning_rate': 0.39439468593389293, 'subsample_for_bin': 224488, 'min_split_gain': 0.23754359841458828, 'min_child_weight': 0.13546223033377142, 'reg_alpha': 43.63989179741846, 'reg_lambda': 43.072612019165035}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,109] Trial 1 finished with value: 0.8239454586506981 and parameters: {'num_leaves': 71, 'min_child_samples': 21, 'n_estimators': 878, 'learning_rate': 0.3685052973034537, 'subsample_for_bin': 288701, 'min_split_gain': 0.1374104343928314, 'min_child_weight': 0.022112260770996928, 'reg_alpha': 12.89377082817999, 'reg_lambda': 82.40183248573463}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,198] Trial 12 finished with value: 0.7850350495320665 and parameters: {'num_leaves': 56, 'min_child_samples': 28, 'n_estimators': 470, 'learning_rate': 0.366435310151418, 'subsample_for_bin': 146993, 'min_split_gain': 0.18863402218717504, 'min_child_weight': 0.029765824600374344, 'reg_alpha': 64.88816032435213, 'reg_lambda': 28.129215627786106}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,206] Trial 13 finished with value: 0.8173105275014763 and parameters: {'num_leaves': 190, 'min_child_samples': 28, 'n_estimators': 62, 'learning_rate': 0.4053998022657245, 'subsample_for_bin': 332905, 'min_split_gain': 0.04788512930747656, 'min_child_weight': 0.018855579851323294, 'reg_alpha': 19.661300180401838, 'reg_lambda': 61.14177044685437}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,364] Trial 14 finished with value: 0.7919601624292802 and parameters: {'num_leaves': 20, 'min_child_samples': 44, 'n_estimators': 181, 'learning_rate': 0.11082922384901069, 'subsample_for_bin': 307690, 'min_split_gain': 0.15270449962540067, 'min_child_weight': 0.09016477619586748, 'reg_alpha': 42.62744961396446, 'reg_lambda': 84.8526599936804}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,613] Trial 11 finished with value: 0.7824243978953115 and parameters: {'num_leaves': 18, 'min_child_samples': 40, 'n_estimators': 677, 'learning_rate': 0.21642230239754467, 'subsample_for_bin': 471238, 'min_split_gain': 0.05237674359155478, 'min_child_weight': 0.0744825529035734, 'reg_alpha': 91.04909024695617, 'reg_lambda': 3.5919354046392193}. Best is trial 6 with value: 0.8318898644927661.
# [I 2023-01-28 12:22:10,668] Trial 8 finished with value: 0.8396128913865577 and parameters: {'num_leaves': 25, 'min_child_samples': 41, 'n_estimators': 749, 'learning_rate': 0.15786393018830477, 'subsample_for_bin': 333224, 'min_split_gain': 0.03862739513978243, 'min_child_weight': 0.03352735579319459, 'reg_alpha': 3.7286512809749386, 'reg_lambda': 7.086856466737477}. Best is trial 8 with value: 0.8396128913865577.
# [I 2023-01-28 12:22:10,727] Trial 16 finished with value: 0.7841448861574672 and parameters: {'num_leaves': 82, 'min_child_samples': 20, 'n_estimators': 507, 'learning_rate': 0.3145008729725234, 'subsample_for_bin': 146442, 'min_split_gain': 0.21608173055763483, 'min_child_weight': 0.10689802340750484, 'reg_alpha': 62.25243569958177, 'reg_lambda': 38.14676263666275}. Best is trial 8 with value: 0.8396128913865577.
# [I 2023-01-28 12:22:10,788] Trial 17 finished with value: 0.8220633163991516 and parameters: {'num_leaves': 177, 'min_child_samples': 41, 'n_estimators': 32, 'learning_rate': 0.37020373448979393, 'subsample_for_bin': 321942, 'min_split_gain': 0.01992433164378804, 'min_child_weight': 0.03143708951444237, 'reg_alpha': 19.29416555658719, 'reg_lambda': 1.941718258071151}. Best is trial 8 with value: 0.8396128913865577.
# [I 2023-01-28 12:22:10,855] Trial 15 finished with value: 0.8402977893399433 and parameters: {'num_leaves': 153, 'min_child_samples': 50, 'n_estimators': 665, 'learning_rate': 0.18149802613208324, 'subsample_for_bin': 183000, 'min_split_gain': 0.0802775470518401, 'min_child_weight': 0.06840015374856338, 'reg_alpha': 3.3672333160771797, 'reg_lambda': 22.965039072977863}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:10,907] Trial 9 finished with value: 0.7847128044512579 and parameters: {'num_leaves': 13, 'min_child_samples': 37, 'n_estimators': 416, 'learning_rate': 0.008761504332805477, 'subsample_for_bin': 79400, 'min_split_gain': 0.2180940110402611, 'min_child_weight': 0.144524488188635, 'reg_alpha': 65.81562904174007, 'reg_lambda': 55.30408571838048}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:10,946] Trial 21 finished with value: 0.7803407675249288 and parameters: {'num_leaves': 15, 'min_child_samples': 12, 'n_estimators': 30, 'learning_rate': 0.06456344051534382, 'subsample_for_bin': 238762, 'min_split_gain': 0.3481214421738486, 'min_child_weight': 0.021193717887664942, 'reg_alpha': 88.02355332998181, 'reg_lambda': 40.88135245423454}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,029] Trial 10 finished with value: 0.8091033179208696 and parameters: {'num_leaves': 155, 'min_child_samples': 26, 'n_estimators': 622, 'learning_rate': 0.4432905433861253, 'subsample_for_bin': 402654, 'min_split_gain': 0.11784058457953774, 'min_child_weight': 0.09777059736119939, 'reg_alpha': 24.775388082759367, 'reg_lambda': 88.22799208653576}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,033] Trial 19 finished with value: 0.7820818673507123 and parameters: {'num_leaves': 89, 'min_child_samples': 37, 'n_estimators': 416, 'learning_rate': 0.30787066396940016, 'subsample_for_bin': 488818, 'min_split_gain': 0.27885646169756384, 'min_child_weight': 0.13484844535200902, 'reg_alpha': 80.59271428000349, 'reg_lambda': 53.239597281315746}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,137] Trial 18 finished with value: 0.8301182992159205 and parameters: {'num_leaves': 197, 'min_child_samples': 12, 'n_estimators': 554, 'learning_rate': 0.48900124287257846, 'subsample_for_bin': 154864, 'min_split_gain': 0.30675836300320747, 'min_child_weight': 0.10157277266831884, 'reg_alpha': 7.426339256872816, 'reg_lambda': 16.59960252311787}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,321] Trial 20 finished with value: 0.8138219420288828 and parameters: {'num_leaves': 33, 'min_child_samples': 50, 'n_estimators': 915, 'learning_rate': 0.2610678519357584, 'subsample_for_bin': 498635, 'min_split_gain': 0.08072463395788186, 'min_child_weight': 0.05753881930462552, 'reg_alpha': 21.67931861972627, 'reg_lambda': 56.03447909274153}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,389] Trial 22 finished with value: 0.8024116765671865 and parameters: {'num_leaves': 120, 'min_child_samples': 22, 'n_estimators': 869, 'learning_rate': 0.12493111723898098, 'subsample_for_bin': 490158, 'min_split_gain': 0.4153347784104759, 'min_child_weight': 0.03882144403560308, 'reg_alpha': 28.731251254548567, 'reg_lambda': 27.532800376115198}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,391] Trial 23 finished with value: 0.7802475979591139 and parameters: {'num_leaves': 104, 'min_child_samples': 19, 'n_estimators': 882, 'learning_rate': 0.3006329081544165, 'subsample_for_bin': 409011, 'min_split_gain': 0.287487876981555, 'min_child_weight': 0.024135929440044935, 'reg_alpha': 93.27345616496211, 'reg_lambda': 25.593876723358033}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,448] Trial 25 finished with value: 0.8364051197389287 and parameters: {'num_leaves': 26, 'min_child_samples': 11, 'n_estimators': 731, 'learning_rate': 0.48530042973499943, 'subsample_for_bin': 485114, 'min_split_gain': 0.4570102033882945, 'min_child_weight': 0.006766846183088621, 'reg_alpha': 2.451543495796656, 'reg_lambda': 0.5301602736237143}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,503] Trial 24 finished with value: 0.7854682248327477 and parameters: {'num_leaves': 101, 'min_child_samples': 17, 'n_estimators': 735, 'learning_rate': 0.11046013786999563, 'subsample_for_bin': 368156, 'min_split_gain': 0.32078614722362253, 'min_child_weight': 0.07070445918151418, 'reg_alpha': 55.93344376289984, 'reg_lambda': 92.64549518042493}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,809] Trial 28 finished with value: 0.8389713590948875 and parameters: {'num_leaves': 160, 'min_child_samples': 11, 'n_estimators': 690, 'learning_rate': 0.4557181759132735, 'subsample_for_bin': 410987, 'min_split_gain': 0.4961797446435219, 'min_child_weight': 0.0030068628933196326, 'reg_alpha': 3.3394088088058367, 'reg_lambda': 1.4283960113728176}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,813] Trial 26 finished with value: 0.8334304262397403 and parameters: {'num_leaves': 69, 'min_child_samples': 13, 'n_estimators': 835, 'learning_rate': 0.49720071085046214, 'subsample_for_bin': 493901, 'min_split_gain': 0.4477757453387436, 'min_child_weight': 0.002922605564103474, 'reg_alpha': 6.6502901228542655, 'reg_lambda': 11.935034564278617}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,861] Trial 27 finished with value: 0.8337103373689064 and parameters: {'num_leaves': 78, 'min_child_samples': 14, 'n_estimators': 758, 'learning_rate': 0.49722900524189595, 'subsample_for_bin': 398985, 'min_split_gain': 0.4998106736103978, 'min_child_weight': 0.001544004182316646, 'reg_alpha': 1.2525511899206645, 'reg_lambda': 65.2199764469778}. Best is trial 15 with value: 0.8402977893399433.
# [I 2023-01-28 12:22:11,893] Trial 29 finished with value: 0.841698936523582 and parameters: {'num_leaves': 164, 'min_child_samples': 14, 'n_estimators': 743, 'learning_rate': 0.48460159990199525, 'subsample_for_bin': 407503, 'min_split_gain': 0.48705033381249085, 'min_child_weight': 0.0027185216761357166, 'reg_alpha': 2.8613651545225687, 'reg_lambda': 0.44038655530828397}. Best is trial 29 with value: 0.841698936523582.
# [I 2023-01-28 12:22:12,061] Trial 30 finished with value: 0.8365723459838718 and parameters: {'num_leaves': 151, 'min_child_samples': 10, 'n_estimators': 784, 'learning_rate': 0.4646769578751731, 'subsample_for_bin': 398416, 'min_split_gain': 0.4850112736173638, 'min_child_weight': 0.0022118556638649903, 'reg_alpha': 3.073341511410746, 'reg_lambda': 14.704504508336619}. Best is trial 29 with value: 0.841698936523582.
# [I 2023-01-28 12:22:12,577] Trial 35 finished with value: 0.8422580562660481 and parameters: {'num_leaves': 46, 'min_child_samples': 49, 'n_estimators': 792, 'learning_rate': 0.1685387500832802, 'subsample_for_bin': 209395, 'min_split_gain': 0.08837783842438879, 'min_child_weight': 0.0675445640349151, 'reg_alpha': 1.3059566171333237, 'reg_lambda': 14.537476509836734}. Best is trial 35 with value: 0.8422580562660481.
# [I 2023-01-28 12:22:12,604] Trial 33 finished with value: 0.8418913542143676 and parameters: {'num_leaves': 133, 'min_child_samples': 50, 'n_estimators': 666, 'learning_rate': 0.16155571135744595, 'subsample_for_bin': 213448, 'min_split_gain': 0.10350701285512308, 'min_child_weight': 0.06050541759689147, 'reg_alpha': 0.9606605148609875, 'reg_lambda': 15.040318081472346}. Best is trial 35 with value: 0.8422580562660481.
# [I 2023-01-28 12:22:12,619] Trial 34 finished with value: 0.8428660235587397 and parameters: {'num_leaves': 139, 'min_child_samples': 50, 'n_estimators': 788, 'learning_rate': 0.15822503181536604, 'subsample_for_bin': 208470, 'min_split_gain': 0.08925649680476658, 'min_child_weight': 0.05604977773770743, 'reg_alpha': 2.322657461011227, 'reg_lambda': 13.6999859931085}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:12,820] Trial 32 finished with value: 0.8400413259170287 and parameters: {'num_leaves': 150, 'min_child_samples': 50, 'n_estimators': 666, 'learning_rate': 0.150460665160201, 'subsample_for_bin': 221508, 'min_split_gain': 0.08234909090728373, 'min_child_weight': 0.0620718303322498, 'reg_alpha': 0.23259551993135918, 'reg_lambda': 15.335877457953035}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,065] Trial 31 finished with value: 0.8365794452039338 and parameters: {'num_leaves': 137, 'min_child_samples': 49, 'n_estimators': 723, 'learning_rate': 0.03322886210853587, 'subsample_for_bin': 204545, 'min_split_gain': 0.0999165894501621, 'min_child_weight': 0.06333478113792562, 'reg_alpha': 5.446481707369657, 'reg_lambda': 15.005109025618061}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,118] Trial 36 finished with value: 0.8392789843820921 and parameters: {'num_leaves': 163, 'min_child_samples': 50, 'n_estimators': 796, 'learning_rate': 0.16562222433852564, 'subsample_for_bin': 364516, 'min_split_gain': 0.4319840272015654, 'min_child_weight': 0.01200587883151962, 'reg_alpha': 2.704836851766193, 'reg_lambda': 16.079816108247208}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,239] Trial 39 finished with value: 0.8413019911338983 and parameters: {'num_leaves': 161, 'min_child_samples': 49, 'n_estimators': 755, 'learning_rate': 0.15508115048268575, 'subsample_for_bin': 212564, 'min_split_gain': 0.18007647707838742, 'min_child_weight': 0.003681065473631535, 'reg_alpha': 3.260981930929923, 'reg_lambda': 9.911614073128694}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,300] Trial 38 finished with value: 0.8389874599077599 and parameters: {'num_leaves': 159, 'min_child_samples': 49, 'n_estimators': 756, 'learning_rate': 0.17325719218878913, 'subsample_for_bin': 222418, 'min_split_gain': 0.17881003760218978, 'min_child_weight': 0.008066956286655935, 'reg_alpha': 4.1079959617367745, 'reg_lambda': 11.275551828742552}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,679] Trial 41 finished with value: 0.840548890339682 and parameters: {'num_leaves': 44, 'min_child_samples': 49, 'n_estimators': 776, 'learning_rate': 0.19145203525379206, 'subsample_for_bin': 220837, 'min_split_gain': 0.17617450472575902, 'min_child_weight': 0.0070730507655226565, 'reg_alpha': 0.1577040129506586, 'reg_lambda': 13.511925632999432}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,725] Trial 43 finished with value: 0.8329853786898876 and parameters: {'num_leaves': 140, 'min_child_samples': 50, 'n_estimators': 617, 'learning_rate': 0.17316092586729254, 'subsample_for_bin': 252620, 'min_split_gain': 0.021329735289545824, 'min_child_weight': 0.05622778433282641, 'reg_alpha': 9.892569505971423, 'reg_lambda': 11.98992511347123}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:13,875] Trial 42 finished with value: 0.8278319189372129 and parameters: {'num_leaves': 139, 'min_child_samples': 50, 'n_estimators': 786, 'learning_rate': 0.16276421212398304, 'subsample_for_bin': 244839, 'min_split_gain': 0.01319899078223986, 'min_child_weight': 0.0556729125724688, 'reg_alpha': 14.02161371119293, 'reg_lambda': 10.713072095721547}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,221] Trial 44 finished with value: 0.8285609187244724 and parameters: {'num_leaves': 141, 'min_child_samples': 50, 'n_estimators': 796, 'learning_rate': 0.19801275745184305, 'subsample_for_bin': 236410, 'min_split_gain': 0.08511893670655492, 'min_child_weight': 0.05654095346182127, 'reg_alpha': 11.994400416140357, 'reg_lambda': 8.007785889371398}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,256] Trial 46 finished with value: 0.8240564280504259 and parameters: {'num_leaves': 139, 'min_child_samples': 49, 'n_estimators': 663, 'learning_rate': 0.4405084894863156, 'subsample_for_bin': 452303, 'min_split_gain': 0.419639571540046, 'min_child_weight': 0.0164864878916752, 'reg_alpha': 12.28508520086826, 'reg_lambda': 7.781801271466896}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,268] Trial 45 finished with value: 0.831174329181577 and parameters: {'num_leaves': 137, 'min_child_samples': 50, 'n_estimators': 804, 'learning_rate': 0.1745334047040573, 'subsample_for_bin': 247444, 'min_split_gain': 0.01130624959425585, 'min_child_weight': 0.05936177830055438, 'reg_alpha': 11.62965631345435, 'reg_lambda': 7.364893992796056}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,553] Trial 40 finished with value: 0.8379750386458777 and parameters: {'num_leaves': 39, 'min_child_samples': 48, 'n_estimators': 759, 'learning_rate': 0.17367943089578478, 'subsample_for_bin': 217790, 'min_split_gain': 0.01581386648897335, 'min_child_weight': 0.0017901758237529259, 'reg_alpha': 0.18000825642118912, 'reg_lambda': 10.20029320509995}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,672] Trial 49 finished with value: 0.8266586332476732 and parameters: {'num_leaves': 135, 'min_child_samples': 47, 'n_estimators': 584, 'learning_rate': 0.20737228652142214, 'subsample_for_bin': 244561, 'min_split_gain': 0.160519109893915, 'min_child_weight': 0.051181787405507995, 'reg_alpha': 12.99081433740314, 'reg_lambda': 9.809161314807326}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,704] Trial 37 finished with value: 0.837481316028538 and parameters: {'num_leaves': 160, 'min_child_samples': 49, 'n_estimators': 782, 'learning_rate': 0.17036095168281867, 'subsample_for_bin': 368486, 'min_split_gain': 0.011052005410439578, 'min_child_weight': 0.00903181521840684, 'reg_alpha': 0.6538021699240915, 'reg_lambda': 15.38020088963911}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,798] Trial 47 finished with value: 0.8252376689565315 and parameters: {'num_leaves': 42, 'min_child_samples': 50, 'n_estimators': 999, 'learning_rate': 0.17727566354543, 'subsample_for_bin': 248183, 'min_split_gain': 0.17915033428424632, 'min_child_weight': 0.053954277914598475, 'reg_alpha': 13.388894106203281, 'reg_lambda': 20.603709077122538}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,817] Trial 50 finished with value: 0.8278309964890931 and parameters: {'num_leaves': 137, 'min_child_samples': 47, 'n_estimators': 597, 'learning_rate': 0.20741669767827495, 'subsample_for_bin': 238553, 'min_split_gain': 0.16406912735414908, 'min_child_weight': 0.048668099027581804, 'reg_alpha': 12.559170213212514, 'reg_lambda': 7.460084562043703}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,931] Trial 48 finished with value: 0.8272981870264843 and parameters: {'num_leaves': 132, 'min_child_samples': 47, 'n_estimators': 990, 'learning_rate': 0.1994875433027776, 'subsample_for_bin': 236695, 'min_split_gain': 0.16780507762297836, 'min_child_weight': 0.05773452215857052, 'reg_alpha': 12.015270502481147, 'reg_lambda': 19.750894914077083}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:14,998] Trial 51 finished with value: 0.8286195768825699 and parameters: {'num_leaves': 136, 'min_child_samples': 46, 'n_estimators': 609, 'learning_rate': 0.20713523860145946, 'subsample_for_bin': 272871, 'min_split_gain': 0.15382848270670646, 'min_child_weight': 0.04677064732988022, 'reg_alpha': 12.284029970392723, 'reg_lambda': 9.85008540270552}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,216] Trial 52 finished with value: 0.825957016141738 and parameters: {'num_leaves': 139, 'min_child_samples': 46, 'n_estimators': 999, 'learning_rate': 0.19551175389242453, 'subsample_for_bin': 235290, 'min_split_gain': 0.14148765548009726, 'min_child_weight': 0.048681400540134, 'reg_alpha': 13.491467587208732, 'reg_lambda': 8.741095556911512}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,276] Trial 55 finished with value: 0.829526733720319 and parameters: {'num_leaves': 137, 'min_child_samples': 46, 'n_estimators': 603, 'learning_rate': 0.21728809363016455, 'subsample_for_bin': 263865, 'min_split_gain': 0.13740416678808945, 'min_child_weight': 0.08143451641763297, 'reg_alpha': 11.230510744686221, 'reg_lambda': 7.536142172520612}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,372] Trial 53 finished with value: 0.8252636918855517 and parameters: {'num_leaves': 140, 'min_child_samples': 46, 'n_estimators': 980, 'learning_rate': 0.19380332822828006, 'subsample_for_bin': 277355, 'min_split_gain': 0.1430652411801478, 'min_child_weight': 0.0521582469867784, 'reg_alpha': 14.025980916385876, 'reg_lambda': 6.969779299531908}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,403] Trial 54 finished with value: 0.8255157468080937 and parameters: {'num_leaves': 136, 'min_child_samples': 46, 'n_estimators': 978, 'learning_rate': 0.20938047729046047, 'subsample_for_bin': 256984, 'min_split_gain': 0.12568809254283989, 'min_child_weight': 0.04798147847257622, 'reg_alpha': 12.986223694249752, 'reg_lambda': 20.608887746344504}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,539] Trial 56 finished with value: 0.8257810180941387 and parameters: {'num_leaves': 130, 'min_child_samples': 46, 'n_estimators': 840, 'learning_rate': 0.20648853256971464, 'subsample_for_bin': 279277, 'min_split_gain': 0.1358777516629222, 'min_child_weight': 0.047799140044259586, 'reg_alpha': 13.994423442074027, 'reg_lambda': 7.648527379707701}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,614] Trial 57 finished with value: 0.8246764448473392 and parameters: {'num_leaves': 171, 'min_child_samples': 46, 'n_estimators': 586, 'learning_rate': 0.21661613667431964, 'subsample_for_bin': 274040, 'min_split_gain': 0.14376941870260246, 'min_child_weight': 0.04975561333690899, 'reg_alpha': 13.30532855209406, 'reg_lambda': 21.37446581568937}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,651] Trial 58 finished with value: 0.8199458487850024 and parameters: {'num_leaves': 177, 'min_child_samples': 46, 'n_estimators': 599, 'learning_rate': 0.25843594588238045, 'subsample_for_bin': 282017, 'min_split_gain': 0.13078167082665712, 'min_child_weight': 0.047567955895149144, 'reg_alpha': 16.552745335851544, 'reg_lambda': 22.456430436209846}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,811] Trial 59 finished with value: 0.8219885692014867 and parameters: {'num_leaves': 173, 'min_child_samples': 46, 'n_estimators': 603, 'learning_rate': 0.2600704154153109, 'subsample_for_bin': 183746, 'min_split_gain': 0.1401258306941348, 'min_child_weight': 0.04888051532267921, 'reg_alpha': 15.888779789653054, 'reg_lambda': 20.215863145937888}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:15,978] Trial 60 finished with value: 0.8212913098952304 and parameters: {'num_leaves': 174, 'min_child_samples': 46, 'n_estimators': 951, 'learning_rate': 0.2574537233902914, 'subsample_for_bin': 277425, 'min_split_gain': 0.12198856261019336, 'min_child_weight': 0.0470490347146936, 'reg_alpha': 16.347748503265368, 'reg_lambda': 22.027226121102697}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,091] Trial 61 finished with value: 0.8214521068206558 and parameters: {'num_leaves': 173, 'min_child_samples': 46, 'n_estimators': 985, 'learning_rate': 0.21838367343204731, 'subsample_for_bin': 275423, 'min_split_gain': 0.13451343015634015, 'min_child_weight': 0.045946398198807234, 'reg_alpha': 16.48816756588502, 'reg_lambda': 21.881225319353252}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,166] Trial 62 finished with value: 0.8232010326157694 and parameters: {'num_leaves': 171, 'min_child_samples': 46, 'n_estimators': 976, 'learning_rate': 0.2338061733839607, 'subsample_for_bin': 272360, 'min_split_gain': 0.14193729094133242, 'min_child_weight': 0.044600865160821714, 'reg_alpha': 16.12375635699448, 'reg_lambda': 4.722472910053259}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,248] Trial 63 finished with value: 0.8202368408651513 and parameters: {'num_leaves': 175, 'min_child_samples': 44, 'n_estimators': 934, 'learning_rate': 0.24010010282529076, 'subsample_for_bin': 269894, 'min_split_gain': 0.13090935713292862, 'min_child_weight': 0.043118582234102046, 'reg_alpha': 16.888103741137307, 'reg_lambda': 32.09541803515087}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,435] Trial 64 finished with value: 0.8333102853827787 and parameters: {'num_leaves': 170, 'min_child_samples': 44, 'n_estimators': 956, 'learning_rate': 0.2376654040825127, 'subsample_for_bin': 182220, 'min_split_gain': 0.129647190607028, 'min_child_weight': 0.044813276385938794, 'reg_alpha': 8.686289572036772, 'reg_lambda': 4.994711194239485}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,524] Trial 65 finished with value: 0.8329642092920312 and parameters: {'num_leaves': 172, 'min_child_samples': 44, 'n_estimators': 936, 'learning_rate': 0.23618430343127356, 'subsample_for_bin': 179291, 'min_split_gain': 0.1341200679891525, 'min_child_weight': 0.08150459933386237, 'reg_alpha': 8.536918207750857, 'reg_lambda': 3.766559417063669}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,588] Trial 66 finished with value: 0.8206684816383426 and parameters: {'num_leaves': 173, 'min_child_samples': 45, 'n_estimators': 838, 'learning_rate': 0.24227599075457829, 'subsample_for_bin': 186118, 'min_split_gain': 0.12165929389967603, 'min_child_weight': 0.083329593143242, 'reg_alpha': 17.324561861146417, 'reg_lambda': 33.37104999513434}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,708] Trial 67 finished with value: 0.833887641661455 and parameters: {'num_leaves': 173, 'min_child_samples': 44, 'n_estimators': 846, 'learning_rate': 0.23745460216378927, 'subsample_for_bin': 177091, 'min_split_gain': 0.12433076399159432, 'min_child_weight': 0.08177735469420662, 'reg_alpha': 7.856553462721029, 'reg_lambda': 4.437033102745233}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,806] Trial 68 finished with value: 0.834915260544317 and parameters: {'num_leaves': 169, 'min_child_samples': 43, 'n_estimators': 839, 'learning_rate': 0.23791849147102337, 'subsample_for_bin': 185550, 'min_split_gain': 0.12308476625795081, 'min_child_weight': 0.015058213104528064, 'reg_alpha': 7.8174378939768125, 'reg_lambda': 4.438007150328689}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:16,935] Trial 69 finished with value: 0.8343136323206516 and parameters: {'num_leaves': 171, 'min_child_samples': 43, 'n_estimators': 857, 'learning_rate': 0.24249953180912498, 'subsample_for_bin': 181476, 'min_split_gain': 0.1148954284449126, 'min_child_weight': 0.040975227271380005, 'reg_alpha': 7.3025702066672835, 'reg_lambda': 32.897934583968976}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,061] Trial 70 finished with value: 0.8330228868625157 and parameters: {'num_leaves': 170, 'min_child_samples': 33, 'n_estimators': 849, 'learning_rate': 0.25092888317838946, 'subsample_for_bin': 175604, 'min_split_gain': 0.10828506295300773, 'min_child_weight': 0.025695618815473126, 'reg_alpha': 7.369213187101927, 'reg_lambda': 31.767347423705612}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,140] Trial 72 finished with value: 0.8307993360409718 and parameters: {'num_leaves': 172, 'min_child_samples': 43, 'n_estimators': 704, 'learning_rate': 0.25723410873694014, 'subsample_for_bin': 176743, 'min_split_gain': 0.1100929686663733, 'min_child_weight': 0.03942236326251731, 'reg_alpha': 8.236104649545052, 'reg_lambda': 24.069212838955313}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,200] Trial 71 finished with value: 0.8352816994607215 and parameters: {'num_leaves': 172, 'min_child_samples': 43, 'n_estimators': 861, 'learning_rate': 0.23589305450200318, 'subsample_for_bin': 177697, 'min_split_gain': 0.10988757053165027, 'min_child_weight': 0.015086425792496912, 'reg_alpha': 6.6927614339387045, 'reg_lambda': 31.662158504552124}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,269] Trial 74 finished with value: 0.8327363895311688 and parameters: {'num_leaves': 55, 'min_child_samples': 43, 'n_estimators': 694, 'learning_rate': 0.23953738839649324, 'subsample_for_bin': 176437, 'min_split_gain': 0.10894236102399876, 'min_child_weight': 0.024781736857858696, 'reg_alpha': 7.4152890655353065, 'reg_lambda': 30.343378699940303}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,317] Trial 73 finished with value: 0.8362632888723293 and parameters: {'num_leaves': 118, 'min_child_samples': 33, 'n_estimators': 707, 'learning_rate': 0.24015310113630878, 'subsample_for_bin': 177055, 'min_split_gain': 0.20532227795928554, 'min_child_weight': 0.01621500851680989, 'reg_alpha': 7.43873634613559, 'reg_lambda': 3.290080758008574}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,565] Trial 75 finished with value: 0.8347529651468042 and parameters: {'num_leaves': 56, 'min_child_samples': 43, 'n_estimators': 700, 'learning_rate': 0.23296915667114693, 'subsample_for_bin': 102685, 'min_split_gain': 0.1056324271845461, 'min_child_weight': 0.01481820993634269, 'reg_alpha': 7.751042961662018, 'reg_lambda': 4.40266534716225}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,754] Trial 78 finished with value: 0.8360009813453358 and parameters: {'num_leaves': 122, 'min_child_samples': 43, 'n_estimators': 687, 'learning_rate': 0.15099709052474636, 'subsample_for_bin': 172223, 'min_split_gain': 0.10475545615647752, 'min_child_weight': 0.0680913441172308, 'reg_alpha': 7.74967732504833, 'reg_lambda': 1.4587387167074113}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,776] Trial 77 finished with value: 0.8339130620341212 and parameters: {'num_leaves': 185, 'min_child_samples': 43, 'n_estimators': 697, 'learning_rate': 0.14773679276309457, 'subsample_for_bin': 166565, 'min_split_gain': 0.10778381965708468, 'min_child_weight': 0.024230869742138356, 'reg_alpha': 7.626843004097168, 'reg_lambda': 32.11364835028995}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,818] Trial 76 finished with value: 0.8407862789353993 and parameters: {'num_leaves': 117, 'min_child_samples': 33, 'n_estimators': 904, 'learning_rate': 0.14009487238021398, 'subsample_for_bin': 176316, 'min_split_gain': 0.06579145149392386, 'min_child_weight': 0.07065111054604038, 'reg_alpha': 4.847594298233295, 'reg_lambda': 3.6266655515296824}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:17,914] Trial 79 finished with value: 0.8352230528268869 and parameters: {'num_leaves': 119, 'min_child_samples': 43, 'n_estimators': 695, 'learning_rate': 0.1426171569499635, 'subsample_for_bin': 188438, 'min_split_gain': 0.10623283383300616, 'min_child_weight': 0.02549144867357224, 'reg_alpha': 7.614292681006576, 'reg_lambda': 2.805001918668692}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,074] Trial 80 finished with value: 0.8369463634138543 and parameters: {'num_leaves': 120, 'min_child_samples': 33, 'n_estimators': 696, 'learning_rate': 0.14522217045252356, 'subsample_for_bin': 171798, 'min_split_gain': 0.10330282488156461, 'min_child_weight': 0.029625859395787355, 'reg_alpha': 6.670497094344532, 'reg_lambda': 2.210070771470254}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,273] Trial 81 finished with value: 0.8395593925519028 and parameters: {'num_leaves': 122, 'min_child_samples': 31, 'n_estimators': 708, 'learning_rate': 0.14688076984677667, 'subsample_for_bin': 85601, 'min_split_gain': 0.06139264429978525, 'min_child_weight': 0.02661981439580082, 'reg_alpha': 6.03447607693149, 'reg_lambda': 0.8069645896103719}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,380] Trial 82 finished with value: 0.8363726751898239 and parameters: {'num_leaves': 120, 'min_child_samples': 32, 'n_estimators': 700, 'learning_rate': 0.13978739867343493, 'subsample_for_bin': 163903, 'min_split_gain': 0.06340646986207711, 'min_child_weight': 0.028142056108325472, 'reg_alpha': 6.092560205911419, 'reg_lambda': 25.03110340810615}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,448] Trial 84 finished with value: 0.8394790066560881 and parameters: {'num_leaves': 123, 'min_child_samples': 33, 'n_estimators': 703, 'learning_rate': 0.14050681538250998, 'subsample_for_bin': 160659, 'min_split_gain': 0.0635134242516808, 'min_child_weight': 0.026551032938257557, 'reg_alpha': 5.439229512893505, 'reg_lambda': 0.5668339588409914}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,546] Trial 85 finished with value: 0.8413304719558266 and parameters: {'num_leaves': 119, 'min_child_samples': 34, 'n_estimators': 712, 'learning_rate': 0.1513319541403804, 'subsample_for_bin': 128042, 'min_split_gain': 0.07294084734644553, 'min_child_weight': 0.03647889217006941, 'reg_alpha': 4.727580304310047, 'reg_lambda': 0.11598116601061115}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:18,632] Trial 83 finished with value: 0.8422494010770025 and parameters: {'num_leaves': 121, 'min_child_samples': 34, 'n_estimators': 703, 'learning_rate': 0.11762442681369786, 'subsample_for_bin': 104474, 'min_split_gain': 0.06003517685059008, 'min_child_weight': 0.06657110735329529, 'reg_alpha': 4.044009024946572, 'reg_lambda': 27.73892218542595}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:19,264] Trial 86 finished with value: 0.8415680597678641 and parameters: {'num_leaves': 186, 'min_child_samples': 48, 'n_estimators': 702, 'learning_rate': 0.14689338376603187, 'subsample_for_bin': 130297, 'min_split_gain': 0.06496524518569696, 'min_child_weight': 0.06615320656537038, 'reg_alpha': 0.20832066974276708, 'reg_lambda': 13.488041812424695}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:19,469] Trial 89 finished with value: 0.8427835004003383 and parameters: {'num_leaves': 122, 'min_child_samples': 48, 'n_estimators': 655, 'learning_rate': 0.15609411272339074, 'subsample_for_bin': 123521, 'min_split_gain': 0.061638705713613115, 'min_child_weight': 0.06678023474389629, 'reg_alpha': 0.30307248266735565, 'reg_lambda': 13.001720942738205}. Best is trial 34 with value: 0.8428660235587397.
# [I 2023-01-28 12:22:19,486] Trial 90 finished with value: 0.8432910592226398 and parameters: {'num_leaves': 148, 'min_child_samples': 48, 'n_estimators': 658, 'learning_rate': 0.1405425346885129, 'subsample_for_bin': 130518, 'min_split_gain': 0.07651800218683834, 'min_child_weight': 0.06325592551202877, 'reg_alpha': 0.9611117595598967, 'reg_lambda': 14.109591752641343}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:19,534] Trial 87 finished with value: 0.8414759050879278 and parameters: {'num_leaves': 120, 'min_child_samples': 48, 'n_estimators': 899, 'learning_rate': 0.1436620327988138, 'subsample_for_bin': 124226, 'min_split_gain': 0.05651319127569549, 'min_child_weight': 0.0692808103486911, 'reg_alpha': 0.4050899576204672, 'reg_lambda': 13.403728279002813}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:19,648] Trial 88 finished with value: 0.8412521694487473 and parameters: {'num_leaves': 187, 'min_child_samples': 48, 'n_estimators': 654, 'learning_rate': 0.14830021820614805, 'subsample_for_bin': 201724, 'min_split_gain': 0.06540213406254333, 'min_child_weight': 0.06540672322930054, 'reg_alpha': 0.19430788173133706, 'reg_lambda': 17.445349417809012}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,079] Trial 92 finished with value: 0.8401497524722763 and parameters: {'num_leaves': 146, 'min_child_samples': 48, 'n_estimators': 652, 'learning_rate': 0.13852452996020007, 'subsample_for_bin': 205997, 'min_split_gain': 0.06288539989561112, 'min_child_weight': 0.0676003686304457, 'reg_alpha': 4.146053280409252, 'reg_lambda': 13.243319124922792}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,124] Trial 91 finished with value: 0.8407558054517192 and parameters: {'num_leaves': 149, 'min_child_samples': 48, 'n_estimators': 536, 'learning_rate': 0.15128060644756172, 'subsample_for_bin': 207541, 'min_split_gain': 0.07191160320181514, 'min_child_weight': 0.0702303748727638, 'reg_alpha': 0.14296205606570891, 'reg_lambda': 13.709367392790899}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,308] Trial 93 finished with value: 0.8426646061930535 and parameters: {'num_leaves': 151, 'min_child_samples': 48, 'n_estimators': 896, 'learning_rate': 0.13312782216350902, 'subsample_for_bin': 203149, 'min_split_gain': 0.06406573953224916, 'min_child_weight': 0.034947583493894666, 'reg_alpha': 3.512085994618728, 'reg_lambda': 12.615335302076328}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,367] Trial 94 finished with value: 0.8398410849476526 and parameters: {'num_leaves': 151, 'min_child_samples': 24, 'n_estimators': 888, 'learning_rate': 0.13677112651849652, 'subsample_for_bin': 203126, 'min_split_gain': 0.0611697586514595, 'min_child_weight': 0.03513756148653771, 'reg_alpha': 4.639736404091243, 'reg_lambda': 17.571793195250393}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,676] Trial 95 finished with value: 0.8429069421898708 and parameters: {'num_leaves': 109, 'min_child_samples': 39, 'n_estimators': 896, 'learning_rate': 0.1294430712665527, 'subsample_for_bin': 205409, 'min_split_gain': 0.07025713436342293, 'min_child_weight': 0.06806915975725299, 'reg_alpha': 0.8273498788864018, 'reg_lambda': 14.023774848816334}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:20,820] Trial 96 finished with value: 0.839316369872877 and parameters: {'num_leaves': 149, 'min_child_samples': 39, 'n_estimators': 651, 'learning_rate': 0.18772204861172245, 'subsample_for_bin': 204941, 'min_split_gain': 0.06601067456276023, 'min_child_weight': 0.0630535604501939, 'reg_alpha': 0.09534561678304332, 'reg_lambda': 13.035360797356427}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:21,006] Trial 98 finished with value: 0.8408301123731375 and parameters: {'num_leaves': 153, 'min_child_samples': 48, 'n_estimators': 661, 'learning_rate': 0.1852778180733171, 'subsample_for_bin': 200751, 'min_split_gain': 0.08823585430123247, 'min_child_weight': 0.06451288806545605, 'reg_alpha': 0.25364992238662776, 'reg_lambda': 13.673071615516836}. Best is trial 90 with value: 0.8432910592226398.
# [I 2023-01-28 12:22:21,129] Trial 99 finished with value: 0.8444944229356498 and parameters: {'num_leaves': 153, 'min_child_samples': 48, 'n_estimators': 640, 'learning_rate': 0.1850455498222412, 'subsample_for_bin': 204143, 'min_split_gain': 0.09050054171954286, 'min_child_weight': 0.06248567288889975, 'reg_alpha': 0.3881070190744442, 'reg_lambda': 12.571087022900329}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:21,225] Trial 97 finished with value: 0.84153348742751 and parameters: {'num_leaves': 152, 'min_child_samples': 48, 'n_estimators': 896, 'learning_rate': 0.1279701124689402, 'subsample_for_bin': 203288, 'min_split_gain': 0.07732726600901958, 'min_child_weight': 0.061977749715653126, 'reg_alpha': 0.43198630363061963, 'reg_lambda': 13.353954413839409}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:21,462] Trial 100 finished with value: 0.8427212176871756 and parameters: {'num_leaves': 146, 'min_child_samples': 28, 'n_estimators': 650, 'learning_rate': 0.1629139639177821, 'subsample_for_bin': 130281, 'min_split_gain': 0.08158150287090579, 'min_child_weight': 0.00607564341512184, 'reg_alpha': 0.06628423193429533, 'reg_lambda': 13.255346507189584}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:21,525] Trial 101 finished with value: 0.8435163179763073 and parameters: {'num_leaves': 106, 'min_child_samples': 35, 'n_estimators': 898, 'learning_rate': 0.1264742784321796, 'subsample_for_bin': 113967, 'min_split_gain': 0.09082697900221333, 'min_child_weight': 0.03609996068138889, 'reg_alpha': 2.6274773877370503, 'reg_lambda': 12.600469195495272}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:21,894] Trial 102 finished with value: 0.8429526149725352 and parameters: {'num_leaves': 99, 'min_child_samples': 35, 'n_estimators': 656, 'learning_rate': 0.11704493173067781, 'subsample_for_bin': 133031, 'min_split_gain': 0.03451862835915105, 'min_child_weight': 0.06436548063436522, 'reg_alpha': 2.7048691021457802, 'reg_lambda': 17.15997183185714}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:21,991] Trial 103 finished with value: 0.8433122287847793 and parameters: {'num_leaves': 104, 'min_child_samples': 38, 'n_estimators': 640, 'learning_rate': 0.113689791176909, 'subsample_for_bin': 50235, 'min_split_gain': 0.049135992905298, 'min_child_weight': 0.06116729030997916, 'reg_alpha': 2.404494367046274, 'reg_lambda': 18.68367238648247}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,072] Trial 105 finished with value: 0.8417781391129701 and parameters: {'num_leaves': 96, 'min_child_samples': 40, 'n_estimators': 549, 'learning_rate': 0.11599672191302327, 'subsample_for_bin': 130256, 'min_split_gain': 0.04152106258825333, 'min_child_weight': 0.061988769674277626, 'reg_alpha': 2.8573402794841063, 'reg_lambda': 12.505123799561227}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,132] Trial 104 finished with value: 0.843531369446428 and parameters: {'num_leaves': 111, 'min_child_samples': 41, 'n_estimators': 643, 'learning_rate': 0.11950841975500873, 'subsample_for_bin': 56494, 'min_split_gain': 0.04403418506426189, 'min_child_weight': 0.06223342418107765, 'reg_alpha': 2.455579746105323, 'reg_lambda': 12.840084761028644}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,397] Trial 106 finished with value: 0.8428588721690048 and parameters: {'num_leaves': 112, 'min_child_samples': 35, 'n_estimators': 643, 'learning_rate': 0.11361486564855991, 'subsample_for_bin': 127785, 'min_split_gain': 0.04151924576107913, 'min_child_weight': 0.060766558051703154, 'reg_alpha': 2.90514372529013, 'reg_lambda': 13.20069401742981}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,677] Trial 107 finished with value: 0.8434394995612197 and parameters: {'num_leaves': 105, 'min_child_samples': 35, 'n_estimators': 645, 'learning_rate': 0.12176222539345068, 'subsample_for_bin': 116864, 'min_split_gain': 0.045845563665933, 'min_child_weight': 0.062009281581874104, 'reg_alpha': 2.356283371540748, 'reg_lambda': 18.85144512592117}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,856] Trial 108 finished with value: 0.8420496595827706 and parameters: {'num_leaves': 109, 'min_child_samples': 36, 'n_estimators': 635, 'learning_rate': 0.11848472714794668, 'subsample_for_bin': 126572, 'min_split_gain': 0.04240352358342137, 'min_child_weight': 0.05959319492991376, 'reg_alpha': 2.468471138399699, 'reg_lambda': 18.644126086029885}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,951] Trial 109 finished with value: 0.8404006951630768 and parameters: {'num_leaves': 110, 'min_child_samples': 39, 'n_estimators': 641, 'learning_rate': 0.12432948081615812, 'subsample_for_bin': 125728, 'min_split_gain': 0.04356276503148714, 'min_child_weight': 0.061714784845419875, 'reg_alpha': 2.7007635105981893, 'reg_lambda': 17.76153940699409}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:22,999] Trial 110 finished with value: 0.842848092063628 and parameters: {'num_leaves': 108, 'min_child_samples': 40, 'n_estimators': 636, 'learning_rate': 0.11992012198264955, 'subsample_for_bin': 52794, 'min_split_gain': 0.04394696917910575, 'min_child_weight': 0.061315639582488424, 'reg_alpha': 2.409755451217817, 'reg_lambda': 16.657513720898507}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:23,354] Trial 111 finished with value: 0.840246972610131 and parameters: {'num_leaves': 97, 'min_child_samples': 39, 'n_estimators': 810, 'learning_rate': 0.11729902206550899, 'subsample_for_bin': 140698, 'min_split_gain': 0.04401307736193879, 'min_child_weight': 0.06168567267312756, 'reg_alpha': 2.6832523080884703, 'reg_lambda': 17.675647750125105}. Best is trial 99 with value: 0.8444944229356498.
# [I 2023-01-28 12:22:23,564] Trial 112 finished with value: 0.8420778787420257 and parameters: {'num_leaves': 109, 'min_child_samples': 16, 'n_estimators': 633, 'learning_rate': 0.12110762672197331, 'subsample_for_bin': 105618, 'min_split_gain': 0.03424416203599704, 'min_child_weight': 0.07541639131172646, 'reg_alpha': 2.723705480185769, 'reg_lambda': 18.223198471673257}. Best is trial 99 with value: 0.8444944229356498.
# ...
# [I 2023-01-28 12:24:46,800] Trial 987 finished with value: 0.7822114516733727 and parameters: {'num_leaves': 148, 'min_child_samples': 35, 'n_estimators': 526, 'learning_rate': 0.4028095561613726, 'subsample_for_bin': 140541, 'min_split_gain': 0.06442006846115486, 'min_child_weight': 0.06246440508226507, 'reg_alpha': 76.53632637323805, 'reg_lambda': 44.07581781816274}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:46,954] Trial 988 finished with value: 0.8392234936863597 and parameters: {'num_leaves': 125, 'min_child_samples': 35, 'n_estimators': 526, 'learning_rate': 0.11204185533816642, 'subsample_for_bin': 142331, 'min_split_gain': 0.2776730381862991, 'min_child_weight': 0.06306819202738047, 'reg_alpha': 0.024466939643806696, 'reg_lambda': 64.61997561072967}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:46,983] Trial 990 finished with value: 0.834477200590829 and parameters: {'num_leaves': 123, 'min_child_samples': 35, 'n_estimators': 519, 'learning_rate': 0.1085454845858123, 'subsample_for_bin': 140279, 'min_split_gain': 0.06450796433508349, 'min_child_weight': 0.13498193476577325, 'reg_alpha': 7.223459184135936, 'reg_lambda': 33.94877341515949}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,032] Trial 989 finished with value: 0.8337734983252526 and parameters: {'num_leaves': 61, 'min_child_samples': 35, 'n_estimators': 629, 'learning_rate': 0.10720511772580597, 'subsample_for_bin': 140332, 'min_split_gain': 0.05584448447939498, 'min_child_weight': 0.06222526185996102, 'reg_alpha': 8.066859770670671, 'reg_lambda': 54.12886176492296}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,344] Trial 993 finished with value: 0.8154614201993652 and parameters: {'num_leaves': 125, 'min_child_samples': 35, 'n_estimators': 522, 'learning_rate': 0.11178266783533349, 'subsample_for_bin': 60983, 'min_split_gain': 0.2500589529492472, 'min_child_weight': 0.05380211217119753, 'reg_alpha': 18.433615363276047, 'reg_lambda': 35.72925423134602}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,538] Trial 994 finished with value: 0.7818047914446153 and parameters: {'num_leaves': 102, 'min_child_samples': 35, 'n_estimators': 523, 'learning_rate': 0.3140452188289802, 'subsample_for_bin': 57894, 'min_split_gain': 0.04357770168165948, 'min_child_weight': 0.05549026592014185, 'reg_alpha': 86.15156831374921, 'reg_lambda': 90.21794698702416}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,554] Trial 992 finished with value: 0.7934362825841693 and parameters: {'num_leaves': 124, 'min_child_samples': 35, 'n_estimators': 628, 'learning_rate': 0.11107460374351676, 'subsample_for_bin': 58766, 'min_split_gain': 0.06017819284969036, 'min_child_weight': 0.08494152548763609, 'reg_alpha': 42.51641198901901, 'reg_lambda': 34.09951270999531}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,586] Trial 991 finished with value: 0.7933703768137947 and parameters: {'num_leaves': 148, 'min_child_samples': 35, 'n_estimators': 627, 'learning_rate': 0.08371054838397422, 'subsample_for_bin': 140322, 'min_split_gain': 0.08570425367248141, 'min_child_weight': 0.13351408606232432, 'reg_alpha': 43.81461001070667, 'reg_lambda': 26.072127908573485}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,669] Trial 996 finished with value: 0.7828540675831476 and parameters: {'num_leaves': 102, 'min_child_samples': 35, 'n_estimators': 627, 'learning_rate': 0.49888192990580416, 'subsample_for_bin': 137697, 'min_split_gain': 0.044590276847456395, 'min_child_weight': 0.05516464934293645, 'reg_alpha': 74.33808470146498, 'reg_lambda': 10.428876470747097}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:47,804] Trial 995 finished with value: 0.8300652279098629 and parameters: {'num_leaves': 103, 'min_child_samples': 41, 'n_estimators': 623, 'learning_rate': 0.08369548087369452, 'subsample_for_bin': 60614, 'min_split_gain': 0.21649791473280286, 'min_child_weight': 0.0916620468986452, 'reg_alpha': 7.39791779824019, 'reg_lambda': 55.20142531695878}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:48,813] Trial 999 finished with value: 0.7925054098213651 and parameters: {'num_leaves': 123, 'min_child_samples': 31, 'n_estimators': 628, 'learning_rate': 0.31185133897778283, 'subsample_for_bin': 140180, 'min_split_gain': 0.35828863192324467, 'min_child_weight': 0.05466354826632195, 'reg_alpha': 40.44129206300397, 'reg_lambda': 58.138894842023}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:48,817] Trial 997 finished with value: 0.8366787275319331 and parameters: {'num_leaves': 102, 'min_child_samples': 35, 'n_estimators': 526, 'learning_rate': 0.10888196546684183, 'subsample_for_bin': 143844, 'min_split_gain': 0.14890739402351025, 'min_child_weight': 0.054436444797898206, 'reg_alpha': 3.3481417198524115, 'reg_lambda': 38.30910177978345}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:48,879] Trial 998 finished with value: 0.8396827300137999 and parameters: {'num_leaves': 124, 'min_child_samples': 35, 'n_estimators': 522, 'learning_rate': 0.10947482891832047, 'subsample_for_bin': 141428, 'min_split_gain': 0.3298107531329031, 'min_child_weight': 0.056868538637064606, 'reg_alpha': 3.194061894649548, 'reg_lambda': 3.3936917610393547}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:49,269] Trial 1000 finished with value: 0.7879627010513767 and parameters: {'num_leaves': 148, 'min_child_samples': 31, 'n_estimators': 621, 'learning_rate': 0.46644152701438063, 'subsample_for_bin': 69842, 'min_split_gain': 0.4510225757756356, 'min_child_weight': 0.03168603285923956, 'reg_alpha': 54.50125403138907, 'reg_lambda': 13.575651569999444}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:49,311] Trial 1001 finished with value: 0.7811085143140478 and parameters: {'num_leaves': 124, 'min_child_samples': 37, 'n_estimators': 628, 'learning_rate': 0.4672966466923065, 'subsample_for_bin': 69350, 'min_split_gain': 0.3527533643035058, 'min_child_weight': 0.10530990765605942, 'reg_alpha': 84.61606229438858, 'reg_lambda': 72.04890690589221}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:49,905] Trial 1002 finished with value: 0.7856248058856661 and parameters: {'num_leaves': 126, 'min_child_samples': 37, 'n_estimators': 627, 'learning_rate': 0.08166894718935498, 'subsample_for_bin': 70105, 'min_split_gain': 0.1341562606017588, 'min_child_weight': 0.05701691707062939, 'reg_alpha': 60.15764664822234, 'reg_lambda': 28.460201510036885}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:49,972] Trial 1003 finished with value: 0.7911581118282965 and parameters: {'num_leaves': 128, 'min_child_samples': 11, 'n_estimators': 670, 'learning_rate': 0.08160985150838619, 'subsample_for_bin': 428354, 'min_split_gain': 0.263532227844888, 'min_child_weight': 0.07766942428790094, 'reg_alpha': 45.94770323523811, 'reg_lambda': 13.262881260075424}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:50,081] Trial 1004 finished with value: 0.789806374924812 and parameters: {'num_leaves': 154, 'min_child_samples': 37, 'n_estimators': 626, 'learning_rate': 0.08296813509110722, 'subsample_for_bin': 71650, 'min_split_gain': 0.13495015040042174, 'min_child_weight': 0.05781398431599365, 'reg_alpha': 50.86782242276199, 'reg_lambda': 29.593614557250234}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:50,678] Trial 1008 finished with value: 0.8410002359706777 and parameters: {'num_leaves': 98, 'min_child_samples': 31, 'n_estimators': 668, 'learning_rate': 0.23886775325744217, 'subsample_for_bin': 68168, 'min_split_gain': 0.49814924541459504, 'min_child_weight': 0.026312304564725972, 'reg_alpha': 0.011614480989741605, 'reg_lambda': 28.867489645836155}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:50,742] Trial 1007 finished with value: 0.8371429039891173 and parameters: {'num_leaves': 122, 'min_child_samples': 31, 'n_estimators': 666, 'learning_rate': 0.48375409852003515, 'subsample_for_bin': 71390, 'min_split_gain': 0.3574132164792857, 'min_child_weight': 0.07741242798930004, 'reg_alpha': 1.5931562762341995, 'reg_lambda': 30.772669349164467}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:50,776] Trial 1005 finished with value: 0.8442896263269489 and parameters: {'num_leaves': 127, 'min_child_samples': 37, 'n_estimators': 623, 'learning_rate': 0.08117254808333071, 'subsample_for_bin': 68721, 'min_split_gain': 0.13574157960356154, 'min_child_weight': 0.07866478521233157, 'reg_alpha': 0.04532285131912195, 'reg_lambda': 28.126911911083422}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:51,329] Trial 1011 finished with value: 0.8361685552050933 and parameters: {'num_leaves': 98, 'min_child_samples': 36, 'n_estimators': 672, 'learning_rate': 0.13983639874394846, 'subsample_for_bin': 70770, 'min_split_gain': 0.22745773962499694, 'min_child_weight': 0.08927700829437439, 'reg_alpha': 1.858061240220795, 'reg_lambda': 78.80598080589135}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:51,472] Trial 1012 finished with value: 0.8398579689253473 and parameters: {'num_leaves': 120, 'min_child_samples': 31, 'n_estimators': 670, 'learning_rate': 0.13809610949445894, 'subsample_for_bin': 70610, 'min_split_gain': 0.2693181536721538, 'min_child_weight': 0.05799174110146182, 'reg_alpha': 0.0157771315101477, 'reg_lambda': 62.68003467464641}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:51,910] Trial 1009 finished with value: 0.842904720550278 and parameters: {'num_leaves': 128, 'min_child_samples': 31, 'n_estimators': 665, 'learning_rate': 0.05775388394723462, 'subsample_for_bin': 68818, 'min_split_gain': 0.13577188758288078, 'min_child_weight': 0.07747162424539074, 'reg_alpha': 1.761048541511907, 'reg_lambda': 27.60890285399041}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:51,984] Trial 1010 finished with value: 0.8449316541253604 and parameters: {'num_leaves': 98, 'min_child_samples': 31, 'n_estimators': 674, 'learning_rate': 0.05689609246227366, 'subsample_for_bin': 68867, 'min_split_gain': 0.1092804812236078, 'min_child_weight': 0.05871762870948854, 'reg_alpha': 0.0477489882647773, 'reg_lambda': 23.421636217768526}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,010] Trial 1014 finished with value: 0.8334274130392602 and parameters: {'num_leaves': 128, 'min_child_samples': 37, 'n_estimators': 667, 'learning_rate': 0.43255524567118697, 'subsample_for_bin': 127657, 'min_split_gain': 0.4614982150556397, 'min_child_weight': 0.14517427565418145, 'reg_alpha': 5.20870641436033, 'reg_lambda': 23.353813199058486}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,166] Trial 1013 finished with value: 0.781441985665485 and parameters: {'num_leaves': 77, 'min_child_samples': 37, 'n_estimators': 664, 'learning_rate': 0.23259150738090165, 'subsample_for_bin': 127370, 'min_split_gain': 0.28806245455211893, 'min_child_weight': 0.04806491980980931, 'reg_alpha': 94.61293860816383, 'reg_lambda': 23.975644855452515}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,617] Trial 1016 finished with value: 0.8351900124501919 and parameters: {'num_leaves': 128, 'min_child_samples': 37, 'n_estimators': 671, 'learning_rate': 0.13772243864056252, 'subsample_for_bin': 129026, 'min_split_gain': 0.2372352491077614, 'min_child_weight': 0.10006569156124741, 'reg_alpha': 5.569009342494687, 'reg_lambda': 23.172437026863193}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,621] Trial 1017 finished with value: 0.8365209572384708 and parameters: {'num_leaves': 98, 'min_child_samples': 37, 'n_estimators': 671, 'learning_rate': 0.13903752575204786, 'subsample_for_bin': 130232, 'min_split_gain': 0.22476438549308453, 'min_child_weight': 0.07908382828845771, 'reg_alpha': 5.2369674947306075, 'reg_lambda': 23.975309898588666}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,689] Trial 1015 finished with value: 0.8373987131529427 and parameters: {'num_leaves': 98, 'min_child_samples': 37, 'n_estimators': 653, 'learning_rate': 0.057045632448017226, 'subsample_for_bin': 130276, 'min_split_gain': 0.110037134471916, 'min_child_weight': 0.1292547126642829, 'reg_alpha': 5.485069902840075, 'reg_lambda': 23.634106829537956}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,738] Trial 1006 finished with value: 0.8405578626620455 and parameters: {'num_leaves': 127, 'min_child_samples': 37, 'n_estimators': 624, 'learning_rate': 0.014520563873808928, 'subsample_for_bin': 75399, 'min_split_gain': 0.13642688899310124, 'min_child_weight': 0.11939169701433802, 'reg_alpha': 1.6844667713912846, 'reg_lambda': 28.902297920612668}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,786] Trial 1019 finished with value: 0.8353576877520689 and parameters: {'num_leaves': 99, 'min_child_samples': 28, 'n_estimators': 674, 'learning_rate': 0.1359120139351999, 'subsample_for_bin': 88097, 'min_split_gain': 0.14779147699918943, 'min_child_weight': 0.07604281290241006, 'reg_alpha': 5.2607161855425995, 'reg_lambda': 25.864346116433605}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:52,965] Trial 1018 finished with value: 0.7844683452421979 and parameters: {'num_leaves': 98, 'min_child_samples': 36, 'n_estimators': 662, 'learning_rate': 0.4341303607085735, 'subsample_for_bin': 89590, 'min_split_gain': 0.14678819161746134, 'min_child_weight': 0.07851125353256809, 'reg_alpha': 65.7874099380464, 'reg_lambda': 47.72070738801219}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:53,058] Trial 1022 finished with value: 0.8064489080260442 and parameters: {'num_leaves': 98, 'min_child_samples': 37, 'n_estimators': 675, 'learning_rate': 0.4220249806503513, 'subsample_for_bin': 88276, 'min_split_gain': 0.10814340837335627, 'min_child_weight': 0.07741551184018873, 'reg_alpha': 29.026880139471196, 'reg_lambda': 25.979770341809356}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:53,233] Trial 1020 finished with value: 0.8367876348970281 and parameters: {'num_leaves': 77, 'min_child_samples': 36, 'n_estimators': 768, 'learning_rate': 0.17066864946797808, 'subsample_for_bin': 86495, 'min_split_gain': 0.1471634461243175, 'min_child_weight': 0.08159716338916861, 'reg_alpha': 3.4044296453250524, 'reg_lambda': 52.20176941900916}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:53,483] Trial 1023 finished with value: 0.8394630558864823 and parameters: {'num_leaves': 138, 'min_child_samples': 37, 'n_estimators': 678, 'learning_rate': 0.0536166335650832, 'subsample_for_bin': 85840, 'min_split_gain': 0.14610848996419065, 'min_child_weight': 0.08370207198082535, 'reg_alpha': 3.5480348234974945, 'reg_lambda': 25.566474197316843}. Best is trial 248 with value: 0.8457791688307298.
# [I 2023-01-28 12:24:53,509] Trial 1021 finished with value: 0.8403977247678255 and parameters: {'num_leaves': 120, 'min_child_samples': 37, 'n_estimators': 992, 'learning_rate': 0.07480454576857287, 'subsample_for_bin': 85832, 'min_split_gain': 0.1432550977065577, 'min_child_weight': 0.12375594638801332, 'reg_alpha': 2.9622226942869894, 'reg_lambda': 25.902747456055238}. Best is trial 248 with value: 0.8457791688307298.
# AUC: 0.8457791688307298
# Best hyperparameters: {'num_leaves': 115, 'min_child_samples': 36, 'n_estimators': 550, 'learning_rate': 0.10731491929854983, 'subsample_for_bin': 112512, 'min_split_gain': 0.10938519795778151, 'min_child_weight': 0.038327697111145566, 'reg_alpha': 0.015324444119449325, 'reg_lambda': 22.009349187593205}

# %% [markdown]
# # Análise Comparativa

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))

ax1.set_title('PSO X Gerações')
ax2.set_title('PSO X Avaliações')

ax1.plot(tracking_PSO_Accuracy)
ax2.plot(Accuracy_PSO)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,5))

ax1.set_title('GA X Gerações')
ax2.set_title('GA X Avaliações')

ax1.plot(tracking_GA_Accuracy)
ax2.plot(Accuracy_GA)
plt.show()

# %% [markdown]
# Gráficos Comparativos Acurácia

# %%
from IPython.core.pylabtools import figsize
from matplotlib.pyplot import figure
import matplotlib.patches as mpatches

plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch, black_patch])
plt.plot(Accuracy_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(Accuracy_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_Accuracy, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_Accuracy)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_Accuracy, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_Accuracy, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_Accuracy, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_Accuracy, color = 'green', linewidth=3, linestyle='-')

# %% [markdown]
# F1 score

# %%
plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch, black_patch])
plt.plot(F1_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(F1_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_F1, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_F1)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_F1, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_F1, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_F1, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_F1, color = 'green', linewidth=3, linestyle='-')

# %% [markdown]
# ROC AUC

# %%
plt.figure(figsize=(12, 6))
red_patch = mpatches.Patch(color='red', label='PSO')
blue_patch = mpatches.Patch(color='blue', label='GA')
green_patch = mpatches.Patch(color='green', label='Optuna')
#black_patch = mpatches.Patch(color='black', label='GridSearch')

plt.legend(handles=[red_patch, blue_patch, green_patch, black_patch])
plt.plot(AUC_GA, color = 'blue', linewidth=1, linestyle='-', )
plt.plot(AUC_PSO, color = 'red', linewidth=1, linestyle='-')
plt.plot(tracking_Optuna_AUC, color = 'green', linewidth=1, linestyle='-')
#plt.plot(tracking_GS, color = 'black', linewidth=3, linestyle='-')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25,15))

ax[0, 0].set_title(f'Genetic Algorithm (GA) - Accuracy: {max(tracking_GA_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[0, 1].set_title(f'Particle Swarm Optimization (PSO) - Accuracy: {max(tracking_PSO_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[1, 0].set_title(f'Grid Search - Accuracy: {max(tracking_GS_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})
ax[1, 1].set_title(f'Optuna - Accuracy: {max(tracking_Optuna_AUC)}', fontdict={'fontsize': 20, 'fontweight': 'medium'})

ax[0,0].plot(tracking_GA_AUC, color = 'blue', linewidth=3, linestyle='-', )
ax[0,1].plot(tracking_PSO_AUC, color = 'red', linewidth=3, linestyle='-')

ax[1,0].plot(tracking_GS_AUC, color = 'black', linewidth=3, linestyle='-')
ax[1,1].plot(tracking_Optuna_AUC, color = 'green', linewidth=3, linestyle='-')
